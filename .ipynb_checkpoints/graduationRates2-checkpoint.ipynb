# %%
# Imports
import pandas as pd
import numpy as np
from __future__ import print_function

# %matplotlib inline

#ignore warnings
#import warnings
#warnings.filterwarnings('ignore')

#Read in raw data
schoolData = pd.read_csv('D:/BenepactLLC/Belk/NC_Report_Card_Data/Summary Data Files/All_Data_By_School_Final.csv'
                         , low_memory=False)
testScores = pd.read_csv('D:/BenepactLLC/Belk/NC_Report_Card_Data/Summary Data Files/1516_Test_Scores.csv', low_memory=False)

#Review raw data before the join
schoolData.info()

#join files using school / unit code
schoolData = schoolData.merge(testScores, on='unit_code', how='left', suffixes=('_schoolData', '_testScores'))

#Review raw data after the join to make sure new fields were added
print('************************************************************')
schoolData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2579 entries, 0 to 2578
# Columns: 293 entries, Year to State_Prin_Exp_Pct_10+_Years
# dtypes: float64(255), int64(17), object(21)
# memory usage: 5.8+ MB
# ************************************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2579 entries, 0 to 2578
# Columns: 365 entries, Year to Passing_Math_III
# dtypes: float64(324), int64(17), object(24)
# memory usage: 7.2+ MB

# %%
#Remove fields not needed for machine learning
excludeFields = ['Year','unit_code_schoolData', 'street_ad','scity_ad','state_ad','szip_ad','Closed_Ind_Text','New_ind_Txt',
                 'grades_BYOD','grades_1_to_1_access','District Name','unit_code_testScores','School Name','SBE District']

keepFields = [col for col in schoolData.columns if col not in excludeFields]

schoolData = schoolData[keepFields]

schoolData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2579 entries, 0 to 2578
# Columns: 353 entries, unit_code to Passing_Math_III
# dtypes: float64(324), int64(15), object(14)
# memory usage: 7.0+ MB

# %%
#Clean up the dataset for machine learning 
boolFields = ['title1_type_flg', 'clp_ind_flg', 'focus_clp_flg', 'summer_program_flg', 
              'asm_no_spg_flg', 'no_data_spg_flg', 'stem_flg']

# Map flag fields into bool 
schoolData['title1_type_flg'] = schoolData['title1_type_flg'].map({-1:True, 0:False})
schoolData['clp_ind_flg'] = schoolData['clp_ind_flg'].map({-1:True, 0:False})
schoolData['focus_clp_flg'] = schoolData['focus_clp_flg'].map({-1:True, 0:False})
schoolData['summer_program_flg'] = schoolData['summer_program_flg'].map({-1:True, 0:False})
schoolData['asm_no_spg_flg'] = schoolData['asm_no_spg_flg'].map({-1:True, 0:False})
schoolData['no_data_spg_flg'] = schoolData['no_data_spg_flg'].map({-1:True, 0:False})
schoolData['stem_flg'] = schoolData['stem_flg'].map({-1:True, 0:False})

#
schoolData['esea_status'] = schoolData['esea_status'].map({'P':'Esea_Pass', 'F':'Esea_Fail', np.nan:'Non_Esea'})
schoolData['Grad_project_status'] = schoolData['Grad_project_status'].map({'Y':True, 'N':False, np.nan:False})

# %%
# Find all the categorical variables
schoolData_Bool = schoolData.loc[:, schoolData.dtypes == bool]
schoolData_Vars = schoolData.loc[:, schoolData.dtypes == object]
cat_list_obj = list(pd.concat([schoolData_Vars, schoolData_Bool]))
cat_list_obj_len = len(cat_list_obj) # number of object attributes
print("Number of Categorical Attributes = ", cat_list_obj_len)
cat_list_obj
# Out:
# Number of Categorical Attributes =  20
# ['1_to_1_access',
#  'Byod',
#  'EVAAS Growth Status',
#  'Grad_project_status',
#  'Math SPG Grade',
#  'Reading SPG Grade',
#  'SPG Grade',
#  'State Gap Compared',
#  'asm_no_spg_flg',
#  'calendar_only_txt',
#  'category_cd',
#  'clp_ind_flg',
#  'esea_status',
#  'focus_clp_flg',
#  'no_data_spg_flg',
#  'school_type_txt',
#  'stem_flg',
#  'summer_program_flg',
#  'title1_type_flg',
#  'type_cd_txt']

# %%
#Review individual data types after data preparation
schoolData.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2579 entries, 0 to 2578
# Data columns (total 352 columns):
# type_cd_txt                                       object
# category_cd                                       object
# school_type_txt                                   object
# calendar_only_txt                                 object
# title1_type_flg                                   bool
# clp_ind_flg                                       bool
# focus_clp_flg                                     bool
# summer_program_flg                                bool
# asm_no_spg_flg                                    bool
# no_data_spg_flg                                   bool
# esea_status                                       object
# student_num                                       float64
# lea_avg_student_num                               float64
# st_avg_student_num                                int64
# Grad_project_status                               bool
# stem_flg                                          bool
# Avg_Class_Size_00                                 float64
# Avg_Class_Size_01                                 float64
# Avg_Class_Size_02                                 float64
# Avg_Class_Size_03                                 float64
# Avg_Class_Size_04                                 float64
# Avg_Class_Size_05                                 float64
# Avg_Class_Size_06                                 float64
# Avg_Class_Size_07                                 float64
# Avg_Class_Size_08                                 float64
# Avg_Class_Size_Biology                            float64
# Avg_Class_Size_EnglishII                          float64
# Avg_Class_Size_MathI                              float64
# Avg_Dist_Size_00                                  float64
# Avg_Dist_Size_01                                  float64
# Avg_Dist_Size_02                                  float64
# Avg_Dist_Size_03                                  float64
# Avg_Dist_Size_04                                  float64
# Avg_Dist_Size_05                                  float64
# Avg_Dist_Size_06                                  float64
# Avg_Dist_Size_07                                  float64
# Avg_Dist_Size_08                                  float64
# Avg_Dist_Size_Biology                             float64
# Avg_Dist_Size_EnglishII                           float64
# Avg_Dist_Size_MathI                               float64
# Avg_State_Size_00                                 float64
# Avg_State_Size_01                                 float64
# Avg_State_Size_02                                 float64
# Avg_State_Size_03                                 float64
# Avg_State_Size_04                                 float64
# Avg_State_Size_05                                 float64
# Avg_State_Size_06                                 float64
# Avg_State_Size_07                                 float64
# Avg_State_Size_08                                 float64
# Avg_State_Size_Biology                            float64
# Avg_State_Size_EnglishII                          float64
# Avg_State_Size_MathI                              float64
# total_expense_num                                 float64
# salary_expense_pct                                float64
# benefits_expense_pct                              float64
# services_expense_pct                              float64
# supplies_expense_pct                              float64
# instruct_equip_exp_pct                            float64
# other_expense_pct                                 float64
# federal_perpupil_num                              float64
# local_perpupil_num                                float64
# state_perpupil_num                                float64
# lea_total_expense_num                             float64
# lea_salary_expense_pct                            float64
# lea_benefits_expense_pct                          float64
# lea_services_expense_pct                          float64
# lea_supplies_expense_pct                          float64
# lea_instruct_equip_exp_pct                        float64
# lea_other_expense_pct                             float64
# lea_federal_perpupil_num                          float64
# lea_local_perpupil_num                            float64
# lea_state_perpupil_num                            float64
# st_total_expense_num                              float64
# st_salary_expense_pct                             float64
# st_benefits_expense_pct                           float64
# st_services_expense_pct                           float64
# st_supplies_expense_pct                           float64
# st_instruct_equip_exp_pct                         float64
# st_other_expense_pct                              int64
# st_federal_perpupil_num                           float64
# st_local_perpupil_num                             float64
# st_state_perpupil_num                             float64
# SPG Grade                                         object
# SPG Score                                         float64
# Reading SPG Grade                                 object
# Reading  SPG Score                                float64
# Math SPG Grade                                    object
# Math SPG Score                                    float64
# EVAAS Growth Status                               object
# EVAAS Growth Score                                float64
# Overall Achievement Score                         float64
# Read Score                                        float64
# Math Score                                        float64
# Science Score                                     float64
# Math I Score                                      float64
# English II Score                                  float64
# Biology Score                                     float64
# The ACT Score                                     float64
# ACT WorkKeys Score                                float64
# Math Course Rigor Score                           float64
# Cohort Graduation Rate Standard Score             float64
# State Gap Compared                                object
# GCE_ALL_School_Pct                                float64
# GCE_LEP_School_Pct                                float64
# GCE_PRM_School_Pct                                float64
# GCE_RPF_School_Pct                                float64
# GCE_SWD_School_Pct                                float64
# PASSED_EOG_School_Pct                             float64
# PASSED_LAA_School_Pct                             float64
# PASSED_RTA_School_Pct                             float64
# PROMOTED_School_Pct                               float64
# RETAINED_School_Pct                               float64
# GCE_ALL_Dist_Pct                                  float64
# GCE_LEP_Dist_Pct                                  float64
# GCE_PRM_Dist_Pct                                  float64
# GCE_RPF_Dist_Pct                                  float64
# GCE_SWD_Dist_Pct                                  float64
# PASSED_EOG_Dist_Pct                               float64
# PASSED_LAA_Dist_Pct                               float64
# PASSED_RTA_Dist_Pct                               float64
# PROMOTED_Dist_Pct                                 float64
# RETAINED_Dist_Pct                                 float64
# GCE_ALL_State_Pct                                 float64
# GCE_LEP_State_Pct                                 float64
# GCE_PRM_State_Pct                                 float64
# GCE_RPF_State_Pct                                 float64
# GCE_SWD_State_Pct                                 float64
# PASSED_EOG_State_Pct                              float64
# PASSED_LAA_State_Pct                              float64
# PASSED_RTA_State_Pct                              float64
# PROMOTED_State_Pct                                float64
# RETAINED_State_Pct                                float64
# sat_avg_score_num                                 float64
# lea_sat_avg_score_num                             float64
# st_sat_avg_score_num                              int64
# nat_sat_avg_score_num                             int64
# sat_participation_pct                             float64
# lea_sat_participation_pct                         float64
# st_sat_participation_pct                          float64
# nat_sat_participation_pct                         float64
# esea_attendance                                   float64
# lea_esea_attendance                               float64
# ap_participation_pct                              float64
# lea_ap_participation_pct                          float64
# st_ap_participation_pct                           float64
# ap_pct_3_or_above                                 float64
# lea_ap_pct_3_or_above                             float64
# st_ap_pct_3_or_above                              float64
# ib_participation_pct                              float64
# lea_ib_participation_pct                          float64
# st_ib_participation_pct                           float64
# ib_pct_4_or_above                                 float64
# lea_ib_pct_4_or_above                             float64
# st_ib_pct_4_or_above                              float64
# AP_Courses_Offered                                float64
# total_specialized_courses                         float64
# ap_ib_courses                                     float64
# cte_courses                                       float64
# univ_college_courses                              float64
# lea_total_specialized_courses                     float64
# lea_ap_ib_courses                                 float64
# lea_cte_courses                                   float64
# lea_univ_college_courses                          float64
# st_total_specialized_courses                      float64
# st_ap_ib_courses                                  float64
# st_cte_courses                                    float64
# st_univ_college_courses                           float64
# sch_percent_college_enrolled_16_mos_post_grad     float64
# One_Yr_College_Complete_wi_2_yrs_Enrolled_2012    float64
# avg_daily_attend_pct                              float64
# crime_per_c_num                                   float64
# short_susp_per_c_num                              float64
# long_susp_per_c_num                               float64
# expelled_per_c_num                                float64
# ttl_crimes_num                                    float64
# stud_internet_comp_num                            float64
# lea_avg_daily_attend_pct                          float64
# lea_crime_per_c_num                               float64
# lea_short_susp_per_c_num                          float64
# lea_long_susp_per_c_num                           float64
# lea_expelled_per_c_num                            float64
# lea_stud_internet_comp_num                        float64
# st_avg_daily_attend_pct                           float64
# st_crime_per_c_num                                float64
# st_short_susp_per_c_num                           float64
# st_long_susp_per_c_num                            float64
# st_expelled_per_c_num                             int64
# st_stud_internet_comp_num                         float64
# digital_media_pct                                 float64
# Byod                                              object
# avg_age_media_collection                          float64
# 1_to_1_access                                     object
# books_per_student                                 float64
# lea_avg_age_media_collection                      float64
# lea_books_per_student                             float64
# st_avg_age_media_collection                       float64
# st_books_per_student                              float64
# wap_num                                           float64
# wap_per_classroom                                 float64
# lea_wap_num                                       float64
# lea_wap_per_classroom                             float64
# st_wap_num                                        int64
# st_wap_per_classroom                              float64
# prin_other_pct                                    float64
# prinyrs_0thru3_pct                                float64
# prinyrs_4thru10_pct                               float64
# prinyrs_11plus_pct                                float64
# prin_advance_dgr_pct                              float64
# _1yr_prin_trnovr_pct                              float64
# prin_male_pct                                     float64
# prin_female_pct                                   float64
# prin_black_pct                                    float64
# prin_white_pct                                    float64
# flicensed_teach_pct                               float64
# tchyrs_0thru3_pct                                 float64
# tchyrs_4thru10_pct                                float64
# tchyrs_11plus_pct                                 float64
# class_teach_num                                   float64
# nbpts_num                                         float64
# advance_dgr_pct                                   float64
# _1yr_tchr_trnovr_pct                              float64
# emer_prov_teach_pct                               float64
# lateral_teach_pct                                 float64
# highqual_class_pct                                float64
# lea_flicensed_teach_pct                           float64
# lea_tchyrs_0thru3_pct                             float64
# lea_tchyrs_4thru10_pct                            float64
# lea_tchyrs_11plus_pct                             float64
# lea_class_teach_num                               float64
# lea_nbpts_num                                     float64
# lea_advance_dgr_pct                               float64
# lea_1yr_tchr_trnovr_pct                           float64
# lea_emer_prov_teach_pct                           float64
# lea_lateral_teach_pct                             float64
# lea_highqual_class_pct                            float64
# lea_highqual_class_hp_pct                         float64
# lea_highqual_class_lp_pct                         float64
# lea_highqual_class_all_pct                        float64
# lea_not_highqual_class_hp_pct                     float64
# lea_not_highqual_class_lp_pct                     float64
# lea_not_highqual_class_all_pct                    float64
# st_flicensed_teach_pct                            float64
# st_tchyrs_0thru3_pct                              float64
# st_tchyrs_4thru10_pct                             float64
# st_tchyrs_11plus_pct                              float64
# st_class_teach_num                                int64
# st_nbpts_num                                      int64
# st_advance_dgr_pct                                float64
# st_1yr_tchr_trnovr_pct                            float64
# st_emer_prov_teach_pct                            float64
# st_lateral_teach_pct                              float64
# st_highqual_class_pct                             float64
# st_highqual_class_hp_pct                          float64
# st_highqual_class_lp_pct                          float64
# st_highqual_class_all_pct                         float64
# st_not_highqual_class_hp_pct                      float64
# st_not_highqual_class_lp_pct                      float64
# st_not_highqual_class_all_pct                     float64
# st_prinyrs_0thru3_pct                             float64
# st_prinyrs_4thru10_pct                            float64
# st_prinyrs_11plus_pct                             float64
# st_prin_advance_dgr_pct                           float64
# st_1yr_prin_trnovr_pct                            float64
# st_prin_male_pct                                  float64
# st_prin_female_pct                                float64
# st_prin_black_pct                                 float64
# st_prin_white_pct                                 float64
# st_prin_other_pct                                 float64
# Tch_Exp_Pct_0_3_Years                             float64
# Tch_Exp_Pct_4_10_Years                            float64
# Tch_Exp_Pct_10+_Years                             float64
# Dist_Tch_Exp_Pct_0_3_Years                        float64
# Dist_Tch_Exp_Pct_4_10_Years                       float64
# Dist_Tch_Exp_Pct_10+_Years                        float64
# State_Tch_Exp_Pct_0_3_Years                       float64
# State_Tch_Exp_Pct_4_10_Years                      float64
# State_Tch_Exp_Pct_10+_Years                       float64
# Dist_Prin_Exp_Pct_0_3_Years                       float64
# Dist_Prin_Exp_Pct_4_10_Years                      float64
# Dist_Prin_Exp_Pct_10+_Years                       float64
# State_Prin_Exp_Pct_0_3_Years                      float64
# State_Prin_Exp_Pct_4_10_Years                     float64
# State_Prin_Exp_Pct_10+_Years                      float64
# ACT_Composite_Score_UNC_Min                       float64
# ACT_English_Benchmark                             float64
# ACT_Math_Benchmark                                float64
# ACT_Pct_of_Benchmarks_Met                         float64
# ACT_Reading_Benchmark                             float64
# ACT_Science_Benchmark                             float64
# ACT_WorkKeys_Silver_Beyond                        float64
# ACT_Writing_Benchmark                             float64
# All_EOC_Subjects_CACR                             float64
# All_EOC_Subjects_GLP                              float64
# All_EOG_EOC_Subjects_CACR                         float64
# All_EOG_EOC_Subjects_GLP                          float64
# All_EOG_Subjects_CACR                             float64
# All_EOG_Subjects_GLP                              float64
# EOC_Biology_CACR                                  float64
# EOC_Biology_GLP                                   float64
# EOC_English_2_CACR                                float64
# EOC_English_2_GLP                                 float64
# EOC_Math_I_CACR                                   float64
# EOC_Math_I_GLP                                    float64
# EOG_Gr3_CACR                                      float64
# EOG_Gr3_GLP                                       float64
# EOG_Gr4_CACR                                      float64
# EOG_Gr4_GLP                                       float64
# EOG_Gr5_CACR                                      float64
# EOG_Gr5_GLP                                       float64
# EOG_Gr6_CACR                                      float64
# EOG_Gr6_GLP                                       float64
# EOG_Gr7_CACR                                      float64
# EOG_Gr7_GLP                                       float64
# EOG_Gr8_CACR                                      float64
# EOG_Gr8_GLP                                       float64
# EOG_Math_Gr3_CACR                                 float64
# EOG_Math_Gr3_GLP                                  float64
# EOG_Math_Gr3-8_CACR                               float64
# EOG_Math_Gr3-8_GLP                                float64
# EOG_Math_Gr4_CACR                                 float64
# EOG_Math_Gr4_GLP                                  float64
# EOG_Math_Gr5_CACR                                 float64
# EOG_Math_Gr5_GLP                                  float64
# EOG_Math_Gr6_CACR                                 float64
# EOG_Math_Gr6_GLP                                  float64
# EOG_Math_Gr7_CACR                                 float64
# EOG_Math_Gr7_GLP                                  float64
# EOG_Math_Gr8_CACR                                 float64
# EOG_Math_Gr8_GLP                                  float64
# EOG_Reading_G3_GLP                                float64
# EOG_Reading_Gr3_CACR                              float64
# EOG_Reading_Gr4_CACR                              float64
# EOG_Reading_Gr4_GLP                               float64
# EOG_Reading_Gr5_CACR                              float64
# EOG_Reading_Gr5_GLP                               float64
# EOG_Reading_Gr6_CACR                              float64
# EOG_Reading_Gr6_GLP                               float64
# EOG_Reading_Gr7_CACR                              float64
# EOG_Reading_Gr7_GLP                               float64
# EOG_Reading_Gr8_CACR                              float64
# EOG_Reading_Gr8_GLP                               float64
# EOG_Reading_Grades_3_8_CACR                       float64
# EOG_Reading_Grades_3_8_GLP                        float64
# EOG_Science_Gr5_CACR                              float64
# EOG_Science_Gr5_GLP                               float64
# EOG_Science_Gr8_CACR                              float64
# EOG_Science_Gr8_GLP                               float64
# EOG_Science_Grades_5&8_CACR                       float64
# EOG_Science_Grades_5&8_GLP                        float64
# Graduation_Rate_5_Yr                              float64
# Graduation_Rate4_Yr                               float64
# Passing_Math_III                                  float64
# dtypes: bool(8), float64(324), int64(8), object(12)
# memory usage: 6.8+ MB

# %%
# Examine categorical variables of interest  
import matplotlib.pyplot as plt

for i in range(0,cat_list_obj_len):
    plt.figure(figsize = (18,4))
    ax = schoolData[cat_list_obj[i]].value_counts().plot(kind='bar')
    plt.title(cat_list_obj[i])
    plt.show()

# %%
#Get high school campuses reporting overall student numbers 
highSchools = schoolData [((schoolData.category_cd == 'H') | 
                          (schoolData.category_cd == 'T') | 
                          (schoolData.category_cd == 'A'))&
                          (schoolData.student_num > 0) & 
                          (schoolData.type_cd_txt == 'Public') &
                          (schoolData.school_type_txt == 'Regular School')
                         ]
highSchools.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 478 entries, 2 to 2419
# Columns: 353 entries, unit_code to Passing_Math_III
# dtypes: bool(8), float64(324), int64(8), object(13)
# memory usage: 1.3+ MB

# %%
#Inspect the high school data fields 
df_temp = highSchools.describe(include='all').T
# include the data type of the column in the dataframe
df_temp['type']= highSchools.dtypes
# Reset the index of the dataframe to have index as numbers to have the number of rows visible in the output
df_temp.reset_index(inplace=True)
df_temp
# Out:
#                            index count unique                   top freq  \
# 0                      unit_code   478    478                700319    1
# 1                    type_cd_txt   478      1                Public  478
# 2                    category_cd   478      3                     H  459
# 3                school_type_txt   478      1        Regular School  478
# 4              calendar_only_txt   478      2  Traditional Calendar  470
# 5                title1_type_flg   478    NaN                   NaN  NaN
# 6                    clp_ind_flg   478    NaN                   NaN  NaN
# 7                  focus_clp_flg   478    NaN                   NaN  NaN
# 8             summer_program_flg   478    NaN                   NaN  NaN
# 9                 asm_no_spg_flg   478    NaN                   NaN  NaN
# 10               no_data_spg_flg   478    NaN                   NaN  NaN
# 11                   esea_status   478      3              Non_Esea  459
# 12                   student_num   478    NaN                   NaN  NaN
# 13           lea_avg_student_num   478    NaN                   NaN  NaN
# 14            st_avg_student_num   478    NaN                   NaN  NaN
# 15           Grad_project_status   478    NaN                   NaN  NaN
# 16                      stem_flg   478    NaN                   NaN  NaN
# 17             Avg_Class_Size_00     2    NaN                   NaN  NaN
# 18             Avg_Class_Size_01     3    NaN                   NaN  NaN
# 19             Avg_Class_Size_02     3    NaN                   NaN  NaN
# 20             Avg_Class_Size_03     3    NaN                   NaN  NaN
# 21             Avg_Class_Size_04     3    NaN                   NaN  NaN
# 22             Avg_Class_Size_05     3    NaN                   NaN  NaN
# 23             Avg_Class_Size_06    12    NaN                   NaN  NaN
# 24             Avg_Class_Size_07    13    NaN                   NaN  NaN
# 25             Avg_Class_Size_08    13    NaN                   NaN  NaN
# 26        Avg_Class_Size_Biology   465    NaN                   NaN  NaN
# 27      Avg_Class_Size_EnglishII   466    NaN                   NaN  NaN
# 28          Avg_Class_Size_MathI   464    NaN                   NaN  NaN
# 29              Avg_Dist_Size_00     2    NaN                   NaN  NaN
# ..                           ...   ...    ...                   ...  ...
# 323             EOG_Math_Gr5_GLP     3    NaN                   NaN  NaN
# 324            EOG_Math_Gr6_CACR    12    NaN                   NaN  NaN
# 325             EOG_Math_Gr6_GLP    12    NaN                   NaN  NaN
# 326            EOG_Math_Gr7_CACR    14    NaN                   NaN  NaN
# 327             EOG_Math_Gr7_GLP    14    NaN                   NaN  NaN
# 328            EOG_Math_Gr8_CACR    14    NaN                   NaN  NaN
# 329             EOG_Math_Gr8_GLP    14    NaN                   NaN  NaN
# 330           EOG_Reading_G3_GLP     3    NaN                   NaN  NaN
# 331         EOG_Reading_Gr3_CACR     3    NaN                   NaN  NaN
# 332         EOG_Reading_Gr4_CACR     3    NaN                   NaN  NaN
# 333          EOG_Reading_Gr4_GLP     3    NaN                   NaN  NaN
# 334         EOG_Reading_Gr5_CACR     3    NaN                   NaN  NaN
# 335          EOG_Reading_Gr5_GLP     3    NaN                   NaN  NaN
# 336         EOG_Reading_Gr6_CACR    12    NaN                   NaN  NaN
# 337          EOG_Reading_Gr6_GLP    12    NaN                   NaN  NaN
# 338         EOG_Reading_Gr7_CACR    14    NaN                   NaN  NaN
# 339          EOG_Reading_Gr7_GLP    14    NaN                   NaN  NaN
# 340         EOG_Reading_Gr8_CACR    14    NaN                   NaN  NaN
# 341          EOG_Reading_Gr8_GLP    14    NaN                   NaN  NaN
# 342  EOG_Reading_Grades_3_8_CACR    16    NaN                   NaN  NaN
# 343   EOG_Reading_Grades_3_8_GLP    16    NaN                   NaN  NaN
# 344         EOG_Science_Gr5_CACR     3    NaN                   NaN  NaN
# 345          EOG_Science_Gr5_GLP     3    NaN                   NaN  NaN
# 346         EOG_Science_Gr8_CACR    14    NaN                   NaN  NaN
# 347          EOG_Science_Gr8_GLP    14    NaN                   NaN  NaN
# 348  EOG_Science_Grades_5&8_CACR    15    NaN                   NaN  NaN
# 349   EOG_Science_Grades_5&8_GLP    15    NaN                   NaN  NaN
# 350         Graduation_Rate_5_Yr   433    NaN                   NaN  NaN
# 351          Graduation_Rate4_Yr   440    NaN                   NaN  NaN
# 352             Passing_Math_III   442    NaN                   NaN  NaN
#
#           mean       std    min     25%    50%      75%    max     type
# 0          NaN       NaN    NaN     NaN    NaN      NaN    NaN   object
# 1          NaN       NaN    NaN     NaN    NaN      NaN    NaN   object
# 2          NaN       NaN    NaN     NaN    NaN      NaN    NaN   object
# 3          NaN       NaN    NaN     NaN    NaN      NaN    NaN   object
# 4          NaN       NaN    NaN     NaN    NaN      NaN    NaN   object
# 5    0.0794979  0.270798  False       0      0        0   True     bool
# 6     0.117155  0.321942  False       0      0        0   True     bool
# 7     0.110879  0.314311  False       0      0        0   True     bool
# 8     0.374477  0.484495  False       0      0        1   True     bool
# 9            0         0  False       0      0        0  False     bool
# 10           0         0  False       0      0        0  False     bool
# 11         NaN       NaN    NaN     NaN    NaN      NaN    NaN   object
# 12     868.567    598.11     52     328  802.5  1260.75   2846  float64
# 13     843.841   371.615    105     598    812      979   1845  float64
# 14     838.502   107.606    268     860    860      860    860    int64
# 15    0.370293  0.483389  False       0      0        1   True     bool
# 16   0.0125523  0.111448  False       0      0        0   True     bool
# 17          15   4.24264     12    13.5     15     16.5     18  float64
# 18     15.6667   4.16333     11      14     17       18     19  float64
# 19          14         3     11    12.5     14     15.5     17  float64
# 20     15.6667   4.50925     11    13.5     16       18     20  float64
# 21     14.6667   4.04145     11    12.5     14     16.5     19  float64
# 22     15.6667   8.14453     10      11     12     18.5     25  float64
# 23     18.4167   4.56186     10   15.75   18.5    21.25     26  float64
# 24     20.2308   6.88179     10      16     22       24     31  float64
# 25     19.5385   5.28544     10      17     20       23     27  float64
# 26     19.5634    4.5991      5      17     20       23     30  float64
# 27     19.9657   4.56576      6      17     20       23     35  float64
# 28     18.9483     4.481      6      16     19       22     31  float64
# 29          17   1.41421     16    16.5     17     17.5     18  float64
# ..         ...       ...    ...     ...    ...      ...    ...      ...
# 323    67.0333   6.92122   62.5   63.05   63.6     69.3     75  float64
# 324    44.0583    21.211   10.3  28.075   45.7     59.1     75  float64
# 325     54.825   24.1113   13.8    35.2   57.8     71.9     90  float64
# 326    42.1714   23.9501   10.2  20.875  39.85   54.475     90  float64
# 327      49.05    24.128     13    29.8   45.4   66.275     90  float64
# 328    33.7143   17.4708   13.4    21.5   27.8   50.925   66.7  float64
# 329    41.1286   18.1159     19   26.95  31.35   58.975     70  float64
# 330    59.6333    25.955   37.5   45.35   53.2     70.7   88.2  float64
# 331    53.8333   25.2698   34.4   39.55   44.7    63.55   82.4  float64
# 332       62.9   15.4347     50   54.35   58.7    69.35     80  float64
# 333    72.5667    14.845   57.1    65.5   73.9     80.3   86.7  float64
# 334       54.1   12.1569   40.4   49.35   58.3    60.95   63.6  float64
# 335    63.4333   11.2611   50.9    58.8   66.7     69.7   72.7  float64
# 336     52.625   15.9778   24.1  41.575  54.95   65.375     75  float64
# 337    66.3667   19.5318   34.5   53.85   66.8     84.1   90.4  float64
# 338    53.0143   20.3201   18.8   41.25  48.05     62.7     90  float64
# 339    66.7357   16.6066   36.4  54.575   66.3   81.025     90  float64
# 340    43.4286   18.3993   16.5   30.35  37.55     57.6   74.5  float64
# 341    57.6143   15.7575   29.3  48.525  58.75   68.475     83  float64
# 342    47.5187   16.4534   22.6   37.75   44.4   57.625   75.8  float64
# 343    62.4437   14.2844   34.6      56  60.25     70.4   86.6  float64
# 344    60.4667   9.40284     50    56.6   63.2     65.7   68.2  float64
# 345    76.1667   9.87235   66.7   71.05   75.4     80.9   86.4  float64
# 346    64.6357   20.4007   33.7  46.875  66.05   82.825   93.3  float64
# 347    73.9286   15.5345   47.4    63.8   77.6    85.55   93.3  float64
# 348    62.7333   17.8085   33.7   49.35   63.2     76.6   87.9  float64
# 349    73.2467   14.3892   47.4    65.4   75.4    84.05   90.4  float64
# 350    90.9905    6.8685   66.7    86.5     91      100    100  float64
# 351    90.1327   7.68064     60    84.8   90.2      100    100  float64
# 352    98.6602   3.70365   75.8     100    100      100    100  float64
#
# [353 rows x 13 columns]

# %%
#List of all int32 fields
int32Fields = ['student_num', 'lea_avg_student_num','Avg_Class_Size_00','Avg_Class_Size_01',
             'Avg_Class_Size_02','Avg_Class_Size_03','Avg_Class_Size_04','Avg_Class_Size_05',
             'Avg_Class_Size_06','Avg_Class_Size_07','Avg_Class_Size_08','Avg_Class_Size_Biology',
             'Avg_Class_Size_EnglishII','Avg_Class_Size_MathI','Avg_Dist_Size_00','Avg_Dist_Size_01',
             'Avg_Dist_Size_02','Avg_Dist_Size_03','Avg_Dist_Size_04','Avg_Dist_Size_05','Avg_Dist_Size_06',
             'Avg_Dist_Size_07','Avg_Dist_Size_08','Avg_Dist_Size_Biology','Avg_Dist_Size_EnglishII',
             'Avg_State_Size_04','Avg_State_Size_05','Avg_State_Size_06','Avg_State_Size_07','Avg_State_Size_08',
             'Avg_State_Size_Biology','Avg_State_Size_EnglishII','Avg_State_Size_MathI','SPG Score','Reading  SPG Score',
             'Math SPG Score','Overall Achievement Score','Read Score','Math Score','Science Score','Math I Score',
             'English II Score','Biology Score','The ACT Score','ACT WorkKeys Score','Math Course Rigor Score',
             'Cohort Graduation Rate Standard Score','sat_avg_score_num','lea_sat_avg_score_num','st_sat_avg_score_num',
             'nat_sat_avg_score_num','avg_age_media_collection','lea_avg_age_media_collection','st_avg_age_media_collection',
             'wap_num','lea_wap_num','st_wap_num','class_teach_num','nbpts_num','lea_class_teach_num','lea_nbpts_num',
             'st_class_teach_num','st_nbpts_num']

#Cannot convert from float64 to int32 due to missing values, should revisit this 
#highSchools[int32Fields] = highSchools[int32Fields].apply(np.int32, axis=1)

# %%
#Look at missing / NaN values by column
for col in highSchools:
    x = highSchools[col].value_counts(dropna=False)
    print(x)
    print('***************************************************')
# Out:
# 700319    1
# 130333    1
# 110352    1
# 490310    1
# 350308    1
# 920441    1
# 860336    1
# 640350    1
# 980336    1
# 422315    1
# 960700    1
# 422310    1
# 182700    1
# 130332    1
# 510324    1
# 410508    1
# 510327    1
# 570317    1
# 100334    1
# 410595    1
# 190342    1
# 760388    1
# 570318    1
# 700317    1
# 600426    1
# 120318    1
# 410556    1
# 940316    1
# 500302    1
# 040700    1
#          ..
# 260357    1
# 900311    1
# 100307    1
# 580368    1
# 990304    1
# 360337    1
# 360336    1
# 010360    1
# 132304    1
# 240334    1
# 410355    1
# 510357    1
# 840302    1
# 340382    1
# 110304    1
# 490320    1
# 340454    1
# 761304    1
# 920588    1
# 900377    1
# 410562    1
# 920582    1
# 292324    1
# 920581    1
# 920586    1
# 410569    1
# 920585    1
# 180376    1
# 410408    1
# 390704    1
# Name: unit_code, dtype: int64
# ***************************************************
# Public    478
# Name: type_cd_txt, dtype: int64
# ***************************************************
# H    459
# T     15
# A      4
# Name: category_cd, dtype: int64
# ***************************************************
# Regular School    478
# Name: school_type_txt, dtype: int64
# ***************************************************
# Traditional Calendar    470
# Year-Round Calendar       8
# Name: calendar_only_txt, dtype: int64
# ***************************************************
# False    440
# True      38
# Name: title1_type_flg, dtype: int64
# ***************************************************
# False    422
# True      56
# Name: clp_ind_flg, dtype: int64
# ***************************************************
# False    425
# True      53
# Name: focus_clp_flg, dtype: int64
# ***************************************************
# False    299
# True     179
# Name: summer_program_flg, dtype: int64
# ***************************************************
# False    478
# Name: asm_no_spg_flg, dtype: int64
# ***************************************************
# False    478
# Name: no_data_spg_flg, dtype: int64
# ***************************************************
# Non_Esea     459
# Esea_Pass     17
# Esea_Fail      2
# Name: esea_status, dtype: int64
# ***************************************************
# 328     3
# 1033    3
# 896     3
# 815     3
# 1319    3
# 210     3
# 1644    3
# 618     3
# 203     2
# 753     2
# 757     2
# 198     2
# 197     2
# 196     2
# 190     2
# 787     2
# 777     2
# 784     2
# 171     2
# 169     2
# 823     2
# 828     2
# 136     2
# 1746    2
# 219     2
# 214     2
# 295     2
# 438     2
# 452     2
# 332     2
#        ..
# 705     1
# 706     1
# 1733    1
# 1742    1
# 724     1
# 630     1
# 1643    1
# 616     1
# 1613    1
# 1574    1
# 552     1
# 559     1
# 561     1
# 571     1
# 1598    1
# 690     1
# 512     1
# 587     1
# 1614    1
# 609     1
# 592     1
# 1617    1
# 1621    1
# 2648    1
# 1625    1
# 603     1
# 605     1
# 607     1
# 608     1
# 1024    1
# Name: student_num, dtype: int64
# ***************************************************
# 1493    25
# 812     22
# 1772    20
# 751     15
# 912     15
# 779     14
# 1122    12
# 1190    11
# 873     10
# 976      9
# 895      9
# 1203     8
# 1021     7
# 944      7
# 837      7
# 985      7
# 979      7
# 778      7
# 972      7
# 1015     7
# 515      7
# 415      6
# 876      6
# 1127     6
# 909      5
# 822      5
# 598      5
# 795      5
# 450      5
# 928      5
#         ..
# 105      1
# 1023     1
# 160      1
# 167      1
# 500      1
# 488      1
# 1478     1
# 956      1
# 438      1
# 421      1
# 930      1
# 1436     1
# 387      1
# 887      1
# 359      1
# 344      1
# 328      1
# 1338     1
# 1845     1
# 307      1
# 305      1
# 813      1
# 759      1
# 745      1
# 210      1
# 188      1
# 184      1
# 183      1
# 681      1
# 512      1
# Name: lea_avg_student_num, dtype: int64
# ***************************************************
# 860    459
# 268     15
# 511      4
# Name: st_avg_student_num, dtype: int64
# ***************************************************
# False    301
# True     177
# Name: Grad_project_status, dtype: int64
# ***************************************************
# False    472
# True       6
# Name: stem_flg, dtype: int64
# ***************************************************
# NaN    476
#  18      1
#  12      1
# Name: Avg_Class_Size_00, dtype: int64
# ***************************************************
# NaN    475
#  19      1
#  17      1
#  11      1
# Name: Avg_Class_Size_01, dtype: int64
# ***************************************************
# NaN    475
#  17      1
#  14      1
#  11      1
# Name: Avg_Class_Size_02, dtype: int64
# ***************************************************
# NaN    475
#  20      1
#  16      1
#  11      1
# Name: Avg_Class_Size_03, dtype: int64
# ***************************************************
# NaN    475
#  19      1
#  14      1
#  11      1
# Name: Avg_Class_Size_04, dtype: int64
# ***************************************************
# NaN    475
#  25      1
#  12      1
#  10      1
# Name: Avg_Class_Size_05, dtype: int64
# ***************************************************
# NaN    466
#  20      2
#  16      2
#  26      1
#  24      1
#  22      1
#  21      1
#  17      1
#  15      1
#  14      1
#  10      1
# Name: Avg_Class_Size_06, dtype: int64
# ***************************************************
# NaN    465
#  22      2
#  10      2
#  31      1
#  28      1
#  27      1
#  24      1
#  23      1
#  21      1
#  18      1
#  16      1
#  11      1
# Name: Avg_Class_Size_07, dtype: int64
# ***************************************************
# NaN    465
#  17      2
#  10      2
#  27      1
#  26      1
#  24      1
#  23      1
#  22      1
#  21      1
#  20      1
#  19      1
#  18      1
# Name: Avg_Class_Size_08, dtype: int64
# ***************************************************
#  19    48
#  21    43
#  23    37
#  22    37
#  20    32
#  17    30
#  24    29
#  18    29
#  16    28
#  15    27
#  26    24
#  25    21
#  14    16
#  13    13
# NaN    13
#  27    11
#  12     7
#  11     6
#  10     5
#  28     4
#  9      4
#  7      4
#  30     3
#  29     2
#  8      2
#  6      2
#  5      1
# Name: Avg_Class_Size_Biology, dtype: int64
# ***************************************************
#  20    49
#  21    48
#  18    36
#  24    36
#  17    34
#  23    34
#  19    32
#  16    28
#  22    24
#  15    23
#  25    23
#  26    21
#  13    12
# NaN    12
#  27    11
#  28    11
#  14     8
#  12     8
#  10     8
#  29     5
#  11     5
#  6      3
#  30     2
#  8      2
#  9      1
#  7      1
#  35     1
# Name: Avg_Class_Size_EnglishII, dtype: int64
# ***************************************************
#  22    46
#  21    42
#  16    41
#  20    40
#  18    35
#  23    35
#  17    34
#  19    34
#  15    24
#  14    21
#  25    19
#  24    16
# NaN    14
#  26    13
#  10    11
#  12    10
#  11    10
#  27     8
#  8      7
#  13     6
#  28     4
#  9      3
#  6      2
#  31     2
#  29     1
# Name: Avg_Class_Size_MathI, dtype: int64
# ***************************************************
# NaN    476
#  18      1
#  16      1
# Name: Avg_Dist_Size_00, dtype: int64
# ***************************************************
# NaN    475
#  17      2
#  18      1
# Name: Avg_Dist_Size_01, dtype: int64
# ***************************************************
# NaN    475
#  18      1
#  16      1
#  15      1
# Name: Avg_Dist_Size_02, dtype: int64
# ***************************************************
# NaN    475
#  16      2
#  17      1
# Name: Avg_Dist_Size_03, dtype: int64
# ***************************************************
# NaN    475
#  20      1
#  19      1
#  15      1
# Name: Avg_Dist_Size_04, dtype: int64
# ***************************************************
# NaN    475
#  19      1
#  15      1
#  13      1
# Name: Avg_Dist_Size_05, dtype: int64
# ***************************************************
# NaN    466
#  22      3
#  23      2
#  21      2
#  13      2
#  20      1
#  19      1
#  18      1
# Name: Avg_Dist_Size_06, dtype: int64
# ***************************************************
# NaN    465
#  24      3
#  22      2
#  10      2
#  26      1
#  25      1
#  23      1
#  21      1
#  18      1
#  15      1
# Name: Avg_Dist_Size_07, dtype: int64
# ***************************************************
# NaN    465
#  24      4
#  21      3
#  23      2
#  20      2
#  18      1
#  10      1
# Name: Avg_Dist_Size_08, dtype: int64
# ***************************************************
#  19    88
#  20    86
#  22    64
#  17    50
#  18    47
#  21    33
#  16    29
#  15    26
#  23    15
#  14    11
# NaN     8
#  12     7
#  13     6
#  11     4
#  6      3
#  24     1
# Name: Avg_Dist_Size_Biology, dtype: int64
# ***************************************************
#  18    109
#  19     91
#  20     50
#  21     48
#  15     32
#  24     30
#  16     26
#  17     22
#  23     21
#  22     20
#  14      9
# NaN      8
#  13      6
#  25      4
#  12      2
# Name: Avg_Dist_Size_EnglishII, dtype: int64
# ***************************************************
#  21    79
#  24    61
#  22    60
#  19    56
#  23    53
#  20    33
#  18    31
#  17    26
#  16    23
#  25    20
#  15    10
#  14     8
# NaN     8
#  26     6
#  12     2
#  13     1
#  7      1
# Name: Avg_Dist_Size_MathI, dtype: int64
# ***************************************************
# NaN    476
#  19      2
# Name: Avg_State_Size_00, dtype: int64
# ***************************************************
# NaN    475
#  19      3
# Name: Avg_State_Size_01, dtype: int64
# ***************************************************
# NaN    475
#  19      3
# Name: Avg_State_Size_02, dtype: int64
# ***************************************************
# NaN    475
#  19      3
# Name: Avg_State_Size_03, dtype: int64
# ***************************************************
# NaN    475
#  20      3
# Name: Avg_State_Size_04, dtype: int64
# ***************************************************
# NaN    475
#  21      3
# Name: Avg_State_Size_05, dtype: int64
# ***************************************************
# NaN    466
#  21     12
# Name: Avg_State_Size_06, dtype: int64
# ***************************************************
# NaN    465
#  22     13
# Name: Avg_State_Size_07, dtype: int64
# ***************************************************
# NaN    465
#  21     13
# Name: Avg_State_Size_08, dtype: int64
# ***************************************************
#  18    470
# NaN      8
# Name: Avg_State_Size_Biology, dtype: int64
# ***************************************************
#  18    470
# NaN      8
# Name: Avg_State_Size_EnglishII, dtype: int64
# ***************************************************
#  20    470
# NaN      8
# Name: Avg_State_Size_MathI, dtype: int64
# ***************************************************
# NaN    478
# Name: total_expense_num, dtype: int64
# ***************************************************
# NaN    478
# Name: salary_expense_pct, dtype: int64
# ***************************************************
# NaN    478
# Name: benefits_expense_pct, dtype: int64
# ***************************************************
# NaN    478
# Name: services_expense_pct, dtype: int64
# ***************************************************
# NaN    478
# Name: supplies_expense_pct, dtype: int64
# ***************************************************
# NaN    478
# Name: instruct_equip_exp_pct, dtype: int64
# ***************************************************
# NaN    478
# Name: other_expense_pct, dtype: int64
# ***************************************************
# NaN    478
# Name: federal_perpupil_num, dtype: int64
# ***************************************************
# NaN    478
# Name: local_perpupil_num, dtype: int64
# ***************************************************
# NaN    478
# Name: state_perpupil_num, dtype: int64
# ***************************************************
# 8521.71     27
# 8536.32     22
# 9326.89     22
# 8265.21     15
# 9032.02     12
# 8114.22     11
# 0.055     6
# 0.086     5
# 0.073     5
# 0.067     5
# 0.102     4
# 0.097     4
# 0.076     4
# 0.062     4
# 0.123     4
# 0.113     4
# 0.145     4
# 0.092     4
# 0.095     4
# 0.114     4
# 0.059     3
# 0.133     3
# 0.101     3
# 0.094     3
# 0.139     2
# 0.151     2
# 0.119     2
# 0.082     2
# 0.052     2
# 0.115     2
# 0.103     1
# 0.116     1
# 0.105     1
# 0.125     1
# Name: lea_services_expense_pct, dtype: int64
# ***************************************************
# 0.073    38
# 0.063    30
# 0.077    26
# 0.050    22
# 0.068    20
# 0.090    18
# 0.095    17
# 0.072    17
# 0.081    16
# 0.091    16
# 0.066    15
# 0.092    14
# 0.088    13
# 0.080    13
# 0.079    12
# 0.075    12
# 0.083    11
# 0.078    10
# 0.074    10
# 0.085    10
# 0.089    10
# 0.067     9
# 0.087     9
# 0.082     8
# 0.070     7
# 0.084     7
# 0.076     7
# 0.102     6
# 0.069     6
# 0.099     6
# 0.094     5
# 0.064     5
# 0.100     5
# 0.049     5
# 0.059     4
# 0.086     4
# 0.108     4
# 0.031     3
# 0.114     3
# 0.110     3
# 0.048     3
# 0.096     3
# 0.109     3
# 0.115     3
# 0.061     3
# 0.055     2
# 0.097     2
# 0.093     2
# 0.133     1
# Name: lea_supplies_expense_pct, dtype: int64
# ***************************************************
# 0.007    94
# 0.012    53
# 0.009    52
# 0.010    44
# 0.002    26
# 0.005    24
# 0.000    22
# 0.006    21
# 0.014    20
# 0.011    19
# 0.013    16
# 0.008    12
# 0.017    11
# 0.001     8
# 0.016     8
# 0.030     7
# 0.037     7
# 0.021     6
# 0.018     6
# 0.015     6
# 0.003     4
# 0.028     3
# 0.020     2
# 0.025     2
# 0.004     2
# 0.023     2
# 0.024     1
# Name: lea_instruct_equip_exp_pct, dtype: int64
# ***************************************************
# 0    478
# Name: lea_other_expense_pct, dtype: int64
# ***************************************************
# 942.34     27
# 1087.81    22
# 659.07     22
# 1180.42    15
# 1080.06    12
# 578.12     11
# 791.56     10
# 971.33     10
# 1126.43    10
# 638.81      9
# 917.31      9
# 923.73      8
# 782.50      8
# 1200.40     8
# 1155.92     7
# 697.11      7
# 1066.11     7
# 1039.15     7
# 1125.24     7
# 1703.87     7
# 886.16      6
# 969.77      6
# 889.67      6
# 1270.05     5
# 1233.78     5
# 1041.44     5
# 1248.84     5
# 1036.06     5
# 879.35      5
# 982.92      5
#            ..
# 1954.50     2
# 1378.91     2
# 668.18      2
# 1997.00     1
# 1297.05     1
# 1887.18     1
# 883.95      1
# 1863.27     1
# 923.51      1
# 1235.35     1
# 1305.75     1
# 506.75      1
# 1497.16     1
# 950.39      1
# 1492.21     1
# 1206.35     1
# 2078.14     1
# 1377.72     1
# 1615.39     1
# 1170.58     1
# 1825.12     1
# 751.97      1
# 1140.47     1
# 1487.57     1
# 1193.68     1
# 1620.29     1
# 1175.29     1
# 1133.43     1
# 942.90      1
# 1380.82     1
# Name: lea_federal_perpupil_num, dtype: int64
# ***************************************************
# 2352.27    27
# 2528.16    22
# 2785.51    22
# 1671.50    15
# 2335.59    12
# 2335.55    11
# 3601.48    10
# 1724.46    10
# 1775.07    10
# 2493.43     9
# 2168.65     9
# 1816.63     8
# 1188.10     8
# 1626.28     8
# 1832.54     7
# 1829.49     7
# 748.37      7
# 1932.31     7
# 1371.15     7
# 2055.04     7
# 2051.93     6
# 2834.70     6
# 1844.10     6
# 1377.45     5
# 1622.43     5
# 1684.10     5
# 1569.55     5
# 1867.73     5
# 1797.03     5
# 1395.28     5
#            ..
# 3124.31     2
# 3386.91     2
# 2136.58     2
# 2045.87     1
# 1756.12     1
# 2341.34     1
# 1844.00     1
# 1518.16     1
# 3291.85     1
# 2355.33     1
# 2467.21     1
# 2163.09     1
# 2187.92     1
# 1867.41     1
# 1469.07     1
# 1920.94     1
# 2143.79     1
# 2316.77     1
# 1526.74     1
# 1256.08     1
# 2058.81     1
# 1900.54     1
# 2090.95     1
# 2134.17     1
# 1899.77     1
# 2203.00     1
# 1830.21     1
# 1518.55     1
# 2767.31     1
# 1687.78     1
# Name: lea_local_perpupil_num, dtype: int64
# ***************************************************
# 5227.10     27
# 5349.09     22
# 5453.57     22
# 5413.29     15
# 5616.37     12
# 5200.55     11
# 5829.04     10
# 5402.62     10
# 5602.21     10
# 5218.56      9
# 5669.00      9
# 6171.58      8
# 5234.47      8
# 5611.71      8
# 5616.83      7
# 5682.81      7
# 5756.15      7
# 5529.50      7
# 5247.34      7
# 6490.65      7
# 5512.80      6
# 5458.65      6
# 6143.62      6
# 5967.87      5
# 6184.32      5
# 6119.80      5
# 6345.98      5
# 6061.38      5
# 6364.61      5
# 5535.55      5
#             ..
# 5645.51      2
# 6446.15      2
# 6433.53      2
# 7812.03      1
# 7965.69      1
# 5206.48      1
# 8256.03      1
# 7439.17      1
# 6040.59      1
# 5866.05      1
# 6791.75      1
# 6063.47      1
# 5987.48      1
# 5684.14      1
# 6518.66      1
# 9321.89      1
# 8295.04      1
# 6767.36      1
# 5876.61      1
# 6091.44      1
# 11739.76     1
# 8969.28      1
# 8092.44      1
# 7031.52      1
# 6110.14      1
# 7538.83      1
# 7981.70      1
# 6390.95      1
# 7230.17      1
# 7225.77      1
# Name: lea_state_perpupil_num, dtype: int64
# ***************************************************
# 8859.04    478
# Name: st_total_expense_num, dtype: int64
# ***************************************************
# 0.62    478
# Name: st_salary_expense_pct, dtype: int64
# ***************************************************
# 0.205    478
# Name: st_benefits_expense_pct, dtype: int64
# ***************************************************
# 0.09    478
# Name: st_services_expense_pct, dtype: int64
# ***************************************************
# 0.075    478
# Name: st_supplies_expense_pct, dtype: int64
# ***************************************************
# 0.01    478
# Name: st_instruct_equip_exp_pct, dtype: int64
# ***************************************************
# 0    478
# Name: st_other_expense_pct, dtype: int64
# ***************************************************
# 967.75    478
# Name: st_federal_perpupil_num, dtype: int64
# ***************************************************
# 2172.86    478
# Name: st_local_perpupil_num, dtype: int64
# ***************************************************
# 5718.43    478
# Name: st_state_perpupil_num, dtype: int64
# ***************************************************
# C       186
# B       139
# A        55
# D        44
# Name: GCE_PRM_School_Pct, dtype: int64
# ***************************************************
# NaN    478
# Name: GCE_RPF_School_Pct, dtype: int64
# ***************************************************
# NaN       477
#  0.208      1
# Name: GCE_SWD_School_Pct, dtype: int64
# ***************************************************
# NaN       475
#  0.521      1
#  0.882      1
#  0.375      1
# Name: PASSED_EOG_School_Pct, dtype: int64
# ***************************************************
# NaN    478
# Name: PASSED_LAA_School_Pct, dtype: int64
# ***************************************************
# NaN    478
# Name: PASSED_RTA_School_Pct, dtype: int64
# ***************************************************
# NaN       475
#  0.950      2
#  0.906      1
# Name: PROMOTED_School_Pct, dtype: int64
# ***************************************************
# NaN    478
# Name: RETAINED_School_Pct, dtype: int64
# ***************************************************
# NaN       474
#  0.112      2
#  0.238      1
#  0.204      1
# Name: GCE_ALL_Dist_Pct, dtype: int64
# ***************************************************
# NaN    478
# Name: GCE_LEP_Dist_Pct, dtype: int64
# ***************************************************
# NaN    478
# Name: GCE_PRM_Dist_Pct, dtype: int64
# ***************************************************
# NaN       476
#  0.104      1
#  0.204      1
# Name: GCE_RPF_Dist_Pct, dtype: int64
# ***************************************************
# NaN       475
#  0.104      2
#  0.101      1
# Name: GCE_SWD_Dist_Pct, dtype: int64
# ***************************************************
# NaN       474
#  0.659      2
#  0.542      1
#  0.685      1
# Name: PASSED_EOG_Dist_Pct, dtype: int64
# ***************************************************
# NaN       475
#  0.077      2
#  0.136      1
# Name: PASSED_LAA_Dist_Pct, dtype: int64
# ***************************************************
# NaN    478
# Name: PASSED_RTA_Dist_Pct, dtype: int64
# ***************************************************
# NaN       474
#  0.899      2
#  0.950      1
#  0.946      1
# Name: PROMOTED_Dist_Pct, dtype: int64
# ***************************************************
# NaN       475
#  0.101      2
#  0.054      1
# Name: RETAINED_Dist_Pct, dtype: int64
# ***************************************************
# NaN       474
#  0.112      4
# Name: GCE_ALL_State_Pct, dtype: int64
# ***************************************************
# NaN    478
# Name: GCE_LEP_State_Pct, dtype: int64
# ***************************************************
# NaN    478
# Name: GCE_PRM_State_Pct, dtype: int64
# ***************************************************
# NaN    478
# Name: GCE_RPF_State_Pct, dtype: int64
# ***************************************************
# NaN       474
#  0.065      4
# Name: GCE_SWD_State_Pct, dtype: int64
# ***************************************************
# NaN       474
#  0.579      4
# Name: PASSED_EOG_State_Pct, dtype: int64
# ***************************************************
# NaN      474
#  0.11      4
# Name: PASSED_LAA_State_Pct, dtype: int64
# ***************************************************
# NaN    478
# Name: PASSED_RTA_State_Pct, dtype: int64
# ***************************************************
# NaN       474
#  0.856      4
# Name: PROMOTED_State_Pct, dtype: int64
# ***************************************************
# NaN       474
#  0.144      4
# Name: RETAINED_State_Pct, dtype: int64
# ***************************************************
# NaN      12
#  1002     7
#  983      7
#  1026     6
#  963      5
#  990      5
#  873      4
#  888      4
#  906      4
#  998      4
#  916      4
#  953      4
#  956      4
#  1075     4
#  966      4
#  971      4
#  1066     4
#  1058     4
#  911      4
#  1023     4
#  909      3
#  973      3
#  1005     3
#  1092     3
#  964      3
#  961      3
#  1039     3
#  1011     3
#  1043     3
#  1022     3
#          ..
#  790      1
#  786      1
#  783      1
#  781      1
#  767      1
#  760      1
#  748      1
#  1400     1
#  729      1
#  1228     1
#  1198     1
#  810      1
#  813      1
#  815      1
#  864      1
#  880      1
#  876      1
#  874      1
#  871      1
#  868      1
#  867      1
#  863      1
#  817      1
#  861      1
#  841      1
#  836      1
#  827      1
#  826      1
#  823      1
#  870      1
# Name: sat_avg_score_num, dtype: int64
# ***************************************************
# 1001    35
# 982     27
# 1067    23
# 952     19
# 1015    16
# 963     16
# 961     15
# 1003    12
# 861     11
# 1051    11
# 945     10
# 972     10
# 942     10
# 1013    10
# 1037     9
# 1000     8
# 1007     8
# 1041     8
# 950      8
# 1026     8
# 939      7
# 971      7
# 1019     7
# 993      6
# 815      6
# 932      6
# 1062     6
# 917      5
# 919      5
# 1009     5
#         ..
# 791      2
# 814      2
# 819      2
# 878      2
# 986      2
# 975      2
# 1043     2
# 863      2
# 915      2
# 806      2
# 1056     1
# 980      1
# 1029     1
# 977      1
# 1076     1
# 1008     1
# 909      1
# 800      1
# 906      1
# 956      1
# 954      1
# 839      1
# 949      1
# 936      1
# 866      1
# 916      1
# 912      1
# 896      1
# 897      1
# 925      1
# Name: lea_sat_avg_score_num, dtype: int64
# ***************************************************
# 997    478
# Name: st_sat_avg_score_num, dtype: int64
# ***************************************************
# 1006    478
# Name: nat_sat_avg_score_num, dtype: int64
# ***************************************************
#  0.42    19
#  0.52    15
#  0.38    15
#  0.45    14
#  0.47    14
#  0.48    14
#  0.33    14
#  0.34    13
# NaN      13
#  0.41    11
#  0.43    11
#  0.65    11
#  0.54    11
#  0.56    10
#  0.58    10
#  0.30    10
#  0.46    10
#  0.37    10
#  0.57     9
#  0.35     9
#  0.28     9
#  0.27     9
#  0.53     9
#  0.36     8
#  0.44     8
#  0.55     8
#  0.40     7
#  0.31     7
#  0.39     7
#  0.29     6
#          ..
#  0.14     2
#  0.64     2
#  0.21     2
#  0.23     2
#  0.17     2
#  0.87     2
#  0.20     2
#  0.13     2
#  0.77     2
#  0.10     2
#  0.32     2
#  0.73     2
#  0.93     2
#  0.68     2
#  0.07     1
#  0.98     1
#  0.04     1
#  0.80     1
#  0.90     1
#  0.16     1
#  0.95     1
#  0.94     1
#  0.06     1
#  0.76     1
#  1.04     1
#  0.86     1
#  0.25     1
#  0.79     1
#  1.05     1
#  0.85     1
# Name: sat_participation_pct, dtype: int64
# ***************************************************
# 0.54    49
# 0.64    35
# 0.62    26
# 0.34    26
# 0.43    23
# 0.40    23
# 0.47    21
# 0.52    20
# 0.51    20
# 0.46    19
# 0.48    16
# 0.53    16
# 0.39    16
# 0.38    14
# 0.37    13
# 0.30    13
# 0.42    12
# 0.35     9
# 0.41     9
# 0.32     8
# 0.22     8
# 0.28     7
# 0.25     7
# 0.31     6
# 0.29     6
# 0.33     6
# 0.76     5
# 0.61     5
# 0.58     5
# 0.45     4
# 0.20     4
# 0.44     3
# 0.13     3
# 0.21     3
# 0.68     3
# 0.66     3
# 0.63     3
# 0.57     2
# 0.24     2
# 0.60     2
# 0.65     1
# 0.27     1
# 0.59     1
# Name: lea_sat_participation_pct, dtype: int64
# ***************************************************
# 0.49    478
# Name: st_sat_participation_pct, dtype: int64
# ***************************************************
# 0.52    478
# Name: nat_sat_participation_pct, dtype: int64
# ***************************************************
# NaN    478
# Name: esea_attendance, dtype: int64
# ***************************************************
# NaN    478
# Name: lea_esea_attendance, dtype: int64
# ***************************************************
# NaN      154
#  0.09     26
#  0.08     25
#  0.10     22
#  0.12     22
#  0.07     21
#  0.14     20
#  0.11     20
#  0.13     17
#  0.19     16
#  0.06     15
#  0.16     13
#  0.15     10
#  0.20     10
#  0.17     10
#  0.18      7
#  0.21      7
#  0.23      5
#  0.24      4
#  0.31      4
#  0.27      4
#  0.29      4
#  0.26      4
#  0.28      4
#  0.36      4
#  0.30      3
#  0.25      3
#  0.33      3
#  0.35      2
#  0.37      2
#  0.49      2
#  0.32      2
#  0.38      2
#  0.22      2
#  0.41      1
#  0.52      1
#  0.54      1
#  0.47      1
#  0.53      1
#  0.39      1
#  0.34      1
#  0.43      1
#  0.44      1
# Name: ap_participation_pct, dtype: int64
# ***************************************************
# NaN      65
#  0.07    39
#  0.11    36
#  0.21    28
#  0.09    28
#  0.18    28
#  0.19    26
#  0.23    25
#  0.12    24
#  0.06    23
#  0.15    22
#  0.08    22
#  0.25    22
#  0.10    21
#  0.14    17
#  0.16    14
#  0.13    12
#  0.17    10
#  0.20     8
#  0.26     3
#  0.44     3
#  0.28     2
# Name: lea_ap_participation_pct, dtype: int64
# ***************************************************
# 0.15    478
# Name: st_ap_participation_pct, dtype: int64
# ***************************************************
# NaN      113
#  0.40     13
#  0.27     11
#  0.34     11
#  0.18     11
#  0.23     11
#  0.53     10
#  0.54      9
#  0.37      9
#  0.38      9
#  0.56      9
#  0.28      9
#  0.31      8
#  0.45      8
#  0.50      7
#  0.48      7
#  0.29      7
#  0.39      7
#  0.19      6
#  0.17      6
#  0.20      6
#  0.32      6
#  0.47      6
#  0.59      6
#  0.69      6
#  0.10      6
#  0.67      5
#  0.95      5
#  0.60      5
#  0.43      5
#         ...
#  0.30      4
#  0.72      4
#  0.26      3
#  0.46      3
#  0.51      3
#  0.55      3
#  0.61      3
#  0.73      3
#  0.35      3
#  0.79      3
#  0.21      3
#  0.44      3
#  0.68      3
#  0.07      2
#  0.14      2
#  0.70      2
#  0.76      2
#  0.09      2
#  0.65      2
#  0.75      2
#  0.78      2
#  0.33      2
#  0.15      1
#  0.83      1
#  0.64      1
#  0.16      1
#  0.82      1
#  0.13      1
#  0.22      1
#  0.63      1
# Name: ap_pct_3_or_above, dtype: int64
# ***************************************************
#  0.53    41
#  0.62    36
#  0.49    30
#  0.31    23
#  0.48    22
#  0.42    20
#  0.34    18
#  0.18    18
#  0.26    15
#  0.25    15
#  0.51    15
#  0.32    14
#  0.56    13
#  0.52    11
#  0.54    11
#  0.68    11
#  0.44    11
#  0.30     9
#  0.35     9
# NaN       8
#  0.38     8
#  0.37     7
#  0.11     7
#  0.41     6
#  0.46     6
#  0.39     6
#  0.20     6
#  0.64     6
#  0.47     5
#  0.23     5
#  0.28     5
#  0.40     4
#  0.19     4
#  0.59     4
#  0.45     4
#  0.36     4
#  0.13     4
#  0.69     3
#  0.70     3
#  0.06     3
#  0.77     3
#  0.95     3
#  0.29     3
#  0.09     3
#  0.17     2
#  0.27     2
#  0.71     2
#  0.75     2
#  0.79     1
#  0.10     1
#  0.58     1
#  0.73     1
#  0.24     1
#  0.55     1
#  0.60     1
#  0.61     1
# Name: lea_ap_pct_3_or_above, dtype: int64
# ***************************************************
# 0.51    478
# Name: st_ap_pct_3_or_above, dtype: int64
# ***************************************************
# NaN      472
#  0.09      1
#  0.12      1
#  0.11      1
#  0.10      1
#  0.07      1
#  0.20      1
# Name: ib_participation_pct, dtype: int64
# ***************************************************
# NaN    478
# Name: lea_ib_participation_pct, dtype: int64
# ***************************************************
# NaN    478
# Name: st_ib_participation_pct, dtype: int64
# ***************************************************
# NaN      454
#  0.95      8
#  0.76      2
#  0.43      2
#  0.70      2
#  0.68      1
#  0.92      1
#  0.66      1
#  0.65      1
#  0.88      1
#  0.85      1
#  0.58      1
#  0.61      1
#  0.79      1
#  0.78      1
# Name: ib_pct_4_or_above, dtype: int64
# ***************************************************
# NaN      293
#  0.71     49
#  0.95     49
#  0.86     22
#  0.66     12
#  0.92     10
#  0.58     10
#  0.70     10
#  0.76      7
#  0.88      5
#  0.61      5
#  0.43      4
#  0.65      2
# Name: lea_ib_pct_4_or_above, dtype: int64
# ***************************************************
# 0.75    478
# Name: st_ib_pct_4_or_above, dtype: int64
# ***************************************************
# NaN    140
#  7      35
#  5      31
#  6      30
#  4      27
#  8      26
#  11     24
#  2      21
#  10     21
#  3      19
#  9      19
#  13     15
#  1      14
#  12     10
#  14      7
#  15      7
#  16      7
#  17      7
#  18      6
#  19      4
#  21      3
#  20      2
#  23      1
#  22      1
#  24      1
# Name: AP_Courses_Offered, dtype: int64
# ***************************************************
#  1.000000    334
# NaN           27
#  0.995595      2
#  0.981936      1
#  0.977682      1
#  0.989568      1
#  0.992492      1
#  0.993827      1
#  0.729535      1
#  0.995133      1
#  0.843365      1
#  0.995475      1
#  0.725518      1
#  0.621538      1
#  0.988166      1
#  0.845395      1
#  0.997778      1
#  0.987526      1
#  0.991736      1
#  0.998607      1
#  0.636401      1
#  0.840000      1
#  0.933174      1
#  0.998597      1
#  0.994649      1
#  0.964286      1
#  0.975904      1
#  0.721080      1
#  0.988433      1
#  0.995866      1
#             ...
#  0.849330      1
#  0.715254      1
#  0.801829      1
#  0.753065      1
#  0.994527      1
#  0.991667      1
#  0.990991      1
#  0.994898      1
#  0.998031      1
#  0.994186      1
#  0.987013      1
#  0.991266      1
#  0.996296      1
#  0.776000      1
#  0.992254      1
#  0.885507      1
#  0.997292      1
#  0.991681      1
#  0.989376      1
#  0.822618      1
#  0.978723      1
#  0.994949      1
#  0.803922      1
#  0.680268      1
#  0.999182      1
#  0.725275      1
#  0.990525      1
#  0.965241      1
#  0.997131      1
#  86.5      1
#  38.5      1
# Name: EOG_Gr6_GLP, dtype: int64
# ***************************************************
# NaN      464
#  14.4      1
#  31.8      1
#  39.8      1
#  50.6      1
#  58.2      1
#  25.8      1
#  57.9      1
#  39.7      1
#  44.9      1
#  36.7      1
#  90.0      1
#  75.0      1
#  25.0      1
#  76.5      1
# Name: EOG_Gr7_CACR, dtype: int64
# ***************************************************
# NaN      464
#  46.8      1
#  58.6      1
#  24.6      1
#  82.8      1
#  54.1      1
#  40.9      1
#  58.7      1
#  65.8      1
#  85.6      1
#  38.7      1
#  90.0      1
#  51.8      1
#  37.5      1
#  74.5      1
# Name: EOG_Gr7_GLP, dtype: int64
# ***************************************************
# NaN      463
#  71.2      1
#  34.3      1
#  21.2      1
#  63.1      1
#  73.3      1
#  47.6      1
#  41.3      1
#  62.9      1
#  28.1      1
#  36.9      1
#  68.1      1
#  39.2      1
#  41.0      1
#  25.0      1
#  33.3      1
# Name: EOG_Gr8_CACR, dtype: int64
# ***************************************************
# NaN      463
#  32.6      1
#  71.7      1
#  76.8      1
#  77.8      1
#  45.6      1
#  46.9      1
#  49.6      1
#  42.9      1
#  41.7      1
#  64.3      1
#  75.2      1
#  47.7      1
#  54.0      1
#  70.2      1
#  50.5      1
# Name: EOG_Gr8_GLP, dtype: int64
# ***************************************************
# NaN      475
#  94.1      1
#  15.6      1
#  44.7      1
# Name: EOG_Math_Gr3_CACR, dtype: int64
# ***************************************************
# NaN       475
#  40.6       1
#  100.0      1
#  66.0       1
# Name: EOG_Math_Gr3_GLP, dtype: int64
# ***************************************************
# NaN      462
#  26.8      1
#  20.5      1
#  18.0      1
#  36.2      1
#  29.7      1
#  25.6      1
#  71.8      1
#  51.6      1
#  54.2      1
#  21.1      1
#  48.1      1
#  14.1      1
#  48.3      1
#  59.9      1
#  68.2      1
#  23.7      1
# Name: EOG_Math_Gr3-8_CACR, dtype: int64
# ***************************************************
# NaN      462
#  33.9      1
#  26.5      1
#  74.5      1
#  34.3      1
#  23.0      1
#  44.2      1
#  84.6      1
#  58.6      1
#  32.8      1
#  19.2      1
#  70.6      1
#  26.3      1
#  62.9      1
#  66.4      1
#  56.6      1
#  34.2      1
# Name: EOG_Math_Gr3-8_GLP, dtype: int64
# ***************************************************
# NaN      475
#  65.2      1
#  86.7      1
#  50.0      1
# Name: EOG_Math_Gr4_CACR, dtype: int64
# ***************************************************
# NaN      475
#  69.6      1
#  57.1      1
#  93.3      1
# Name: EOG_Math_Gr4_GLP, dtype: int64
# ***************************************************
# NaN      475
#  58.3      1
#  53.6      1
#  63.6      1
# Name: EOG_Math_Gr5_CACR, dtype: int64
# ***************************************************
# NaN      475
#  63.6      1
#  75.0      1
#  62.5      1
# Name: EOG_Math_Gr5_GLP, dtype: int64
# ***************************************************
# NaN      466
#  45.7      2
#  41.7      1
#  10.3      1
#  65.7      1
#  56.9      1
#  29.6      1
#  14.6      1
#  75.0      1
#  70.0      1
#  50.0      1
#  23.5      1
# Name: EOG_Math_Gr6_CACR, dtype: int64
# ***************************************************
# NaN      466
#  69.2      1
#  22.9      1
#  82.7      1
#  59.1      1
#  13.8      1
#  34.9      1
#  52.8      1
#  60.7      1
#  90.0      1
#  80.0      1
#  35.3      1
#  56.5      1
# Name: EOG_Math_Gr6_GLP, dtype: int64
# ***************************************************
# NaN      464
#  72.4      1
#  69.7      1
#  28.9      1
#  55.1      1
#  45.2      1
#  52.6      1
#  18.2      1
#  16.1      1
#  46.9      1
#  17.9      1
#  32.7      1
#  90.0      1
#  10.2      1
#  34.5      1
# Name: EOG_Math_Gr7_CACR, dtype: int64
# ***************************************************
# NaN      464
#  41.8      1
#  81.8      1
#  63.2      1
#  79.3      1
#  27.3      1
#  67.3      1
#  51.2      1
#  37.9      1
#  22.6      1
#  90.0      1
#  49.0      1
#  25.0      1
#  37.3      1
#  13.0      1
# Name: EOG_Math_Gr7_GLP, dtype: int64
# ***************************************************
# NaN      464
#  14.3      1
#  13.4      1
#  22.9      1
#  66.7      1
#  44.7      1
#  54.1      1
#  22.7      1
#  28.6      1
#  29.7      1
#  21.1      1
#  53.0      1
#  27.0      1
#  55.3      1
#  18.5      1
# Name: EOG_Math_Gr8_CACR, dtype: int64
# ***************************************************
# NaN      464
#  59.6      1
#  57.1      1
#  28.9      1
#  26.3      1
#  60.9      1
#  30.3      1
#  25.7      1
#  20.1      1
#  32.4      1
#  29.6      1
#  70.0      1
#  60.6      1
#  55.3      1
#  19.0      1
# Name: EOG_Math_Gr8_GLP, dtype: int64
# ***************************************************
# NaN      475
#  88.2      1
#  53.2      1
#  37.5      1
# Name: EOG_Reading_G3_GLP, dtype: int64
# ***************************************************
# NaN      475
#  44.7      1
#  34.4      1
#  82.4      1
# Name: EOG_Reading_Gr3_CACR, dtype: int64
# ***************************************************
# NaN      475
#  58.7      1
#  80.0      1
#  50.0      1
# Name: EOG_Reading_Gr4_CACR, dtype: int64
# ***************************************************
# NaN      475
#  57.1      1
#  86.7      1
#  73.9      1
# Name: EOG_Reading_Gr4_GLP, dtype: int64
# ***************************************************
# NaN      475
#  58.3      1
#  63.6      1
#  40.4      1
# Name: EOG_Reading_Gr5_CACR, dtype: int64
# ***************************************************
# NaN      475
#  72.7      1
#  66.7      1
#  50.9      1
# Name: EOG_Reading_Gr5_GLP, dtype: int64
# ***************************************************
# NaN      466
#  24.1      1
#  45.8      1
#  51.2      1
#  69.2      1
#  31.7      1
#  41.2      1
#  64.3      1
#  58.7      1
#  41.7      1
#  75.0      1
#  60.0      1
#  68.6      1
# Name: EOG_Reading_Gr6_CACR, dtype: int64
# ***************************************************
# NaN      466
#  71.4      1
#  58.8      1
#  87.7      1
#  62.2      1
#  90.4      1
#  37.6      1
#  54.2      1
#  82.9      1
#  73.9      1
#  90.0      1
#  52.8      1
#  34.5      1
# Name: EOG_Reading_Gr6_GLP, dtype: int64
# ***************************************************
# NaN      464
#  32.1      1
#  44.8      1
#  18.8      1
#  61.2      1
#  50.6      1
#  83.3      1
#  63.2      1
#  42.9      1
#  40.7      1
#  90.0      1
#  56.0      1
#  77.6      1
