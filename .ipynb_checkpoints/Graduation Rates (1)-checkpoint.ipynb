# %%
# Imports
import pandas as pd
import numpy as np
from __future__ import print_function

# %matplotlib inline

#ignore warnings
#import warnings
#warnings.filterwarnings('ignore')

#Read in raw data
schoolData = pd.read_csv('D:/BenepactLLC/Belk/NC_Report_Card_Data/Summary Data Files/All_Data_By_School_Final.csv'
                         , low_memory=False)
testScores = pd.read_csv('D:/BenepactLLC/Belk/NC_Report_Card_Data/Summary Data Files/1516_Test_Scores.csv', low_memory=False)

#Review raw data before the join
schoolData.info()

#join files using school / unit code
schoolData = schoolData.join(testScores, on='unit_code',how='left', lsuffix='_schoolData', rsuffix='_testScores')

#Review raw data after the join to make sure new fields were added
print('************************************************************')
schoolData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2579 entries, 0 to 2578
# Columns: 293 entries, Year to State_Prin_Exp_Pct_10+_Years
# dtypes: float64(255), int64(17), object(21)
# memory usage: 5.8+ MB
# ************************************************************
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2579 entries, 0 to 2578
# Columns: 366 entries, Year to Passing_Math_III
# dtypes: float64(324), int64(17), object(25)
# memory usage: 7.2+ MB

# %%
#Remove fields not needed for machine learning
excludeFields = ['Year','unit_code_schoolData', 'street_ad','scity_ad','state_ad','szip_ad','Closed_Ind_Text','New_ind_Txt',
                 'grades_BYOD','grades_1_to_1_access','District Name','unit_code_testScores','School Name','SBE District']

keepFields = [col for col in schoolData.columns if col not in excludeFields]

schoolData = schoolData[keepFields]

schoolData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2579 entries, 0 to 2578
# Columns: 352 entries, type_cd_txt to Passing_Math_III
# dtypes: float64(324), int64(15), object(13)
# memory usage: 6.9+ MB

# %%
#Clean up the dataset for machine learning 
boolFields = ['title1_type_flg', 'clp_ind_flg', 'focus_clp_flg', 'summer_program_flg', 
              'asm_no_spg_flg', 'no_data_spg_flg', 'stem_flg']

# Map flag fields into bool 
schoolData['title1_type_flg'] = schoolData['title1_type_flg'].map({-1:True, 0:False})
schoolData['clp_ind_flg'] = schoolData['clp_ind_flg'].map({-1:True, 0:False})
schoolData['focus_clp_flg'] = schoolData['focus_clp_flg'].map({-1:True, 0:False})
schoolData['summer_program_flg'] = schoolData['summer_program_flg'].map({-1:True, 0:False})
schoolData['asm_no_spg_flg'] = schoolData['asm_no_spg_flg'].map({-1:True, 0:False})
schoolData['no_data_spg_flg'] = schoolData['no_data_spg_flg'].map({-1:True, 0:False})
schoolData['stem_flg'] = schoolData['stem_flg'].map({-1:True, 0:False})

# %%
# Find all the categorical variables
schoolData_Vars = schoolData.loc[:, schoolData.dtypes == object]
cat_list_obj = list(schoolData_Vars)
cat_list_obj_len = len(cat_list_obj) # number of object attributes
print("Number of Categorical Attributes = ", cat_list_obj_len)
cat_list_obj
# Out:
# Number of Categorical Attributes =  13
# ['type_cd_txt',
#  'category_cd',
#  'school_type_txt',
#  'calendar_only_txt',
#  'esea_status',
#  'Grad_project_status',
#  'SPG Grade',
#  'Reading SPG Grade',
#  'Math SPG Grade',
#  'EVAAS Growth Status',
#  'State Gap Compared',
#  'Byod',
#  '1_to_1_access']

# %%
#Review individual data types after data preparation
schoolData.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2579 entries, 0 to 2578
# Data columns (total 352 columns):
# type_cd_txt                                       object
# category_cd                                       object
# school_type_txt                                   object
# calendar_only_txt                                 object
# title1_type_flg                                   bool
# clp_ind_flg                                       bool
# focus_clp_flg                                     bool
# summer_program_flg                                bool
# asm_no_spg_flg                                    bool
# no_data_spg_flg                                   bool
# esea_status                                       object
# student_num                                       float64
# lea_avg_student_num                               float64
# st_avg_student_num                                int64
# Grad_project_status                               object
# stem_flg                                          bool
# Avg_Class_Size_00                                 float64
# Avg_Class_Size_01                                 float64
# Avg_Class_Size_02                                 float64
# Avg_Class_Size_03                                 float64
# Avg_Class_Size_04                                 float64
# Avg_Class_Size_05                                 float64
# Avg_Class_Size_06                                 float64
# Avg_Class_Size_07                                 float64
# Avg_Class_Size_08                                 float64
# Avg_Class_Size_Biology                            float64
# Avg_Class_Size_EnglishII                          float64
# Avg_Class_Size_MathI                              float64
# Avg_Dist_Size_00                                  float64
# Avg_Dist_Size_01                                  float64
# Avg_Dist_Size_02                                  float64
# Avg_Dist_Size_03                                  float64
# Avg_Dist_Size_04                                  float64
# Avg_Dist_Size_05                                  float64
# Avg_Dist_Size_06                                  float64
# Avg_Dist_Size_07                                  float64
# Avg_Dist_Size_08                                  float64
# Avg_Dist_Size_Biology                             float64
# Avg_Dist_Size_EnglishII                           float64
# Avg_Dist_Size_MathI                               float64
# Avg_State_Size_00                                 float64
# Avg_State_Size_01                                 float64
# Avg_State_Size_02                                 float64
# Avg_State_Size_03                                 float64
# Avg_State_Size_04                                 float64
# Avg_State_Size_05                                 float64
# Avg_State_Size_06                                 float64
# Avg_State_Size_07                                 float64
# Avg_State_Size_08                                 float64
# Avg_State_Size_Biology                            float64
# Avg_State_Size_EnglishII                          float64
# Avg_State_Size_MathI                              float64
# total_expense_num                                 float64
# salary_expense_pct                                float64
# benefits_expense_pct                              float64
# services_expense_pct                              float64
# supplies_expense_pct                              float64
# instruct_equip_exp_pct                            float64
# other_expense_pct                                 float64
# federal_perpupil_num                              float64
# local_perpupil_num                                float64
# state_perpupil_num                                float64
# lea_total_expense_num                             float64
# lea_salary_expense_pct                            float64
# lea_benefits_expense_pct                          float64
# lea_services_expense_pct                          float64
# lea_supplies_expense_pct                          float64
# lea_instruct_equip_exp_pct                        float64
# lea_other_expense_pct                             float64
# lea_federal_perpupil_num                          float64
# lea_local_perpupil_num                            float64
# lea_state_perpupil_num                            float64
# st_total_expense_num                              float64
# st_salary_expense_pct                             float64
# st_benefits_expense_pct                           float64
# st_services_expense_pct                           float64
# st_supplies_expense_pct                           float64
# st_instruct_equip_exp_pct                         float64
# st_other_expense_pct                              int64
# st_federal_perpupil_num                           float64
# st_local_perpupil_num                             float64
# st_state_perpupil_num                             float64
# SPG Grade                                         object
# SPG Score                                         float64
# Reading SPG Grade                                 object
# Reading  SPG Score                                float64
# Math SPG Grade                                    object
# Math SPG Score                                    float64
# EVAAS Growth Status                               object
# EVAAS Growth Score                                float64
# Overall Achievement Score                         float64
# Read Score                                        float64
# Math Score                                        float64
# Science Score                                     float64
# Math I Score                                      float64
# English II Score                                  float64
# Biology Score                                     float64
# The ACT Score                                     float64
# ACT WorkKeys Score                                float64
# Math Course Rigor Score                           float64
# Cohort Graduation Rate Standard Score             float64
# State Gap Compared                                object
# GCE_ALL_School_Pct                                float64
# GCE_LEP_School_Pct                                float64
# GCE_PRM_School_Pct                                float64
# GCE_RPF_School_Pct                                float64
# GCE_SWD_School_Pct                                float64
# PASSED_EOG_School_Pct                             float64
# PASSED_LAA_School_Pct                             float64
# PASSED_RTA_School_Pct                             float64
# PROMOTED_School_Pct                               float64
# RETAINED_School_Pct                               float64
# GCE_ALL_Dist_Pct                                  float64
# GCE_LEP_Dist_Pct                                  float64
# GCE_PRM_Dist_Pct                                  float64
# GCE_RPF_Dist_Pct                                  float64
# GCE_SWD_Dist_Pct                                  float64
# PASSED_EOG_Dist_Pct                               float64
# PASSED_LAA_Dist_Pct                               float64
# PASSED_RTA_Dist_Pct                               float64
# PROMOTED_Dist_Pct                                 float64
# RETAINED_Dist_Pct                                 float64
# GCE_ALL_State_Pct                                 float64
# GCE_LEP_State_Pct                                 float64
# GCE_PRM_State_Pct                                 float64
# GCE_RPF_State_Pct                                 float64
# GCE_SWD_State_Pct                                 float64
# PASSED_EOG_State_Pct                              float64
# PASSED_LAA_State_Pct                              float64
# PASSED_RTA_State_Pct                              float64
# PROMOTED_State_Pct                                float64
# RETAINED_State_Pct                                float64
# sat_avg_score_num                                 float64
# lea_sat_avg_score_num                             float64
# st_sat_avg_score_num                              int64
# nat_sat_avg_score_num                             int64
# sat_participation_pct                             float64
# lea_sat_participation_pct                         float64
# st_sat_participation_pct                          float64
# nat_sat_participation_pct                         float64
# esea_attendance                                   float64
# lea_esea_attendance                               float64
# ap_participation_pct                              float64
# lea_ap_participation_pct                          float64
# st_ap_participation_pct                           float64
# ap_pct_3_or_above                                 float64
# lea_ap_pct_3_or_above                             float64
# st_ap_pct_3_or_above                              float64
# ib_participation_pct                              float64
# lea_ib_participation_pct                          float64
# st_ib_participation_pct                           float64
# ib_pct_4_or_above                                 float64
# lea_ib_pct_4_or_above                             float64
# st_ib_pct_4_or_above                              float64
# AP_Courses_Offered                                float64
# total_specialized_courses                         float64
# ap_ib_courses                                     float64
# cte_courses                                       float64
# univ_college_courses                              float64
# lea_total_specialized_courses                     float64
# lea_ap_ib_courses                                 float64
# lea_cte_courses                                   float64
# lea_univ_college_courses                          float64
# st_total_specialized_courses                      float64
# st_ap_ib_courses                                  float64
# st_cte_courses                                    float64
# st_univ_college_courses                           float64
# sch_percent_college_enrolled_16_mos_post_grad     float64
# One_Yr_College_Complete_wi_2_yrs_Enrolled_2012    float64
# avg_daily_attend_pct                              float64
# crime_per_c_num                                   float64
# short_susp_per_c_num                              float64
# long_susp_per_c_num                               float64
# expelled_per_c_num                                float64
# ttl_crimes_num                                    float64
# stud_internet_comp_num                            float64
# lea_avg_daily_attend_pct                          float64
# lea_crime_per_c_num                               float64
# lea_short_susp_per_c_num                          float64
# lea_long_susp_per_c_num                           float64
# lea_expelled_per_c_num                            float64
# lea_stud_internet_comp_num                        float64
# st_avg_daily_attend_pct                           float64
# st_crime_per_c_num                                float64
# st_short_susp_per_c_num                           float64
# st_long_susp_per_c_num                            float64
# st_expelled_per_c_num                             int64
# st_stud_internet_comp_num                         float64
# digital_media_pct                                 float64
# Byod                                              object
# avg_age_media_collection                          float64
# 1_to_1_access                                     object
# books_per_student                                 float64
# lea_avg_age_media_collection                      float64
# lea_books_per_student                             float64
# st_avg_age_media_collection                       float64
# st_books_per_student                              float64
# wap_num                                           float64
# wap_per_classroom                                 float64
# lea_wap_num                                       float64
# lea_wap_per_classroom                             float64
# st_wap_num                                        int64
# st_wap_per_classroom                              float64
# prin_other_pct                                    float64
# prinyrs_0thru3_pct                                float64
# prinyrs_4thru10_pct                               float64
# prinyrs_11plus_pct                                float64
# prin_advance_dgr_pct                              float64
# _1yr_prin_trnovr_pct                              float64
# prin_male_pct                                     float64
# prin_female_pct                                   float64
# prin_black_pct                                    float64
# prin_white_pct                                    float64
# flicensed_teach_pct                               float64
# tchyrs_0thru3_pct                                 float64
# tchyrs_4thru10_pct                                float64
# tchyrs_11plus_pct                                 float64
# class_teach_num                                   float64
# nbpts_num                                         float64
# advance_dgr_pct                                   float64
# _1yr_tchr_trnovr_pct                              float64
# emer_prov_teach_pct                               float64
# lateral_teach_pct                                 float64
# highqual_class_pct                                float64
# lea_flicensed_teach_pct                           float64
# lea_tchyrs_0thru3_pct                             float64
# lea_tchyrs_4thru10_pct                            float64
# lea_tchyrs_11plus_pct                             float64
# lea_class_teach_num                               float64
# lea_nbpts_num                                     float64
# lea_advance_dgr_pct                               float64
# lea_1yr_tchr_trnovr_pct                           float64
# lea_emer_prov_teach_pct                           float64
# lea_lateral_teach_pct                             float64
# lea_highqual_class_pct                            float64
# lea_highqual_class_hp_pct                         float64
# lea_highqual_class_lp_pct                         float64
# lea_highqual_class_all_pct                        float64
# lea_not_highqual_class_hp_pct                     float64
# lea_not_highqual_class_lp_pct                     float64
# lea_not_highqual_class_all_pct                    float64
# st_flicensed_teach_pct                            float64
# st_tchyrs_0thru3_pct                              float64
# st_tchyrs_4thru10_pct                             float64
# st_tchyrs_11plus_pct                              float64
# st_class_teach_num                                int64
# st_nbpts_num                                      int64
# st_advance_dgr_pct                                float64
# st_1yr_tchr_trnovr_pct                            float64
# st_emer_prov_teach_pct                            float64
# st_lateral_teach_pct                              float64
# st_highqual_class_pct                             float64
# st_highqual_class_hp_pct                          float64
# st_highqual_class_lp_pct                          float64
# st_highqual_class_all_pct                         float64
# st_not_highqual_class_hp_pct                      float64
# st_not_highqual_class_lp_pct                      float64
# st_not_highqual_class_all_pct                     float64
# st_prinyrs_0thru3_pct                             float64
# st_prinyrs_4thru10_pct                            float64
# st_prinyrs_11plus_pct                             float64
# st_prin_advance_dgr_pct                           float64
# st_1yr_prin_trnovr_pct                            float64
# st_prin_male_pct                                  float64
# st_prin_female_pct                                float64
# st_prin_black_pct                                 float64
# st_prin_white_pct                                 float64
# st_prin_other_pct                                 float64
# Tch_Exp_Pct_0_3_Years                             float64
# Tch_Exp_Pct_4_10_Years                            float64
# Tch_Exp_Pct_10+_Years                             float64
# Dist_Tch_Exp_Pct_0_3_Years                        float64
# Dist_Tch_Exp_Pct_4_10_Years                       float64
# Dist_Tch_Exp_Pct_10+_Years                        float64
# State_Tch_Exp_Pct_0_3_Years                       float64
# State_Tch_Exp_Pct_4_10_Years                      float64
# State_Tch_Exp_Pct_10+_Years                       float64
# Dist_Prin_Exp_Pct_0_3_Years                       float64
# Dist_Prin_Exp_Pct_4_10_Years                      float64
# Dist_Prin_Exp_Pct_10+_Years                       float64
# State_Prin_Exp_Pct_0_3_Years                      float64
# State_Prin_Exp_Pct_4_10_Years                     float64
# State_Prin_Exp_Pct_10+_Years                      float64
# ACT_Composite_Score_UNC_Min                       float64
# ACT_English_Benchmark                             float64
# ACT_Math_Benchmark                                float64
# ACT_Pct_of_Benchmarks_Met                         float64
# ACT_Reading_Benchmark                             float64
# ACT_Science_Benchmark                             float64
# ACT_WorkKeys_Silver_Beyond                        float64
# ACT_Writing_Benchmark                             float64
# All_EOC_Subjects_CACR                             float64
# All_EOC_Subjects_GLP                              float64
# All_EOG_EOC_Subjects_CACR                         float64
# All_EOG_EOC_Subjects_GLP                          float64
# All_EOG_Subjects_CACR                             float64
# All_EOG_Subjects_GLP                              float64
# EOC_Biology_CACR                                  float64
# EOC_Biology_GLP                                   float64
# EOC_English_2_CACR                                float64
# EOC_English_2_GLP                                 float64
# EOC_Math_I_CACR                                   float64
# EOC_Math_I_GLP                                    float64
# EOG_Gr3_CACR                                      float64
# EOG_Gr3_GLP                                       float64
# EOG_Gr4_CACR                                      float64
# EOG_Gr4_GLP                                       float64
# EOG_Gr5_CACR                                      float64
# EOG_Gr5_GLP                                       float64
# EOG_Gr6_CACR                                      float64
# EOG_Gr6_GLP                                       float64
# EOG_Gr7_CACR                                      float64
# EOG_Gr7_GLP                                       float64
# EOG_Gr8_CACR                                      float64
# EOG_Gr8_GLP                                       float64
# EOG_Math_Gr3_CACR                                 float64
# EOG_Math_Gr3_GLP                                  float64
# EOG_Math_Gr3-8_CACR                               float64
# EOG_Math_Gr3-8_GLP                                float64
# EOG_Math_Gr4_CACR                                 float64
# EOG_Math_Gr4_GLP                                  float64
# EOG_Math_Gr5_CACR                                 float64
# EOG_Math_Gr5_GLP                                  float64
# EOG_Math_Gr6_CACR                                 float64
# EOG_Math_Gr6_GLP                                  float64
# EOG_Math_Gr7_CACR                                 float64
# EOG_Math_Gr7_GLP                                  float64
# EOG_Math_Gr8_CACR                                 float64
# EOG_Math_Gr8_GLP                                  float64
# EOG_Reading_G3_GLP                                float64
# EOG_Reading_Gr3_CACR                              float64
# EOG_Reading_Gr4_CACR                              float64
# EOG_Reading_Gr4_GLP                               float64
# EOG_Reading_Gr5_CACR                              float64
# EOG_Reading_Gr5_GLP                               float64
# EOG_Reading_Gr6_CACR                              float64
# EOG_Reading_Gr6_GLP                               float64
# EOG_Reading_Gr7_CACR                              float64
# EOG_Reading_Gr7_GLP                               float64
# EOG_Reading_Gr8_CACR                              float64
# EOG_Reading_Gr8_GLP                               float64
# EOG_Reading_Grades_3_8_CACR                       float64
# EOG_Reading_Grades_3_8_GLP                        float64
# EOG_Science_Gr5_CACR                              float64
# EOG_Science_Gr5_GLP                               float64
# EOG_Science_Gr8_CACR                              float64
# EOG_Science_Gr8_GLP                               float64
# EOG_Science_Grades_5&8_CACR                       float64
# EOG_Science_Grades_5&8_GLP                        float64
# Graduation_Rate_5_Yr                              float64
# Graduation_Rate4_Yr                               float64
# Passing_Math_III                                  float64
# dtypes: bool(7), float64(324), int64(8), object(13)
# memory usage: 6.8+ MB

# %%
# Examine categorical variables of interest  
import matplotlib.pyplot as plt

for i in range(0,cat_list_obj_len):
    plt.figure(figsize = (18,4))
    ax = schoolData[cat_list_obj[i]].value_counts().plot(kind='bar')
    plt.title(cat_list_obj[i])
    plt.show()

# %%
#Get high school campuses
highSchools = schoolData[(schoolData.category_cd == 'H') | 
                         (schoolData.category_cd == 'T') | 
                         (schoolData.category_cd == 'A')]
highSchools.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 639 entries, 0 to 2572
# Columns: 352 entries, type_cd_txt to Passing_Math_III
# dtypes: bool(7), float64(324), int64(8), object(13)
# memory usage: 1.7+ MB

# %%
#Inspect the high school data fields 
df_temp = highSchools.describe(include='all').T
# include the data type of the column in the dataframe
df_temp['type']= highSchools.dtypes
# Reset the index of the dataframe to have index as numbers to have the number of rows visible in the output
df_temp.reset_index(inplace=True)
df_temp
# Out:
#                            index count unique                   top freq  \
# 0                    type_cd_txt   639      2                Public  578
# 1                    category_cd   639      3                     H  505
# 2                school_type_txt   639      6        Regular School  538
# 3              calendar_only_txt   638      2  Traditional Calendar  619
# 4                title1_type_flg   639    NaN                   NaN  NaN
# 5                    clp_ind_flg   639    NaN                   NaN  NaN
# 6                  focus_clp_flg   639    NaN                   NaN  NaN
# 7             summer_program_flg   639    NaN                   NaN  NaN
# 8                 asm_no_spg_flg   639    NaN                   NaN  NaN
# 9                no_data_spg_flg   639    NaN                   NaN  NaN
# 10                   esea_status    49      2                     P   47
# 11                   student_num   631    NaN                   NaN  NaN
# 12           lea_avg_student_num   576    NaN                   NaN  NaN
# 13            st_avg_student_num   639    NaN                   NaN  NaN
# 14           Grad_project_status   594      2                     N  390
# 15                      stem_flg   639    NaN                   NaN  NaN
# 16             Avg_Class_Size_00    37    NaN                   NaN  NaN
# 17             Avg_Class_Size_01    37    NaN                   NaN  NaN
# 18             Avg_Class_Size_02    37    NaN                   NaN  NaN
# 19             Avg_Class_Size_03    36    NaN                   NaN  NaN
# 20             Avg_Class_Size_04    38    NaN                   NaN  NaN
# 21             Avg_Class_Size_05    40    NaN                   NaN  NaN
# 22             Avg_Class_Size_06    63    NaN                   NaN  NaN
# 23             Avg_Class_Size_07    71    NaN                   NaN  NaN
# 24             Avg_Class_Size_08    73    NaN                   NaN  NaN
# 25        Avg_Class_Size_Biology   588    NaN                   NaN  NaN
# 26      Avg_Class_Size_EnglishII   594    NaN                   NaN  NaN
# 27          Avg_Class_Size_MathI   595    NaN                   NaN  NaN
# 28              Avg_Dist_Size_00     3    NaN                   NaN  NaN
# 29              Avg_Dist_Size_01     4    NaN                   NaN  NaN
# ..                           ...   ...    ...                   ...  ...
# 322             EOG_Math_Gr5_GLP     0    NaN                   NaN  NaN
# 323            EOG_Math_Gr6_CACR     0    NaN                   NaN  NaN
# 19     21.8611   5.80715     10     20    22      24    47  float64
# 20     20.2895   4.36762     10  18.25    21   23.75    28  float64
# 21      21.075   4.32872     10  19.75  22.5      24    28  float64
# 22     20.2698   4.97804     10     17    20    23.5    40  float64
# 23     19.9014   5.57841     10     17    20      24    39  float64
# 24     18.6712    5.0057     10     15    19      22    27  float64
# 25     18.2211   5.57575      5     15    19      22    32  float64
# 26     18.4781   5.67682      5     15    19      23    41  float64
# 27     18.0034   6.23852      5     15    18      22    95  float64
# 28          18         2     16     17    18      19    20  float64
# 29          18   1.41421     17     17  17.5    18.5    20  float64
# ..         ...       ...    ...    ...   ...     ...   ...      ...
# 322        NaN       NaN    NaN    NaN   NaN     NaN   NaN  float64
# 323        NaN       NaN    NaN    NaN   NaN     NaN   NaN  float64
# 324        NaN       NaN    NaN    NaN   NaN     NaN   NaN  float64
# 325        NaN       NaN    NaN    NaN   NaN     NaN   NaN  float64
# 326        NaN       NaN    NaN    NaN   NaN     NaN   NaN  float64
# 327        NaN       NaN    NaN    NaN   NaN     NaN   NaN  float64
# 328        NaN       NaN    NaN    NaN   NaN     NaN   NaN  float64
# 329        NaN       NaN    NaN    NaN   NaN     NaN   NaN  float64
# 330        NaN       NaN    NaN    NaN   NaN     NaN   NaN  float64
# 331        NaN       NaN    NaN    NaN   NaN     NaN   NaN  float64
# 332        NaN       NaN    NaN    NaN   NaN     NaN   NaN  float64
# 333        NaN       NaN    NaN    NaN   NaN     NaN   NaN  float64
# 334        NaN       NaN    NaN    NaN   NaN     NaN   NaN  float64
# 335        NaN       NaN    NaN    NaN   NaN     NaN   NaN  float64
# 336        NaN       NaN    NaN    NaN   NaN     NaN   NaN  float64
# 337        NaN       NaN    NaN    NaN   NaN     NaN   NaN  float64
# 338        NaN       NaN    NaN    NaN   NaN     NaN   NaN  float64
# 339        NaN       NaN    NaN    NaN   NaN     NaN   NaN  float64
# 340        NaN       NaN    NaN    NaN   NaN     NaN   NaN  float64
# 341        NaN       NaN    NaN    NaN   NaN     NaN   NaN  float64
# 342        NaN       NaN    NaN    NaN   NaN     NaN   NaN  float64
# 343        NaN       NaN    NaN    NaN   NaN     NaN   NaN  float64
# 344        NaN       NaN    NaN    NaN   NaN     NaN   NaN  float64
# 345        NaN       NaN    NaN    NaN   NaN     NaN   NaN  float64
# 346        NaN       NaN    NaN    NaN   NaN     NaN   NaN  float64
# 347        NaN       NaN    NaN    NaN   NaN     NaN   NaN  float64
# 348        NaN       NaN    NaN    NaN   NaN     NaN   NaN  float64
# 349        NaN       NaN    NaN    NaN   NaN     NaN   NaN  float64
# 350        NaN       NaN    NaN    NaN   NaN     NaN   NaN  float64
# 351        NaN       NaN    NaN    NaN   NaN     NaN   NaN  float64
#
# [352 rows x 13 columns]

# %%
#List of all int32 fields
int32Fields = ['student_num', 'lea_avg_student_num','Avg_Class_Size_00','Avg_Class_Size_01',
             'Avg_Class_Size_02','Avg_Class_Size_03','Avg_Class_Size_04','Avg_Class_Size_05',
             'Avg_Class_Size_06','Avg_Class_Size_07','Avg_Class_Size_08','Avg_Class_Size_Biology',
             'Avg_Class_Size_EnglishII','Avg_Class_Size_MathI','Avg_Dist_Size_00','Avg_Dist_Size_01',
             'Avg_Dist_Size_02','Avg_Dist_Size_03','Avg_Dist_Size_04','Avg_Dist_Size_05','Avg_Dist_Size_06',
             'Avg_Dist_Size_07','Avg_Dist_Size_08','Avg_Dist_Size_Biology','Avg_Dist_Size_EnglishII',
             'Avg_Dist_Size_MathI','Avg_State_Size_00','Avg_State_Size_01','Avg_State_Size_02','Avg_State_Size_03',
             'Avg_State_Size_04','Avg_State_Size_05','Avg_State_Size_06','Avg_State_Size_07','Avg_State_Size_08',
             'Avg_State_Size_Biology','Avg_State_Size_EnglishII','Avg_State_Size_MathI','SPG Score','Reading  SPG Score',
             'Math SPG Score','Overall Achievement Score','Read Score','Math Score','Science Score','Math I Score',
             'English II Score','Biology Score','The ACT Score','ACT WorkKeys Score','Math Course Rigor Score',
             'Cohort Graduation Rate Standard Score','sat_avg_score_num','lea_sat_avg_score_num','st_sat_avg_score_num',
             'nat_sat_avg_score_num','avg_age_media_collection','lea_avg_age_media_collection','st_avg_age_media_collection',
             'wap_num','lea_wap_num','st_wap_num','class_teach_num','nbpts_num','lea_class_teach_num','lea_nbpts_num',
             'st_class_teach_num','st_nbpts_num']

#Cannot convert from float64 to int32 due to missing values, should revisit this 
#highSchools[int32Fields] = highSchools[int32Fields].apply(np.int32, axis=1)

# %%
#Look at missing / NaN values by column
for col in highSchools:
    x = highSchools[col].value_counts(dropna=False)
    print(x)
    print('***************************************************')
# Out:
# Public     578
# Charter     61
# Name: type_cd_txt, dtype: int64
# ***************************************************
# H    505
# T     71
# A     63
# Name: category_cd, dtype: int64
# ***************************************************
# Regular School           538
# Alternative Education     64
# Magnet School             23
# Vocational Education       7
# Special Education          6
# Hospital School            1
# Name: school_type_txt, dtype: int64
# ***************************************************
# Traditional Calendar    619
# Year-Round Calendar      19
# NaN                       1
# Name: calendar_only_txt, dtype: int64
# ***************************************************
# False    541
# True      98
# Name: title1_type_flg, dtype: int64
# ***************************************************
# False    570
# True      69
# Name: clp_ind_flg, dtype: int64
# ***************************************************
# False    571
# True      68
# Name: focus_clp_flg, dtype: int64
# ***************************************************
# False    434
# True     205
# Name: summer_program_flg, dtype: int64
# ***************************************************
# False    569
# True      70
# Name: asm_no_spg_flg, dtype: int64
# ***************************************************
# False    631
# True       8
# Name: no_data_spg_flg, dtype: int64
# ***************************************************
# NaN    590
# P       47
# F        2
# Name: esea_status, dtype: int64
# ***************************************************
# NaN      8
#  120     5
#  74      4
#  815     3
#  155     3
#  1319    3
#  896     3
#  697     3
#  44      3
#  132     3
#  33      3
#  328     3
#  84      3
#  75      3
#  210     3
#  1033    3
#  214     3
#  198     3
#  1644    3
#  618     3
#  750     2
#  753     2
#  757     2
#  136     2
#  357     2
#  828     2
#  1278    2
#  133     2
#  111     2
#  205     2
#         ..
#  1613    1
#  515     1
#  547     1
#  1542    1
#  521     1
#  1547    1
#  1548    1
#  525     1
#  526     1
#  1552    1
#  58      1
#  530     1
#  532     1
#  540     1
#  2589    1
#  1573    1
#  587     1
#  1574    1
#  1186    1
#  552     1
#  2425    1
#  561     1
#  639     1
#  571     1
#  1597    1
#  1598    1
#  512     1
#  1240    1
#  582     1
#  410     1
# Name: student_num, dtype: int64
# ***************************************************
# NaN      63
#  812     28
#  1493    27
#  1772    26
#  912     16
#  1122    15
#  779     15
#  751     15
#  1190    11
#  873     11
#  895     10
#  976     10
#  1203     8
#  985      8
#  778      7
#  1021     7
#  837      7
#  515      7
#  1015     7
#  979      7
#  972      7
#  1127     7
#  944      7
#  425      6
#  876      6
#  415      6
#  400      6
#  794      5
#  377      5
#  450      5
#          ..
#  1436     1
#  438      1
#  120      1
#  1478     1
#  585      1
#  179      1
#  488      1
#  540      1
#  500      1
#  512      1
#  307      1
#  305      1
#  759      1
#  813      1
#  122      1
#  124      1
#  132      1
#  133      1
#  140      1
#  146      1
#  154      1
#  155      1
#  160      1
#  930      1
#  530      1
#  183      1
#  184      1
#  210      1
#  887      1
#  1023     1
# Name: lea_avg_student_num, dtype: int64
# ***************************************************
# 860    505
# 268     71
# 511     63
# Name: st_avg_student_num, dtype: int64
# ***************************************************
# N      390
# Y      204
# NaN     45
# Name: Grad_project_status, dtype: int64
# ***************************************************
# False    632
# True       7
# Name: stem_flg, dtype: int64
# ***************************************************
# NaN    602
#  21      9
#  19      5
#  22      4
#  20      4
#  18      4
#  16      3
#  15      3
#  24      1
#  23      1
#  17      1
#  14      1
#  12      1
# Name: Avg_Class_Size_00, dtype: int64
# ***************************************************
# NaN    602
#  21      7
#  22      6
#  24      3
#  23      3
#  20      3
#  19      3
#  17      3
#  25      2
#  18      2
#  27      1
#  16      1
#  15      1
#  11      1
#  10      1
# Name: Avg_Class_Size_01, dtype: int64
# ***************************************************
# NaN    602
#  22      7
# NaN    636
#  20      1
#  18      1
#  16      1
# Name: Avg_Dist_Size_00, dtype: int64
# ***************************************************
# NaN    635
#  17      2
#  20      1
#  18      1
# Name: Avg_Dist_Size_01, dtype: int64
# ***************************************************
# NaN    635
#  20      1
#  18      1
#  16      1
#  15      1
# Name: Avg_Dist_Size_02, dtype: int64
# ***************************************************
# NaN    635
#  16      2
#  20      1
#  17      1
# Name: Avg_Dist_Size_03, dtype: int64
# ***************************************************
# NaN    635
#  22      1
#  20      1
#  19      1
#  15      1
# Name: Avg_Dist_Size_04, dtype: int64
# ***************************************************
# NaN    634
#  22      1
#  19      1
#  17      1
#  15      1
#  13      1
# Name: Avg_Dist_Size_05, dtype: int64
# ***************************************************
# NaN    619
#  22      6
#  21      6
#  23      2
#  13      2
#  25      1
#  20      1
#  19      1
#  18      1
# Name: Avg_Dist_Size_06, dtype: int64
# ***************************************************
# NaN    613
#  22      8
#  23      5
#  24      3
#  21      3
#  10      2
#  26      1
#  25      1
#  20      1
#  18      1
#  15      1
# Name: Avg_Dist_Size_07, dtype: int64
# ***************************************************
# NaN    610
#  20      8
#  23      7
#  21      6
#  24      4
#  18      2
#  19      1
#  10      1
# Name: Avg_Dist_Size_08, dtype: int64
# ***************************************************
#  19    107
#  20    106
# NaN     84
#  22     75
#  17     60
#  18     53
#  21     35
#  16     34
#  15     32
#  23     17
#  14     12
#  12      8
#  13      7
#  11      5
#  6       3
#  24      1
# Name: Avg_Dist_Size_Biology, dtype: int64
# ***************************************************
#  18    131
#  19    108
# NaN     84
#  20     63
#  21     57
#  15     37
#  16     33
#  24     32
#  17     25
#  23     23
#  22     22
#  14     10
#  13      8
#  25      4
#  12      2
# Name: Avg_Dist_Size_EnglishII, dtype: int64
# ***************************************************
#  21    86
# NaN    84
#  22    76
#  19    74
#  24    67
#  23    64
#  20    38
#  18    37
#  17    31
#  16    27
#  25    24
#  15    12
#  14     9
#  26     6
#  12     2
#  13     1
#  7      1
# Name: Avg_Dist_Size_MathI, dtype: int64
# ***************************************************
# NaN    602
#  19     37
# Name: Avg_State_Size_00, dtype: int64
# ***************************************************
# NaN    602
#  19     37
# Name: Avg_State_Size_01, dtype: int64
# ***************************************************
# NaN    602
#  19     37
# Name: Avg_State_Size_02, dtype: int64
# ***************************************************
# NaN    603
#  19     36
# Name: Avg_State_Size_03, dtype: int64
# ***************************************************
# NaN    601
#  20     38
# Name: Avg_State_Size_04, dtype: int64
# ***************************************************
# NaN    599
#  21     40
# Name: Avg_State_Size_05, dtype: int64
# ***************************************************
# NaN    576
#  21     63
# Name: Avg_State_Size_06, dtype: int64
# ***************************************************
# NaN    568
#  22     71
# Name: Avg_State_Size_07, dtype: int64
# ***************************************************
# NaN    566
#  21     73
# Name: Avg_State_Size_08, dtype: int64
# ***************************************************
#  18    616
# NaN     23
# Name: Avg_State_Size_Biology, dtype: int64
# ***************************************************
#  18    616
# NaN     23
# Name: Avg_State_Size_EnglishII, dtype: int64
# ***************************************************
#  20    616
# NaN     23
# Name: Avg_State_Size_MathI, dtype: int64
# ***************************************************
# NaN          578
#  3124.31     2
#  1627.16     2
#  1313.65     2
#  4550.26     2
#  2417.40     2
#  1151.06     2
#  2163.09     1
#  2090.95     1
#  2058.81     1
#  1756.12     1
#  1526.74     1
#  1256.08     1
#  2467.21     1
#  2341.34     1
#  1518.55     1
#  1867.41     1
#  2355.33     1
#  2187.92     1
#  2045.87     1
#  1900.54     1
#  2203.00     1
#  1687.78     1
#  1899.77     1
#  1830.21     1
#  1844.00     1
#  2316.77     1
#  1920.94     1
#  2143.79     1
#  2134.17     1
#  1518.16     1
# Name: lea_local_perpupil_num, dtype: int64
# ***************************************************
# NaN          61
#  5227.10     32
#  5453.57     32
#  5349.09     29
#  5616.37     21
#  5413.29     16
#  5829.04     14
#  5200.55     12
#  5402.62     12
#  5602.21     11
#  5669.00     10
#  5218.56     10
#  5234.47     10
#  5611.71      9
#  5529.50      9
#  6171.58      9
#  6490.65      8
#  5458.65      8
#  6143.62      8
#  5682.81      8
#  5967.87      7
#  5247.34      7
#  5616.83      7
#  6119.80      7
#  5512.80      7
#  5756.15      7
#  5964.99      6
#  5652.12      6
#  6136.93      6
#  5501.99      6
#              ..
#  5773.92      2
#  8245.73      2
#  5759.60      2
#  7466.23      2
#  5686.20      2
#  8013.64      2
#  7812.03      1
#  8969.28      1
#  7965.69      1
#  5876.61      1
#  6040.59      1
#  7538.83      1
#  9321.89      1
#  6791.75      1
#  5866.05      1
#  8295.04      1
#  6063.47      1
#  6091.44      1
#  7439.17      1
#  7230.17      1
#  7981.70      1
#  8092.44      1
#  7031.52      1
#  6110.14      1
#  11739.76     1
#  5684.14      1
#  6518.66      1
#  7225.77      1
#  6390.95      1
#  8256.03      1
# Name: lea_state_perpupil_num, dtype: int64
# ***************************************************
# 8859.04    639
# Name: st_total_expense_num, dtype: int64
# ***************************************************
# 0.62    639
# Name: st_salary_expense_pct, dtype: int64
# ***************************************************
# 0.205    639
# Name: st_benefits_expense_pct, dtype: int64
# ***************************************************
# 0.09    639
# Name: st_services_expense_pct, dtype: int64
# ***************************************************
# 0.075    639
# Name: st_supplies_expense_pct, dtype: int64
# ***************************************************
# 0.01    639
# Name: st_instruct_equip_exp_pct, dtype: int64
# ***************************************************
# 0    639
# Name: st_other_expense_pct, dtype: int64
# ***************************************************
# 967.75    639
# Name: st_federal_perpupil_num, dtype: int64
# ***************************************************
# 2172.86    639
# Name: st_local_perpupil_num, dtype: int64
# ***************************************************
# 5718.43    639
# Name: st_state_perpupil_num, dtype: int64
# ***************************************************
# C       203
# B       169
# NaN     107
# A        61
# D        52
# A+NG     31
# F        11
# I         5
# Name: SPG Grade, dtype: int64
# ***************************************************
# NaN    112
#  64     19
#  69     19
#  72     18
#  75     17
#  70     16
#  59     16
#  86     16
#  66     16
#  67     16
#  74     15
#  81     15
#  62     14
#  60     14
#  77     14
#  68     14
#  78     13
#  61     13
#  73     12
#  65     12
#  55     11
#  63     11
#  85     10
#  87     10
#  56     10
#  91     10
#  58     10
#  51      9
#  76      9
#  54      9
#       ...
#  93      6
#  90      6
#  89      6
#  84      6
#  82      5
#  96      5
#  49      4
#  52      4
#  41       1
#  56       1
#  50       1
#  44       1
#  45       1
#  46       1
#  47       1
#  48       1
#  94       1
#  95       1
# Name: ACT WorkKeys Score, dtype: int64
# ***************************************************
#  100    385
# NaN     152
#  95      22
#  94      18
#  93      12
#  92      10
#  89       7
#  90       6
#  91       5
#  88       4
#  87       4
#  81       3
#  63       2
#  85       2
#  82       2
#  75       1
#  72       1
#  71       1
#  83       1
#  86       1
# Name: Math Course Rigor Score, dtype: int64
# ***************************************************
# NaN     152
#  100    120
#  90      35
#  87      32
#  92      27
#  91      27
#  89      23
#  85      23
#  88      21
#  83      20
#  93      19
#  84      18
#  81      16
#  95      16
#  94      15
#  82      13
#  80      13
#  86      12
#  78       6
#  77       5
#  76       4
#  75       4
#  74       4
#  79       3
#  67       3
#  72       2
#  66       2
#  71       1
#  69       1
#  52       1
#  36       1
# Name: Cohort Graduation Rate Standard Score, dtype: int64
# ***************************************************
# NaN    547
# N       56
# Y       36
# Name: State Gap Compared, dtype: int64
# ***************************************************
# NaN       586
#  0.000     16
#  1.000      5
#  0.234      2
#  0.091      2
#  0.098      1
#  0.156      1
#  0.101      1
#  0.146      1
#  0.014      1
#  0.227      1
#  0.123      1
#  0.009      1
#  0.375      1
#  0.500      1
#  0.250      1
#  0.198      1
#  0.059      1
#  0.042      1
#  0.208      1
#  0.111      1
#  0.095      1
#  0.167      1
#  0.036      1
#  0.444      1
#  0.833      1
#  0.168      1
#  0.017      1
#  0.179      1
#  0.253      1
#  0.143      1
#  0.263      1
#  0.182      1
# Name: GCE_ALL_School_Pct, dtype: int64
# ***************************************************
# NaN      638
#  0.95      1
# Name: GCE_LEP_School_Pct, dtype: int64
# ***************************************************
# NaN    639
# Name: GCE_PRM_School_Pct, dtype: int64
# ***************************************************
# NaN       629
#  0.221      1
#  0.187      1
#  0.325      1
#  0.234      1
#  0.132      1
#  0.119      1
#  0.219      1
#  0.121      1
#  0.070      1
#  0.227      1
# Name: GCE_RPF_School_Pct, dtype: int64
# ***************************************************
# NaN       636
#  0.067      1
#  0.208      1
#  0.125      1
# Name: GCE_SWD_School_Pct, dtype: int64
# ***************************************************
# NaN       601
#  0.762      2
#  0.667      2
#  0.909      2
#  0.790      1
#  0.860      1
#  0.876      1
#  0.718      1
#  0.935      1
#  0.474      1
#  0.872      1
#  0.844      1
#  0.714      1
#  0.681      1
#  0.500      1
#  0.250      1
#  0.750      1
#  0.375      1
#  0.510      1
#  0.710      1
#  0.654      1
#  0.386      1
#  0.575      1
#  0.865      1
#  0.477      1
#  0.475      1
#  0.882      1
#  0.550      1
#  0.708      1
#  0.698      1
#  0.792      1
#  0.705      1
#  0.521      1
#  0.821      1
#  0.736      1
#  0.752      1
# Name: PASSED_EOG_School_Pct, dtype: int64
# ***************************************************
# NaN       632
#  0.304      1
#  0.131      1
#  0.088      1
#  0.216      1
#  0.146      1
#  0.220      1
#  0.257      1
# Name: PASSED_LAA_School_Pct, dtype: int64
# ***************************************************
# NaN       638
#  0.104      1
# Name: PASSED_RTA_School_Pct, dtype: int64
# ***************************************************
# NaN       599
#  0.950     18
#  0.940      2
#  0.942      1
#  0.941      1
#  0.500      1
#  0.852      1
#  0.767      1
#  0.945      1
#  0.932      1
#  0.909      1
#  0.636      1
#  0.771      1
#  0.720      1
#  0.778      1
#  0.884      1
#  0.897      1
#  0.917      1
#  0.906      1
#  0.595      1
#  0.901      1
#  0.671      1
#  0.864      1
# Name: PROMOTED_School_Pct, dtype: int64
# ***************************************************
# NaN       628
#  0.148      1
#  0.280      1
#  0.222      1
#  0.099      1
#  0.103      1
#  0.229      1
#  0.233      1
#  0.405      1
#  0.116      1
#  0.329      1
#  0.500      1
# Name: RETAINED_School_Pct, dtype: int64
# ***************************************************
# NaN       623
#  0.238      2
#  0.112      2
#  0.143      1
#  0.160      1
#  0.068      1
#  0.168      1
#  0.204      1
#  0.095      1
#  0.139      1
#  0.258      1
#  0.103      1
#  0.121      1
#  0.149      1
#  0.125      1
# Name: GCE_ALL_Dist_Pct, dtype: int64
# ***************************************************
# NaN    639
# Name: GCE_LEP_Dist_Pct, dtype: int64
# ***************************************************
# NaN    639
# Name: GCE_PRM_Dist_Pct, dtype: int64
# ***************************************************
# NaN       630
#  0.104      2
#  0.071      1
#  0.150      1
#  0.084      1
#  0.204      1
#  0.055      1
#  0.098      1
#  0.070      1
# Name: GCE_RPF_Dist_Pct, dtype: int64
# ***************************************************
# NaN       626
#  0.104      3
#  0.075      2
#  0.101      2
#  0.103      2
#  0.085      1
#  0.063      1
#  0.086      1
#  0.052      1
# Name: GCE_SWD_Dist_Pct, dtype: int64
# ***************************************************
# NaN       623
#  0.542      2
#  0.659      2
#  0.559      1
#  0.605      1
#  0.529      1
#  0.532      1
#  0.486      1
#  0.692      1
#  0.576      1
#  0.485      1
#  0.598      1
#  0.578      1
#  0.685      1
#  0.500      1
# Name: PASSED_EOG_Dist_Pct, dtype: int64
# ***************************************************
# NaN       625
#  0.136      2
#  0.077      2
#  0.138      1
#  0.221      1
#  0.100      1
#  0.079      1
#  0.167      1
#  0.083      1
#  0.156      1
#  0.269      1
#  0.119      1
#  0.105      1
# Name: PASSED_LAA_Dist_Pct, dtype: int64
# ***************************************************
# NaN    639
# Name: PASSED_RTA_Dist_Pct, dtype: int64
# ***************************************************
# NaN       623
#  0.950      3
#  0.946      2
#  0.899      2
#  0.815      1
#  0.923      1
#  0.821      1
#  0.919      1
#  0.925      1
#  0.862      1
#  0.825      1
#  0.883      1
#  0.804      1
# Name: PROMOTED_Dist_Pct, dtype: int64
# ***************************************************
# NaN       626
#  0.054      2
#  0.101      2
#  0.081      1
#  0.138      1
#  0.179      1
#  0.075      1
#  0.185      1
#  0.175      1
#  0.117      1
#  0.196      1
#  0.077      1
# Name: RETAINED_Dist_Pct, dtype: int64
# ***************************************************
# NaN       586
#  0.112     53
# Name: GCE_ALL_State_Pct, dtype: int64
# ***************************************************
# NaN    639
# Name: GCE_LEP_State_Pct, dtype: int64
# ***************************************************
# NaN    639
# Name: GCE_PRM_State_Pct, dtype: int64
# ***************************************************
# NaN    639
# Name: GCE_RPF_State_Pct, dtype: int64
# ***************************************************
# NaN       586
#  0.065     53
# Name: GCE_SWD_State_Pct, dtype: int64
# ***************************************************
# NaN       586
#  0.579     53
# Name: PASSED_EOG_State_Pct, dtype: int64
# ***************************************************
# NaN      586
#  0.11     53
# Name: PASSED_LAA_State_Pct, dtype: int64
# ***************************************************
# NaN    639
# Name: PASSED_RTA_State_Pct, dtype: int64
# ***************************************************
# NaN       586
#  0.856     53
# Name: PROMOTED_State_Pct, dtype: int64
# ***************************************************
# NaN       586
#  0.144     53
# Name: RETAINED_State_Pct, dtype: int64
# ***************************************************
# NaN      100
#  983       7
#  1002      7
#  1026      6
#  953       5
#  963       5
#  990       5
#  1058      5
#  888       4
#  906       4
#  909       4
#  911       4
#  998       4
#  873       4
#  956       4
#  961       4
#  1075      4
#  966       4
#  971       4
#  980       4
#  1066      4
#  916       4
#  1023      4
#  1011      4
#  1015      3
#  1018      3
#  965       3
#  964       3
#  922       3
#  1008      3
#         ...
#  1209      1
#  1198      1
#  1189      1
#  1184      1
#  1175      1
#  1173      1
#  893       1
#  1169      1
#  1163      1
#  1160      1
#  935       1
#  1430      1
#  683       1
#  716       1
#  777       1
#  790       1
#  787       1
#  786       1
#  785       1
#  783       1
#  781       1
#  770       1
#  718       1
#  767       1
#  760       1
#  748       1
#  729       1
#  723       1
#  721       1
#  999       1
# Name: sat_avg_score_num, dtype: int64
# ***************************************************
# NaN      61
#  1001    43
#  982     38
#  1067    31
#  1003    21
#  952     20
#  1015    18
#  963     18
#  961     17
#  942     14
#  972     12
#  1051    12
#  945     12
#  861     12
#  1041    11
#  1013    11
#  1026    10
#  1037    10
#  950      9
#  1000     9
#  1007     9
#  1019     8
#  932      8
#  939      8
#  979      7
#  971      7
#  815      7
#  1062     7
#  928      6
#  941      6
#          ..
#  964      3
#  915      3
#  806      2
#  814      2
#  975      2
#  1010     2
#  1036     2
#  791      2
#  1008     2
#  819      2
#  906      2
#  854      2
#  949      1
#  1056     1
#  1029     1
#  956      1
#  936      1
#  925      1
#  896      1
#  1076     1
#  977      1
#  980      1
#  897      1
#  916      1
#  866      1
#  912      1
#  800      1
#  909      1
#  839      1
#  954      1
# Name: lea_sat_avg_score_num, dtype: int64
# ***************************************************
# 997    639
# Name: st_sat_avg_score_num, dtype: int64
# ***************************************************
# 1006    639
# Name: nat_sat_avg_score_num, dtype: int64
# ***************************************************
# NaN      102
#  0.42     19
#  0.52     17
#  0.38     16
#  0.33     14
#  0.47     14
#  0.48     14
#  0.45     14
#  0.34     13
#  0.46     12
#  0.53     12
#  0.54     11
#  0.65     11
#  0.41     11
#  0.56     11
#  0.43     11
#  0.55     10
#  0.58     10
#  0.37     10
#  0.35     10
#  0.30     10
#  0.27      9
#  0.57      9
#  0.36      9
#  0.28      9
#  0.31      8
#  0.40      8
#  0.62      8
#  0.44      8
#  0.60      7
#         ...
#  0.79      2
#  0.14      2
#  0.23      2
#  0.98      2
#  0.77      2
#  0.32      2
#  0.64      2
#  0.03      2
#  0.92      2
#  0.11      2
#  1.01      1
#  0.16      1
#  0.84      1
#  1.20      1
#  1.00      1
#  0.86      1
#  0.89      1
#  0.07      1
#  0.94      1
#  0.80      1
#  0.05      1
#  1.05      1
#  1.21      1
#  0.96      1
#  0.95      1
#  0.04      1
#  0.76      1
#  1.15      1
#  1.04      1
#  0.01      1
# Name: sat_participation_pct, dtype: int64
# ***************************************************
# ...
# 0.237    639
# Name: st_prin_black_pct, dtype: int64
# ***************************************************
# 0.737    639
# Name: st_prin_white_pct, dtype: int64
# ***************************************************
# 0.026    639
# Name: st_prin_other_pct, dtype: int64
# ***************************************************
# NaN       62
#  0.000    28
#  0.167    22
#  0.333    15
#  0.200    14
#  0.250    13
#  0.143    11
#  0.111     9
#  0.286     8
#  0.194     8
#  0.273     7
#  0.375     7
#  0.125     7
#  0.091     7
#  0.235     6
#  0.100     6
#  0.300     5
#  0.571     5
#  0.230     5
#  0.254     5
#  0.083     5
#  0.267     5
#  0.163     5
#  0.268     5
#  0.182     5
#  0.222     5
#  0.175     4
#  0.169     4
#  0.219     4
#  0.281     4
#           ..
#  0.406     1
#  0.354     1
#  0.165     1
#  0.450     1
#  0.099     1
#  0.833     1
#  0.244     1
#  0.444     1
#  0.600     1
#  0.221     1
#  0.087     1
#  0.151     1
#  0.045     1
#  0.379     1
#  0.162     1
#  0.128     1
#  0.190     1
#  0.419     1
#  0.088     1
#  0.421     1
#  0.065     1
#  0.170     1
#  0.067     1
#  0.358     1
#  0.565     1
#  0.291     1
#  0.341     1
#  0.409     1
#  0.106     1
#  0.324     1
# Name: Tch_Exp_Pct_0_3_Years, dtype: int64
# ***************************************************
# NaN       62
#  0.200    20
#  0.250    19
#  0.333    17
#  0.167    17
#  0.000    16
#  0.286    14
#  0.273    11
#  0.500     9
#  0.203     9
#  0.222     9
#  0.182     8
#  0.125     7
#  0.217     7
#  0.231     6
#  0.300     6
#  0.143     6
#  0.161     6
#  0.400     6
#  0.190     6
#  0.214     6
#  0.293     6
#  0.357     5
#  0.216     5
#  0.211     5
#  0.169     5
#  0.240     5
#  0.172     5
#  0.204     5
#  0.111     5
#           ..
#  0.071     1
#  0.407     1
#  0.155     1
#  0.462     1
#  0.327     1
#  0.378     1
#  0.409     1
#  0.245     1
#  0.038     1
#  0.229     1
#  0.082     1
#  0.274     1
#  0.346     1
#  0.087     1
#  0.136     1
#  0.141     1
#  0.348     1
#  0.202     1
#  0.146     1
#  0.255     1
#  0.158     1
#  0.132     1
#  0.220     1
#  0.284     1
#  0.600     1
#  0.219     1
#  0.171     1
#  0.818     1
#  0.120     1
#  0.252     1
# Name: Tch_Exp_Pct_4_10_Years, dtype: int64
# ***************************************************
# NaN       62
#  0.500    28
#  0.333    20
#  0.667    15
#  0.429    12
#  0.400    11
#  0.750     9
#  0.444     7
#  0.615     6
#  0.727     6
#  0.455     6
#  0.571     5
#  0.545     5
#  0.833     5
#  0.551     5
#  0.583     5
#  0.561     5
#  0.625     5
#  0.375     5
#  0.538     5
#  0.507     4
#  0.586     4
#  0.542     4
#  0.700     4
#  0.417     4
#  0.453     4
#  0.643     4
#  0.611     4
#  0.588     4
#  0.525     4
#           ..
#  0.650     1
#  0.414     1
#  0.624     1
#  0.647     1
#  0.442     1
#  0.409     1
#  0.520     1
#  0.714     1
#  0.617     1
#  1.000     1
#  0.611     1
#  0.542     1
#  0.769     1
#  0.577     1
#  0.400     1
#  0.900     1
#  0.565     1
#  0.786     1
#  0.455     1
#  0.688     1
#  0.857     1
#  0.551     1
#  0.800     1
#  0.758     1
#  0.606     1
#  0.679     1
#  0.839     1
#  0.649     1
#  0.453     1
#  0.700     1
#  0.273     1
# Name: Dist_Tch_Exp_Pct_10+_Years, dtype: int64
# ***************************************************
# 0.231    505
# 0.253     71
# 0.227     63
# Name: State_Tch_Exp_Pct_0_3_Years, dtype: int64
# ***************************************************
# 0.235    505
# 0.229     71
# 0.226     63
# Name: State_Tch_Exp_Pct_4_10_Years, dtype: int64
# ***************************************************
# 0.534    505
# 0.518     71
# 0.547     63
# Name: State_Tch_Exp_Pct_10+_Years, dtype: int64
# ***************************************************
#  0.333    64
# NaN       61
#  0.381    32
#  0.355    29
#  0.500    24
#  0.228    21
#  0.291    16
#  0.429    15
#  0.536    13
#  0.327    12
#  0.444    12
#  0.423    12
#  0.600    11
#  0.477    11
#  0.385    11
#  0.357    10
#  0.395    10
#  0.514    10
#  0.375    10
#  0.273     9
#  0.417     9
#  0.571     9
#  0.389     9
#  0.310     8
#  0.625     8
#  0.657     8
#  0.343     7
#  0.314     7
#  0.519     7
#  0.556     7
#           ..
#  0.667     6
#  0.565     6
#  0.348     6
#  0.364     5
#  0.474     5
#  0.526     5
#  0.360     5
#  0.409     5
#  0.480     5
#  0.438     5
#  0.464     5
#  0.706     5
#  0.435     4
#  0.200     4
#  0.300     4
#  0.471     4
#  0.368     4
#  0.563     4
#  0.929     4
#  0.529     4
#  0.111     4
#  0.294     4
#  0.583     3
#  0.308     3
#  0.800     3
#  0.714     2
#  0.167     2
#  0.125     2
#  0.875     1
#  0.900     1
# Name: Dist_Prin_Exp_Pct_0_3_Years, dtype: int64
# ***************************************************
# NaN       61
#  0.442    51
#  0.500    36
#  0.516    32
#  0.512    32
#  0.357    26
#  0.494    21
#  0.600    19
#  0.556    19
#  0.333    19
#  0.250    18
#  0.400    16
#  0.593    16
#  0.429    16
#  0.375    15
#  0.417    12
#  0.000    12
#  0.300    11
#  0.200    11
#  0.432    11
#  0.368    10
#  0.378    10
#  0.485     9
#  0.343     9
#  0.370     7
#  0.571     7
#  0.290     7
#  0.486     7
#  0.276     7
#  0.565     6
#  0.476     6
#  0.346     6
#  0.261     6
#  0.462     5
#  0.389     5
#  0.455     5
#  0.235     5
#  0.440     5
#  0.438     4
#  0.474     4
#  0.778     4
#  0.176     4
#  0.167     4
#  0.563     4
#  0.471     4
#  0.313     4
#  0.182     4
#  0.800     4
#  0.435     4
#  0.071     4
#  0.529     4
#  0.538     3
#  0.364     3
#  0.750     2
#  0.286     2
#  0.100     1
# Name: Dist_Prin_Exp_Pct_4_10_Years, dtype: int64
# ***************************************************
# NaN       61
#  0.107    45
#  0.000    42
#  0.111    38
#  0.151    32
#  0.203    29
#  0.278    21
#  0.091    19
#  0.116    16
#  0.071    13
#  0.143    12
#  0.073    12
#  0.063    12
#  0.135    12
#  0.167    11
#  0.040    11
#  0.056    10
#  0.100    10
#  0.108    10
#  0.163    10
#  0.286    10
#  0.083     9
#  0.059     9
#  0.242     9
#  0.086     9
#  0.158     9
#  0.250     9
#  0.190     8
#  0.154     8
#  0.310     8
#  0.171     7
#  0.222     7
#  0.257     7
#  0.034     7
#  0.097     7
#  0.333     6
#  0.125     6
#  0.095     6
#  0.087     6
#  0.269     6
#  0.200     6
#  0.174     6
#  0.182     5
#  0.105     5
#  0.313     5
#  0.080     5
#  0.188     4
#  0.176     4
#  0.294     4
#  0.130     4
#  0.300     4
#  0.273     4
#  0.444     3
#  0.667     1
# Name: Dist_Prin_Exp_Pct_10+_Years, dtype: int64
# ***************************************************
# 0.43    639
# Name: State_Prin_Exp_Pct_0_3_Years, dtype: int64
# ***************************************************
# 0.427    639
# Name: State_Prin_Exp_Pct_4_10_Years, dtype: int64
# ***************************************************
# 0.143    639
# Name: State_Prin_Exp_Pct_10+_Years, dtype: int64
# ***************************************************
# NaN    639
# Name: ACT_Composite_Score_UNC_Min, dtype: int64
# ***************************************************
# NaN    639
# Name: ACT_English_Benchmark, dtype: int64
# ***************************************************
# NaN    639
# Name: ACT_Math_Benchmark, dtype: int64
# ***************************************************
# NaN    639
# Name: ACT_Pct_of_Benchmarks_Met, dtype: int64
# ***************************************************
# NaN    639
# Name: ACT_Reading_Benchmark, dtype: int64
# ***************************************************
# NaN    639
# Name: ACT_Science_Benchmark, dtype: int64
# ***************************************************
# NaN    639
# Name: ACT_WorkKeys_Silver_Beyond, dtype: int64
# ***************************************************
# NaN    639
# Name: ACT_Writing_Benchmark, dtype: int64
# ***************************************************
# NaN    639
# Name: All_EOC_Subjects_CACR, dtype: int64
# ***************************************************
# NaN    639
# Name: All_EOC_Subjects_GLP, dtype: int64
# ***************************************************
# NaN    639
# Name: All_EOG_EOC_Subjects_CACR, dtype: int64
# ***************************************************
# NaN    639
# Name: All_EOG_EOC_Subjects_GLP, dtype: int64
# ***************************************************
# NaN    639
# Name: All_EOG_Subjects_CACR, dtype: int64
# ***************************************************
# NaN    639
# Name: All_EOG_Subjects_GLP, dtype: int64
# ***************************************************
# NaN    639
# Name: EOC_Biology_CACR, dtype: int64
# ***************************************************
# NaN    639
# Name: EOC_Biology_GLP, dtype: int64
# ***************************************************
# NaN    639
# Name: EOC_English_2_CACR, dtype: int64
# ***************************************************
# NaN    639
# Name: EOC_English_2_GLP, dtype: int64
# ***************************************************
# NaN    639
# Name: EOC_Math_I_CACR, dtype: int64
# ***************************************************
# NaN    639
# Name: EOC_Math_I_GLP, dtype: int64
# ***************************************************
# NaN    639
# Name: EOG_Gr3_CACR, dtype: int64
# ***************************************************
# NaN    639
# Name: EOG_Gr3_GLP, dtype: int64
# ***************************************************
# NaN    639
# Name: EOG_Gr4_CACR, dtype: int64
# ***************************************************
# NaN    639
# Name: EOG_Gr4_GLP, dtype: int64
# ***************************************************
# NaN    639
# Name: EOG_Gr5_CACR, dtype: int64
# ***************************************************
# NaN    639
# Name: EOG_Gr5_GLP, dtype: int64
# ***************************************************
# NaN    639
# Name: EOG_Gr6_CACR, dtype: int64
# ***************************************************
# NaN    639
# Name: EOG_Gr6_GLP, dtype: int64
# ***************************************************
# NaN    639
# Name: EOG_Gr7_CACR, dtype: int64
# ***************************************************
# NaN    639
# Name: EOG_Gr7_GLP, dtype: int64
# ***************************************************
# NaN    639
# Name: EOG_Gr8_CACR, dtype: int64
# ***************************************************
# NaN    639
# Name: EOG_Gr8_GLP, dtype: int64
# ***************************************************
# NaN    639
# Name: EOG_Math_Gr3_CACR, dtype: int64
# ***************************************************
# NaN    639
# Name: EOG_Math_Gr3_GLP, dtype: int64
# ***************************************************
# NaN    639
# Name: EOG_Math_Gr3-8_CACR, dtype: int64
# ***************************************************
# NaN    639
# Name: EOG_Math_Gr3-8_GLP, dtype: int64
# ***************************************************
# NaN    639
# Name: EOG_Math_Gr4_CACR, dtype: int64
# ***************************************************
# NaN    639
# Name: EOG_Math_Gr4_GLP, dtype: int64
# ***************************************************
# NaN    639
# Name: EOG_Math_Gr5_CACR, dtype: int64
# ***************************************************
# NaN    639
# Name: EOG_Math_Gr5_GLP, dtype: int64
# ***************************************************
# NaN    639
# Name: EOG_Math_Gr6_CACR, dtype: int64
# ***************************************************
# NaN    639
# Name: EOG_Math_Gr6_GLP, dtype: int64
# ***************************************************
# NaN    639
# Name: EOG_Math_Gr7_CACR, dtype: int64
# ***************************************************
# NaN    639
# Name: EOG_Math_Gr7_GLP, dtype: int64
# ***************************************************
# NaN    639
# Name: EOG_Math_Gr8_CACR, dtype: int64
# ***************************************************
# NaN    639
# Name: EOG_Math_Gr8_GLP, dtype: int64
# ***************************************************
# NaN    639
# Name: EOG_Reading_G3_GLP, dtype: int64
# ***************************************************
# NaN    639
# Name: EOG_Reading_Gr3_CACR, dtype: int64
# ***************************************************
# NaN    639
# Name: EOG_Reading_Gr4_CACR, dtype: int64
# ***************************************************
# NaN    639
# Name: EOG_Reading_Gr4_GLP, dtype: int64
# ***************************************************
# NaN    639
# Name: EOG_Reading_Gr5_CACR, dtype: int64
# ***************************************************
# NaN    639
# Name: EOG_Reading_Gr5_GLP, dtype: int64
# ***************************************************
# NaN    639
# Name: EOG_Reading_Gr6_CACR, dtype: int64
# ***************************************************
# NaN    639
# Name: EOG_Reading_Gr6_GLP, dtype: int64
# ***************************************************
# NaN    639
# Name: EOG_Reading_Gr7_CACR, dtype: int64
# ***************************************************
# NaN    639
# Name: EOG_Reading_Gr7_GLP, dtype: int64
# ***************************************************
# NaN    639
# Name: EOG_Reading_Gr8_CACR, dtype: int64
# ***************************************************
# NaN    639
# Name: EOG_Reading_Gr8_GLP, dtype: int64
# ***************************************************
# NaN    639
# Name: EOG_Reading_Grades_3_8_CACR, dtype: int64
# ***************************************************
# NaN    639
# Name: EOG_Reading_Grades_3_8_GLP, dtype: int64
# ***************************************************
# NaN    639
# Name: EOG_Science_Gr5_CACR, dtype: int64
# ***************************************************
# NaN    639
# Name: EOG_Science_Gr5_GLP, dtype: int64
# ***************************************************
# NaN    639
# Name: EOG_Science_Gr8_CACR, dtype: int64
# ***************************************************
# NaN    639
# Name: EOG_Science_Gr8_GLP, dtype: int64
# ***************************************************
# NaN    639
# Name: EOG_Science_Grades_5&8_CACR, dtype: int64
# ***************************************************
# NaN    639
# Name: EOG_Science_Grades_5&8_GLP, dtype: int64
# ***************************************************
# NaN    639
# Name: Graduation_Rate_5_Yr, dtype: int64
# ***************************************************
# NaN    639
# Name: Graduation_Rate4_Yr, dtype: int64
# ***************************************************
# NaN    639
# Name: Passing_Math_III, dtype: int64
# ***************************************************
