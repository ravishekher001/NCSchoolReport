# %% [markdown]
# ## MINI Project: LOGISTIC REGRESSION and SVM -- North Carolina Education Data Set
#
# ** Austin Hancock, Shravan Kuchkula, Kevin Okiah, Damarcus Thomas **

# %% [markdown]
# # Table of contents
# 1. [Introduction](#introduction)
# 2. [Data Meaning Type](#dataMeaningType)
#     - 2.1 [Data dictionary](#dataDict)
#     - 2.2 [Data quality](#dataQuality)
#         - 2.2.1 [Missing data statistics](#missingDataStatistics)
#         - 2.2.2 [Replace missing data](#replaceMissingData)
#     - 2.3 [New Features](#newFeatures)
# 3. [Pre-processing](#preprocessing)
#     - 3.1 [Remove high correlation](#removeCorrelation)
#     - 3.2 [Remove non-unique features](#noUniqueValues)
#     - 3.3 [Class distribution](#classDistribution)
#     - 3.4 [Create dummy variables](#dummyVariables)
# 4. [Section 1](#question1)
#     - 4.1 [Comparing Logistic Regression vs SVM](#logVSsvm)
#     - 4.2 [Tune Models](#tune)
#         - 4.2.1 [Approach1: Feature selection](#approach1)
#         - 4.2.2 [Approach2: Hyperparameterization](#approach2)
#         - 4.2.3 [Approach3: Stochastic Gradient Descent](#approach3)
#         - 4.2.4 [Summary](#approachSummary)
# 5. [Section 2](#question2)
# 6. [Section 3](#question3)
# 7. [Section 4](#question4)

# %% [markdown]
# ### Introduction <a class="anchor" id="introduction"></a>
# * For this project we'll be using the North Carolina Schools education data set. The data is a combination of multiple data tables publicly available by the North Carolina Department of Public Instruction (NCDPI) which is charged with implementing the state's public-school laws and the State Board of Education's policies and procedures governing pre-kindergarten through 12th grade public education. You can learn more about the data by visiting http://www.ncpublicschools.org/data/reports/
#
# * Our starting datasets [All_Data_By_School_Final] and [1516_Test_Scores] were taken from Dr. Drews GitHub where he combines multiple datasets from North Carolina Schools education data, preprocesses them and cleans for Machine learning. You can learn more on the data set from Dr. Drew's GitHub https://github.com/jakemdrew/EducationDataNC.
#
# * We performed Visualization on a subset of the data targeted for schools with `high schools`, which can be accessed from https://github.com/kevimwe/NC_EDUCATION_DATA/tree/master/NC_EDUC_Visualization_Data_Processing.

# %%
#ignore warnings
import warnings
warnings.filterwarnings("ignore")

#import required Libraries
import pandas as pd
import numpy as np

import os 
pd.set_option('display.max_colwidth', -1)
import requests
import io

# Import the stats library
from scipy import stats
import statsmodels.api as sm

# These are the plotting libraries we'll use:
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
plt.style.use("classic")
import seaborn as sns

#Machine learning
from sklearn import linear_model
from sklearn.cross_validation import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import accuracy_score


# Command for plots to appear in the iPython Notebook
# %matplotlib inline

wd = os.getcwd() #get working directory

#Read in raw data

url="https://raw.githubusercontent.com/kevimwe/NC_EDUCATION_DATA/master/NC_EDUC_Visualization_Data_Processing/data/All_Data_By_School_Final.csv"
s=requests.get(url).content

schoolData=pd.read_csv(io.StringIO(s.decode('utf-8')))

url="https://raw.githubusercontent.com/kevimwe/NC_EDUCATION_DATA/master/NC_EDUC_Visualization_Data_Processing/data/1516_Test_Scores.csv"
t=requests.get(url).content

testScores=pd.read_csv(io.StringIO(t.decode('utf-8')))

#Review raw data before the join
schoolData.info()

#join files using school / unit code
schoolData = schoolData.join(testScores, on='unit_code',how='left', lsuffix='_schoolData', rsuffix='_testScores')

schoolData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2579 entries, 0 to 2578
# Columns: 293 entries, Year to State_Prin_Exp_Pct_10+_Years
# dtypes: float64(255), int64(17), object(21)
# memory usage: 5.8+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2579 entries, 0 to 2578
# Columns: 305 entries, Year to Percent GLP
# dtypes: float64(262), int64(17), object(26)
# memory usage: 6.0+ MB

# %% [markdown]
# ### Data Meaning Type <a class="anchor" id="dataMeaningType"></a>

# %%
url = 'https://raw.githubusercontent.com/kevimwe/NC_EDUCATION_DATA/master/NC_EDUC_Visualization_Data_Processing/data/DataMeaningType.csv'

s=requests.get(url).content
pd.set_option('display.max_rows', 500) 
pd.set_option('display.max_colwidth', 150)
pd.read_csv(io.StringIO(s.decode('utf-8')))
# Out:
#                                           Attribute  \
# 0                                         unit_code
# 1                                       type_cd_txt
# 2                                       category_cd
# 3                                   school_type_txt
# 4                                 calendar_only_txt
# 5                                   title1_type_flg
# 6                                       clp_ind_flg
# 7                                     focus_clp_flg
# 8                                summer_program_flg
# 9                                    asm_no_spg_flg
# 10                                  no_data_spg_flg
# 11                                      esea_status
# 12                                      student_num
# 13                              lea_avg_student_num
# 14                               st_avg_student_num
# 15                              Grad_project_status
# 16                                         stem_flg
# 17                                Avg_Class_Size_00
# 18                                Avg_Class_Size_01
# 19                                Avg_Class_Size_02
# 20                                Avg_Class_Size_03
# 21                                Avg_Class_Size_04
# 22                                Avg_Class_Size_05
# 23                                Avg_Class_Size_06
# 24                                Avg_Class_Size_07
# 25                                Avg_Class_Size_08
# 26                           Avg_Class_Size_Biology
# 27                         Avg_Class_Size_EnglishII
# 28                             Avg_Class_Size_MathI
# 29                                 Avg_Dist_Size_00
# 30                                 Avg_Dist_Size_01
# 31                                 Avg_Dist_Size_02
# 32                                 Avg_Dist_Size_03
# 33                                 Avg_Dist_Size_04
# 34                                 Avg_Dist_Size_05
# 35                                 Avg_Dist_Size_06
# 36                                 Avg_Dist_Size_07
# 37                                 Avg_Dist_Size_08
# 38                            Avg_Dist_Size_Biology
# 39                          Avg_Dist_Size_EnglishII
# 40                              Avg_Dist_Size_MathI
# 41                                Avg_State_Size_00
# 42                                Avg_State_Size_01
# 43                                Avg_State_Size_02
# 44                                Avg_State_Size_03
# 45                                Avg_State_Size_04
# 46                                Avg_State_Size_05
# 47                                Avg_State_Size_06
# 48                                Avg_State_Size_07
# 49                                Avg_State_Size_08
# 50                           Avg_State_Size_Biology
# 51                         Avg_State_Size_EnglishII
# 52                             Avg_State_Size_MathI
# 53                                total_expense_num
# 54                               salary_expense_pct
# 55                             benefits_expense_pct
# 56                             services_expense_pct
# 57                             supplies_expense_pct
# 58                           instruct_equip_exp_pct
# 59                                other_expense_pct
# 60                             federal_perpupil_num
# 61                               local_perpupil_num
# 62                               state_perpupil_num
# 63                            lea_total_expense_num
# 64                           lea_salary_expense_pct
# 65                         lea_benefits_expense_pct
# 66                         lea_services_expense_pct
# 67                         lea_supplies_expense_pct
# 68                       lea_instruct_equip_exp_pct
# 69                            lea_other_expense_pct
# 70                         lea_federal_perpupil_num
# 71                           lea_local_perpupil_num
# 72                           lea_state_perpupil_num
# 73                             st_total_expense_num
# 74                            st_salary_expense_pct
# 75                          st_benefits_expense_pct
# 76                          st_services_expense_pct
# 77                          st_supplies_expense_pct
# 78                        st_instruct_equip_exp_pct
# 79                             st_other_expense_pct
# 80                          st_federal_perpupil_num
# 81                            st_local_perpupil_num
# 82                            st_state_perpupil_num
# 83                                        SPG Grade
# 84                                        SPG Score
# 85                                Reading SPG Grade
# 86                               Reading  SPG Score
# 87                                   Math SPG Grade
# 88                                   Math SPG Score
# 89                              EVAAS Growth Status
# 90                               EVAAS Growth Score
# 91                        Overall Achievement Score
# 92                                       Read Score
# 93                                       Math Score
# 94                                    Science Score
# 95                                     Math I Score
# 96                                 English II Score
# 97                                    Biology Score
# 98                                    The ACT Score
# 99                               ACT WorkKeys Score
# 100                         Math Course Rigor Score
# 101           Cohort Graduation Rate Standard Score
# 102                              State Gap Compared
# 103                              GCE_ALL_School_Pct
# 104                              GCE_LEP_School_Pct
# 105                              GCE_PRM_School_Pct
# 106                              GCE_RPF_School_Pct
# 107                              GCE_SWD_School_Pct
# 108                           PASSED_EOG_School_Pct
# 109                           PASSED_LAA_School_Pct
# 110                           PASSED_RTA_School_Pct
# 111                             PROMOTED_School_Pct
# 112                             RETAINED_School_Pct
# 113                                GCE_ALL_Dist_Pct
# 114                                GCE_LEP_Dist_Pct
# 115                                GCE_PRM_Dist_Pct
# 116                                GCE_RPF_Dist_Pct
# 117                                GCE_SWD_Dist_Pct
# 118                             PASSED_EOG_Dist_Pct
# 119                             PASSED_LAA_Dist_Pct
# 120                             PASSED_RTA_Dist_Pct
# 121                               PROMOTED_Dist_Pct
# 122                               RETAINED_Dist_Pct
# 123                               GCE_ALL_State_Pct
# 124                               GCE_LEP_State_Pct
# 125                               GCE_PRM_State_Pct
# 126                               GCE_RPF_State_Pct
# 127                               GCE_SWD_State_Pct
# 128                            PASSED_EOG_State_Pct
# 129                            PASSED_LAA_State_Pct
# 130                            PASSED_RTA_State_Pct
# 131                              PROMOTED_State_Pct
# 132                              RETAINED_State_Pct
# 133                               sat_avg_score_num
# 134                           lea_sat_avg_score_num
# 135                            st_sat_avg_score_num
# 136                           nat_sat_avg_score_num
# 137                           sat_participation_pct
# 138                       lea_sat_participation_pct
# 139                        st_sat_participation_pct
# 140                       nat_sat_participation_pct
# 141                                 esea_attendance
# 142                             lea_esea_attendance
# 143                            ap_participation_pct
# 144                        lea_ap_participation_pct
# 145                         st_ap_participation_pct
# 146                               ap_pct_3_or_above
# 147                           lea_ap_pct_3_or_above
# 148                            st_ap_pct_3_or_above
# 149                            ib_participation_pct
# 150                        lea_ib_participation_pct
# 151                         st_ib_participation_pct
# 152                               ib_pct_4_or_above
# 153                           lea_ib_pct_4_or_above
# 154                            st_ib_pct_4_or_above
# 155                              AP_Courses_Offered
# 156                       total_specialized_courses
# 157                                   ap_ib_courses
# 158                                     cte_courses
# 159                            univ_college_courses
# 160                   lea_total_specialized_courses
# 161                               lea_ap_ib_courses
# 162                                 lea_cte_courses
# 163                        lea_univ_college_courses
# 164                    st_total_specialized_courses
# 165                                st_ap_ib_courses
# 166                                  st_cte_courses
# 167                         st_univ_college_courses
# 168   sch_percent_college_enrolled_16_mos_post_grad
# 169  One_Yr_College_Complete_wi_2_yrs_Enrolled_2012
# 170                            avg_daily_attend_pct
# 171                                 crime_per_c_num
# 172                            short_susp_per_c_num
# 173                             long_susp_per_c_num
# 174                              expelled_per_c_num
# 175                                  ttl_crimes_num
# 176                          stud_internet_comp_num
# 177                        lea_avg_daily_attend_pct
# 178                             lea_crime_per_c_num
# 179                        lea_short_susp_per_c_num
# 180                         lea_long_susp_per_c_num
# 181                          lea_expelled_per_c_num
# 182                      lea_stud_internet_comp_num
# 183                         st_avg_daily_attend_pct
# 184                              st_crime_per_c_num
# 185                         st_short_susp_per_c_num
# 186                          st_long_susp_per_c_num
# 187                           st_expelled_per_c_num
# 188                       st_stud_internet_comp_num
# 189                               digital_media_pct
# 190                                            Byod
# 191                        avg_age_media_collection
# 192                                   1_to_1_access
# 193                               books_per_student
# 194                    lea_avg_age_media_collection
# 195                           lea_books_per_student
# 196                     st_avg_age_media_collection
# 197                            st_books_per_student
# 198                                         wap_num
# 199                               wap_per_classroom
# 200                                     lea_wap_num
# 201                           lea_wap_per_classroom
# 202                                      st_wap_num
# 203                            st_wap_per_classroom
# 204                                  prin_other_pct
# 205                              prinyrs_0thru3_pct
# 206                             prinyrs_4thru10_pct
# 207                              prinyrs_11plus_pct
# 208                            prin_advance_dgr_pct
# 209                            _1yr_prin_trnovr_pct
# 210                                   prin_male_pct
# 211                                 prin_female_pct
# 212                                  prin_black_pct
# 213                                  prin_white_pct
# 214                             flicensed_teach_pct
# 215                               tchyrs_0thru3_pct
# 216                              tchyrs_4thru10_pct
# 217                               tchyrs_11plus_pct
# 218                                 class_teach_num
# 219                                       nbpts_num
# 220                                 advance_dgr_pct
# 221                            _1yr_tchr_trnovr_pct
# 222                             emer_prov_teach_pct
# 223                               lateral_teach_pct
# 224                              highqual_class_pct
# 225                         lea_flicensed_teach_pct
# 226                           lea_tchyrs_0thru3_pct
# 227                          lea_tchyrs_4thru10_pct
# 228                           lea_tchyrs_11plus_pct
# 229                             lea_class_teach_num
# 230                                   lea_nbpts_num
# 231                             lea_advance_dgr_pct
# 232                         lea_1yr_tchr_trnovr_pct
# 233                         lea_emer_prov_teach_pct
# 234                           lea_lateral_teach_pct
# 235                          lea_highqual_class_pct
# 236                       lea_highqual_class_hp_pct
# 237                       lea_highqual_class_lp_pct
# 238                      lea_highqual_class_all_pct
# 239                   lea_not_highqual_class_hp_pct
# 240                   lea_not_highqual_class_lp_pct
# 241                  lea_not_highqual_class_all_pct
# 242                          st_flicensed_teach_pct
# 243                            st_tchyrs_0thru3_pct
# 244                           st_tchyrs_4thru10_pct
# 245                            st_tchyrs_11plus_pct
# 246                              st_class_teach_num
# 247                                    st_nbpts_num
# 248                              st_advance_dgr_pct
# 249                          st_1yr_tchr_trnovr_pct
# 250                          st_emer_prov_teach_pct
# 251                            st_lateral_teach_pct
# 252                           st_highqual_class_pct
# 253                        st_highqual_class_hp_pct
# 254                        st_highqual_class_lp_pct
# 255                       st_highqual_class_all_pct
# 256                    st_not_highqual_class_hp_pct
# 257                    st_not_highqual_class_lp_pct
# 258                   st_not_highqual_class_all_pct
# 259                           st_prinyrs_0thru3_pct
# 260                          st_prinyrs_4thru10_pct
# 261                           st_prinyrs_11plus_pct
# 262                         st_prin_advance_dgr_pct
# 263                          st_1yr_prin_trnovr_pct
# 264                                st_prin_male_pct
# 265                              st_prin_female_pct
# 266                               st_prin_black_pct
# 267                               st_prin_white_pct
# 268                               st_prin_other_pct
# 269                           Tch_Exp_Pct_0_3_Years
# 270                          Tch_Exp_Pct_4_10_Years
# 271                           Tch_Exp_Pct_10+_Years
# 272                      Dist_Tch_Exp_Pct_0_3_Years
# 273                     Dist_Tch_Exp_Pct_4_10_Years
# 274                      Dist_Tch_Exp_Pct_10+_Years
# 275                     State_Tch_Exp_Pct_0_3_Years
# 276                    State_Tch_Exp_Pct_4_10_Years
# 277                     State_Tch_Exp_Pct_10+_Years
# 278                     Dist_Prin_Exp_Pct_0_3_Years
# 279                    Dist_Prin_Exp_Pct_4_10_Years
# 280                     Dist_Prin_Exp_Pct_10+_Years
# 281                    State_Prin_Exp_Pct_0_3_Years
# 282                   State_Prin_Exp_Pct_4_10_Years
# 283                    State_Prin_Exp_Pct_10+_Years
# 284                                     School Code
# 285                                         Subject
# 286                                 Percent Level 1
# 287                                 Percent Level 2
# 288                                 Percent Level 3
# 289                                 Percent Level 4
# 290                                 Percent Level 5
# 291                                     Percent CCR
# 292                                     Percent GLP
# 293                                               A
# 294                                               E
# 295                                               H
# 296                                               I
# 297                                               M
# 298                                               T
#
#                                                                                                                                      Meaning  \
# 0                                                                                                          Code to identify School/LEA/State
# 1                                                                                                          Type of school (Chater or Public)
# 2                                                                                                   Category of School (E, M, H, I, T, or A)
# 3                                                                                                                 Description of School type
# 4                                                                                        Description of Calendar (Traditional or Year-Round)
# 5                                                                                                                             Title I Status
# 6                                                                                                         Consistently low performing school
# 7                                                                                                      Focus school designation based on CLP
# 8                                                                                  Summer school program included in Read to Achieve results
# 9                                                                               No School Performance Grade due to alternative school status
# 10                                                                                           No School Performance Grade due to lack of data
# 11                                                      Elementry and Secondary Education Act (ESEA) status (Non_Esea, Esea_Pass, Esea_Fail)
# 12                                                                                                          Number of students at the school
# 13                                                         Average number of students within the Local Education Agency (LEA) a.k.a District
# 14                                                                                               Average number of students within the state
# 15                                                                                                             A graduation project required
# 16                                                                                                               The school is a STEM school
# 17                                                                                                         Average Class Size PK (by school)
# 18                                                                                                 Average Class Size 1st grade  (by school)
# 19                                                                                                 Average Class Size 2nd grade  (by school)
# 20                                                                                                 Average Class Size 3rd grade  (by school)
# 21                                                                                                  Average Class Size 4th grade (by school)
# 22                                                                                                  Average Class Size 5th grade (by school)
# 23                                                                                                  Average Class Size 6th grade (by school)
# 24                                                                                                  Average Class Size 7th grade (by school)
# 25                                                                                                  Average Class Size 8th grade (by school)
# 26                                                                                                 Average Class Size Highschool (by school)
# 27                                                                                                 Average Class Size Highschool (by school)
# 28                                                                                                 Average Class Size Highschool (by school)
# 29                                                                                                       Average Class Size PK (by district)
# 30                                                                                               Average Class Size 1st grade  (by district)
# 31                                                                                               Average Class Size 2nd grade  (by district)
# 32                                                                                               Average Class Size 3rd grade  (by district)
# 33                                                                                                Average Class Size 4th grade (by district)
# 34                                                                                                Average Class Size 5th grade (by district)
# 35                                                                                                Average Class Size 6th grade (by district)
# 36                                                                                                Average Class Size 7th grade (by district)
# 37                                                                                                Average Class Size 8th grade (by district)
# 38                                                                                               Average Class Size Highschool (by district)
# 39                                                                                               Average Class Size Highschool (by district)
# 40                                                                                               Average Class Size Highschool (by district)
# 41                                                                                                             Average Class Size PK (state)
# 42                                                                                                     Average Class Size 1st grade  (state)
# 43                                                                                                      Average Class Size 2nd grade (state)
# 44                                                                                                      Average Class Size 3rd grade (state)
# 45                                                                                                      Average Class Size 4th grade (state)
# 46                                                                                                       Average Class Size 5th grade(state)
# 47                                                                                                      Average Class Size 6th grade (state)
# 48                                                                                                      Average Class Size 7th grade (state)
# 49                                                                                                      Average Class Size 8th grade (state)
# 50                                                                                                     Average Class Size Highschool (state)
# 51                                                                                                     Average Class Size Highschool (state)
# 52                                                                                                     Average Class Size Highschool (state)
# 53                                                                                                             Dollars spent at school level
# 54                                                                                      Percent of dollars spent on salaries at school level
# 55                                                                                      Percent of dollars spent on benefits at school level
# 56                                                                                      Percent of dollars spent on services at school level
# 57                                                                                      Percent of dollars spent on supplies at school level
# 58                                                                       Percent of dollars spent on instructional equipment at school level
# 59                                                                                Percent of dollars spent on other expenses at school level
# 60                                                                                                 Federal expsnse per pupil at school level
# 61                                                                                                   Local expense per pupil at school level
# 62                                                                                                   State expense per pupil at school level
# 63                                                                                                           Dollars spent at district level
# 64                                                                                    Percent of dollars spent on salaries at district level
# 65                                                                                    Percent of dollars spent on benefits at district level
# 66                                                                                    Percent of dollars spent on services at district level
# 67                                                                                    Percent of dollars spent on supplies at district level
# 68                                                                     Percent of dollars spent on instructional equipment at district level
# 69                                                                              Percent of dollars spent on other expenses at district level
# 70                                                                                               Federal expsnse per pupil at district level
# 71                                                                                                 Local expense per pupil at district level
# 72                                                                                                 State expense per pupil at district level
# 73                                                                                                              Dollars spent at state level
# 74                                                                                       Percent of dollars spent on salaries at state level
# 75                                                                                       Percent of dollars spent on benefits at state level
# 76                                                                                       Percent of dollars spent on services at state level
# 77                                                                                       Percent of dollars spent on supplies at state level
# 78                                                                        Percent of dollars spent on instructional equipment at state level
# 79                                                                                 Percent of dollars spent on other expenses at state level
# 80                                                                                                  Federal expsnse per pupil at state level
# 81                                                                                                    Local expense per pupil at state level
# 82                                                                                                    State expense per pupil at state level
# 83                                                                                                                  School performance grade
# 84                                                                                                            School performance grade score
# 85                                                                                                                         Reading SPG Grade
# 86                                                                                                                         Reading SPG Score
# 87                                                                                                                            Math SPG Grade
# 88                                                                                                                            Math SPG Score
# 89                                                                                    Education Value-Added Assessment System. Growth status
# 90                                                                                                                              Growth score
# 91                                                                                                                 Overall Achievement Score
# 92                                                                                                                             Reading Score
# 93                                                                                                                                Math Score
# 94                                                                                                                             Science Score
# 95                                                                                                                              Math I Score
# 96                                                                                                                          English II Score
# 97                                                                                                                             Biology Score
# 98                                                                                                                                 ACT score
# 99                                                                                                                        ACT WorkKeys Score
# 100                                                                                                                  Math Course Rigor Score
# 101                                                                                                 Graduation Rate Standard Score of Cohort
# 102                                                                                                                       State Gap Compared
# 103                                           Percentage of Third Grade Students Passed with Good Cause Exemption by School (All categories)
# 104                               Percentage of Third Grade Students Passed with Good Cause Exemption Limited English Proficiency by School
# 105                                       Percentage of Third Grade Students Passed with Good Cause Exemption Previously Retained by School
# 106                           Percentage of Third Grade Students with Good Cause Exemption Proficient through a Reading Portfolio by School
# 107                                Percentage of Third Grade Students Passed with Good Cause Exemption Students with Disabilities by School
# 108                                                     Percentage of Third Grade Students Passed BOG3 and/or Grade 3 Reading EOG by School
# 109                                                         Percentage of Third Grade Students Passed Local Alternative Assesment by School
# 110                                                    Percentage of Third Grade Students Passed State Read to Achieve Assessment by School
# 111                                                                   Percentage of Third Grade Students Promoted to Fourth Grade by School
# 112                                                                    Percentage of Third Grade Students Retained in Third Grade by School
# 113                                         Percentage of Third Grade Students Passed with Good Cause Exemption by District (All categories)
# 114                             Percentage of Third Grade Students Passed with Good Cause Exemption Limited English Proficiency by District
# 115                                     Percentage of Third Grade Students Passed with Good Cause Exemption Previously Retained by District
# 116                         Percentage of Third Grade Students with Good Cause Exemption Proficient through a Reading Portfolio by District
# 117                              Percentage of Third Grade Students Passed with Good Cause Exemption Students with Disabilities by District
# 118                                                   Percentage of Third Grade Students Passed BOG3 and/or Grade 3 Reading EOG by District
# 119                                                       Percentage of Third Grade Students Passed Local Alternative Assesment by District
# 120                                                  Percentage of Third Grade Students Passed State Read to Achieve Assessment by District
# 121                                                                 Percentage of Third Grade Students Promoted to Fourth Grade by District
# 122                                                                  Percentage of Third Grade Students Retained in Third Grade by District
# 123                                            Percentage of Third Grade Students Passed with Good Cause Exemption by State (All categories)
# 124                                Percentage of Third Grade Students Passed with Good Cause Exemption Limited English Proficiency by State
# 125                                        Percentage of Third Grade Students Passed with Good Cause Exemption Previously Retained by State
# 126                            Percentage of Third Grade Students with Good Cause Exemption Proficient through a Reading Portfolio by State
# 127                                 Percentage of Third Grade Students Passed with Good Cause Exemption Students with Disabilities by State
# 128                                                      Percentage of Third Grade Students Passed BOG3 and/or Grade 3 Reading EOG by State
# 129                                                          Percentage of Third Grade Students Passed Local Alternative Assesment by State
# 130                                                     Percentage of Third Grade Students Passed State Read to Achieve Assessment by State
# 131                                                                    Percentage of Third Grade Students Promoted to Fourth Grade by State
# 132                                                                     Percentage of Third Grade Students Retained in Third Grade by State
# 133                                                                                       Average SAT score (Reading + Math) at School Level
# 134                                                                                     Average SAT score (Reading + Math) at District Level
# 135                                                                                         Average SAT score (Reading + Math) at Sate Level
# 136                                                                                     Average SAT score (Reading + Math) at National Level
# 137                                                                         Percentage of High School Seniors taking the SAT at School Level
# 138                                                                       Percentage of High School Seniors taking the SAT at District Level
# 139                                                                          Percentage of High School Seniors taking the SAT at State Level
# 140                                                                       Percentage of High School Seniors taking the SAT at National Level
# 141                                                                                    Met ESEA attendance requirement at the district level
# 142                                                                                      Met ESEA attendance requirement at the school level
# 143                                                                 Percentage of High School Students taking an AP exam at the school level
# 144                                                               Percentage of High School Students taking an AP exam at the district level
# 145                                                                  Percentage of High School Students taking an AP exam at the state level
# 146                                                                     Percentage of AP Exams with scores of 3 or above at the school level
# 147                                                                   Percentage of AP Exams with scores of 3 or above at the district level
# 148                                                                      Percentage of AP Exams with scores of 3 or above at the state level
# 149                                                                 Percentage of High School Students taking an IB exam at the school level
# 150                                                               Percentage of High School Students taking an IB exam at the district level
# 151                                                                  Percentage of High School Students taking an IB exam at the state level
# 152                                                                     Percentage of IB Exams with scores of 4 or above at the school level
# 153                                                                   Percentage of IB Exams with scores of 4 or above at the district level
# 154                                                                      Percentage of IB Exams with scores of 4 or above at the state level
# 155                                                                                              Count of AP courses offered at School level
# 156                                                      Percent of students enrolled in at least one specialized course at the school level
# 157                                                         Percent of students enrolled in at least one AP or IB course at the school level
# 158                             Percent of students enrolled in at least one career and Technical Education (CTE) course at the school level
# 159                    Percent of students enrolled in at least one academic course at a community college or university at the school level
# 160                                                    Percent of students enrolled in at least one specialized course at the district level
# 161                                                       Percent of students enrolled in at least one AP or IB course at the district level
# 162                           Percent of students enrolled in at least one career and Technical Education (CTE) course at the district level
# 163                  Percent of students enrolled in at least one academic course at a community college or university at the district level
# 164                                                       Percent of students enrolled in at least one specialized course at the state level
# 165                                                          Percent of students enrolled in at least one AP or IB course at the state level
# 166                              Percent of students enrolled in at least one career and Technical Education (CTE) course at the state level
# 167                     Percent of students enrolled in at least one academic course at a community college or university at the state level
# 168                                                           Enrolled in an IHE within 16 months of receiving a regular high school diploma
# 169  Percentage of students that completed at least one year's worth of credit within two years of enrollment in the IHE at the school level
# 170                                                                                  Average daily attendance percentage at the school level
# 171                                                                                    Number of crimes per 100 students at the school level
# 172                                                                              Short term suspensions per 100 students at the school level
# 173                                                                               Long term suspensions per 100 students at the school level
# 174                                                                                          Expulsions per 100 students at the school level
# 175                                                                                                                   Total number of crimes
# 176                                                                     Ratio of students to internet connected computer at the school level
# 177                                                                                Average daily attendance percentage at the district level
# 178                                                                                  Number of crimes per 100 students at the district level
# 179                                                                            Short term suspensions per 100 students at the district level
# 180                                                                             Long term suspensions per 100 students at the district level
# 181                                                                                        Expulsions per 100 students at the district level
# 182                                                                   Ratio of students to internet connected computer at the district level
# 183                                                                                   Average daily attendance percentage at the state level
# 184                                                                                     Number of crimes per 100 students at the state level
# 185                                                                               Short term suspensions per 100 students at the state level
# 186                                                                                Long term suspensions per 100 students at the state level
# 187                                                                                           Expulsions per 100 students at the state level
# 188                                                                      Ratio of students to internet connected computer at the state level
# 189                                                                                                                 Percent of digital media
# 190                                                                                                                    Bring your own device
# 191                                                                                          Average age of media collection at school level
# 192                                                                                                               Devices provided by school
# 193                                                                                                        Books per student at school level
# 194                                                                                        Average age of media collection at district level
# 195                                                                                                      Books per student at district level
# 196                                                                                           Average age of media collection at state level
# 197                                                                                                         Books per student at state level
# 198                                                                    Number of Wireless Application Protocol devices total at school level
# 199                                                            Number of Wireless Application Protocol devices per classroom at school level
# 200                                                                  Number of Wireless Application Protocol devices total at district level
# 201                                                          Number of Wireless Application Protocol devices per classroom at district level
# 202                                                                     Number of Wireless Application Protocol devices total at state level
# 203                                                             Number of Wireless Application Protocol devices per classroom at state level
# 204                                                                                   Percent of principals of other races at District level
# 205                                                                                    Percent of principals with 0 to 3 years of experience
# 206                                                                                   Percent of principals with 4 to 10 years of experience
# 207                                                                                   Percent of principals with 11 plus years of experience
# 208                                                                             Percent of principals with advanced degrees at Distric level
# 209                                                                                   One year principal turnover rate at the District level
# 210                                                                                             Percent of male principals at District level
# 211                                                                                            Percent of female principals at Distric level
# 212                                                                                             Percent of black principals at Distric level
# 213                                                                                             Percent of white principals at Distric level
# 214                                                               Percent of teachers that meet NC fully licensed definition at school level
# 215                                                                      Percent of teachers with 0 to 3 years of experience at school level
# 216                                                                     Percent of teachers with 4 to 10 years of experience at school level
# ...
# 220                                                                        Percent of teachers with masters or higher degree at school level
# 221                                                                                     One Year Teacher turnover percentage at school level
# 222                                                                                Percent of emergency provisional teachesr at school level
# 223                                                                                         Lateral entry teacher percentage at school level
# 224                                                                                      Percent of highly qualified classes at school level
# 225                                                             Percent of teachers that meet NC fully licensed definition at district level
# 226                                                                    Percent of teachers with 0 to 3 years of experience at district level
# 227                                                                   Percent of teachers with 4 to 10 years of experience at district level
# 228                                                                   Percent of teachers with 11 plus years of experience at district level
# 229                                                                                   Average number of classroom teachers at district level
# 230                                                                               Number of National Board Certified Staff at district level
# 231                                                                      Percent of teachers with masters or higher degree at district level
# 232                                                                                   One Year Teacher turnover percentage at district level
# 233                                                                              Percent of emergency provisional teachesr at district level
# 234                                                                                       Lateral entry teacher percentage at district level
# 235                                                                                    Percent of highly qualified classes at district level
# 236                                        Percent of classes taught by highly qualified teachers in high poeverty schools at district level
# 237                                         Percent of classes taught by highly qualified teachers in low poeverty schools at district level
# 238                                                  Percent of classes taught by highly qualified teachers in all schools at district level
# 239                                    Percent of classes not taught by highly qualified teachers in high poeverty schools at district level
# 240                                     Percent of classes not taught by highly qualified teachers in low poeverty schools at district level
# 241                                              Percent of classes not taught by highly qualified teachers in all schools at district level
# 242                                                                Percent of teachers that meet NC fully licensed definition at state level
# 243                                                                       Percent of teachers with 0 to 3 years of experience at state level
# 244                                                                      Percent of teachers with 4 to 10 years of experience at state level
# 245                                                                      Percent of teachers with 11 plus years of experience at state level
# 246                                                                                      Average number of classroom teachers at state level
# 247                                                                                  Number of National Board Certified Staff at state level
# 248                                                                         Percent of teachers with masters or higher degree at state level
# 249                                                                                      One Year Teacher turnover percentage at state level
# 250                                                                                 Percent of emergency provisional teachers at state level
# 251                                                                                          Lateral entry teacher percentage at state level
# 252                                                                                       Percent of highly qualified classes at state level
# 253                                           Percent of classes taught by highly qualified teachers in high poeverty schools at state level
# 254                                            Percent of classes taught by highly qualified teachers in low poeverty schools at state level
# 255                                                     Percent of classes taught by highly qualified teachers in all schools at state level
# 256                                       Percent of classes not taught by highly qualified teachers in high poeverty schools at state level
# 257                                        Percent of classes not taught by highly qualified teachers in low poeverty schools at state level
# 258                                                 Percent of classes not taught by highly qualified teachers in all schools at state level
# 259                                                                     Percent of principals with 0 to 3 years of experience at state level
# 260                                                                    Percent of principals with 4 to 10 years of experience at state level
# 261                                                                    Percent of principals with 11 plus years of experience at state level
# 262                                                                               Percent of principals with advanced degrees at State level
# 263                                                                                      One year principal turnover rate at the State level
# 264                                                                                                Percent of male principals at State level
# 265                                                                                              Percent of female principals at State level
# 266                                                                                               Percent of black principals at State level
# 267                                                                                               Percent of white principals at State level
# 268                                                                                      Percent of principals of other races at State level
# 269                                                                   Percentage of teachers at a given experience level at the school level
# 270                                                                   Percentage of teachers at a given experience level at the school level
# 271                                                                   Percentage of teachers at a given experience level at the school level
# 272                                                                 Percentage of teachers at a given experience level at the district level
# 273                                                                 Percentage of teachers at a given experience level at the district level
# 274                                                                 Percentage of teachers at a given experience level at the district level
# 275                                                                    Percentage of teachers at a given experience level at the state level
# 276                                                                    Percentage of teachers at a given experience level at the state level
# 277                                                                    Percentage of teachers at a given experience level at the state level
# 278                                                               Percentage of principlas at a given experience level at the district level
# 279                                                               Percentage of principlas at a given experience level at the district level
# 280                                                               Percentage of principlas at a given experience level at the district level
# 281                                                                  Percentage of principlas at a given experience level at the state level
# 282                                                                  Percentage of principlas at a given experience level at the state level
# 283                                                                  Percentage of principlas at a given experience level at the state level
# 284                                                                                                                              School Code
# 285                                                                                                                                  Subject
# 286                                                                                                                       Percent at level 1
# 287                                                                                                                       Percent at level 2
# 288                                                                                                                       Percent at level 3
# 289                                                                                                                       Percent at level 4
# 290                                                                                                                       Percent at level 5
# 291                                                                                                                              Percent CCR
# 292                                                                                                                              Percent GLP
# 293                                                                                    School has elementary, middle, and high school grades
# 294                                                                                              School has elementary schools grades (PK-5)
# 295                                                                                                    School has high schools grades (9-13)
# 296                                                                                   Schools with elementary, middle and high school grades
# 297                                                                                                   School has middle schools grades (6-8)
# 298                                                                                                 School has middle and high school grades
#
#         Type
# 0     Object
# 1     Object
# 2     Object
# 3     Object
# 4     object
# 5       bool
# 6       bool
# 7       bool
# 8       bool
# 9       bool
# 10      bool
# 11    object
# 12   float64
# 13   float64
# 14     int64
# 15      bool
# 16      bool
# 17   float64
# 18   float64
# 19   float64
# 20   float64
# 21   float64
# 22   float64
# 23   float64
# 24   float64
# 25   float64
# 26   float64
# 27   float64
# 28   float64
# 29   float64
# 30   float64
# 31   float64
# 32   float64
# 33   float64
# 34   float64
# 35   float64
# 36   float64
# 37   float64
# 38   float64
# 39   float64
# 40   float64
# 41   float64
# 42   float64
# 43   float64
# 44   float64
# 45   float64
# 46   float64
# 47   float64
# 48   float64
# 49   float64
# 50   float64
# 51   float64
# 52   float64
# 53   float64
# 54   float64
# 55   float64
# 56   float64
# 57   float64
# 58   float64
# 59   float64
# 60   float64
# 61   float64
# 62   float64
# 63   float64
# 64   float64
# 65   float64
# 66   float64
# 67   float64
# 68   float64
# 69   float64
# 70   float64
# 71   float64
# 72   float64
# 73   float64
# 74   float64
# 75   float64
# 76   float64
# 77   float64
# 78   float64
# 79   float64
# 80   float64
# 81   float64
# 82   float64
# 83    Object
# 84   float64
# 85    Object
# 86   float64
# 87    Object
# 88   float64
# 89    Object
# 90   float64
# 91   float64
# 92   float64
# 93   float64
# 94   float64
# 95   float64
# 96   float64
# 97   float64
# 98   float64
# 99   float64
# 100  float64
# 101  float64
# 102   Object
# 103  float64
# 104  float64
# 105  float64
# 106  float64
# 107  float64
# 108  float64
# 109  float64
# 110  float64
# 111  float64
# 112  float64
# 113  float64
# 114  float64
# 115  float64
# 116  float64
# 117  float64
# 118  float64
# 119  float64
# 120  float64
# 121  float64
# 122  float64
# 123  float64
# 124  float64
# 125  float64
# 126  float64
# 127  float64
# 128  float64
# 129  float64
# 130  float64
# 131  float64
# 132  float64
# 133  float64
# 134  float64
# 135    int64
# 136    int64
# 137  float64
# 138  float64
# 139  float64
# 140  float64
# 141  float64
# 142  float64
# 143  float64
# 144  float64
# 145  float64
# 146  float64
# 147  float64
# 148  float64
# 149  float64
# 150  float64
# 151  float64
# 152  float64
# 153  float64
# 154  float64
# 155  float64
# 156  float64
# 157  float64
# 158  float64
# 159  float64
# 160  float64
# 161  float64
# 162  float64
# 163  float64
# 164  float64
# 165  float64
# 166  float64
# 167  float64
# 168  float64
# 169  float64
# 170  float64
# 171  float64
# 172  float64
# 173  float64
# 174  float64
# 175  float64
# 176  float64
# 177  float64
# 178  float64
# 179  float64
# 180  float64
# 181  float64
# 182  float64
# 183  float64
# 184  float64
# 185  float64
# 186  float64
# 187    int64
# 188  float64
# 189  float64
# 190   Object
# 191  float64
# 192   Object
# 193  float64
# 194  float64
# 195  float64
# 196  float64
# 197  float64
# 198  float64
# 199  float64
# 200  float64
# 201  float64
# 202    int64
# 203  float64
# 204  float64
# 205  float64
# 206  float64
# 207  float64
# 208  float64
# 209  float64
# 210  float64
# 211  float64
# 212  float64
# 213  float64
# 214  float64
# 215  float64
# 216  float64
# 217  float64
# 218  float64
# 219  float64
# 220  float64
# 221  float64
# 222  float64
# 223  float64
# 224  float64
# 225  float64
# 226  float64
# 227  float64
# 228  float64
# 229  float64
# 230  float64
# 231  float64
# 232  float64
# 233  float64
# 234  float64
# 235  float64
# 236  float64
# 237  float64
# 238  float64
# 239  float64
# 240  float64
# 241  float64
# 242  float64
# 243  float64
# 244  float64
# 245  float64
# 246    int64
# 247    int64
# 248  float64
# 249  float64
# 250  float64
# 251  float64
# 252  float64
# 253  float64
# 254  float64
# 255  float64
# 256  float64
# 257  float64
# 258  float64
# 259  float64
# 260  float64
# 261  float64
# 262  float64
# 263  float64
# 264  float64
# 265  float64
# 266  float64
# 267  float64
# 268  float64
# 269  float64
# 270  float64
# 271  float64
# 272  float64
# 273  float64
# 274  float64
# 275  float64
# 276  float64
# 277  float64
# 278  float64
# 279  float64
# 280  float64
# 281  float64
# 282  float64
# 283  float64
# 284  float64
# 285  float64
# 286  float64
# 287  float64
# 288  float64
# 289  float64
# 290  float64
# 291  float64
# 292  float64
# 293   Object
# 294   Object
# 295   Object
# 296   Object
# 297   Object
# 298   Object

# %% [markdown]
# #### Data Dictionary <a class="anchor" id="dataDict"></a>
# > Since this dataset has numerous columns we needed a fast way to quickly find column name descriptions for easy reference. For exceptional work, we created a function to quickly pull the data from a csv data file. This involved converting the pdf document to an excel spreadsheet and formatting the data so that we could easily import into pandas. The code below is a working code for our data dictionary.

# %%
DataDict=pd.read_csv(io.StringIO(s.decode('utf-8')))

DataDict.head()
#DataDict = DataDict.columns['COLUMN_NAME', 'DESCRIPTION']
def get_ColDescription(colname = 'Year'):
    colName = input("Enter column name to check description in Dictionary. You can enter multiple columns separated by comma: ")
    
    print('You entered: ', colName.strip())
    temp = pd.DataFrame()
    colNames = colName.split(',')
    
    try:
        for i in range(0,len(colNames)):
            get = (DataDict[DataDict.Attribute==colNames[i].strip().lower()])
            temp = temp.append(get)
        return(temp)
    except Exception as e:
        print(e.args) 

get_ColDescription()
# Out:
# Enter column name to check description in Dictionary. You can enter multiple columns separated by comma:
# You entered:
# Empty DataFrame
# Columns: [Attribute, Meaning, Type]
# Index: []

# %% [markdown]
# ### Data Quality <a class="anchor" id="dataQuality"></a>

# %% [markdown]
# ##### *Missing Data Statistics* <a class="anchor" id="missingDataStatistics"></a>
#
# > In this section we explore missing data in the highschool data set that was created from the original North Carolina data set. After exploring the missing data we will discuss the approach for handling them below.

# %%
schoolData['title1_type_flg'] = schoolData['title1_type_flg'].map({-1:True, 0:False})
schoolData['clp_ind_flg'] = schoolData['clp_ind_flg'].map({-1:True, 0:False})
schoolData['focus_clp_flg'] = schoolData['focus_clp_flg'].map({-1:True, 0:False})
schoolData['summer_program_flg'] = schoolData['summer_program_flg'].map({-1:True, 0:False})
schoolData['asm_no_spg_flg'] = schoolData['asm_no_spg_flg'].map({-1:True, 0:False})
schoolData['no_data_spg_flg'] = schoolData['no_data_spg_flg'].map({-1:True, 0:False})
schoolData['stem_flg'] = schoolData['stem_flg'].map({-1:True, 0:False})
schoolData = schoolData.drop(['street_ad'],axis=1)

# %% [markdown]
# >We are dropping `street_ad` because it does not contribute to the prediction accuracy.

# %%
#Check for missing values
Temp = pd.DataFrame(schoolData.isnull().sum())
#print(Temp)
Temp.columns =['DataMissing']
#Columns with at least 1 missing value
MissingCount = Temp[Temp.DataMissing>0]

#sort 
MissingCount = MissingCount.sort_values('DataMissing',ascending=False)
#basic stats on missing data
print("##################################################")
print("###", '             Stats on missing data        ',  "###")
print("##################################################")
print('No. of rows in schoolData: ',len(schoolData))
print('No. of Columns in schoolData: ',len(schoolData.columns))
print('No. of Columns with Missing data: ',len(MissingCount))
print('No.  of Complete data columns: ', len(schoolData.columns) - len(MissingCount))
print('No. of Columns with 100% missing Values: ',sum(1 for item in MissingCount.DataMissing if item==len(schoolData)))
print('No. of Columns with more than 95% missing Values: ',sum(1 for item in MissingCount.DataMissing if item>=0.95*len(schoolData)))
print('% of Columns with some Missing data: ',round(float(100*len(MissingCount))/len(schoolData.columns),3),'%')
print('% of Columns with 100% Missing data: ',round(float(100*sum(1 for item in MissingCount.DataMissing if item==len(schoolData)))/len(schoolData.columns),3),'%')
print('% of Columns with more than 95% Missing data: ',round(float(100*sum(1 for item in MissingCount.DataMissing if item>=0.95*len(schoolData)))/len(schoolData.columns),3),'%')

print(" ")
print("##################################################")
print("###",'       Columns with >95% missing data     ',    "###")
print("##################################################")
#add a columnName for Bar charts plot
MissingCount['ColumnName'] = MissingCount.index
MissingCount['Missing %'] = 100*(MissingCount.DataMissing/len(schoolData))
MissingCount = MissingCount.reset_index()
del MissingCount['index']
print((MissingCount.head(50)))
# Out:
# ##################################################
# ###              Stats on missing data         ###
# ##################################################
# No of rows in schoolData:  2579
# No of Columns in schoolData:  304
# No. of Columns with Missing data:  228
# No  of Complete data columns:  76
# No. of Columns with 100% missing Values:  32
# No. of Columns more than 95% missing Values:  39
# % of Columns with some Missing data:  75.0 %
# % of Columns with 100% Missing data:  10.526 %
# % of Columns with more than 95% Missing data:  12.829 %
#
# ##################################################
# ###        Columns with >95% missing data      ###
# ##################################################
#     DataMissing                ColumnName   Missing %
# 0          2579               Percent GLP  100.000000
# 1          2579            prin_other_pct  100.000000
# 2          2579           Percent Level 5  100.000000
# 3          2579         GCE_RPF_State_Pct  100.000000
# 4          2579           Percent Level 3  100.000000
# 5          2579           Percent Level 2  100.000000
# 6          2579           Percent Level 1  100.000000
# 7          2579                   Subject  100.000000
# 8          2579              SBE District  100.000000
# 9          2579               School Name  100.000000
# 10         2579               School Code  100.000000
# 11         2579             District Name  100.000000
# 12         2579   st_ib_participation_pct  100.000000
# 13         2579  lea_ib_participation_pct  100.000000
# 14         2579       lea_esea_attendance  100.000000
# 15         2579          GCE_PRM_Dist_Pct  100.000000
# 16         2579           esea_attendance  100.000000
# 17         2579      PASSED_RTA_State_Pct  100.000000
# 18         2579         GCE_LEP_State_Pct  100.000000
# 19         2579            ttl_crimes_num  100.000000
# 20         2579           Percent Level 4  100.000000
# 21         2579        prinyrs_0thru3_pct  100.000000
# 22         2579       prinyrs_4thru10_pct  100.000000
# 23         2579               Percent CCR  100.000000
# 24         2579            prin_white_pct  100.000000
# 25         2579            prin_black_pct  100.000000
# 26         2579           prin_female_pct  100.000000
# 27         2579             prin_male_pct  100.000000
# 28         2579      _1yr_prin_trnovr_pct  100.000000
# 29         2579      prin_advance_dgr_pct  100.000000
# 30         2579        prinyrs_11plus_pct  100.000000
# 31         2579         GCE_PRM_State_Pct  100.000000
# 32         2574        GCE_PRM_School_Pct   99.806126
# 33         2572      ib_participation_pct   99.728577
# 34         2570        GCE_LEP_School_Pct   99.651028
# 35         2568          GCE_LEP_Dist_Pct   99.573478
# 36         2553     PASSED_RTA_School_Pct   98.991857
# 37         2549         ib_pct_4_or_above   98.836758
# 38         2534       PASSED_RTA_Dist_Pct   98.255138
# 39         2426        State Gap Compared   94.067468
# 40         2419        state_perpupil_num   93.796045
# 41         2419    instruct_equip_exp_pct   93.796045
# 42         2419        local_perpupil_num   93.796045
# 43         2419      federal_perpupil_num   93.796045
# 44         2419         other_expense_pct   93.796045
# 45         2419      benefits_expense_pct   93.796045
# 46         2419      supplies_expense_pct   93.796045
# 47         2419      services_expense_pct   93.796045
# 48         2419        salary_expense_pct   93.796045
# 49         2419         total_expense_num   93.796045

# %% [markdown]
# > From above we note, of the 304 columns in SchoolData, 228 (74.8%) of them have some missing data. 32(10.5%) of columns have all the data missing where 39 (12.8%) of the columns miss more than 95% of the data. For columns with 100% missing data we are left but to wonder if these were new fields introduced recently and the schools have not collected it. On the other hand, for the partially completed datasets, some schools might have left these columns blank, if it wasn't applicable.
#
# > For the sake of this analysis we will drop the columns that have `>95` missing data rather than try to complete the missing data with either mean, median, mode, or various regression and prediction techniques to reduce bias.

# %%
#All columns from Original schoolData
AllColumns =schoolData.columns 

# All columns with some missing value
ColumnsWithMissingdata = MissingCount.ColumnName 

#columns with more than 95% missing data
Columns2Drop = MissingCount.ColumnName.head(39) 

#columns with missing values that are kept
Columns2Keep = MissingCount.ColumnName.tail(len(MissingCount)-99) 

#All the other columns except those with >95% missing data
SelectedColumns = list(set(AllColumns)-set(Columns2Drop)) 

#new dataset, columns with >95% missing data dropped

schoolDataNew = schoolData[SelectedColumns]

#drop the key column. 
del schoolDataNew['unit_code']

print("##################################################")
print("###", '          Orginal Highschooldata info     ',  "###")
print("##################################################")
print(schoolData.info())
print("##################################################")
print("###", '  Columns with >95 data missing   dropped ',  "###")
print("##################################################")
print(schoolDataNew.info())
schoolDataNew.head(5)
# Out:
# ##################################################
# ###           Orginal Highschooldata info      ###
# ##################################################
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2579 entries, 0 to 2578
# Columns: 304 entries, Year to Percent GLP
# dtypes: bool(7), float64(262), int64(10), object(25)
# memory usage: 5.9+ MB
# None
# ##################################################
# ###   Columns with >95 data missing   dropped  ###
# ##################################################
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2579 entries, 0 to 2578
# Columns: 264 entries, expelled_per_c_num to st_not_highqual_class_lp_pct
# dtypes: bool(7), float64(228), int64(10), object(19)
# memory usage: 5.1+ MB
# None
#    expelled_per_c_num  Avg_Class_Size_01  flicensed_teach_pct  Math SPG Score  \
# 0                 0.0               18.0                0.893             NaN
# 1                 0.0                NaN                0.800             NaN
# 2                 0.0                NaN                1.000             NaN
# 3                 0.0               19.0                0.958             NaN
# 4                 0.0               18.0                1.000             NaN
#
#    st_class_teach_num  st_local_perpupil_num  Avg_Dist_Size_01  \
# 0                  36                2172.86               NaN
# 1                  32                2172.86               NaN
# 2                  54                2172.86               NaN
# 3                  34                2172.86              18.0
# 4                  34                2172.86              18.0
#
#    Math Course Rigor Score  PROMOTED_State_Pct  st_lateral_teach_pct  \
# 0                      NaN               0.856                 0.068
# 1                      NaN               0.856                 0.046
# 2                      NaN                 NaN                 0.092
# 3                      NaN               0.856                 0.015
# 4                      NaN               0.856                 0.015
#
#                ...               long_susp_per_c_num  st_emer_prov_teach_pct  \
# 0              ...                               0.0                   0.003
# 1              ...                               0.0                   0.003
# 2              ...                               0.0                   0.003
# 3              ...                               0.0                   0.004
# 4              ...                               0.0                   0.004
#
#    st_total_expense_num  ap_pct_3_or_above Byod  st_1yr_tchr_trnovr_pct  \
# 0               8859.04               0.64  NaN                   0.157
# 1               8859.04                NaN  NaN                   0.127
# 2               8859.04                NaN  NaN                   0.148
# 3               8859.04                NaN   No                   0.134
# 4               8859.04                NaN   No                   0.134
#
#   nat_sat_avg_score_num  Dist_Prin_Exp_Pct_4_10_Years  \
# 0                  1006                           NaN
# 1                  1006                           NaN
# 2                  1006                         0.417
# 3                  1006                         0.417
# 4                  1006                         0.417
#
#    State_Prin_Exp_Pct_10+_Years  st_not_highqual_class_lp_pct
# 0                         0.143                         0.024
# 1                         0.143                         0.024
# 2                         0.143                         0.024
# 3                         0.143                         0.024
# 4                         0.143                         0.024
#
# [5 rows x 264 columns]

# %% [markdown]
# > In the code block above, we dropped 38 columns which had >95% of the data missing. We also deleted the unit_code column which is key to identifying the school/Lea/state attributes.

# %%
#Exploring the columns with missing dataset that are retained
df = schoolDataNew
temp_df = df.copy() 
print("##################################################")
temp  = df.select_dtypes(include=['int','float'])
temp2  = df.select_dtypes(include=['object', 'bool'])
print("#      Columns with continuous data (int, float) #")
print("##################################################")
temp.info()
print(" ")
print("##########################################")
print("#     Columns with Categorical data      #")
print("##########################################")
temp2.info()
print(" ")
print("Total # of columns: ",len(schoolDataNew.columns))
# Out:
# ##################################################
# #      Columns with continious data (int, float) #
# ##################################################
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2579 entries, 0 to 2578
# Columns: 238 entries, expelled_per_c_num to st_not_highqual_class_lp_pct
# dtypes: float64(228), int64(10)
# memory usage: 4.7 MB
#
# ##########################################
# #     Columns with Categorical data      #
# ##########################################
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2579 entries, 0 to 2578
# Data columns (total 26 columns):
# stem_flg                2579 non-null bool
# 1_to_1_access           2313 non-null object
# school_type_txt         2579 non-null object
# esea_status             201 non-null object
# type_cd_txt             2579 non-null object
# grades_1_to_1_access    2313 non-null object
# SPG Grade               2364 non-null object
# Grad_project_status     597 non-null object
# title1_type_flg         2579 non-null bool
# grades_BYOD             2313 non-null object
# summer_program_flg      2579 non-null bool
# Closed_Ind_Text         2579 non-null object
# asm_no_spg_flg          2579 non-null bool
# Math SPG Grade          1870 non-null object
# focus_clp_flg           2579 non-null bool
# New_ind_Txt             2579 non-null object
# EVAAS Growth Status     2312 non-null object
# category_cd             2579 non-null object
# Reading SPG Grade       1870 non-null object
# calendar_only_txt       2578 non-null object
# state_ad                2579 non-null object
# no_data_spg_flg         2579 non-null bool
# scity_ad                2579 non-null object
# clp_ind_flg             2579 non-null bool
# State Gap Compared      153 non-null object
# Byod                    2313 non-null object
# dtypes: bool(7), object(19)
# memory usage: 400.5+ KB
#
# Total # of columns:  264

# %% [markdown]
# > In the code block above we explored the columns with missing data that we retained. We grouped the columns into two groups based on data type, there were two different approaches for replacing the missing data;
# 1. #### Columns with continuous data types (ints and floats)
# Of the 129 columns retained with missing data, 120 are of dtype float64. After reviewing individual columns description from the data dictionary, we chose to replace these missing float types with median. We didn't go with mean simply because with existence of outliers, mean would be screwed compared to median.
# 2. #### Columns with categorical data types (objects and bool)
# For the 9 categorical columns, we will be replacing the missing values with mode.

# %% [markdown]
# ### Replace missing data <a class="anchor" id="replaceMissingData"></a>

# %%
#this function replaces NA's for columns with continuous 'Con' (int or float) variables with median and categorical 'Cat' variable(bool or object) with mode
def ReplaceMissingdata(df = schoolDataNew):
    temp_df = df.copy() 
    print("#######################################")
    print("## continuous and categorical columns ##")
    print("#######################################")
    temp  = df.select_dtypes(include=['int64','float'])    #continuous values columns
    columnnames = temp.columns
    temp1  = df.select_dtypes(include=['object','bool']) #categorical values columns
    columnnames1 = temp1.columns
    print(" ")
    
    print("##############################")
    print("## NA count Before Cleaning ##")
    print("##############################")
    print(df.isnull().sum())
    #replacing missing continuous values with median
    for i in range(0,len(columnnames)):
        try:
            temp_array =temp[temp[columnnames[i]]!=np.nan][columnnames[i]] #temp array of non NAs for continuous values to calculate median
            # replace NAs with median for continuous variables created from above arrays
            temp_df[columnnames[i]] =temp_df[columnnames[i]].replace(np.nan,temp_array.median())     
        except Exception as e:
            print(e.args) 
            
    #replacing missing categorical values with mode
    for i in range(0,len(columnnames1)):
        try:
            temp_array1 =temp1[temp1[columnnames1[i]]!=np.nan][columnnames1[i]] #temp array of non NAs for categorical values to calculate mode
            # replace NAs with median for categorical values created from above arrays with mode
            temp_df[columnnames1[i]] =temp_df[columnnames1[i]].replace(np.nan,str(temp_array1.mode()[0]))      
        except Exception as e:
            print(e.args)

    print("##############################")
    print("## NA Count After Cleaning  ##")
    print("##############################")
    print(temp_df.isnull().sum())
    df = temp_df
    return df

new_schooldata = ReplaceMissingdata(schoolDataNew)    

new_schooldata.info()
# Out:
# #######################################
# ## continous and categorical columns ##
# #######################################
#
# ##############################
# ## NA count Before Cleaning ##
# ##############################
# expelled_per_c_num                                   7
# Avg_Class_Size_01                                 1192
# flicensed_teach_pct                                  2
# Math SPG Score                                     709
# st_class_teach_num                                   0
# st_local_perpupil_num                                0
# Avg_Dist_Size_01                                  1302
# Math Course Rigor Score                           2092
# PROMOTED_State_Pct                                1120
# st_lateral_teach_pct                                 0
# Reading  SPG Score                                 709
# lea_univ_college_courses                          2044
# Tch_Exp_Pct_0_3_Years                              162
# total_specialized_courses                         1971
# stem_flg                                             0
# emer_prov_teach_pct                               2250
# 1_to_1_access                                      266
# st_highqual_class_lp_pct                             0
# lea_ap_participation_pct                           422
# lea_highqual_class_pct                             165
# Read Score                                         709
# Dist_Tch_Exp_Pct_0_3_Years                         160
# school_type_txt                                      0
# Overall Achievement Score                          256
# lea_not_highqual_class_hp_pct                      245
# Avg_State_Size_00                                 1185
# st_advance_dgr_pct                                   0
# Tch_Exp_Pct_4_10_Years                             162
# RETAINED_School_Pct                               1926
# esea_status                                       2378
# st_1yr_prin_trnovr_pct                               0
# type_cd_txt                                          0
# st_avg_student_num                                   0
# st_salary_expense_pct                                0
# grades_1_to_1_access                               266
# stud_internet_comp_num                             120
# st_short_susp_per_c_num                              0
# st_ap_pct_3_or_above                                 0
# st_expelled_per_c_num                                0
# st_prin_male_pct                                     0
# st_cte_courses                                    1971
# st_state_perpupil_num                                0
# lea_ib_pct_4_or_above                             1530
# lea_flicensed_teach_pct                            160
# PASSED_EOG_State_Pct                              1120
# wap_per_classroom                                  103
# Avg_Class_Size_02                                 1191
# Avg_Dist_Size_Biology                             1540
# lea_cte_courses                                   2036
# total_expense_num                                 2419
# SPG Grade                                          215
# lea_highqual_class_lp_pct                          399
# Grad_project_status                               1982
# st_long_susp_per_c_num                               0
# lea_highqual_class_all_pct                         160
# highqual_class_pct                                  15
# Dist_Tch_Exp_Pct_4_10_Years                        160
# title1_type_flg                                      0
# st_services_expense_pct                              0
# Avg_Dist_Size_EnglishII                           1540
# sch_percent_college_enrolled_16_mos_post_grad     2034
# lateral_teach_pct                                 1179
# Avg_State_Size_07                                 1915
# st_highqual_class_all_pct                            0
# Avg_Class_Size_03                                 1196
# Avg_Class_Size_04                                 1176
# lea_books_per_student                              359
# Avg_State_Size_MathI                              1434
# State_Tch_Exp_Pct_4_10_Years                         0
# other_expense_pct                                 2419
# supplies_expense_pct                              2419
# GCE_RPF_Dist_Pct                                  2131
# GCE_SWD_Dist_Pct                                  1593
# Avg_Class_Size_Biology                            1984
# GCE_ALL_Dist_Pct                                  1248
# Avg_Dist_Size_05                                  1317
# sat_avg_score_num                                 2040
# books_per_student                                  269
# univ_college_courses                              2154
# Avg_State_Size_06                                 1880
# st_books_per_student                               266
# st_highqual_class_pct                                0
# nat_sat_participation_pct                            0
# State_Prin_Exp_Pct_4_10_Years                        0
# lea_sat_avg_score_num                              160
# lea_total_expense_num                              160
# class_teach_num                                      2
# EVAAS Growth Score                                 267
# State_Tch_Exp_Pct_0_3_Years                          0
# PASSED_EOG_School_Pct                             1168
# st_univ_college_courses                           1971
# st_not_highqual_class_hp_pct                         0
# lea_1yr_tchr_trnovr_pct                            160
# Avg_Class_Size_EnglishII                          1983
# Science Score                                      797
# st_other_expense_pct                                 0
# lea_instruct_equip_exp_pct                         160
# Math Score                                         709
# GCE_SWD_State_Pct                                 1120
# tchyrs_11plus_pct                                  162
# lea_avg_age_media_collection                       314
# Avg_State_Size_EnglishII                          1434
# Avg_Dist_Size_03                                  1304
# SPG Score                                          256
# st_ap_participation_pct                              0
# Avg_Class_Size_05                                 1206
# grades_BYOD                                        266
# summer_program_flg                                   0
# benefits_expense_pct                              2419
# Cohort Graduation Rate Standard Score             2092
# st_prinyrs_4thru10_pct                               0
# cte_courses                                       2013
# lea_benefits_expense_pct                           160
# lea_long_susp_per_c_num                            162
# GCE_ALL_State_Pct                                 1120
# lea_stud_internet_comp_num                         160
# st_wap_per_classroom                                 0
# instruct_equip_exp_pct                            2419
# lea_wap_num                                        160
# st_benefits_expense_pct                              0
# short_susp_per_c_num                                 7
# st_ib_pct_4_or_above                                 0
# szip_ad                                              0
# services_expense_pct                              2419
# lea_local_perpupil_num                             160
# lea_tchyrs_0thru3_pct                              160
# Closed_Ind_Text                                      0
# Avg_Dist_Size_02                                  1302
# salary_expense_pct                                2419
# tchyrs_4thru10_pct                                 162
# lea_ap_pct_3_or_above                              179
# wap_num                                            103
# ap_ib_courses                                     2148
# lea_avg_student_num                                162
# lea_highqual_class_hp_pct                          245
# student_num                                          8
# Avg_Class_Size_00                                 1185
# Biology Score                                     2068
# nbpts_num                                          360
# local_perpupil_num                                2419
# lea_federal_perpupil_num                           160
# English II Score                                  2072
# federal_perpupil_num                              2419
# st_stud_internet_comp_num                            0
# GCE_ALL_School_Pct                                1120
# PASSED_LAA_State_Pct                              1120
# lea_salary_expense_pct                             160
# asm_no_spg_flg                                       0
# RETAINED_Dist_Pct                                 1337
# Avg_State_Size_05                                 1206
# st_supplies_expense_pct                              0
# State_Tch_Exp_Pct_10+_Years                          0
# st_prinyrs_11plus_pct                                0
# Avg_Class_Size_06                                 1880
# lea_not_highqual_class_all_pct                     160
# st_flicensed_teach_pct                               0
# Math SPG Grade                                     709
# State_Prin_Exp_Pct_0_3_Years                         0
# avg_daily_attend_pct                                 7
# lea_tchyrs_4thru10_pct                             160
# st_instruct_equip_exp_pct                            0
# ap_participation_pct                              2203
# st_prin_other_pct                                    0
# Avg_Class_Size_07                                 1915
# focus_clp_flg                                        0
# Avg_State_Size_04                                 1176
# st_federal_perpupil_num                              0
# st_nbpts_num                                         0
# Avg_Dist_Size_07                                  2020
# Avg_State_Size_Biology                            1434
# lea_short_susp_per_c_num                           162
# st_tchyrs_11plus_pct                                 0
# st_not_highqual_class_all_pct                        0
# st_prin_advance_dgr_pct                              0
# st_avg_daily_attend_pct                              0
# Avg_Dist_Size_06                                  1991
# Avg_State_Size_08                                 1922
# Math I Score                                      1561
# New_ind_Txt                                          0
# PROMOTED_School_Pct                               1143
# EVAAS Growth Status                                267
# Avg_State_Size_03                                 1196
# st_prin_black_pct                                    0
# lea_services_expense_pct                           160
# Avg_Dist_Size_04                                  1289
# category_cd                                          0
# lea_lateral_teach_pct                              384
# lea_nbpts_num                                      192
# lea_not_highqual_class_lp_pct                      399
# GCE_SWD_School_Pct                                2333
# The ACT Score                                     2077
# Dist_Tch_Exp_Pct_10+_Years                         160
# st_prinyrs_0thru3_pct                                0
# lea_emer_prov_teach_pct                           1139
# st_sat_avg_score_num                                 0
# lea_class_teach_num                                160
# Dist_Prin_Exp_Pct_10+_Years                        160
# st_crime_per_c_num                                   0
# Avg_State_Size_01                                 1192
# st_tchyrs_4thru10_pct                                0
# st_sat_participation_pct                             0
# sat_participation_pct                             2042
# st_prin_female_pct                                   0
# Avg_Dist_Size_08                                  2020
# avg_age_media_collection                           266
# crime_per_c_num                                      7
# _1yr_tchr_trnovr_pct                               171
# Reading SPG Grade                                  709
# lea_crime_per_c_num                                162
# st_ap_ib_courses                                  1971
# PASSED_EOG_Dist_Pct                               1248
# PASSED_LAA_Dist_Pct                               1360
# RETAINED_State_Pct                                1120
# lea_avg_daily_attend_pct                           160
# Dist_Prin_Exp_Pct_0_3_Years                        160
# lea_ap_ib_courses                                 2041
# Avg_Class_Size_08                                 1922
# lea_wap_per_classroom                              160
# ACT WorkKeys Score                                2203
# st_wap_num                                           0
# calendar_only_txt                                    1
# PROMOTED_Dist_Pct                                 1248
# st_avg_age_media_collection                        266
# advance_dgr_pct                                    162
# lea_advance_dgr_pct                                160
# lea_tchyrs_11plus_pct                              160
# st_tchyrs_0thru3_pct                                 0
# st_prin_white_pct                                    0
# tchyrs_0thru3_pct                                  162
# GCE_RPF_School_Pct                                2410
# PASSED_LAA_School_Pct                             2031
# lea_state_perpupil_num                             160
# Avg_Class_Size_MathI                              1455
# One_Yr_College_Complete_wi_2_yrs_Enrolled_2012    2034
# Avg_State_Size_02                                 1191
# lea_supplies_expense_pct                           160
# lea_expelled_per_c_num                             162
# Avg_Dist_Size_00                                  1299
# digital_media_pct                                  271
# Avg_Dist_Size_MathI                               1540
# state_ad                                             0
# no_data_spg_flg                                      0
# lea_total_specialized_courses                     2036
# Year                                                 0
# Tch_Exp_Pct_10+_Years                              162
# scity_ad                                             0
# lea_sat_participation_pct                          160
# lea_other_expense_pct                              160
# st_highqual_class_hp_pct                             0
# clp_ind_flg                                          0
# st_total_specialized_courses                      1971
# AP_Courses_Offered                                2226
# State Gap Compared                                2426
# state_perpupil_num                                2419
# long_susp_per_c_num                                  7
# st_emer_prov_teach_pct                               0
# st_total_expense_num                                 0
# ap_pct_3_or_above                                 2145
# Byod                                               266
# st_1yr_tchr_trnovr_pct                               0
# nat_sat_avg_score_num                                0
# Dist_Prin_Exp_Pct_4_10_Years                       160
# State_Prin_Exp_Pct_10+_Years                         0
# st_not_highqual_class_lp_pct                         0
# dtype: int64
# ##############################
# ## NA Count After Cleaning  ##
# ##############################
# expelled_per_c_num                                0
# Avg_Class_Size_01                                 0
# flicensed_teach_pct                               0
# Math SPG Score                                    0
# st_class_teach_num                                0
# st_local_perpupil_num                             0
# Avg_Dist_Size_01                                  0
# Math Course Rigor Score                           0
# PROMOTED_State_Pct                                0
# st_lateral_teach_pct                              0
# Reading  SPG Score                                0
# lea_univ_college_courses                          0
# Tch_Exp_Pct_0_3_Years                             0
# total_specialized_courses                         0
# stem_flg                                          0
# emer_prov_teach_pct                               0
# 1_to_1_access                                     0
# st_highqual_class_lp_pct                          0
# lea_ap_participation_pct                          0
# lea_highqual_class_pct                            0
# Read Score                                        0
# Dist_Tch_Exp_Pct_0_3_Years                        0
# school_type_txt                                   0
# Overall Achievement Score                         0
# lea_not_highqual_class_hp_pct                     0
# Avg_State_Size_00                                 0
# st_advance_dgr_pct                                0
# Tch_Exp_Pct_4_10_Years                            0
# RETAINED_School_Pct                               0
# esea_status                                       0
# st_1yr_prin_trnovr_pct                            0
# type_cd_txt                                       0
# st_avg_student_num                                0
# st_salary_expense_pct                             0
# grades_1_to_1_access                              0
# stud_internet_comp_num                            0
# st_short_susp_per_c_num                           0
# st_ap_pct_3_or_above                              0
# st_expelled_per_c_num                             0
# st_prin_male_pct                                  0
# st_cte_courses                                    0
# st_state_perpupil_num                             0
# lea_ib_pct_4_or_above                             0
# lea_flicensed_teach_pct                           0
# PASSED_EOG_State_Pct                              0
# wap_per_classroom                                 0
# Avg_Class_Size_02                                 0
# Avg_Dist_Size_Biology                             0
# lea_cte_courses                                   0
# total_expense_num                                 0
# SPG Grade                                         0
# lea_highqual_class_lp_pct                         0
# Grad_project_status                               0
# st_long_susp_per_c_num                            0
# lea_highqual_class_all_pct                        0
# highqual_class_pct                                0
# Dist_Tch_Exp_Pct_4_10_Years                       0
# title1_type_flg                                   0
# st_services_expense_pct                           0
# Avg_Dist_Size_EnglishII                           0
# sch_percent_college_enrolled_16_mos_post_grad     0
# lateral_teach_pct                                 0
# Avg_State_Size_07                                 0
# st_highqual_class_all_pct                         0
# Avg_Class_Size_03                                 0
# Avg_Class_Size_04                                 0
# lea_books_per_student                             0
# Avg_State_Size_MathI                              0
# State_Tch_Exp_Pct_4_10_Years                      0
# other_expense_pct                                 0
# supplies_expense_pct                              0
# GCE_RPF_Dist_Pct                                  0
# GCE_SWD_Dist_Pct                                  0
# Avg_Class_Size_Biology                            0
# GCE_ALL_Dist_Pct                                  0
# Avg_Dist_Size_05                                  0
# sat_avg_score_num                                 0
# books_per_student                                 0
# univ_college_courses                              0
# Avg_State_Size_06                                 0
# st_books_per_student                              0
# st_highqual_class_pct                             0
# nat_sat_participation_pct                         0
# State_Prin_Exp_Pct_4_10_Years                     0
# lea_sat_avg_score_num                             0
# lea_total_expense_num                             0
# class_teach_num                                   0
# EVAAS Growth Score                                0
# State_Tch_Exp_Pct_0_3_Years                       0
# PASSED_EOG_School_Pct                             0
# st_univ_college_courses                           0
# st_not_highqual_class_hp_pct                      0
# lea_1yr_tchr_trnovr_pct                           0
# Avg_Class_Size_EnglishII                          0
# Science Score                                     0
# st_other_expense_pct                              0
# lea_instruct_equip_exp_pct                        0
# Math Score                                        0
# GCE_SWD_State_Pct                                 0
# tchyrs_11plus_pct                                 0
# lea_avg_age_media_collection                      0
# Avg_State_Size_EnglishII                          0
# Avg_Dist_Size_03                                  0
# SPG Score                                         0
# st_ap_participation_pct                           0
# Avg_Class_Size_05                                 0
# grades_BYOD                                       0
# summer_program_flg                                0
# benefits_expense_pct                              0
# Cohort Graduation Rate Standard Score             0
# st_prinyrs_4thru10_pct                            0
# cte_courses                                       0
# lea_benefits_expense_pct                          0
# lea_long_susp_per_c_num                           0
# GCE_ALL_State_Pct                                 0
# lea_stud_internet_comp_num                        0
# st_wap_per_classroom                              0
# instruct_equip_exp_pct                            0
# lea_wap_num                                       0
# st_benefits_expense_pct                           0
# short_susp_per_c_num                              0
# st_ib_pct_4_or_above                              0
# szip_ad                                           0
# services_expense_pct                              0
# lea_local_perpupil_num                            0
# lea_tchyrs_0thru3_pct                             0
# Closed_Ind_Text                                   0
# Avg_Dist_Size_02                                  0
# salary_expense_pct                                0
# tchyrs_4thru10_pct                                0
# lea_ap_pct_3_or_above                             0
# wap_num                                           0
# ap_ib_courses                                     0
# lea_avg_student_num                               0
# lea_highqual_class_hp_pct                         0
# student_num                                       0
# Avg_Class_Size_00                                 0
# Biology Score                                     0
# nbpts_num                                         0
# local_perpupil_num                                0
# lea_federal_perpupil_num                          0
# English II Score                                  0
# federal_perpupil_num                              0
# st_stud_internet_comp_num                         0
# GCE_ALL_School_Pct                                0
# PASSED_LAA_State_Pct                              0
# lea_salary_expense_pct                            0
# asm_no_spg_flg                                    0
# RETAINED_Dist_Pct                                 0
# Avg_State_Size_05                                 0
# st_supplies_expense_pct                           0
# State_Tch_Exp_Pct_10+_Years                       0
# st_prinyrs_11plus_pct                             0
# Avg_Class_Size_06                                 0
# lea_not_highqual_class_all_pct                    0
# st_flicensed_teach_pct                            0
# Math SPG Grade                                    0
# State_Prin_Exp_Pct_0_3_Years                      0
# avg_daily_attend_pct                              0
# lea_tchyrs_4thru10_pct                            0
# st_instruct_equip_exp_pct                         0
# ap_participation_pct                              0
# st_prin_other_pct                                 0
# Avg_Class_Size_07                                 0
# focus_clp_flg                                     0
# Avg_State_Size_04                                 0
# st_federal_perpupil_num                           0
# st_nbpts_num                                      0
# Avg_Dist_Size_07                                  0
# Avg_State_Size_Biology                            0
# lea_short_susp_per_c_num                          0
# st_tchyrs_11plus_pct                              0
# st_not_highqual_class_all_pct                     0
# st_prin_advance_dgr_pct                           0
# st_avg_daily_attend_pct                           0
# Avg_Dist_Size_06                                  0
# Avg_State_Size_08                                 0
# Math I Score                                      0
# New_ind_Txt                                       0
# PROMOTED_School_Pct                               0
# EVAAS Growth Status                               0
# Avg_State_Size_03                                 0
# st_prin_black_pct                                 0
# lea_services_expense_pct                          0
# Avg_Dist_Size_04                                  0
# category_cd                                       0
# lea_lateral_teach_pct                             0
# lea_nbpts_num                                     0
# lea_not_highqual_class_lp_pct                     0
# GCE_SWD_School_Pct                                0
# The ACT Score                                     0
# Dist_Tch_Exp_Pct_10+_Years                        0
# st_prinyrs_0thru3_pct                             0
# lea_emer_prov_teach_pct                           0
# st_sat_avg_score_num                              0
# lea_class_teach_num                               0
# Dist_Prin_Exp_Pct_10+_Years                       0
# st_crime_per_c_num                                0
# Avg_State_Size_01                                 0
# st_tchyrs_4thru10_pct                             0
# st_sat_participation_pct                          0
# sat_participation_pct                             0
# st_prin_female_pct                                0
# Avg_Dist_Size_08                                  0
# avg_age_media_collection                          0
# crime_per_c_num                                   0
# _1yr_tchr_trnovr_pct                              0
# Reading SPG Grade                                 0
# lea_crime_per_c_num                               0
# st_ap_ib_courses                                  0
# PASSED_EOG_Dist_Pct                               0
# PASSED_LAA_Dist_Pct                               0
# RETAINED_State_Pct                                0
# lea_avg_daily_attend_pct                          0
# Dist_Prin_Exp_Pct_0_3_Years                       0
# lea_ap_ib_courses                                 0
# Avg_Class_Size_08                                 0
# lea_wap_per_classroom                             0
# ACT WorkKeys Score                                0
# st_wap_num                                        0
# calendar_only_txt                                 0
# PROMOTED_Dist_Pct                                 0
# st_avg_age_media_collection                       0
# advance_dgr_pct                                   0
# lea_advance_dgr_pct                               0
# lea_tchyrs_11plus_pct                             0
# st_tchyrs_0thru3_pct                              0
# st_prin_white_pct                                 0
# tchyrs_0thru3_pct                                 0
# GCE_RPF_School_Pct                                0
# PASSED_LAA_School_Pct                             0
# lea_state_perpupil_num                            0
# Avg_Class_Size_MathI                              0
# One_Yr_College_Complete_wi_2_yrs_Enrolled_2012    0
# Avg_State_Size_02                                 0
# lea_supplies_expense_pct                          0
# lea_expelled_per_c_num                            0
# Avg_Dist_Size_00                                  0
# digital_media_pct                                 0
# Avg_Dist_Size_MathI                               0
# state_ad                                          0
# no_data_spg_flg                                   0
# lea_total_specialized_courses                     0
# Year                                              0
# Tch_Exp_Pct_10+_Years                             0
# scity_ad                                          0
# lea_sat_participation_pct                         0
# lea_other_expense_pct                             0
# st_highqual_class_hp_pct                          0
# clp_ind_flg                                       0
# st_total_specialized_courses                      0
# AP_Courses_Offered                                0
# State Gap Compared                                0
# state_perpupil_num                                0
# long_susp_per_c_num                               0
# st_emer_prov_teach_pct                            0
# st_total_expense_num                              0
# ap_pct_3_or_above                                 0
# Byod                                              0
# st_1yr_tchr_trnovr_pct                            0
# nat_sat_avg_score_num                             0
# Dist_Prin_Exp_Pct_4_10_Years                      0
# State_Prin_Exp_Pct_10+_Years                      0
# st_not_highqual_class_lp_pct                      0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2579 entries, 0 to 2578
# Columns: 264 entries, expelled_per_c_num to st_not_highqual_class_lp_pct
# dtypes: bool(7), float64(228), int64(10), object(19)
# memory usage: 5.1+ MB

# %% [markdown]
# > In the code block above, we replaced missing categorical values with the mode and missing continuous values with the median. A total of 129 columns with missing values have been cleaned and "recovered".

# %%
new_schooldata.shape
# Out:
# (2579, 264)

# %%
# School Category Factor plot 
fig, ax = plt.subplots(figsize=(16, 7))
sns.countplot("category_cd",data=new_schooldata)
new_schooldata.groupby(["category_cd"]).size()
# Out:
# category_cd
# A      63
# E    1320
# H     505
# I     142
# M     478
# T      71
# dtype: int64

# %% [markdown]
# >  The bar graph above is shows the distribution of different school categories in state of North Carolina. See summary table below for school category descriptions and % distribution

# %% [markdown]
# Category | Description|Count |Percentage
# --- | --- | ---|---
# A | School has elementary, middle, and high school grades  | 63|2.44%
# E | School has elementary schools grades (PK-5) | 1320|51.18%
# H | School has high schools grades (9-13)  | 505|19.58%
# I | Schools with elementary, middle and high school grades | 142|5.51%
# M | School has middle schools grades (6-8)  | 478|18.53%
# T | School has middle and high school grades | 71|2.75%

# %% [markdown]
# ### New Features <a class="anchor" id="newFeatures"></a>

# %%
#1
#################################################
#               New Features                    #
#################################################
# create Factors for 'Overall Achievement Score'
# A: 85-100
# B: 70-84
# C: 55-69
# D: 40-54
# F:<40
new_schooldata = new_schooldata.assign(Overall_Achievement_Score_bins = pd.cut(np.array(new_schooldata['Overall Achievement Score']), 
                                              5, labels=["<40", "40-54", "55-69",'70-84',"85-100"]))
#2
#SchoolWeightedScore:  Summation of all achievement measures Scores.
bin1 = ['EVAAS Growth Score','Overall Achievement Score' ] # Weight 0.6
bin2 = ['The ACT Score','ACT WorkKeys Score' ,'Math Course Rigor Score'] # weight 0.3
bin3 = ['Math I Score', 'English II Score','Biology Score'] # EOC scores weight 0.1
#print(Achievement_measures)
new_schooldata = new_schooldata.assign(BIN1=new_schooldata[bin1].sum(axis=1)*.6)
new_schooldata = new_schooldata.assign(BIN2=new_schooldata[bin2].sum(axis=1)*.3)
new_schooldata = new_schooldata.assign(BIN3=new_schooldata[bin3].sum(axis=1)*.1)
groupedbins = ['BIN1','BIN2','BIN3']
new_schooldata = new_schooldata.assign(SchoolWeightedScore = new_schooldata[groupedbins].sum(axis =1))


School_Final = new_schooldata.drop(groupedbins, 1)
School_Final.T
# Out:
#                                                                 0     \
# expelled_per_c_num                                                 0
# Avg_Class_Size_01                                                 18
# flicensed_teach_pct                                            0.893
# Math SPG Score                                                    58
# st_class_teach_num                                                36
# st_local_perpupil_num                                        2172.86
# Avg_Dist_Size_01                                                  19
# Math Course Rigor Score                                          100
# PROMOTED_State_Pct                                             0.856
# st_lateral_teach_pct                                           0.068
# Reading  SPG Score                                                60
# lea_univ_college_courses                                   0.0727742
# Tch_Exp_Pct_0_3_Years                                          0.216
# total_specialized_courses                                          1
# stem_flg                                                       False
# emer_prov_teach_pct                                            0.024
# 1_to_1_access                                                     No
# st_highqual_class_lp_pct                                       0.976
# lea_ap_participation_pct                                        0.15
# lea_highqual_class_pct                                         0.986
# Read Score                                                        56
# Dist_Tch_Exp_Pct_0_3_Years                                     0.215
# school_type_txt                                       Regular School
# Overall Achievement Score                                         59
# lea_not_highqual_class_hp_pct                                  0.018
# Avg_State_Size_00                                                 19
# st_advance_dgr_pct                                             0.277
# Tch_Exp_Pct_4_10_Years                                          0.25
# RETAINED_School_Pct                                            0.214
# esea_status                                                        F
# st_1yr_prin_trnovr_pct                                         0.089
# type_cd_txt                                                  Charter
# st_avg_student_num                                               511
# st_salary_expense_pct                                           0.62
# grades_1_to_1_access                                               -
# stud_internet_comp_num                                          1.19
# st_short_susp_per_c_num                                         8.39
# st_ap_pct_3_or_above                                            0.51
# st_expelled_per_c_num                                              0
# st_prin_male_pct                                               0.398
# st_cte_courses                                              0.639203
# st_state_perpupil_num                                        5718.43
# lea_ib_pct_4_or_above                                           0.76
# lea_flicensed_teach_pct                                        0.972
# PASSED_EOG_State_Pct                                           0.579
# wap_per_classroom                                               1.15
# Avg_Class_Size_02                                                 22
# Avg_Dist_Size_Biology                                             19
# lea_cte_courses                                             0.700774
# total_expense_num                                            8297.25
# SPG Grade                                                          C
# lea_highqual_class_lp_pct                                      0.987
# Grad_project_status                                                N
# st_long_susp_per_c_num                                          0.06
# lea_highqual_class_all_pct                                     0.981
# highqual_class_pct                                             0.872
# Dist_Tch_Exp_Pct_4_10_Years                                     0.26
# title1_type_flg                                                False
# st_services_expense_pct                                         0.09
# Avg_Dist_Size_EnglishII                                           19
# sch_percent_college_enrolled_16_mos_post_grad                73.1183
# lateral_teach_pct                                              0.019
# Avg_State_Size_07                                                 22
# st_highqual_class_all_pct                                      0.963
# Avg_Class_Size_03                                                 25
# Avg_Class_Size_04                                                 25
# lea_books_per_student                                          19.64
# Avg_State_Size_MathI                                              20
# State_Tch_Exp_Pct_4_10_Years                                   0.226
# other_expense_pct                                                  0
# supplies_expense_pct                                           0.087
# GCE_RPF_Dist_Pct                                               0.091
# GCE_SWD_Dist_Pct                                               0.078
# Avg_Class_Size_Biology                                            14
# GCE_ALL_Dist_Pct                                               0.103
# Avg_Dist_Size_05                                                  21
# sat_avg_score_num                                               1087
# books_per_student                                              20.76
# univ_college_courses                                       0.0696517
# Avg_State_Size_06                                                 21
# st_books_per_student                                           19.18
# st_highqual_class_pct                                           0.82
# nat_sat_participation_pct                                       0.52
# State_Prin_Exp_Pct_4_10_Years                                  0.427
# lea_sat_avg_score_num                                            982
# lea_total_expense_num                                        8795.42
# class_teach_num                                                  103
# EVAAS Growth Score                                              80.2
# State_Tch_Exp_Pct_0_3_Years                                    0.227
# PASSED_EOG_School_Pct                                          0.872
# st_univ_college_courses                                    0.0706403
# st_not_highqual_class_hp_pct                                   0.036
# lea_1yr_tchr_trnovr_pct                                        0.132
# Avg_Class_Size_EnglishII                                          23
# Science Score                                                     68
# st_other_expense_pct                                               0
# lea_instruct_equip_exp_pct                                     0.009
# Math Score                                                        53
# GCE_SWD_State_Pct                                              0.065
# tchyrs_11plus_pct                                              0.512
# lea_avg_age_media_collection                                    2000
# Avg_State_Size_EnglishII                                          18
# Avg_Dist_Size_03                                                  19
# SPG Score                                                         63
# st_ap_participation_pct                                         0.15
# Avg_Class_Size_05                                                 26
# grades_BYOD                                                        -
# summer_program_flg                                             False
# benefits_expense_pct                                           0.146
# Cohort Graduation Rate Standard Score                             90
# st_prinyrs_4thru10_pct                                         0.427
# cte_courses                                                 0.703974
# lea_benefits_expense_pct                                        0.21
# lea_long_susp_per_c_num                                            0
# GCE_ALL_State_Pct                                              0.112
# lea_stud_internet_comp_num                                      1.14
# st_wap_per_classroom                                            1.12
# instruct_equip_exp_pct                                         0.012
# lea_wap_num                                                     1497
# st_benefits_expense_pct                                        0.205
# short_susp_per_c_num                                            0.77
# st_ib_pct_4_or_above                                            0.75
# szip_ad                                                        28115
# services_expense_pct                                           0.267
# lea_local_perpupil_num                                        1984.2
# lea_tchyrs_0thru3_pct                                          0.215
# Closed_Ind_Text                                                 Open
# Avg_Dist_Size_02                                                  19
# salary_expense_pct                                             0.488
# tchyrs_4thru10_pct                                              0.25
# lea_ap_pct_3_or_above                                           0.48
# wap_num                                                           40
# ap_ib_courses                                               0.135721
# lea_avg_student_num                                              531
# lea_highqual_class_hp_pct                                      0.982
# student_num                                                     1694
# Avg_Class_Size_00                                                 20
# Biology Score                                                     55
# nbpts_num                                                          4
# local_perpupil_num                                           2871.81
# lea_federal_perpupil_num                                     1041.44
# English II Score                                                  60
# federal_perpupil_num                                          158.82
# st_stud_internet_comp_num                                        1.2
# GCE_ALL_School_Pct                                                 0
# PASSED_LAA_State_Pct                                            0.11
# lea_salary_expense_pct                                         0.626
# asm_no_spg_flg                                                 False
# RETAINED_Dist_Pct                                              0.142
# Avg_State_Size_05                                                 21
# st_supplies_expense_pct                                        0.075
# State_Tch_Exp_Pct_10+_Years                                    0.547
# st_prinyrs_11plus_pct                                          0.143
# Avg_Class_Size_06                                                 26
# lea_not_highqual_class_all_pct                                 0.019
# st_flicensed_teach_pct                                         0.808
# Math SPG Grade                                                     C
# State_Prin_Exp_Pct_0_3_Years                                    0.43
# avg_daily_attend_pct                                           0.969
# lea_tchyrs_4thru10_pct                                          0.26
# st_instruct_equip_exp_pct                                       0.01
# ap_participation_pct                                             0.4
# st_prin_other_pct                                              0.026
# Avg_Class_Size_07                                                 27
# focus_clp_flg                                                  False
# Avg_State_Size_04                                                 20
# st_federal_perpupil_num                                       967.75
# st_nbpts_num                                                       2
# Avg_Dist_Size_07                                                  22
# Avg_State_Size_Biology                                            18
# lea_short_susp_per_c_num                                       10.59
# st_tchyrs_11plus_pct                                           0.547
# st_not_highqual_class_all_pct                                  0.037
# st_prin_advance_dgr_pct                                        0.222
# st_avg_daily_attend_pct                                        0.958
# Avg_Dist_Size_06                                                  22
# Avg_State_Size_08                                                 21
# Math I Score                                                      80
# New_ind_Txt                                        School Is Not New
# PROMOTED_School_Pct                                             0.95
# EVAAS Growth Status                                              Met
# Avg_State_Size_03                                                 19
# st_prin_black_pct                                              0.237
# lea_services_expense_pct                                       0.081
# Avg_Dist_Size_04                                                  21
# category_cd                                                        A
# lea_lateral_teach_pct                                          0.026
# lea_nbpts_num                                                      5
# lea_not_highqual_class_lp_pct                                  0.013
# GCE_SWD_School_Pct                                             0.119
# The ACT Score                                                   61.5
# Dist_Tch_Exp_Pct_10+_Years                                     0.518
# st_prinyrs_0thru3_pct                                           0.43
# lea_emer_prov_teach_pct                                        0.005
# st_sat_avg_score_num                                             997
# lea_class_teach_num                                               37
# Dist_Prin_Exp_Pct_10+_Years                                    0.116
# st_crime_per_c_num                                              0.58
# Avg_State_Size_01                                                 19
# st_tchyrs_4thru10_pct                                          0.226
# st_sat_participation_pct                                        0.49
# sat_participation_pct                                           0.92
# st_prin_female_pct                                             0.596
# Avg_Dist_Size_08                                                  23
# avg_age_media_collection                                        2000
# crime_per_c_num                                                  0.3
# _1yr_tchr_trnovr_pct                                           0.129
# Reading SPG Grade                                                  C
# lea_crime_per_c_num                                              0.3
# st_ap_ib_courses                                              0.1649
# PASSED_EOG_Dist_Pct                                            0.578
# PASSED_LAA_Dist_Pct                                            0.105
# RETAINED_State_Pct                                             0.144
# lea_avg_daily_attend_pct                                       0.951
# Dist_Prin_Exp_Pct_0_3_Years                                    0.385
# lea_ap_ib_courses                                           0.147809
# Avg_Class_Size_08                                                 23
# lea_wap_per_classroom                                           1.15
# ACT WorkKeys Score                                                72
# st_wap_num                                                    111757
# calendar_only_txt                               Traditional Calendar
# PROMOTED_Dist_Pct                                               0.87
# st_avg_age_media_collection                                     2000
# advance_dgr_pct                                                0.268
# lea_advance_dgr_pct                                            0.274
# lea_tchyrs_11plus_pct                                          0.518
# st_tchyrs_0thru3_pct                                           0.227
# st_prin_white_pct                                              0.737
# tchyrs_0thru3_pct                                              0.216
# GCE_RPF_School_Pct                                             0.179
# PASSED_LAA_School_Pct                                          0.088
# lea_state_perpupil_num                                       5638.31
# Avg_Class_Size_MathI                                              28
# One_Yr_College_Complete_wi_2_yrs_Enrolled_2012               73.1183
# Avg_State_Size_02                                                 19
# lea_supplies_expense_pct                                       0.076
# lea_expelled_per_c_num                                             0
# Avg_Dist_Size_00                                                  19
# digital_media_pct                                               0.01
# Avg_Dist_Size_MathI                                               21
# state_ad                                                          NC
# no_data_spg_flg                                                False
# lea_total_specialized_courses                                      1
# Year                                                            2016
# Tch_Exp_Pct_10+_Years                                          0.512
# scity_ad                                                 Mooresville
# lea_sat_participation_pct                                       0.47
# lea_other_expense_pct                                              0
# st_highqual_class_hp_pct                                       0.964
# clp_ind_flg                                                    False
# st_total_specialized_courses                                0.964635
# AP_Courses_Offered                                                 7
# State Gap Compared                                                 Y
# state_perpupil_num                                           5266.62
# long_susp_per_c_num                                                0
# st_emer_prov_teach_pct                                         0.003
# st_total_expense_num                                         8859.04
# ap_pct_3_or_above                                               0.64
# Byod                                                              No
# st_1yr_tchr_trnovr_pct                                         0.157
# nat_sat_avg_score_num                                           1006
# Dist_Prin_Exp_Pct_4_10_Years                                   0.442
# State_Prin_Exp_Pct_10+_Years                                   0.143
# st_not_highqual_class_lp_pct                                   0.024
# Overall_Achievement_Score_bins                                 55-69
# SchoolWeightedScore                                           173.07
#
#                                                                 1     \
# expelled_per_c_num                                                 0
# Avg_Class_Size_01                                                 19
# flicensed_teach_pct                                              0.8
# Math SPG Score                                                    58
# st_class_teach_num                                                32
# st_local_perpupil_num                                        2172.86
# Avg_Dist_Size_01                                                  19
# Math Course Rigor Score                                          100
# PROMOTED_State_Pct                                             0.856
# st_lateral_teach_pct                                           0.046
# Reading  SPG Score                                                60
# lea_univ_college_courses                                   0.0727742
# Tch_Exp_Pct_0_3_Years                                          0.216
# total_specialized_courses                                          1
# stem_flg                                                       False
# emer_prov_teach_pct                                            0.024
# 1_to_1_access                                                     No
# st_highqual_class_lp_pct                                       0.976
# lea_ap_participation_pct                                        0.15
# lea_highqual_class_pct                                         0.986
# Read Score                                                        56
# Dist_Tch_Exp_Pct_0_3_Years                                     0.215
# school_type_txt                                       Regular School
# Overall Achievement Score                                         59
# lea_not_highqual_class_hp_pct                                  0.018
# Avg_State_Size_00                                                 19
# st_advance_dgr_pct                                             0.262
# Tch_Exp_Pct_4_10_Years                                          0.25
# RETAINED_School_Pct                                            0.214
# esea_status                                                        F
# st_1yr_prin_trnovr_pct                                         0.089
# type_cd_txt                                                  Charter
# st_avg_student_num                                               475
# st_salary_expense_pct                                           0.62
# grades_1_to_1_access                                               -
# stud_internet_comp_num                                          1.19
# st_short_susp_per_c_num                                         8.76
# st_ap_pct_3_or_above                                            0.51
# st_expelled_per_c_num                                              0
# st_prin_male_pct                                               0.398
# st_cte_courses                                              0.639203
# st_state_perpupil_num                                        5718.43
# lea_ib_pct_4_or_above                                           0.76
# lea_flicensed_teach_pct                                        0.972
# PASSED_EOG_State_Pct                                           0.579
# wap_per_classroom                                               1.15
# Avg_Class_Size_02                                                 19
# Avg_Dist_Size_Biology                                             19
# lea_cte_courses                                             0.700774
# total_expense_num                                            7955.28
# SPG Grade                                                          C
# lea_highqual_class_lp_pct                                      0.987
# Grad_project_status                                                N
# st_long_susp_per_c_num                                          0.06
# lea_highqual_class_all_pct                                     0.981
# highqual_class_pct                                             0.909
# Dist_Tch_Exp_Pct_4_10_Years                                     0.26
# title1_type_flg                                                False
# st_services_expense_pct                                         0.09
# Avg_Dist_Size_EnglishII                                           19
# sch_percent_college_enrolled_16_mos_post_grad                55.4217
# lateral_teach_pct                                               0.05
# Avg_State_Size_07                                                 22
# st_highqual_class_all_pct                                      0.963
# Avg_Class_Size_03                                                 19
# Avg_Class_Size_04                                                 21
# lea_books_per_student                                          19.64
# Avg_State_Size_MathI                                              20
# State_Tch_Exp_Pct_4_10_Years                                   0.254
# other_expense_pct                                                  0
# supplies_expense_pct                                           0.043
# GCE_RPF_Dist_Pct                                               0.091
# GCE_SWD_Dist_Pct                                               0.078
# Avg_Class_Size_Biology                                            19
# GCE_ALL_Dist_Pct                                               0.103
# Avg_Dist_Size_05                                                  21
# sat_avg_score_num                                                974
# books_per_student                                              20.76
# univ_college_courses                                       0.0696517
# Avg_State_Size_06                                                 21
# st_books_per_student                                           19.18
# st_highqual_class_pct                                          0.894
# nat_sat_participation_pct                                       0.52
# State_Prin_Exp_Pct_4_10_Years                                  0.427
# lea_sat_avg_score_num                                            982
# lea_total_expense_num                                        8795.42
# class_teach_num                                                   40
# EVAAS Growth Score                                              80.2
# State_Tch_Exp_Pct_0_3_Years                                    0.255
# PASSED_EOG_School_Pct                                          0.903
# st_univ_college_courses                                    0.0706403
# st_not_highqual_class_hp_pct                                   0.036
# lea_1yr_tchr_trnovr_pct                                        0.132
# Avg_Class_Size_EnglishII                                          19
# Science Score                                                     68
# st_other_expense_pct                                               0
# lea_instruct_equip_exp_pct                                     0.009
# Math Score                                                        53
# GCE_SWD_State_Pct                                              0.065
# tchyrs_11plus_pct                                              0.512
# lea_avg_age_media_collection                                    2000
# Avg_State_Size_EnglishII                                          18
# Avg_Dist_Size_03                                                  19
# SPG Score                                                         63
# st_ap_participation_pct                                         0.15
# Avg_Class_Size_05                                                 21
# grades_BYOD                                                        -
# summer_program_flg                                             False
# benefits_expense_pct                                           0.137
# Cohort Graduation Rate Standard Score                             90
# st_prinyrs_4thru10_pct                                         0.427
# cte_courses                                                 0.703974
# lea_benefits_expense_pct                                        0.21
# lea_long_susp_per_c_num                                            0
# GCE_ALL_State_Pct                                              0.112
# lea_stud_internet_comp_num                                      1.14
# st_wap_per_classroom                                            1.12
# instruct_equip_exp_pct                                         0.004
# lea_wap_num                                                     1497
# st_benefits_expense_pct                                        0.205
# short_susp_per_c_num                                               0
# st_ib_pct_4_or_above                                            0.75
# szip_ad                                                        27560
# services_expense_pct                                           0.204
# lea_local_perpupil_num                                        1984.2
# lea_tchyrs_0thru3_pct                                          0.215
# Closed_Ind_Text                                                 Open
# Avg_Dist_Size_02                                                  19
# salary_expense_pct                                             0.612
# tchyrs_4thru10_pct                                              0.25
# lea_ap_pct_3_or_above                                           0.48
# wap_num                                                           40
# ap_ib_courses                                               0.135721
# lea_avg_student_num                                              531
# lea_highqual_class_hp_pct                                      0.982
# student_num                                                      590
# Avg_Class_Size_00                                                 24
# Biology Score                                                     55
# nbpts_num                                                          4
# local_perpupil_num                                           2453.72
# lea_federal_perpupil_num                                     1041.44
# English II Score                                                  60
# federal_perpupil_num                                          157.43
# st_stud_internet_comp_num                                        1.2
# GCE_ALL_School_Pct                                             0.042
# PASSED_LAA_State_Pct                                            0.11
# lea_salary_expense_pct                                         0.626
# asm_no_spg_flg                                                 False
# RETAINED_Dist_Pct                                              0.142
# Avg_State_Size_05                                                 21
# st_supplies_expense_pct                                        0.075
# State_Tch_Exp_Pct_10+_Years                                    0.491
# st_prinyrs_11plus_pct                                          0.143
# Avg_Class_Size_06                                                 21
# lea_not_highqual_class_all_pct                                 0.019
# st_flicensed_teach_pct                                         0.895
# Math SPG Grade                                                     C
# State_Prin_Exp_Pct_0_3_Years                                    0.43
# avg_daily_attend_pct                                           0.961
# lea_tchyrs_4thru10_pct                                          0.26
# st_instruct_equip_exp_pct                                       0.01
# ap_participation_pct                                            0.14
# st_prin_other_pct                                              0.026
# Avg_Class_Size_07                                                 12
# focus_clp_flg                                                  False
# Avg_State_Size_04                                                 20
# st_federal_perpupil_num                                       967.75
# st_nbpts_num                                                       5
# Avg_Dist_Size_07                                                  22
# Avg_State_Size_Biology                                            18
# lea_short_susp_per_c_num                                       10.59
# st_tchyrs_11plus_pct                                           0.491
# st_not_highqual_class_all_pct                                  0.037
# st_prin_advance_dgr_pct                                        0.222
# st_avg_daily_attend_pct                                        0.957
# Avg_Dist_Size_06                                                  22
# Avg_State_Size_08                                                 21
# Math I Score                                                      80
# New_ind_Txt                                        School Is Not New
# PROMOTED_School_Pct                                             0.95
# EVAAS Growth Status                                              Met
# Avg_State_Size_03                                                 19
# st_prin_black_pct                                              0.237
# lea_services_expense_pct                                       0.081
# Avg_Dist_Size_04                                                  21
# category_cd                                                        I
# lea_lateral_teach_pct                                          0.026
# lea_nbpts_num                                                      5
# lea_not_highqual_class_lp_pct                                  0.013
# GCE_SWD_School_Pct                                             0.119
# The ACT Score                                                   61.5
# Dist_Tch_Exp_Pct_10+_Years                                     0.518
# st_prinyrs_0thru3_pct                                           0.43
# lea_emer_prov_teach_pct                                        0.005
# st_sat_avg_score_num                                             997
# lea_class_teach_num                                               37
# Dist_Prin_Exp_Pct_10+_Years                                    0.116
# st_crime_per_c_num                                              0.24
# Avg_State_Size_01                                                 19
# st_tchyrs_4thru10_pct                                          0.254
# st_sat_participation_pct                                        0.49
# sat_participation_pct                                           0.45
# st_prin_female_pct                                             0.596
# Avg_Dist_Size_08                                                  23
# avg_age_media_collection                                        2000
# crime_per_c_num                                                    0
# _1yr_tchr_trnovr_pct                                           0.129
# Reading SPG Grade                                                  C
# lea_crime_per_c_num                                              0.3
# st_ap_ib_courses                                              0.1649
# PASSED_EOG_Dist_Pct                                            0.578
# PASSED_LAA_Dist_Pct                                            0.105
# RETAINED_State_Pct                                             0.144
# lea_avg_daily_attend_pct                                       0.951
# Dist_Prin_Exp_Pct_0_3_Years                                    0.385
# lea_ap_ib_courses                                           0.147809
# Avg_Class_Size_08                                                 12
# lea_wap_per_classroom                                           1.15
# ACT WorkKeys Score                                                72
# st_wap_num                                                    111757
# calendar_only_txt                               Traditional Calendar
# PROMOTED_Dist_Pct                                               0.87
# st_avg_age_media_collection                                     2000
# advance_dgr_pct                                                0.268
# lea_advance_dgr_pct                                            0.274
# lea_tchyrs_11plus_pct                                          0.518
# st_tchyrs_0thru3_pct                                           0.255
# st_prin_white_pct                                              0.737
# tchyrs_0thru3_pct                                              0.216
# GCE_RPF_School_Pct                                             0.179
# PASSED_LAA_School_Pct                                          0.173
# lea_state_perpupil_num                                       5638.31
# Avg_Class_Size_MathI                                              16
# One_Yr_College_Complete_wi_2_yrs_Enrolled_2012               55.4217
# Avg_State_Size_02                                                 19
# lea_supplies_expense_pct                                       0.076
# lea_expelled_per_c_num                                             0
# Avg_Dist_Size_00                                                  19
# digital_media_pct                                               0.01
# Avg_Dist_Size_MathI                                               21
# state_ad                                                          NC
# no_data_spg_flg                                                False
# lea_total_specialized_courses                                      1
# Year                                                            2016
# Tch_Exp_Pct_10+_Years                                          0.512
# scity_ad                                                 Morrisville
# lea_sat_participation_pct                                       0.47
# lea_other_expense_pct                                              0
# st_highqual_class_hp_pct                                       0.964
# clp_ind_flg                                                    False
# st_total_specialized_courses                                0.964635
# AP_Courses_Offered                                                 7
# State Gap Compared                                                 Y
# state_perpupil_num                                           5344.13
# long_susp_per_c_num                                                0
# st_emer_prov_teach_pct                                         0.003
# st_total_expense_num                                         8859.04
# ap_pct_3_or_above                                                0.4
# Byod                                                              No
# st_1yr_tchr_trnovr_pct                                         0.127
# nat_sat_avg_score_num                                           1006
# Dist_Prin_Exp_Pct_4_10_Years                                   0.442
# State_Prin_Exp_Pct_10+_Years                                   0.143
# st_not_highqual_class_lp_pct                                   0.024
# Overall_Achievement_Score_bins                                 55-69
# SchoolWeightedScore                                           173.07
#
#                                                                 2     \
# expelled_per_c_num                                                 0
# Avg_Class_Size_01                                                 19
# flicensed_teach_pct                                                1
# Math SPG Score                                                    58
# st_class_teach_num                                                54
# st_local_perpupil_num                                        2172.86
# Avg_Dist_Size_01                                                  19
# Math Course Rigor Score                                          100
# PROMOTED_State_Pct                                             0.856
# st_lateral_teach_pct                                           0.092
# Reading  SPG Score                                                60
# lea_univ_college_courses                                   0.0727742
# Tch_Exp_Pct_0_3_Years                                              0
# total_specialized_courses                                          1
# stem_flg                                                       False
# emer_prov_teach_pct                                            0.024
# 1_to_1_access                                                     No
# st_highqual_class_lp_pct                                       0.976
# lea_ap_participation_pct                                        0.15
# lea_highqual_class_pct                                         0.889
# Read Score                                                        56
# Dist_Tch_Exp_Pct_0_3_Years                                     0.242
# school_type_txt                                       Regular School
# Overall Achievement Score                                         59
# lea_not_highqual_class_hp_pct                                  0.076
# Avg_State_Size_00                                                 19
# st_advance_dgr_pct                                             0.248
# Tch_Exp_Pct_4_10_Years                                         0.286
# RETAINED_School_Pct                                            0.214
# esea_status                                                        F
# st_1yr_prin_trnovr_pct                                         0.089
# type_cd_txt                                                   Public
# st_avg_student_num                                               860
# st_salary_expense_pct                                           0.62
# grades_1_to_1_access                                               -
# stud_internet_comp_num                                          0.69
# st_short_susp_per_c_num                                        14.02
# st_ap_pct_3_or_above                                            0.51
# st_expelled_per_c_num                                              0
# st_prin_male_pct                                               0.398
# st_cte_courses                                              0.639203
# st_state_perpupil_num                                        5718.43
# lea_ib_pct_4_or_above                                           0.76
# lea_flicensed_teach_pct                                        0.903
# PASSED_EOG_State_Pct                                           0.579
# wap_per_classroom                                               1.15
# Avg_Class_Size_02                                                 19
# Avg_Dist_Size_Biology                                             18
# lea_cte_courses                                             0.700774
# total_expense_num                                            8358.47
# SPG Grade                                                          C
# lea_highqual_class_lp_pct                                      0.914
# Grad_project_status                                                N
# st_long_susp_per_c_num                                          0.07
# lea_highqual_class_all_pct                                      0.94
# highqual_class_pct                                             0.964
# Dist_Tch_Exp_Pct_4_10_Years                                     0.24
# title1_type_flg                                                False
# st_services_expense_pct                                         0.09
# Avg_Dist_Size_EnglishII                                           18
# sch_percent_college_enrolled_16_mos_post_grad                     45
# lateral_teach_pct                                              0.061
# Avg_State_Size_07                                                 22
# st_highqual_class_all_pct                                      0.963
# Avg_Class_Size_03                                                 19
# Avg_Class_Size_04                                                 21
# lea_books_per_student                                          19.64
# Avg_State_Size_MathI                                              20
# State_Tch_Exp_Pct_4_10_Years                                   0.235
# other_expense_pct                                                  0
# supplies_expense_pct                                          0.0615
# GCE_RPF_Dist_Pct                                               0.091
# GCE_SWD_Dist_Pct                                               0.078
# Avg_Class_Size_Biology                                            13
# GCE_ALL_Dist_Pct                                               0.103
# Avg_Dist_Size_05                                                  21
# sat_avg_score_num                                               1034
# books_per_student                                              20.76
# univ_college_courses                                       0.0696517
# Avg_State_Size_06                                                 21
# st_books_per_student                                           19.18
# st_highqual_class_pct                                          0.964
# nat_sat_participation_pct                                       0.52
# State_Prin_Exp_Pct_4_10_Years                                  0.427
# lea_sat_avg_score_num                                            961
# lea_total_expense_num                                        8517.96
# class_teach_num                                                    7
# EVAAS Growth Score                                              80.2
# State_Tch_Exp_Pct_0_3_Years                                    0.231
# PASSED_EOG_School_Pct                                          0.575
# st_univ_college_courses                                    0.0706403
# st_not_highqual_class_hp_pct                                   0.036
# lea_1yr_tchr_trnovr_pct                                         0.13
# Avg_Class_Size_EnglishII                                          13
# Science Score                                                     68
# st_other_expense_pct                                               0
# lea_instruct_equip_exp_pct                                     0.009
# Math Score                                                        53
# GCE_SWD_State_Pct                                              0.065
# tchyrs_11plus_pct                                              0.714
# lea_avg_age_media_collection                                    2000
# Avg_State_Size_EnglishII                                          18
# Avg_Dist_Size_03                                                  19
# SPG Score                                                         63
# st_ap_participation_pct                                         0.15
# Avg_Class_Size_05                                                 21
# grades_BYOD                                                        -
# summer_program_flg                                             False
# benefits_expense_pct                                          0.1255
# Cohort Graduation Rate Standard Score                             90
# st_prinyrs_4thru10_pct                                         0.427
# cte_courses                                                 0.703974
# lea_benefits_expense_pct                                       0.212
# lea_long_susp_per_c_num                                         0.23
# GCE_ALL_State_Pct                                              0.112
# lea_stud_internet_comp_num                                      1.24
# st_wap_per_classroom                                            1.12
# instruct_equip_exp_pct                                          0.01
# lea_wap_num                                                     1380
# st_benefits_expense_pct                                        0.205
# short_susp_per_c_num                                               0
# st_ib_pct_4_or_above                                            0.75
# szip_ad                                                        27253
# services_expense_pct                                           0.243
# lea_local_perpupil_num                                       1832.54
# lea_tchyrs_0thru3_pct                                          0.242
# Closed_Ind_Text                                                 Open
# Avg_Dist_Size_02                                                  19
# salary_expense_pct                                             0.515
# tchyrs_4thru10_pct                                             0.286
# lea_ap_pct_3_or_above                                           0.37
# ...
# lea_ib_pct_4_or_above                                           0.76
# lea_flicensed_teach_pct                                        0.972
# PASSED_EOG_State_Pct                                           0.579
# wap_per_classroom                                               1.15
# Avg_Class_Size_02                                                 22
# Avg_Dist_Size_Biology                                             19
# lea_cte_courses                                             0.700774
# total_expense_num                                            7090.06
# SPG Grade                                                          C
# lea_highqual_class_lp_pct                                      0.987
# Grad_project_status                                                N
# st_long_susp_per_c_num                                          0.06
# lea_highqual_class_all_pct                                     0.981
# highqual_class_pct                                             0.689
# Dist_Tch_Exp_Pct_4_10_Years                                     0.26
# title1_type_flg                                                 True
# st_services_expense_pct                                         0.09
# Avg_Dist_Size_EnglishII                                           19
# sch_percent_college_enrolled_16_mos_post_grad                55.4217
# lateral_teach_pct                                              0.043
# Avg_State_Size_07                                                 22
# st_highqual_class_all_pct                                      0.963
# Avg_Class_Size_03                                                 23
# Avg_Class_Size_04                                                 22
# lea_books_per_student                                          19.64
# Avg_State_Size_MathI                                              20
# State_Tch_Exp_Pct_4_10_Years                                   0.254
# other_expense_pct                                                  0
# supplies_expense_pct                                           0.056
# GCE_RPF_Dist_Pct                                               0.091
# GCE_SWD_Dist_Pct                                               0.078
# Avg_Class_Size_Biology                                            19
# GCE_ALL_Dist_Pct                                               0.103
# Avg_Dist_Size_05                                                  21
# sat_avg_score_num                                                974
# books_per_student                                              20.76
# univ_college_courses                                       0.0696517
# Avg_State_Size_06                                                 21
# st_books_per_student                                           19.18
# st_highqual_class_pct                                          0.894
# nat_sat_participation_pct                                       0.52
# State_Prin_Exp_Pct_4_10_Years                                  0.427
# lea_sat_avg_score_num                                            982
# lea_total_expense_num                                        8795.42
# class_teach_num                                                   23
# EVAAS Growth Score                                              75.3
# State_Tch_Exp_Pct_0_3_Years                                    0.255
# PASSED_EOG_School_Pct                                          0.455
# st_univ_college_courses                                    0.0706403
# st_not_highqual_class_hp_pct                                   0.036
# lea_1yr_tchr_trnovr_pct                                        0.132
# Avg_Class_Size_EnglishII                                          19
# Science Score                                                     66
# st_other_expense_pct                                               0
# lea_instruct_equip_exp_pct                                     0.009
# Math Score                                                        45
# GCE_SWD_State_Pct                                              0.065
# tchyrs_11plus_pct                                              0.512
# lea_avg_age_media_collection                                    2000
# Avg_State_Size_EnglishII                                          18
# Avg_Dist_Size_03                                                  19
# SPG Score                                                         60
# st_ap_participation_pct                                         0.15
# Avg_Class_Size_05                                                 24
# grades_BYOD                                                        -
# summer_program_flg                                              True
# benefits_expense_pct                                           0.105
# Cohort Graduation Rate Standard Score                             90
# st_prinyrs_4thru10_pct                                         0.427
# cte_courses                                                0.0833333
# lea_benefits_expense_pct                                        0.21
# lea_long_susp_per_c_num                                            0
# GCE_ALL_State_Pct                                              0.112
# lea_stud_internet_comp_num                                      1.14
# st_wap_per_classroom                                            1.12
# instruct_equip_exp_pct                                         0.015
# lea_wap_num                                                     1497
# st_benefits_expense_pct                                        0.205
# short_susp_per_c_num                                            4.63
# st_ib_pct_4_or_above                                            0.75
# szip_ad                                                        27896
# services_expense_pct                                           0.321
# lea_local_perpupil_num                                        1984.2
# lea_tchyrs_0thru3_pct                                          0.215
# Closed_Ind_Text                                                 Open
# Avg_Dist_Size_02                                                  19
# salary_expense_pct                                             0.503
# tchyrs_4thru10_pct                                              0.25
# lea_ap_pct_3_or_above                                           0.48
# wap_num                                                           40
# ap_ib_courses                                               0.135721
# lea_avg_student_num                                              531
# lea_highqual_class_hp_pct                                      0.982
# student_num                                                      432
# Avg_Class_Size_00                                                 22
# Biology Score                                                     55
# nbpts_num                                                          4
# local_perpupil_num                                            1489.8
# lea_federal_perpupil_num                                     1041.44
# English II Score                                                  60
# federal_perpupil_num                                          216.32
# st_stud_internet_comp_num                                        1.2
# GCE_ALL_School_Pct                                             0.182
# PASSED_LAA_State_Pct                                            0.11
# lea_salary_expense_pct                                         0.626
# asm_no_spg_flg                                                 False
# RETAINED_Dist_Pct                                              0.142
# Avg_State_Size_05                                                 21
# st_supplies_expense_pct                                        0.075
# State_Tch_Exp_Pct_10+_Years                                    0.491
# st_prinyrs_11plus_pct                                          0.143
# Avg_Class_Size_06                                                 21
# lea_not_highqual_class_all_pct                                 0.019
# st_flicensed_teach_pct                                         0.895
# Math SPG Grade                                                     D
# State_Prin_Exp_Pct_0_3_Years                                    0.43
# avg_daily_attend_pct                                           0.965
# lea_tchyrs_4thru10_pct                                          0.26
# st_instruct_equip_exp_pct                                       0.01
# ap_participation_pct                                            0.14
# st_prin_other_pct                                              0.026
# Avg_Class_Size_07                                                 22
# focus_clp_flg                                                  False
# Avg_State_Size_04                                                 20
# st_federal_perpupil_num                                       967.75
# st_nbpts_num                                                       5
# Avg_Dist_Size_07                                                  22
# Avg_State_Size_Biology                                            18
# lea_short_susp_per_c_num                                       10.59
# st_tchyrs_11plus_pct                                           0.491
# st_not_highqual_class_all_pct                                  0.037
# st_prin_advance_dgr_pct                                        0.222
# st_avg_daily_attend_pct                                        0.957
# Avg_Dist_Size_06                                                  22
# Avg_State_Size_08                                                 21
# Math I Score                                                      80
# New_ind_Txt                                        School Is Not New
# PROMOTED_School_Pct                                            0.795
# EVAAS Growth Status                                              Met
# Avg_State_Size_03                                                 19
# st_prin_black_pct                                              0.237
# lea_services_expense_pct                                       0.081
# Avg_Dist_Size_04                                                  21
# category_cd                                                        I
# lea_lateral_teach_pct                                          0.026
# lea_nbpts_num                                                      5
# lea_not_highqual_class_lp_pct                                  0.013
# GCE_SWD_School_Pct                                             0.119
# The ACT Score                                                   61.5
# Dist_Tch_Exp_Pct_10+_Years                                     0.518
# st_prinyrs_0thru3_pct                                           0.43
# lea_emer_prov_teach_pct                                        0.005
# st_sat_avg_score_num                                             997
# lea_class_teach_num                                               37
# Dist_Prin_Exp_Pct_10+_Years                                    0.116
# st_crime_per_c_num                                              0.24
# Avg_State_Size_01                                                 19
# st_tchyrs_4thru10_pct                                          0.254
# st_sat_participation_pct                                        0.49
# sat_participation_pct                                           0.45
# st_prin_female_pct                                             0.596
# Avg_Dist_Size_08                                                  23
# avg_age_media_collection                                        2000
# crime_per_c_num                                                    0
# _1yr_tchr_trnovr_pct                                           0.129
# Reading SPG Grade                                                  C
# lea_crime_per_c_num                                              0.3
# st_ap_ib_courses                                              0.1649
# PASSED_EOG_Dist_Pct                                            0.578
# PASSED_LAA_Dist_Pct                                            0.105
# RETAINED_State_Pct                                             0.144
# lea_avg_daily_attend_pct                                       0.951
# Dist_Prin_Exp_Pct_0_3_Years                                    0.385
# lea_ap_ib_courses                                           0.147809
# Avg_Class_Size_08                                                 19
# lea_wap_per_classroom                                           1.15
# ACT WorkKeys Score                                                72
# st_wap_num                                                    111757
# calendar_only_txt                               Traditional Calendar
# PROMOTED_Dist_Pct                                               0.87
# st_avg_age_media_collection                                     2000
# advance_dgr_pct                                                0.268
# lea_advance_dgr_pct                                            0.274
# lea_tchyrs_11plus_pct                                          0.518
# st_tchyrs_0thru3_pct                                           0.255
# st_prin_white_pct                                              0.737
# tchyrs_0thru3_pct                                              0.216
# GCE_RPF_School_Pct                                             0.179
# PASSED_LAA_School_Pct                                          0.173
# lea_state_perpupil_num                                       5638.31
# Avg_Class_Size_MathI                                               9
# One_Yr_College_Complete_wi_2_yrs_Enrolled_2012               55.4217
# Avg_State_Size_02                                                 19
# lea_supplies_expense_pct                                       0.076
# lea_expelled_per_c_num                                             0
# Avg_Dist_Size_00                                                  19
# digital_media_pct                                               0.01
# Avg_Dist_Size_MathI                                               21
# state_ad                                                          NC
# no_data_spg_flg                                                False
# lea_total_specialized_courses                                      1
# Year                                                            2016
# Tch_Exp_Pct_10+_Years                                          0.512
# scity_ad                                                      Wilson
# lea_sat_participation_pct                                       0.47
# lea_other_expense_pct                                              0
# st_highqual_class_hp_pct                                       0.964
# clp_ind_flg                                                    False
# st_total_specialized_courses                                0.964635
# AP_Courses_Offered                                                 7
# State Gap Compared                                                 Y
# state_perpupil_num                                           5383.94
# long_susp_per_c_num                                                0
# st_emer_prov_teach_pct                                         0.003
# st_total_expense_num                                         8859.04
# ap_pct_3_or_above                                                0.4
# Byod                                                              No
# st_1yr_tchr_trnovr_pct                                         0.127
# nat_sat_avg_score_num                                           1006
# Dist_Prin_Exp_Pct_4_10_Years                                   0.442
# State_Prin_Exp_Pct_10+_Years                                   0.143
# st_not_highqual_class_lp_pct                                   0.024
# Overall_Achievement_Score_bins                                 55-69
# SchoolWeightedScore                                           168.33
#
# [266 rows x 2579 columns]

# %%
School_Final.shape
# Out:
# (2579, 266)

# %% [markdown]
# > From the above code, we have created two new features from our dataset.
#
# > 1. Overall_Achievement_Score_bins:
# this is to group the Overall Achievement Score into bins
# A: 85-100,
# B: 70-84,
# C: 55-69,
# D: 40-54,
# F:<40
# > 2. SchoolWeightedScore: Summation of all achievement measures Scores.`EVAAS Growth Score` and `Overall Achievement Score` are put on bin1 and given a  weight 0.6 of the overall weighted school score. `The ACT Score`, `ACT WorkKeys Score` , and `Math Course Rigor Score` are put in bin 2 carrying a weight of 0.3 while bin3 contains End of Course scores for `Math I Score`, `English II Score`, and `Biology Score` given a weight 0.1. When we get to lab two, we will use these features to see if they improved our model performance.

# %% [markdown]
# ### Moving forward we will use this data with the new created features for modeling...

# %%
modelingdata=School_Final.copy()
modelingdata.head()
# Out:
#    expelled_per_c_num  Avg_Class_Size_01  flicensed_teach_pct  Math SPG Score  \
# 0                 0.0               18.0                0.893            58.0
# 1                 0.0               19.0                0.800            58.0
# 2                 0.0               19.0                1.000            58.0
# 3                 0.0               19.0                0.958            58.0
# 4                 0.0               18.0                1.000            58.0
#
#    st_class_teach_num  st_local_perpupil_num  Avg_Dist_Size_01  \
# 0                  36                2172.86              19.0
# 1                  32                2172.86              19.0
# 2                  54                2172.86              19.0
# 3                  34                2172.86              18.0
# 4                  34                2172.86              18.0
#
#    Math Course Rigor Score  PROMOTED_State_Pct  st_lateral_teach_pct  \
# 0                    100.0               0.856                 0.068
# 1                    100.0               0.856                 0.046
# 2                    100.0               0.856                 0.092
# 3                    100.0               0.856                 0.015
# 4                    100.0               0.856                 0.015
#
#           ...           st_total_expense_num  ap_pct_3_or_above  Byod  \
# 0         ...                        8859.04               0.64    No
# 1         ...                        8859.04               0.40    No
# 2         ...                        8859.04               0.40    No
# 3         ...                        8859.04               0.40    No
# 4         ...                        8859.04               0.40    No
#
#    st_1yr_tchr_trnovr_pct nat_sat_avg_score_num  Dist_Prin_Exp_Pct_4_10_Years  \
# 0                   0.157                  1006                         0.442
# 1                   0.127                  1006                         0.442
# 2                   0.148                  1006                         0.417
# 3                   0.134                  1006                         0.417
# 4                   0.134                  1006                         0.417
#
#   State_Prin_Exp_Pct_10+_Years  st_not_highqual_class_lp_pct  \
# 0                        0.143                         0.024
# 1                        0.143                         0.024
# 2                        0.143                         0.024
# 3                        0.143                         0.024
# 4                        0.143                         0.024
#
#    Overall_Achievement_Score_bins  SchoolWeightedScore
# 0                           55-69               173.07
# 1                           55-69               173.07
# 2                           55-69               173.07
# 3                           55-69               173.07
# 4                           55-69               173.07
#
# [5 rows x 266 columns]

# %% [markdown]
# ### Data pre-processing for Classification <a class="anchor" id="preprocessing"></a>

# %% [markdown]
# #### summer_program_flg  Classification

# %% [markdown]
# For this Classification exercise (Logistic regression and SVM) modeling we have chosen to build models to predict if a school has a summer program  or not which is depicted by the boolean attribute `summer_program_flg` based on all the other features of the North Carolina Education data. In the code block below we create two datasets, the observed data X and an external variable y.

# %%
# %%time
#Create data = x
df_X = modelingdata.copy()
#create target = Y
df_y = df_X.summer_program_flg
print('X shape before ')
print(df_X.shape)
#drop the response column from the x dataset
df_X.pop('summer_program_flg')
print('X shape after ')
print(df_X.shape)
print('Y shape after ')
print(df_y.shape)
# Out:
# X shape before
# (2579, 266)
# X shape after
# (2579, 265)
# Y shape after
# (2579,)
# CPU times: user 3.78 ms, sys: 2.36 ms, total: 6.13 ms
# Wall time: 4.13 ms

# %% [markdown]
# > In above code, we split that data into X and y for modeling

# %% [markdown]
# #### Run Correlation to get the highly correlated columns to eliminate <a class="anchor" id="removeCorrelation"></a>
# > To improve the performance of our logistics regression model, we begin by running a correlation matrix on our X dataset to identify Multicollinearity of predictors and eliminate the highly correlated predictors.

# %%
#finding a list of the most correlated features


temp  = df_X.select_dtypes(include=['int','float']) # select int to run corr on
catcols  = df_X.select_dtypes(include=['object', 'bool', 'category']) #category columns
#print(catcols)
print('X df before running correlation')
print(df_X.shape)
c = temp.corr().abs()
s =pd.DataFrame(c.unstack())
#print(s)
#so = s.order(kind="quicksort")
s['Correlation Pair'] = s.index
s = s.reset_index()
#del s['index']
s.columns = ['Column1', 'Column2', 'correlation','Correlation Pair']
result = s.sort_values('correlation', ascending=0)

#filter to correlation between range
#keepnew =  result[result.Column1 == result.Column2]
result1 =  result[((result.correlation <= 0.95))]

#result1
#combine the columns into a list
col= pd.DataFrame(result1.Column1)
col.columns = ['Columns']
col1 =pd.DataFrame(result1.Column2)
col1.columns = ['Columns']
df = col.append(col1)
#df = df.append(catcols)



#find only unique columns
UniqueColumns =pd.unique(df.Columns)

df_X_temp = df_X[UniqueColumns]

df_X =  pd.concat([df_X_temp, catcols], axis=1)

#shape on the new df_X
df_X.reset_index()
df_y.reset_index()
print('X df after running correlation')
print(df_X.shape)
#print(cols)
##plt.matshow(c)
# Out:
# X df before running correlation
# (2579, 265)
# X df after running correlation
# (2579, 242)

# %% [markdown]
# In the code block above we found and ran correlation matrices on the X df to identify the most strongly correlated features >0.95 and remove them.  **23 features are eliminated for being highly correlated thus redundant.**

# %% [markdown]
# ### Dropping columns that don't have unique values <a class="anchor" id="noUniqueValues"></a>

# %%
## Count unique per columns
#Inspect the high school data fields 
df_X_temp = df_X.copy()
df_X_temp = df_X_temp.describe(include='all').T
# include the data type of the column in the dataframe
df_X_temp['type']= df_X.dtypes
# Reset the index of the dataframe to have index as numbers to have the number of rows visible in the output
df_X_temp.reset_index(inplace=True)
df_X_temp.rename(columns={'index': 'column_name'}, inplace=True)
x= {}
#count unique values per column
for i in df_X.columns:
    #print(i,len(pd.unique(df_X[i])))
    index=i
    unique = len(pd.unique(df_X[i]))
    x.update({index: unique})
temp =pd.DataFrame(list(x.items()), columns=['column_name', 'Unique'])

#merge the two dataframe on column name
df_X_temp = df_X_temp.merge(temp, on='column_name')

# Select columns where unique value is 1
temp1 = df_X_temp[df_X_temp['Unique']==1]

#df_X = df_X.drop(temp1['column_name'], axis =1)

print('###columns to be dropped ####')
df_X.drop( temp1['column_name'], axis=1, inplace=True)
print(temp1['column_name'])
# Out:
# ###columns to be dropped ####
# 172                GCE_SWD_State_Pct
# 173        nat_sat_participation_pct
# 174               PROMOTED_State_Pct
# 175            st_state_perpupil_num
# 176            st_prinyrs_11plus_pct
# 177     State_Prin_Exp_Pct_10+_Years
# 178     st_total_specialized_courses
# 179                 st_prin_male_pct
# 180                GCE_ALL_State_Pct
# 181                st_prin_other_pct
# 182             PASSED_EOG_State_Pct
# 183             st_wap_per_classroom
# 184             PASSED_LAA_State_Pct
# 185             st_books_per_student
# 186        st_stud_internet_comp_num
# 187          st_supplies_expense_pct
# 188          st_ap_participation_pct
# 189          st_services_expense_pct
# 190           st_prinyrs_4thru10_pct
# 191    State_Prin_Exp_Pct_4_10_Years
# 192             st_total_expense_num
# 193            st_prinyrs_0thru3_pct
# 194     State_Prin_Exp_Pct_0_3_Years
# 195                   st_cte_courses
# 196            st_salary_expense_pct
# 197          st_prin_advance_dgr_pct
# 198        st_highqual_class_all_pct
# 199           st_1yr_prin_trnovr_pct
# 200                st_prin_black_pct
# 201          st_univ_college_courses
# 202               st_prin_female_pct
# 203     st_not_highqual_class_lp_pct
# 204          st_benefits_expense_pct
# 205    st_not_highqual_class_all_pct
# 206            st_local_perpupil_num
# 207         st_highqual_class_lp_pct
# 208             st_ap_pct_3_or_above
# 209         st_highqual_class_hp_pct
# 210               RETAINED_State_Pct
# 211     st_not_highqual_class_hp_pct
# 212         st_sat_participation_pct
# 213                 st_ap_ib_courses
# 214        st_instruct_equip_exp_pct
# 215                st_prin_white_pct
# 226                  Closed_Ind_Text
# 230                      New_ind_Txt
# 235                         state_ad
# Name: column_name, dtype: object

# %%
print('New Shape')
df_X.shape
# Out:
# New Shape
# (2579, 195)

# %% [markdown]
# ### Class Distribution <a class="anchor" id="classDistribution"></a>

# %%
# %%time
import collections
import matplotlib.pyplot as plt
a = df_y
data=collections.Counter(a)
print('Summer_program_flg')
print(data)

names = list(data.keys())
values = list(data.values())
plt.figure(figsize = (18,4))
plt.title('Summer_program_flg')
plt.bar(range(len(data)),values,tick_label=names)

#plt.savefig('bar.png')
plt.show()
# Out:
# Summer_program_flg
# Counter({False: 1702, True: 877})
# CPU times: user 276 ms, sys: 15 ms, total: 291 ms
# Wall time: 305 ms

# %% [markdown]
# > There is some imbalance of the class variable, with 66% of schools **not** having a summer school program and 34% of the schools having a summer school program. Whenever we have class imbalance, it might be useful to calculate the accuracy of the **Null Model** - that is, what if our estimator always predicted the majority class?
#
# >A model which always predicts False will have an accuracy of 66%. This number gives us a baseline to compare the model performance (using accuracy as the metric) in the subsequent sections.

# %%
df_X.head()
# Out:
#    st_tchyrs_4thru10_pct  st_flicensed_teach_pct  \
# 0                  0.226                   0.808
# 1                  0.254                   0.895
# 2                  0.235                   0.897
# 3                  0.273                   0.975
# 4                  0.273                   0.975
#
#    State_Tch_Exp_Pct_4_10_Years  local_perpupil_num  total_expense_num  \
# 0                         0.226            2871.810            8297.25
# 1                         0.254            2453.720            7955.28
# 2                         0.235            2423.365            8358.47
# 3                         0.273            2423.365            8358.47
# 4                         0.273            2423.365            8358.47
#
#    PROMOTED_Dist_Pct  RETAINED_Dist_Pct  st_advance_dgr_pct  \
# 0              0.870              0.142               0.277
# 1              0.870              0.142               0.262
# 2              0.870              0.142               0.248
# 3              0.825              0.175               0.285
# 4              0.825              0.175               0.285
#
#    st_avg_student_num  st_crime_per_c_num               ...                \
# 0                 511                0.58               ...
# 1                 475                0.24               ...
# 2                 860                1.27               ...
# 3                 493                0.21               ...
# 4                 493                0.21               ...
#
#    EVAAS Growth Status  category_cd  Reading SPG Grade     calendar_only_txt  \
# 0                  Met            A                  C  Traditional Calendar
# 1                  Met            I                  C  Traditional Calendar
# 2                  Met            H                  C  Traditional Calendar
# 3                  Met            E                  C  Traditional Calendar
# 4                  Met            E                  C  Traditional Calendar
#
#    no_data_spg_flg     scity_ad  clp_ind_flg  State Gap Compared  Byod  \
# 0            False  Mooresville        False                   Y    No
# 1            False  Morrisville        False                   Y    No
# 2            False       Graham        False                   Y    No
# 3            False       Graham        False                   Y    No
# 4            False         Elon        False                   Y    No
#
#    Overall_Achievement_Score_bins
# 0                           55-69
# 1                           55-69
# 2                           55-69
# 3                           55-69
# 4                           55-69
#
# [5 rows x 195 columns]

# %% [markdown]
# ### Create dummy variables <a class="anchor" id="dummyVariables"></a>

# %%
# %%time
def dummy_Create(df):
    schoolDataFinal = df.copy()
    SchoolDataCat = schoolDataFinal.loc[:,(schoolDataFinal.dtypes == object) 
                                        |(schoolDataFinal.dtypes == 'category')]
    
    
    print(SchoolDataCat.columns)
    cat_vars=SchoolDataCat.columns
    for var in cat_vars:
        cat_list='var'+'_'+var
        cat_list = pd.get_dummies(schoolDataFinal[var], prefix=var)
        df=pd.concat([df,cat_list], axis=1)
    data=df
    cat_vars=SchoolDataCat.columns
    data_vars=data.columns.values.tolist()
    
    to_keep=[i for i in data_vars if i not in cat_vars]

    ## Final data columns
    data_final=data[to_keep]
    data_final.columns.values
    data_final_vars=data_final.columns.values.tolist()
    #return(SchoolDataCat)
    y=['summer_program_flg']
    X=[i for i in data_final_vars if i not in y]
 
    list(data_final_vars)
    print(y)
    #print(X)
    SchoolDataCat.describe().T
    return(data_final.abs())
    
df_X_new = dummy_Create(df_X)
# Out:
# Index(['1_to_1_access', 'school_type_txt', 'esea_status', 'type_cd_txt',
#        'grades_1_to_1_access', 'SPG Grade', 'Grad_project_status',
#        'grades_BYOD', 'Math SPG Grade', 'EVAAS Growth Status', 'category_cd',
#        'Reading SPG Grade', 'calendar_only_txt', 'scity_ad',
#        'State Gap Compared', 'Byod', 'Overall_Achievement_Score_bins'],
#       dtype='object')
# ['summer_program_flg']
# CPU times: user 273 ms, sys: 51.4 ms, total: 324 ms
# Wall time: 328 ms

# %% [markdown]
# > For the purpose of modeling, we encoded selected categorical columns as individual integer columns with 1 and zeros. This is achieved using the function above which identifies categorical columns and creates dummy variables for them then deletes the old features from where the dummy variables have been derived from.
#
# > When we attempted to run the logistic model the first time we noticed that some boolean columns we encoded as -1 and 0. We called abs() function on the data to convert all the negative values to positive in order to run our model.

# %% [markdown]
# #### Splitting dataset into train and test datasets

# %%
df_X = df_X_new.copy()
df_X.shape
# Out:
# (2579, 831)

# %%
# pickle the data set
df_X.to_pickle('df_X.pickle')

# %% [markdown]
# > # LOGISTIC REGRESSION and SUPPORT VECTOR MACHINE <a class="anchor" id="question1"></a>

# %%
df_X = pd.read_pickle('df_X.pickle')

# %%
df_X.shape
# Out:
# (2579, 831)

# %% [markdown]
# ### SECTION 1:
# 1. Create a logistic regression model and a support vector machine model for the classification task involved with your dataset.
#
# 2. Assess how well each model performs (use 80/20 training/testing split for your data).
# 3. Adjust parameters of the models to make them more accurate. If your dataset size requires the use of stochastic gradient descent, then linear kernel only is fine to use. That is, the SGDClassifier is fine to use for optimizing logistic regression and linear support vector machines.
# 4. For many problems, SGD will be required in order to train the SVM model in a reasonable timeframe.

# %% [markdown]
# ## Comparing SVM vs Logistic regression accuracy on the same raw data dataset <a class="anchor" id="logVSsvm"></a>

# %% [markdown]
# > After completing the data encoding, we split our data into 80% instances for train dataset and the remaining 20% for the test dataset. We used a random_state seed of 4 to ensure reproducibility of our results.
#
# > For the purposes of cross validation, we repeated this process of separating the testing and training data 3 times. We used the cross validation method built into scikit-learn.
#
# > To easily compare the performance of SVM and Logistics regression models in classification, we ran both models back to back on the same dataset
#
# > `The Code block below is derived from Professor Larson's notebook on Logits and SVM for MSDS 7331` https://github.com/eclarson/DataMiningNotebooks/blob/master/04.%20Logits%20and%20SVM.ipynb

# %%
# %%time
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.model_selection import ShuffleSplit
from sklearn.linear_model import LogisticRegression
from sklearn import metrics as mt
import pandas as pd

Frame = pd.DataFrame() # define dataframe to hold accuracy score

X = df_X.values
y = df_y.values

num_cv_iterations = 3
num_instances = len(y)
cv_object = ShuffleSplit(n_splits=num_cv_iterations,
                         test_size  = 0.2, random_state = 4)
                         
print(cv_object)
svc = SVC() #create a resusable SVC object

lr_clf = LogisticRegression() # get object

iter_num=0
# the indices are the rows used for training and testing in each iteration
for train_indices, test_indices in cv_object.split(X,y): 
    # I will create new variables here so that it is more obvious what 
    # the code is doing (you can compact this syntax and avoid duplicating memory,
    # but it makes this code less readable)
    X_train = X[train_indices]
    y_train = y[train_indices]
    
    X_test = X[test_indices]
    y_test = y[test_indices]
    
    # train the reusable SVC model on the training data
    svc.fit(X_train,y_train)  # train object
    y_hat_SVC = svc.predict(X_test) # get test set precitions
    
    #train the resusable Logistic Regression Model on training data
    lr_clf.fit(X_train,y_train)  # train object
    y_hat_lr = lr_clf.predict(X_test) # get test set precitions

    # now let's get the accuracy and confusion matrix for this iterations of training/testing
    acc_SVC = mt.accuracy_score(y_test,y_hat_SVC)
    acc_LR = mt.accuracy_score(y_test,y_hat_lr)
    #conf = mt.confusion_matrix(y_test,y_hat_SVC)
    print("====Iteration",iter_num," ====")
    print("SVM accuracy :", acc_SVC )
    print("LR  accuracy :", acc_LR )
    temp = {'Iteration':iter_num,'SVM Accuracy':acc_SVC,'Logits Accuracy':acc_LR}
    Frame = Frame.append(pd.DataFrame(list(temp.items()), columns =['Category', 'Value']), ignore_index=True)
    #print("confusion matrix\n",conf)
    iter_num+=1
# Out:
# ShuffleSplit(n_splits=3, random_state=4, test_size=0.2, train_size=None)
# ====Iteration 0  ====
# SVM accuracy : 0.697674418605
# LR  accuracy : 0.763565891473
# ====Iteration 1  ====
# SVM accuracy : 0.664728682171
# LR  accuracy : 0.757751937984
# ====Iteration 2  ====
# SVM accuracy : 0.664728682171
# LR  accuracy : 0.765503875969
# CPU times: user 27.4 s, sys: 393 ms, total: 27.8 s
# Wall time: 28.9 s

# %% [markdown]
# > On the raw dataset, both SVM and Logits are able to classify a school as having either a summer program or not with accuracies above 65%. On three iterations of shuffle split for training and predictions on the same dataset, Logistic Regression performs slightly better with scores of [76.4%, 75.8% and 76.6%] vs SVM scores of [69.8%, 66.5% and 66.5%]. These are results using the same dataset for both models.

# %% [markdown]
# ## Tune Logistic and SVM models <a class="anchor" id="tune"></a>

# %% [markdown]
# ### Approach 1: Finding the optimal Feature selection <a class = "anchor" id="approach1"></a>
#
# > To further optimize the performance of our models we explored feature selection using the chi-squared test. As a recap, chi-square test measures dependence between stochastic variables, so using this function we hoped to weed out the features that are the most likely to be independent of class, and therefore irrelevant for classification.
#
# > Below, we ran a systematic feature selection to identify the optimal number of features that we needed in order to fit our data the best by looking at the model accuracy based on % of features used. We ran this using both SVM and Logits.  Similar to what we did previously we split our data.
#
# > Reference:
# > https://nbviewer.jupyter.org/url/bmobasher.com/Class/CSC478/Titanic.ipynb
#
# > http://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.chi2.html

# %%
#create test and training sets from data and target created above
X_train,X_test,y_train,y_test = train_test_split(df_X, df_y, test_size = 0.2, random_state = 4)

# %%
# %%time
from sklearn import cross_validation
from sklearn import feature_selection
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
LR = LogisticRegression() 
SV = SVC()


percentiles = range(1, 100, 5)
results = []
results2 = []
for i in range(1, 100, 5):
    fs = feature_selection.SelectPercentile(feature_selection.chi2, percentile=i)
    X_train_fs = fs.fit_transform(X_train, y_train)
    scores = cross_validation.cross_val_score(LR, X_train_fs, y_train, cv=2)
    scores2 = cross_validation.cross_val_score(SV, X_train_fs, y_train, cv=2)
    print(i,' LR : ',scores.mean())
    print(i,' SVM :',scores2.mean())
    results = np.append(results, scores.mean())
    results2 = np.append(results2, scores2.mean())
# Out:
# 1  LR :  0.67619963308
# 1  SVM : 0.662626692682
# 6  LR :  0.703837998782
# 6  SVM : 0.654871465199
# 11  LR :  0.710141147678
# 11  SVM : 0.654871465199
# 16  LR :  0.708199403755
# 16  SVM : 0.654871465199
# 21  LR :  0.728564218528
# 21  SVM : 0.655840927375
# 26  LR :  0.695595455605
# 26  SVM : 0.655840927375
# 31  LR :  0.700444176272
# 31  SVM : 0.655840927375
# 36  LR :  0.721763415514
# 36  SVM : 0.655840927375
# 41  LR :  0.698985518688
# 41  SVM : 0.655840927375
# 46  LR :  0.703352562801
# 46  SVM : 0.656810389552
# 51  LR :  0.723214084316
# 51  SVM : 0.656810389552
# 56  LR :  0.694625993429
# 56  SVM : 0.657295355604
# 61  LR :  0.699475184024
# 61  SVM : 0.658264817781
# 66  LR :  0.710616245235
# 66  SVM : 0.658264817781
# 71  LR :  0.703837058925
# 71  SVM : 0.659234279957
# 76  LR :  0.699955450793
# 76  SVM : 0.660203272205
# 81  LR :  0.70576987421
# 81  SVM : 0.659718776081
# 86  LR :  0.707714437703
# 86  SVM : 0.659718776081
# 91  LR :  0.710624234017
# 91  SVM : 0.659718776081
# 96  LR :  0.701900484214
# 96  SVM : 0.660688708186
# CPU times: user 1min 13s, sys: 1.49 s, total: 1min 14s
# Wall time: 1min 11s

# %%
###### Plot percentile of features VS. cross-validation scores
import pylab as pl
pl.figure()
pl.xlabel("Percentage of features selected")
pl.ylabel("Cross validation accuracy")
pl.plot(percentiles,results, label="Logistic Regression")
pl.plot(percentiles,results2, label="SVM")
plt.axis([0, 100, 0.6, 0.8])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.title('Model Accuracy Vs % of features selected')
plt.grid(True)

# %% [markdown]
# > The figure above visualizes comparison of cross validation accuracy vs percentage of features selected for both SVM and Linear Regression model on our North Carolina education data.
#
# > **We note the following trends:**
#
# > 1. For Linear Regression model; 31% of the features gives us the best performing model that fits our data well.  When more than 31% of the features are used, accuracy for Logistic regression model starts to degrade.
#
# > 2.  Accuracy for SVM increases with increasing number of features used. The only down side is it takes much longer to train an SVM model with the increase in the number of features.
#
# > 3.  Across the board, logistic regression is superior to SVM for classification accuracy regardless of the number of features used on our data.
#
# > We chose to proceed with 31% of the features as our optimal number of features to use for our classification task.

# %%
from sklearn import feature_selection
fs = feature_selection.SelectPercentile(feature_selection.chi2, percentile=31)
df_X_train_fs = fs.fit_transform(X_train, y_train)

np.set_printoptions(suppress=True, precision=2, linewidth=80)
print(fs.get_support())
print(fs.scores_)
print('')
Chi2_Score = pd.DataFrame()

for i in range(len(df_X.columns.values)):
    if fs.get_support()[i]:
        #print(df_X.columns.values[i],'\t', fs.scores_[i] )
        Feature ={'Feature': df_X.columns.values[i], 'chi-squared':fs.scores_[i]}
        Chi2_Score =Chi2_Score.append(Feature, ignore_index=True)
Chi2_Score
# Out:
# [False False False  True  True False False False  True False False False False
#   True  True  True  True  True False  True False False False  True  True  True
#  False False False  True False False False False False False False  True  True
#   True  True False False False  True  True  True  True  True False False False
#  False False False False  True  True False False False  True  True  True  True
#   True  True  True  True  True  True  True False False False False False False
#  False False  True  True  True  True  True False False False False False False
#   True False  True False False False False  True  True False  True False False
#  False False False False False False False  True  True False False False False
#  False False False False False False False  True False False False False False
#  False  True  True False False False False False  True False  True  True  True
#   True False False False  True False False False False False False False  True
#  False False False  True False False False False False False False False False
#   True  True  True  True  True  True False  True  True False False  True False
#   True  True  True  True False False False False False  True False False  True
#  False  True False False  True  True False False False False False False False
#  False False False False False  True False False False False False False False
#  False False False  True False False  True  True  True False  True  True  True
#  False False False False False False False False False False False False False
#  False False False False False False False  True False False False False False
#  False False False False False False False  True False False False False False
#  False False False  True  True False False False False False False False False
#  False False False False False False False False  True  True False False  True
#  False False False  True False False False False  True  True  True False  True
#  False False  True  True False False  True  True False  True False False  True
#  False False  True False  True  True False False False False False False False
#  False  True False False False False  True  True False False False False  True
#  False False False False False False False False  True False False  True  True
#   True False False False False False  True False  True  True  True False  True
#  False False  True False  True False False False False  True False  True False
#  False False False  True  True False  True False False False False  True False
#  False False False  True False False False False False  True False False False
#   True False False False False  True False False False  True  True False False
#  False False False False False False  True  True  True False False False  True
#   True  True  True  True  True False False  True False False  True False  True
#   True  True  True False False False False  True False False False False False
#   True False False False  True False  True  True False False False False  True
#   True  True False False False False False False  True False  True  True  True
#   True False False False  True False False  True  True False False False False
#   True False False False  True  True False  True False  True False False  True
#  False False  True  True False False  True  True False  True False False  True
#   True False False False False  True False False False  True False False  True
#   True False False False False False False False  True False False  True False
#  False False  True False False  True False False False  True False  True False
#   True False False False False  True False False  True False False  True  True
#   True False False  True  True False False False False  True False False False
#   True False  True False False  True False  True False  True False  True  True
#  False False  True False False False False  True False False False False  True
#  False False False False  True False False  True False  True False  True  True
#  False False False False False False  True False False False False False False
#  False False False False  True False False False False False False  True False
#   True False False False False False  True  True False False False False  True
#  False  True False False False False False  True  True False  True  True  True
#  False False False  True  True False False False False False  True False  True
#   True False False  True False False False False False False False False False
#  False  True False  True  True False False False False False False False  True
#  False False  True False False False False False False False False False False
#  False False False False False False False False False False False False  True
#   True False  True False False  True False False False False  True False False
#  False False False False  True False False False False False  True False  True
#   True False  True False  True False False  True  True  True  True False False
#  False False False False False False False False False False  True  True False
#   True False False False  True False False False False False False False  True
#  False False False False False False False  True  True False False  True]
# [      0.         0.01       0.        90.28     124.59       0.04       0.32
#        0.        39.13       0.03       1.28       0.         0.96      45.29
#      115.82      84.82      35.71      80.97       0.01      66.8        0.
#        0.         0.        11.05      20.56     133.3        0.09       0.08
#        0.        11.8        0.02       0.02       0.57       0.57       0.76
#        1.92       0.01       6.89       5.35   16209.57     645.21       0.
#        0.05       0.22      30.69      76.83   15793.3    11305.29      38.06
#        0.5        0.08       0.06       0.68       0.68       0.06       1.36
#      481.75     147.91       0.1        0.08       0.76       2.91      34.07
#        5.27       3.09   12664.18      84.36     578.1        2.68       3.92
#        4.72   10861.17       0.52       0.64       0.01       0.02       0.01
#        0.         0.5        0.         4.39       2.11       5.07       6.35
#        3.3        0.97       0.39       0.16       1.46       0.         0.04
#     6173.95       1.98       4.35       0.29       0.         0.05       0.42
#        2.82     150.65       0.04     189.24       1.39       1.35       0.4
#        1.18       0.37       0.06       0.29       0.09       0.05      19.06
#       17.32       0.01       0.5        0.03       0.22       0.         0.
#        0.         0.31       0.35       0.2        0.01  764210.93       0.16
#        0.16       0.13       0.03       0.13       0.         3.5        6.63
#        0.06       0.02       0.26       0.26       1.61       2.96       1.11
#        2.41       7.58       3.76     410.44       0.01       0.01       0.72
#        3.33       0.12       0.07       0.04       0.2        0.01       0.12
#        1.64     353.16       0.         0.         0.01     308.86       0.
#        0.02       0.05       0.         0.         0.01       0.01       0.
#        0.44      22.03      31.97       7.03       3.64      22.95      11.84
#        1.28      18.97       3.3        0.01       0.04      10.11       0.53
#       12.84       2.56       2.11       3.69       0.01       0.4        1.46
#        0.1        0.01       5.69       0.53       1.05      20.04        nan
#        2.14       0.53       0.53       5.27       5.69       0.53       0.53
#        0.21       1.9        0.18       0.53       0.53       0.53       0.
#         nan       0.53       0.11       3.16       1.05       0.53       0.53
#        1.27        nan       0.48       0.         1.9        0.53       0.53
#        2.64       0.53       0.53       5.17       4.44       6.33       2.05
#        5.95       3.5       17.39       0.08       0.95       0.28       0.53
#        0.85       0.53       1.9        0.85        nan       0.53       0.53
#        0.39       1.58       0.47        nan        nan       0.53       0.93
#        0.53       0.53       3.15       1.44       1.9        0.47       0.53
#        0.02       1.9        0.53       1.05       1.37        nan       0.53
#        1.05       2.77       0.53       0.53       0.53       0.53       1.9
#        0.04       1.76       1.9        7.59       4.         0.21       0.85
#        0.53        nan       1.9        0.53       0.53       1.9        1.9
#        0.21       0.21       0.59        nan       1.05       1.9        1.9
#        9.26       4.62       0.12       1.76      10.91       0.2        0.37
#        0.17      11.68       0.08       0.02       0.07       1.89       2.16
#       11.91       9.6        0.01      10.66       0.54       0.35       2.11
#        4.74       1.58       1.05       7.59       4.22       0.53       5.69
#        0.42       0.53       3.15        nan       1.05       5.69       1.05
#        8.44      13.87       0.53       1.9        1.9        1.9         nan
#        0.53       1.9        1.05       5.69        nan       1.05        nan
#        0.53       3.79       2.11       1.9        1.05       0.         0.21
#        2.11       0.42       1.05       0.53       1.05       0.53       1.9
#        0.         0.53       2.11        nan        nan       2.64       3.79
#        3.79       0.42       1.9        1.58       0.         1.9        3.79
#        0.21       9.49       7.91      15.18       1.9        3.79       1.58
#        0.         2.9        0.53       2.9        0.53       0.53       1.05
#        1.58      10.3        0.53       3.79       1.05       0.53       1.9
#        1.9        7.19      40.37       1.37      11.38       0.53       0.
#        1.58       1.05       4.22       1.58       0.21       1.9        1.9
#        5.8        1.37       1.9        1.9        0.53        nan       5.69
#        0.21        nan       1.99       5.69       1.37       1.9        0.53
#         nan       2.64        nan       0.53       0.53       8.12       3.79
#        0.21       1.9        0.53       1.44        nan       1.05       0.53
#         nan       3.79       2.64      11.38       0.53       0.53       1.58
#       11.38      52.71       5.69       3.79       3.79       3.16       1.05
#        1.9        4.74       0.42       1.9        2.11       1.9        3.79
#        2.11       2.11       5.69        nan       0.         1.9        1.9
#        2.11       1.9        1.9        1.9        0.53       1.05      85.82
#        0.53       0.21       1.9        6.33       1.05       4.22       7.59
#        1.05       0.53       1.9        0.53       2.11       4.74       7.59
#        0.36       0.53       1.58       1.9        1.05       1.9        5.65
#        1.9        3.16       2.11      29.47       8.43        nan       0.53
#         nan       3.79       1.9         nan       5.69       9.49       1.9
#         nan       0.53       0.21       3.16       0.53       1.58       0.53
#       18.05      21.09       1.9        4.31       0.53      12.65       0.53
#        1.9        7.45       0.21       1.58       3.69      11.38       1.9
#        0.53       2.11       5.8        0.53       2.64       1.05       1.9
#        4.14       3.16       1.05       0.53        nan       1.9        2.74
#        1.9        0.53       1.05       6.32       1.37       1.44       2.11
#        5.27        nan        nan       0.47       0.53       1.05       0.53
#        1.9        3.79        nan       1.9       11.77       1.05       1.9
#        1.9        2.11       0.6         nan      23.55       0.          nan
#        0.42       3.64       0.53       3.79       0.53       9.94       0.53
#        1.9        0.53       1.9        4.64        nan       1.58       2.11
#        0.         1.9       11.77       3.79       5.69       1.58       0.53
#        6.32       2.11       0.53       0.53       0.53       1.58       2.64
#        0.53       0.53       0.53       3.79       1.05       3.79       1.9
#        0.53       4.74       1.9        8.43        nan       6.17       1.05
#        2.11      14.44       1.05       1.9        7.45       1.05       0.
#         nan       1.05       3.79       1.05       0.53       1.05       1.9
#        5.8        1.9         nan       1.58       1.9        6.85       1.05
#        0.         2.11       0.         5.69       0.53       2.11       2.11
#        0.53       1.05       0.53       1.9        1.05        nan       9.94
#         nan        nan       1.58       1.9        1.05       1.05       1.9
#        1.9         nan       0.53       3.79        nan       1.05       0.53
#        0.53       0.21       0.53       2.9         nan       3.79       1.9
#        1.9        0.53       0.53       0.53      15.18      34.02       0.
#        0.16       0.53       1.05       5.27        nan       2.11       0.21
#        0.42        nan       1.37       1.37       3.79      11.38       1.9
#        3.64       3.79       2.11       1.58       1.9        0.         5.69
#        3.79       1.58       1.72       0.53       0.53       1.9        7.59
#        1.05       3.79      22.96       1.9         nan      28.46       0.53
#        1.9        1.05        nan       1.05       0.53       1.05       1.58
#        0.53       0.53       6.32       0.53       2.74       3.69        nan
#        0.53       0.42       0.53       1.58       1.58       1.05       3.79
#        0.21       1.05       8.12       0.42        nan       0.53       0.53
#        0.53       0.53       1.9        0.01       1.9         nan        nan
#        0.53        nan       0.53       1.9        0.53       0.53       0.53
#        1.05       0.53       0.42       1.58       5.69       5.69       0.53
#        4.22       1.27       0.53      12.65       0.53       0.53       0.53
#         nan       3.79       0.16       0.         1.58       1.9        0.53
#        0.53       5.69       1.05       0.53       1.9        0.53       1.9
#       11.38       1.9        2.18       2.11       0.53       2.9        1.05
#        2.64       1.05       0.32       5.27       2.77       2.9        3.79
#        2.11        nan       1.05       0.53        nan       0.53       0.85
#        1.9        1.58       1.9        0.21       0.53      12.33       2.98
#         nan      11.38       0.21       1.05       0.53      11.59       1.66
#        2.11        nan       1.9        0.53       1.37       0.21       2.9
#        2.11       0.53       1.6        0.04       0.21       0.28       0.88
#        2.57       3.02       0.76       0.06      22.47]
#                                                              Feature  \
# 0                                                 local_perpupil_num
# 1                                                  total_expense_num
# 2                                                 st_avg_student_num
# 3                                                 Reading  SPG Score
# 4                                                         Math Score
# 5                                                         Read Score
# 6                                                SchoolWeightedScore
# 7                                                          SPG Score
# 8                                                     Math SPG Score
# 9                                                   English II Score
# 10                                                     The ACT Score
# 11                                         Overall Achievement Score
# 12                                                     Biology Score
# 13                                               long_susp_per_c_num
# 14                                           lea_long_susp_per_c_num
# 15                                          lea_federal_perpupil_num
# 16                                             lea_sat_avg_score_num
# 17                                              short_susp_per_c_num
# 18                                          lea_short_susp_per_c_num
# 19                                            lea_state_perpupil_num
# 20                                             lea_total_expense_num
# 21                                                 sat_avg_score_num
# 22                                               lea_class_teach_num
# 23                                                     lea_nbpts_num
# 24                                                  Avg_Dist_Size_05
# 25                                                     Science Score
# 26                                                  Avg_Dist_Size_02
# 27                                                  Avg_Dist_Size_01
# 28                                                       student_num
# 29                                                           wap_num
# 30                                                   class_teach_num
# 31                                                  Avg_Dist_Size_03
# 32                                          lea_ap_participation_pct
# 33                                         lea_sat_participation_pct
# 34                                               lea_avg_student_num
# 35                                             Avg_Dist_Size_Biology
# 36                                           Avg_Dist_Size_EnglishII
# 37                                             lea_ap_pct_3_or_above
# 38                                               lea_crime_per_c_num
# 39                                               Avg_Dist_Size_MathI
# 40                                            lea_local_perpupil_num
# 41                                                 wap_per_classroom
# 42                                                  Avg_Dist_Size_00
# 43                                                         nbpts_num
# 44                                              federal_perpupil_num
# 45                                                      Math I Score
# 46                                                state_perpupil_num
# 47                                                       lea_wap_num
# 48                                                 Avg_Class_Size_05
# 49                                                AP_Courses_Offered
# 50                                                 Avg_Class_Size_04
# 51                                                 Avg_Class_Size_01
# 52                                                 Avg_Class_Size_02
# 53                                                 Avg_Class_Size_03
# 54                                             lea_books_per_student
# 55                                        lea_stud_internet_comp_num
# 56                                                 books_per_student
# 57                                                           szip_ad
# 58                                            stud_internet_comp_num
# 59                                          avg_age_media_collection
# 60                                                 digital_media_pct
# 61                                                          stem_flg
# 62                                                   title1_type_flg
# 63                                                    asm_no_spg_flg
# 64                                                   no_data_spg_flg
# 65                                                       clp_ind_flg
# 66                             school_type_txt_Alternative Education
# 67                                     school_type_txt_Magnet School
# 68                                    school_type_txt_Regular School
# 69                                 school_type_txt_Special Education
# 70                              school_type_txt_Vocational Education
# 71                                     grades_1_to_1_access_10:11:12
# 72                                      grades_1_to_1_access_3:04:05
# 73                                         grades_1_to_1_access_4:05
# 74                                            grades_1_to_1_access_5
# 75                                         grades_1_to_1_access_5:06
# 76                                            grades_1_to_1_access_8
# 77                                  grades_1_to_1_access_K:1:2:3:4:5
# 78                                                       SPG Grade_A
# 79                                                    SPG Grade_A+NG
# 80                                                       SPG Grade_B
# 81                                                       SPG Grade_D
# 82                                                       SPG Grade_F
# 83                                                       SPG Grade_I
# 84                                                     grades_BYOD_5
# 85                                                  grades_BYOD_7:08
# 86                                             grades_BYOD_K:1:2:3:4
# 87                                           grades_BYOD_K:1:2:3:4:5
# 88                                                  Math SPG Grade_A
# 89                                                  Math SPG Grade_B
# 90                                                  Math SPG Grade_F
# 91                                                     category_cd_A
# 92                                                     category_cd_T
# 93                                               Reading SPG Grade_A
# 94                                               Reading SPG Grade_B
# 95                                               Reading SPG Grade_D
# 96   calendar_only_txt_Traditional Calendar plus Year-Round Calendar
# 97                             calendar_only_txt_Year-Round Calendar
# 98                                                  scity_ad_Ahoskie
# 99                                                scity_ad_Albemarle
# 100                                                 scity_ad_Andrews
# 101                                                    scity_ad_Apex
# 102                                                   scity_ad_Arden
# 103                                                scity_ad_Asheboro
# 104                                               scity_ad_Asheville
# 105                                             scity_ad_Bakersville
# 106                                              scity_ad_Battleboro
# 107                                                 scity_ad_Bayboro
# 108                                                  scity_ad_Benson
# 109                                                 scity_ad_Bolivia
# 110                                                   scity_ad_Boone
# 111                                               scity_ad_Boonville
# 112                                                  scity_ad_Bostic
# 113                                                    scity_ad_Bunn
# 114                                                  scity_ad_Burgaw
# 115                                              scity_ad_Burlington
# 116                                              scity_ad_Burnsville
# 117                                                  scity_ad_Buxton
# 118                                                 scity_ad_Candler
# 119                                                  scity_ad_Canton
# 120                                                    scity_ad_Cary
# 121                                                scity_ad_Cashiers
# 122                                             scity_ad_Chapel Hill
# 123                                               scity_ad_Charlotte
# 124                                             scity_ad_China Grove
# 125                                                 scity_ad_Clayton
# 126                                                 scity_ad_Clinton
# 127                                                scity_ad_Columbia
# 128                                        scity_ad_Connelly Springs
# 129                                               scity_ad_Cornelius
# 130                                               scity_ad_Creedmoor
# 131                                                scity_ad_Creswell
# 132                                                  scity_ad_Denton
# 133                                                  scity_ad_Denver
# 134                                                  scity_ad_Dobson
# 135                                                    scity_ad_Dunn
# 136                                                  scity_ad_Durham
# 137                                               scity_ad_East Bend
# 138                                          scity_ad_East Flat Rock
# 139                                                scity_ad_Eastover
# 140                                                    scity_ad_Eden
# 141                                          scity_ad_Elizabeth City
# 142                                                   scity_ad_Elkin
# 143                                                 scity_ad_Ellerbe
# 144                                                scity_ad_Elm City
# 145                                                    scity_ad_Elon
# 146                                                 scity_ad_Enfield
# 147                                                scity_ad_Fairmont
# 148                                            scity_ad_Fayetteville
# 149                                             scity_ad_Forest City
# 150                                                scity_ad_Franklin
# 151                                             scity_ad_Franklinton
# 152                                           scity_ad_Fuquay-Varina
# 153                                                  scity_ad_Garner
# 154                                                  scity_ad_Gaston
# 155                                               scity_ad_Goldsboro
# 156                                                  scity_ad_Graham
# 157                                           scity_ad_Granite Falls
# 158                                              scity_ad_Greensboro
# 159                                              scity_ad_Greenville
# 160                                                 scity_ad_Halifax
# 161                                                  scity_ad_Hamlet
# 162                                               scity_ad_Hampstead
# 163                                                scity_ad_Havelock
# 164                                               scity_ad_Henderson
# 165                                          scity_ad_Hendersonville
# 166                                                 scity_ad_Hickory
# 167                                              scity_ad_High Point
# 168                                            scity_ad_Hillsborough
# 169                                           scity_ad_Holly Springs
# 170                                              scity_ad_Hope Mills
# 171                                                  scity_ad_Hudson
# 172                                            scity_ad_Huntersville
# 173                                            scity_ad_Indian Trail
# 174                                            scity_ad_Jacksonville
# 175                                               scity_ad_Jamestown
# 176                                              scity_ad_Kannapolis
# 177                                            scity_ad_Kernersville
# 178                                          scity_ad_Kings Mountain
# 179                                                 scity_ad_Kinston
# 180                                           scity_ad_Lake Waccamaw
# 181                                              scity_ad_Laurinburg
# 182                                                  scity_ad_Leland
# 183                                               scity_ad_Lexington
# 184                                              scity_ad_Lincolnton
# 185                                               scity_ad_Littleton
# 186                                               scity_ad_Louisburg
# 187                                               scity_ad_Lumberton
# 188                                                  scity_ad_Maiden
# 189                                                  scity_ad_Marion
# 190                                               scity_ad_Mars Hill
# 191                                                scity_ad_Marshall
# 192                                                scity_ad_Matthews
# 193                                                  scity_ad_Maxton
# 194                                                  scity_ad_Mebane
# 195                                             scity_ad_Mill Spring
# 196                                             scity_ad_Mills River
# 197                                              scity_ad_Mocksville
# 198                                                  scity_ad_Monroe
# 199                                             scity_ad_Mooresville
# 200                                           scity_ad_Morehead City
# 201                                               scity_ad_Morganton
# 202                                              scity_ad_Mount Airy
# 203                                              scity_ad_Mount Ulla
# 204                                                  scity_ad_Murphy
# 205                                                scity_ad_New Bern
# 206                                                 scity_ad_Newport
# 207                                            scity_ad_Newton Grove
# 208                                        scity_ad_North Wilkesboro
# 209                                                 scity_ad_Norwood
# 210                                                  scity_ad_Oxford
# 211                                                scity_ad_Pinetops
# 212                                               scity_ad_Pittsboro
# 213                                                scity_ad_Plymouth
# 214                                                 scity_ad_Raeford
# 215                                                 scity_ad_Raleigh
# 216                                              scity_ad_Reidsville
# 217                                               scity_ad_Richlands
# 218                                           scity_ad_Robersonville
# 219                                              scity_ad_Rockingham
# 220                                             scity_ad_Rocky Mount
# 221                                             scity_ad_Rocky Point
# 222                                              scity_ad_Rolesville
# 223                                                scity_ad_Roseboro
# 224                                                  scity_ad_Rosman
# 225                                           scity_ad_Rutherfordton
# 226                                               scity_ad_Salemburg
# 227                                               scity_ad_Salisbury
# 228                                                 scity_ad_Sanford
# 229                                                  scity_ad_Shelby
# 230                                              scity_ad_Siler City
# 231                                              scity_ad_Smithfield
# 232                                                 scity_ad_Spencer
# 233                                             scity_ad_Spring Lake
# 234                                                   scity_ad_Sylva
# 235                                              scity_ad_Tabor City
# 236                                                 scity_ad_Tarboro
# 237                                             scity_ad_Thomasville
# 238                                                 scity_ad_Trenton
# 239                                                 scity_ad_Valdese
# 240                                               scity_ad_Wadesboro
# 241                                             scity_ad_Wake Forest
# 242                                              scity_ad_Walkertown
# 243                                             scity_ad_Walnut Cove
# 244                                               scity_ad_Warrenton
# 245                                                  scity_ad_Waxhaw
# 246                                             scity_ad_Waynesville
# 247                                             scity_ad_Weaverville
# 248                                                  scity_ad_Weldon
# 249                                              scity_ad_Wilmington
# 250                                                  scity_ad_Wilson
# 251                                                 scity_ad_Windsor
# 252                                           scity_ad_Winston Salem
# 253                                             scity_ad_Youngsville
# 254                               Overall_Achievement_Score_bins_<40
# 255                             Overall_Achievement_Score_bins_40-54
# 256                            Overall_Achievement_Score_bins_85-100
#
#        chi-squared
# 0        90.280231
# 1       124.591269
# 2        39.132134
# 3        45.293129
# 4       115.819749
# 5        84.815191
# 6        35.709018
# 7        80.969567
# 8        66.795962
# 9        11.054753
# 10       20.562560
# 11      133.300901
# 12       11.799992
# 13        6.891557
# 14        5.345063
# 15    16209.571590
# 16      645.205583
# 17       30.686806
# 18       76.825779
# 19    15793.302835
# 20    11305.287919
# 21       38.056037
# 22      481.745251
# 23      147.911975
# 24        2.912653
# 25       34.070512
# 26        5.265193
# 27        3.092149
# 28    12664.176872
# 29       84.363359
# 30      578.095338
# 31        2.676114
# 32        3.919211
# 33        4.717192
# 34    10861.167382
# 35        4.391751
# 36        2.112867
# 37        5.068380
# 38        6.351455
# 39        3.299373
# 40     6173.949493
# 41        4.353202
# 42        2.816727
# 43      150.652899
# 44      189.242139
# 45       19.061696
# 46       17.323373
# 47   764210.929043
# 48        3.502035
# 49        6.632292
# 50        2.956845
# 51        2.412673
# 52        7.583676
# 53        3.755338
# 54      410.442283
# 55        3.325924
# 56      353.159569
# 57      308.860617
# 58       22.034578
# 59       31.973438
# 60        7.032328
# 61        3.638878
# 62       22.952641
# 63       11.842527
# 64       18.972613
# 65        3.304747
# 66       10.107775
# 67       12.837383
# 68        2.558797
# 69        2.108068
# 70        3.689119
# 71        5.692416
# 72       20.038174
# 73        2.139564
# 74        5.270170
# 75        5.692416
# 76        3.162102
# 77        2.635085
# 78        5.166038
# 79        4.438719
# 80        6.334630
# 81        5.948386
# 82        3.499651
# 83       17.391562
# 84        3.145379
# 85        2.772494
# 86        7.589888
# 87        4.003907
# 88        9.259709
# 89        4.620442
# 90       10.912271
# 91       11.676833
# 92        2.156545
# 93       11.912450
# 94        9.602436
# 95       10.661040
# 96        2.108068
# 97        4.737310
# 98        7.589888
# 99        4.216136
# 100       5.692416
# 101       3.145379
# 102       5.692416
# 103       8.441390
# 104      13.865769
# 105       5.692416
# 106       3.794944
# 107       2.108068
# 108       2.108068
# 109       2.108068
# 110       2.635085
# 111       3.794944
# 112       3.794944
# 113       3.794944
# 114       9.487360
# 115       7.905255
# 116      15.179775
# 117       3.794944
# 118       2.901066
# 119       2.901066
# 120      10.298371
# 121       3.794944
# 122       7.192157
# 123      40.374471
# 124      11.384831
# 125       4.216136
# 126       5.802132
# 127       5.692416
# 128       5.692416
# 129       2.635085
# 130       8.119429
# 131       3.794944
# 132       3.794944
# 133       2.635085
# 134      11.384831
# 135      11.384831
# 136      52.707543
# 137       5.692416
# 138       3.794944
# 139       3.794944
# 140       3.162102
# 141       4.743153
# 142       2.108068
# 143       3.794944
# 144       2.108068
# 145       2.108068
# 146       5.692416
# 147       2.108068
# 148      85.816067
# 149       6.327302
# 150       4.216136
# 151       7.589888
# 152       2.108068
# 153       4.743153
# 154       7.589888
# 155       5.654769
# 156       3.162102
# 157       2.108068
# 158      29.466221
# 159       8.432272
# 160       3.794944
# 161       5.692416
# 162       9.487360
# 163       3.162102
# 164      18.052055
# 165      21.085698
# 166       4.311189
# 167      12.648409
# 168       7.453799
# 169       3.689119
# 170      11.384831
# 171       2.108068
# 172       5.797187
# 173       2.635085
# 174       4.137533
# 175       3.162102
# 176       2.744603
# 177       6.324204
# 178       2.108068
# 179       5.270170
# 180       3.794944
# 181      11.773913
# 182       2.108068
# 183      23.547827
# 184       3.638878
# 185       3.794944
# 186       9.937893
# 187       4.640239
# 188       2.108068
# 189      11.773913
# 190       3.794944
# 191       5.692416
# 192       6.324204
# 193       2.108068
# 194       2.635085
# 195       3.794944
# 196       3.794944
# 197       4.743153
# 198       8.432272
# 199       6.165519
# 200       2.108068
# 201      14.438628
# 202       7.453799
# 203       3.794944
# 204       5.802132
# 205       6.851221
# 206       2.108068
# 207       5.692416
# 208       2.108068
# 209       2.108068
# 210       9.937893
# 211       3.794944
# 212       2.901066
# 213       3.794944
# 214      15.179775
# 215      34.017887
# 216       5.270170
# 217       2.108068
# 218       3.794944
# 219      11.384831
# 220       3.638878
# 221       3.794944
# 222       2.108068
# 223       5.692416
# 224       3.794944
# 225       7.589888
# 226       3.794944
# 227      22.962101
# 228      28.462079
# 229       6.324204
# 230       2.744603
# 231       3.689119
# 232       3.794944
# 233       8.119429
# 234       5.692416
# 235       5.692416
# 236       4.220695
# 237      12.654605
# 238       3.794944
# 239       5.692416
# 240      11.384831
# 241       2.180729
# 242       2.108068
# 243       2.901066
# 244       2.635085
# 245       5.270170
# 246       2.772494
# 247       2.901066
# 248       3.794944
# 249      12.331039
# 250       2.977051
# 251      11.384831
# 252      11.594375
# 253       2.901066
# 254       2.572848
# 255       3.015798
# 256      22.467882

# %% [markdown]
# > * In the code above, we select 31% of the features in our training set based on the Chi2 test.
# > * The above table shows our selected features with their chi-squared score.

# %%
#Update x data to the selected columns from feature selection above
X_train_new = X_train[Chi2_Score.Feature]
X_test_new = X_test[Chi2_Score.Feature]

# %%
# %%time
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
dt = LogisticRegression()
sv = SVC()

lencol = int(0.51*X_train.shape[1]) #count 51% of the columns
X_new = SelectKBest(chi2, k=lencol).fit_transform(X_train, y_train) #select the  best cols

scores = cross_validation.cross_val_score(dt, X_new, y_train, cv=2)
scores2 = cross_validation.cross_val_score(sv, X_new, y_train, cv=2)

#values for 30 fold cross validation
print('Logistic Regression 20 fold cross validation score')
print('-------------------------------')
print(scores)
#average score
print('-------------------------------')
print('Logits average score of the 20 fold cross validation')
print(scores.mean())
#values for 30 fold cross validation
print('SVM 20 fold cross validation score')
print('-------------------------------')
print(scores2)
#average score
print('-------------------------------')
print('SVM average score of the 20 fold cross validation')
print(scores2.mean())
# Out:
# Logistic Regression 20 fold cross validation score
# -------------------------------
# [ 0.69  0.71]
# -------------------------------
# Logits average score of the 20 fold cross validation
# 0.696563977925
# SVM 20 fold cross validation score
# -------------------------------
# [ 0.66  0.66]
# -------------------------------
# SVM average score of the 20 fold cross validation
# 0.656810389552
# CPU times: user 3.45 s, sys: 49.8 ms, total: 3.5 s
# Wall time: 3.11 s

# %% [markdown]
# > A Logistics regression model trained and tested on the training dataset with 31% of features selected based on the chi-square yields 70% accurancy as shown above where as SVM yields 66%.

# %% [markdown]
# ## Approach 2: Tuning Parameters <a class="anchor" id="approach2"></a>

# %% [markdown]
# We will be using `df_X` and `df_y` since we are passing it to cross_val_score.

# %%
# %%time
from sklearn import metrics
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# prepare models
models = []
models.append(("LogReg", LogisticRegression()))
models.append(("LogReg_C2", LogisticRegression(C=2)))
models.append(("LogReg_C10", LogisticRegression(C=10)))
models.append(("SVM", SVC()))
models.append(("SVM_Kernel_linear", SVC(kernel='linear')))
models.append(("SVM_Kernel_linear_C1.5", SVC(C=1.5, kernel='linear')))

# declare results
results = []

# declare names to hold model names
names = []

scoring='accuracy'

for name, model in models:
    kfold = KFold(n_splits=10, shuffle=True, random_state=4)
    cv_results = cross_val_score(model, df_X, df_y, cv=kfold, scoring=scoring)
    results.append(cv_results) 
    names.append(name) 
    print("%s: %f" %(name, cv_results.mean()))
# Out:
# LogReg: 0.745245
# LogReg_C2: 0.740205
# LogReg_C10: 0.749115
# SVM: 0.678552
# SVM_Kernel_linear: 0.733997
# SVM_Kernel_linear_C1.5: 0.720804
# CPU times: user 24min 14s, sys: 20.2 s, total: 24min 34s
# Wall time: 27min 15s

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
fig.suptitle('Model comparision')
ax = fig.add_subplot(111)
plt.boxplot(results)
plt.xlabel("Model")
plt.ylabel("Accuracy")
ax = ax.set_xticklabels(names, rotation='15')

# %% [markdown]
# We chose to manipulate the cost variable with our finalized data set within our logistic regression, and Kernel and Cost in our SVM by analyzing accuracies. Our original default of Cost = 1 produced the highest accuracy ratings in 2 out of 3 iterations. Due to this, we have chosen to leave our model alone, as was originally computed.

# %% [markdown]
# In this section, we will compare the Logistic Regression model with SVM model. The key to a fair comparison of machine learning algorithms is ensuring that each algorithm is evaluated in the same way on the same data. We can achieve this by forcing each algorithm to be evaluated on a consistent test harness.

# %% [markdown]
# ## Approach 3: Using Stochastic Gradient descent <a class="anchor" id="approach3"></a>

# %% [markdown]
# Stochastic Gradient Descent (SGD) is a simple yet very efficient approach to discriminative learning of linear classifiers under convex functions such as (linear) Support Vector Machines and Logistic Regression. The class `SGDClassifier` implements a plain stochastic gradient descent learning routine which supports different loss functions and penalties for classification. The loss function can be set via the `loss` parameter. Using a `loss` function `loss="hinge"` corresponds to *linear Support Vector Machine* and using `loss="log"` corresponds to  *logistic regression*

# %%
# Step 1: import the class
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score


# prepare models
models = []
models.append(('SGD_LR', SGDClassifier(loss = "log", penalty="l2")))
models.append(('SGD_SVM', SGDClassifier(loss = "hinge", penalty="l2")))
models.append(('SGD_LR', SGDClassifier(loss = "log", penalty="l2", n_iter=10)))
models.append(('SGD_SVM', SGDClassifier(loss = "hinge", penalty="l2", n_iter=10)))
models.append(('SGD_LR', SGDClassifier(loss = "log", penalty="l2", n_iter=100)))
models.append(('SGD_SVM', SGDClassifier(loss = "hinge", penalty="l2", n_iter=100)))

# results
results = []
names = []

scoring = 'accuracy'

for name, model in models:
    kfold = KFold(n_splits=10, shuffle=True, random_state=4)
    cv_results = cross_val_score(model, df_X, df_y, cv=kfold, scoring=scoring)
    results.append(cv_results)
    names.append(name)
    print("%s: %f" %(name, cv_results.mean()))

import matplotlib.pyplot as plt
fig = plt.figure()
fig.suptitle('Model comparision')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names, rotation='15')
# Out:
# SGD_LR: 0.648720
# SGD_SVM: 0.659176
# SGD_LR: 0.613825
# SGD_SVM: 0.626245
# SGD_LR: 0.552190
# SGD_SVM: 0.661497
# [<matplotlib.text.Text at 0x11f1ecc88>,
#  <matplotlib.text.Text at 0x11f1f2240>,
#  <matplotlib.text.Text at 0x125b27828>,
#  <matplotlib.text.Text at 0x125b2c358>,
#  <matplotlib.text.Text at 0x125b2ce48>,
#  <matplotlib.text.Text at 0x125b33978>]

# %% [markdown]
# ## Tuning Summary <a class="anchor" id="approachSummary"></a>

# %% [markdown]
# ### SECTION 2: <a class="anchor" id="question2"></a>
#
# 1. Discuss the advantages of each model for each classification task.
# 2. Does one type of model offer superior performance over another in terms of prediction accuracy?
# 3. In terms of training time or efficiency? Explain in detail.

# %% [markdown]
# ### Advantages and Disadvantages of  SVM vs  Logistic Regression

# %% [markdown]
#  #### Advantages

# %% [markdown]
# > ** Logistic Regression **
# > * ** ` Simple nice probabilistic interpretation: `**
# > Since Predictions are mapped to be between 0 and 1 through the logistic function, predictions can be interpreted as class probabilities. This makes Logistic regression a much simpler model to interpret compared to SVM.
#
#
# > ** SVM **
#
# > * ** ` Less overfitting, robust to noise: `**
# > Generally speaking, SVM is robust to outliers for cases where data is linearly separable as it considers only support vectors to set the boundary. Any interior points aren't going to affect the boundary. Once the support vectors are identified, all other instances in the training data could be deleted without changing the position of the dividing hyperplane

# %% [markdown]
#  #### Disadvantages

# %% [markdown]
# > ** Logistic Regression **
#
# > * ** `Overfitting the Model: `**
# > Logistic regression tends to be vulnerable to overconfidence in cases involving imbalanced classes. In such cases, Logistic regression model tends to only predict the majority class data. The features of the minority class are treated as noise and are often ignored. Thus, there is a high probability of misclassification of the minority class as compared to the majority class.  This is a particular important aspect to consider for our model where our predicted variable summer_program_flag is imbalanced with False: 1702 and True: 877 observations.
#
# >    Reference: https://www.analyticsvidhya.com/blog/2017/03/imbalanced-classification-problem/
# >* **`Limited Outcome Variables: `**
# > Logistic regression works well for predicting categorical outcomes like admission and rejection but not continuous like graduation rate which what we plan to predict in Lab 2. We were tempted to attempt to convert the graduation rate into discrete categories like "high graduation" or "low graduation", based on a selected threshold but by doing so we would sacrifice the precision of the data set. This is a significant disadvantage when working with data on a continuous scale. Considering that we decided to classify schools based on whether they have a summer program or not which was already a categorical variable.
#
# > ** SVM **
#
# > * **`Long training time on large data sets: ` **
# > Not considering stochastic gradient descent, SVM is Computationally expensive, thus runs slow.  Shown below, it took 7.36 sec to train an SVM model vs 1.4 seconds needed on the small dataset. These times are bound to scale exponentially for a larger dataset.

# %% [markdown]
# ### Training Time  and Prediction accuracy: SVM vs Logistic Regression

# %% [markdown]
# ###  ** Training time **

# %% [markdown]
# > #### 1. Logistic Regression

# %%
# %%time
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
dt = LogisticRegression(random_state = 4)

scores = cross_validation.cross_val_score(dt, X_train_new, y_train, cv=30)

#values for 30 fold cross validation
print('Logistic Regression 30 fold cross validation score')
print('-------------------------------')
print(scores.mean())
# Out:
# Logistic Regression 30 fold cross validation score
# -------------------------------
# 0.729549384971
# CPU times: user 25.2 s, sys: 460 ms, total: 25.7 s
# Wall time: 23 s

# %% [markdown]
# > #### 2. SVM

# %%
# %%time
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
sv = SVC(random_state = 4)

scores = cross_validation.cross_val_score(sv, X_train_new, y_train, cv=30)

#values for 30 fold cross validation
print('SVM 30 fold cross validation score')
print('-------------------------------')
print(scores.mean())
# Out:
# SVM 30 fold cross validation score
# -------------------------------
# 0.655870377136
# CPU times: user 47 s, sys: 620 ms, total: 47.6 s
# Wall time: 49.2 s

# %% [markdown]
# > #### 3. SGD

# %%
# %%time
from sklearn.linear_model import SGDClassifier

sgd_logreg = SGDClassifier(random_state = 4)

scores = cross_validation.cross_val_score(sgd_logreg, X_train_new, y_train, cv=30)


#values for 30 fold cross validation
print('SGD 30 fold cross validation score')
print('-------------------------------')
print(scores.mean())
# Out:
# SGD 30 fold cross validation score
# -------------------------------
# 0.63939288759
# CPU times: user 2.7 s, sys: 42.9 ms, total: 2.75 s
# Wall time: 1.55 s

# %% [markdown]
# >Fitting SVM on its own is slower than the Linear regression model. It takes about 3X longer to train SVM (1min 21s) compared to Linear regression (26.4 s) on the same selected dataset. Also note, Stochastic Gradient Descent is 10X much fastest than Linear regression on our selected dataset.

# %% [markdown]
# ###  ** Predictive Power **

# %% [markdown]
# > #### 1. Logistic Regression

# %%
# %%time
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

logis= LogisticRegression() 
logis.fit(X_train_new, y_train)

## Predicting the test set results AND calculating the accuracy
y_pred = logis.predict(X_test_new)
print('Accuracy of logistic regression classifier on test set: {:.4f}'.format(logis.score(X_test_new, y_test))) 
conf = mt.confusion_matrix(y_test,y_pred)
print("confusion matrix\n",conf)
# Out:
# Accuracy of logistic regression classifier on test set: 0.7461
# confusion matrix
#  [[297  54]
#  [ 77  88]]
# CPU times: user 885 ms, sys: 13 ms, total: 898 ms
# Wall time: 798 ms

# %% [markdown]
# > #### 2. SVM

# %%
# %%time
from sklearn import metrics
from sklearn.svm import SVC
SV = SVC()
SV.fit(X_train_new, y_train)

## Predicting the test set results AND calculating the accuracy
y_pred = SV.predict(X_test_new)
print('Accuracy of SVM classifier on test set: {:.4f}'.format(SV.score(X_test_new, y_test))) 
conf = mt.confusion_matrix(y_test,y_pred)
print("confusion matrix\n",conf)
# Out:
# Accuracy of SVM classifier on test set: 0.6802
# confusion matrix
#  [[351   0]
#  [165   0]]
# CPU times: user 2.43 s, sys: 27 ms, total: 2.45 s
# Wall time: 2.36 s

# %% [markdown]
# > #### 3. SGD

# %%
# %%time
from sklearn import metrics
from sklearn.linear_model import SGDClassifier

sgd_logreg = SGDClassifier(random_state = 4)

sgd_logreg.fit(X_train_new, y_train)

## Predicting the test set results AND calculating the accuracy
y_pred = SV.predict(X_test_new)
print('Accuracy of SGD classifier on test set: {:.4f}'.format(sgd_logreg.score(X_test_new, y_test))) 
conf = mt.confusion_matrix(y_test,y_pred)
print("confusion matrix\n",conf)
# Out:
# Accuracy of SGD classifier on test set: 0.6802
# confusion matrix
#  [[351   0]
#  [165   0]]
# CPU times: user 424 ms, sys: 6.5 ms, total: 430 ms
# Wall time: 447 ms

# %% [markdown]
# >From an accuracy standpoint, Linear Regression with 80.0%  is the clear winner followed by SVM and SGD which showed similar prediction accuracy of ~68.8%

# %% [markdown]
# ## Summary

# %% [markdown]
# > Referencing the advantages and disadvantages; training time and model accuracy discussed above, below we summaries which model has an upper hand considering our dataset. Our analysis is based on using our final dataset with limited more critical features selected by Chi-Squared. Our training set has 380 features and 516 observations.
#
# >* **** Model Training Time: ****
# > As illustrated above, SVM training with stochastic gradient descent for 30 cross validations about 10X much faster for our selected data set (~2.16s) vs. logistic regression training (~26s). This time is bound to increase with an increase in the size of our dataset. In this regard **`SVM with Stochastic gradient descent`** is the winner.
#
# >* **** Model Prediction Accuracy: ****
# > For a 30-fold cross validation, **`Logistic Regression`** is the clear winner with an accuracy of ~77% vs base SVM accuracy of 65% or SVM with stochastic gradient descent of 64%.

# %% [markdown]
# ## Comparison of Calibration

# %% [markdown]
# > Well calibrated classifiers are probabilistic classifiers for which the output of the predict_proba method can be directly interpreted as a confidence level. For instance, a well calibrated (binary) classifier should classify the samples such that among the samples to which it gave a predict_proba value close to 0.8, approx. 80% actually belong to the positive class. LogisticRegression returns well calibrated predictions as it directly optimizes log-loss.
#
# > Reference: http://scikit-learn.org/stable/auto_examples/calibration/plot_compare_calibration.html#sphx-glr-auto-examples-calibration-plot-compare-calibration-py

# %%
#Update x data to the selected columns from feature selection above
X_train_new = X_train[Chi2_Score.Feature]
X_test_new = X_test[Chi2_Score.Feature]

# %%
# %%time

import numpy as np
np.random.seed(0)

import matplotlib.pyplot as plt

from sklearn import datasets
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.calibration import calibration_curve

lr = LogisticRegression()
svc = LinearSVC(C=1.0)

plt.figure(figsize=(10, 10))
ax1 = plt.subplot2grid((3, 1), (0, 0), rowspan=2)
ax2 = plt.subplot2grid((3, 1), (2, 0))

ax1.plot([0, 1], [0, 1], "k:", label="Perfectly calibrated")
for clf, name in [(lr, 'Logistic'),
                  (svc, 'Support Vector Classification')]:
    clf.fit(X_train_new, y_train)
    if hasattr(clf, "predict_proba"):
        prob_pos = clf.predict_proba(X_test_new)[:, 1]
    else:  # use decision function
        prob_pos = clf.decision_function(X_test_new)
        prob_pos = \
            (prob_pos - prob_pos.min()) / (prob_pos.max() - prob_pos.min())
    fraction_of_positives, mean_predicted_value = \
        calibration_curve(y_test, prob_pos, n_bins=10)

    ax1.plot(mean_predicted_value, fraction_of_positives, "s-",
             label="%s" % (name, ))

    ax2.hist(prob_pos, range=(0, 1), bins=10, label=name,
             histtype="step", lw=2)

ax1.set_ylabel("Fraction of positives")
ax1.set_ylim([-0.05, 1.05])
ax1.legend(loc="lower right")
ax1.set_title('Calibration plots  (reliability curve)')

ax2.set_xlabel("Mean predicted value")
ax2.set_ylabel("Count")
ax2.legend(loc="upper center", ncol=2)

plt.tight_layout()
plt.show()

# Author: Jan Hendrik Metzen <jhm@informatik.uni-bremen.de>
# License: BSD Style.
# Out:
# CPU times: user 2.37 s, sys: 95.1 ms, total: 2.47 s
# Wall time: 2.36 s

# %% [markdown]
# > Logistic Regression returns well calibrated predictions as it directly optimizes log-loss, in contrast to the SVM.

# %% [markdown]
# ### SECTION 3: <a class="anchor" id="question3"></a>
#
# 1. Use the weights from logistic regression to interpret the importance of different features for the classification task.
# 2. Explain your interpretation in detail. Why do you think some variables are more important?

# %% [markdown]
# For this section, we used the `LogisticRegression` model with `C=10`. The weights can be obtained from `coef_` attribute of the model object. We then combine these weights with the corresponding features and sort the features based on the absolute value of the weights. We then list the 20 features which are contributing the most towards this model.

# %%
from sklearn.linear_model import LogisticRegression

# best model
LR = LogisticRegression(C=10)

# fit the model
LR.fit(X_train_new, y_train)

# coefs
coefs = list(abs(LR.coef_[0]))

# features
features = list(X_train_new.columns)

# zip them up
zipped = list(zip(features, coefs))

# create dictionary
coef_features = dict(zipped)

import operator
sorted_coef_features = sorted(coef_features.items(), key=operator.itemgetter(1), reverse=True)

# print features that have weights greater than 
i = 0
for feature, weight in sorted_coef_features:
    if (i <= 10):
        print(feature, weight)
        i=i+1
# Out:
# Avg_Dist_Size_02 0.128043293186
# lea_nbpts_num 0.111065256175
# scity_ad_Fayetteville 0.0827993259475
# Avg_Dist_Size_MathI 0.0808788375473
# stud_internet_comp_num 0.0806093343447
# lea_class_teach_num 0.078313814854
# lea_crime_per_c_num 0.078188766636
# Avg_Dist_Size_03 0.0669375562524
# Avg_Dist_Size_01 0.0632553894358
# scity_ad_Durham 0.0556655794162
# Avg_Class_Size_01 0.0497113122603
# Avg_Dist_Size_Biology 0.0487099369437
# title1_type_flg 0.0483212429782
# wap_per_classroom 0.04584180724
# no_data_spg_flg 0.0392676852021
# Avg_Dist_Size_EnglishII 0.0374638527818
# lea_books_per_student 0.0366004267645
# SPG Grade_I 0.0359483754193
# The ACT Score 0.0347635661469
# Reading SPG Grade_D 0.0341975078222
# Avg_Class_Size_02 0.0320938846834

# %% [markdown]
# The average size of a second grade class at the district level being the highest weighted variable gives us pause. Since we see other elementary classes at the district level with high weights there may perhaps be an interaction between class size and school category that influence whether a school has a summer program. The idea behind this being that schools which have elementary grades would, or would not, have a summer school program depending on the number of students at the school.
#
# The next highest variable, lea_nbpts_num, lends itself to an easier interpretation. This variable represents the number of National Board Certified staff at the district level. To earn this certification, teachers must have taught for more than 3 years, pay the $1,900 fee, and pass the certification process which may take up to five years to complete (http://www.teachhub.com/national-board-certification-why-how-get-it). Teachers who complete such a rigorous process display an intellect and passion that could lead them to push for summer school programs, making it easy to see why having a high number of teachers with this certification would impact a school having these programs or not.
#
# There are a number of variables which we will group together for the next bit of analysis which we believe to be financially driven; scity_ad_Fayetteville, stud_internet_comp_num, scity_ad_Durham, wap_per_classroom, and title1_type_flg. The city fields listed could have more money to pay for summer programs, or perhaps the cities believe summer school programs to be an initiative worth pursuing and therefor the schools within this city tend to have such programs. The number of students with internet connected computers and the number of wireless application protocol devices per program would be higher in schools which had more money. It would seem reasonable that a school that can afford to have a high number of these devices would also be able to have summer programs. If the summer programs were of a technical nature, then this would be even more reason for schools that possess this equipment to offer them. The title1_type_flg variable represents schools that have Title 1 Status. The Title 1 program provides financial assistance to schools with a high percentage of poor students. Allocating some of this money towards summer school programs seems a reasonable assumption.

# %% [markdown]
# ### SECTION 4: <a class="anchor" id="question4"></a>
#
# Look at the chosen support vectors for the classification task.
# 1. Do these provide any insight into the data? Explain.
# 2. If you used stochastic gradient descent (and therefore did not explicitly solve for support vectors), try subsampling your data to train the SVC model— then analyze the support vectors from the subsampled dataset.

# %%
# %%time 
from sklearn import metrics
from sklearn.svm import SVC 
SV = SVC(kernel='linear') 
SV.fit(X_train_new, y_train) ## Predicting the test set results AND calculating the accuracy 
y_pred = SV.predict(X_test_new) 
print('Accuracy of SVM classifier on test set: {:.4f}'.format(SV.score(X_test_new, y_test))) 
conf = mt.confusion_matrix(y_test,y_pred) 
print("confusion matrix\n",conf)
# Out:
# Accuracy of SVM classifier on test set: 0.7287
# confusion matrix
#  [[294  57]
#  [ 83  82]]
# CPU times: user 1min 24s, sys: 2.23 s, total: 1min 26s
# Wall time: 1min 58s

# %%
# get support vectors 
print(SV.support_vectors_.shape) #[n_SV, n_features] 
# get indices of support vectors 
print(SV.support_.shape) #[n_SV] 
# get number of support vectors for each class 
print(SV.n_support_ )
# Out:
# (914, 257)
# (914,)
# [462 452]

# %%
# if using linear kernel, these make sense to look at (not otherwise, why?) 
#print(SV.coef_) 
weights = pd.Series(abs(SV.coef_[0]),index=X_train_new.columns)
topDF = pd.DataFrame(weights)
topDF = topDF.sort(0, ascending=False)
ax = topDF.head(n=20).plot(kind='barh')

# %% [markdown]
# lea_nbpts_num is number 1 in SVM and number 2 in LR.
#
# title1_type_flg - Title 1 is a program that provides financial assistance to schools with a high percentage of poor students
#
# Fayetteville had
#
# Some of these variables make a lot of sense.
#
# wap_per_classroom - Number of Wireless Application Protocol devices per classroom at school level
#
# stud_internet_comp_num - ratio
#
# ACT Score -
#
# Reading SPG Score -
