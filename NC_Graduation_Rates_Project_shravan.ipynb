# %%
import os 

# The normal imports
import numpy as np
import pandas as pd
pd.set_option('display.max_colwidth', -1)

# Import the stats library
from scipy import stats

# These are the plottinglibraries we'll use:
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import seaborn as sns

# Command for plots to appear in the iPython Notebook
# %matplotlib inline

#ignore warnings
import warnings
warnings.filterwarnings("ignore")

#Starting with the dataset that Dr.Drew helped clean.->highschools saved to .cvs file from graduations rates (2) notebook
wd = os.getcwd() #get working directory
#highschools = pd.read_csv(wd+'\\data\\highschools.csv', low_memory=False)
highschools = pd.read_csv(wd+'/data/highschools.csv', low_memory=False)
highschools.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478 entries, 0 to 477
# Columns: 294 entries, Unnamed: 0 to Percent GLP
# dtypes: bool(8), float64(264), int64(9), object(13)
# memory usage: 1.0+ MB

# %%
highschools.columns
# Out:
# Index(['Unnamed: 0', 'unit_code', 'type_cd_txt', 'category_cd',
#        'school_type_txt', 'calendar_only_txt', 'title1_type_flg',
#        'clp_ind_flg', 'focus_clp_flg', 'summer_program_flg',
#        ...
#        'State_Prin_Exp_Pct_10+_Years', 'School Code', 'Subject',
#        'Percent Level 1', 'Percent Level 2', 'Percent Level 3',
#        'Percent Level 4', 'Percent Level 5', 'Percent CCR', 'Percent GLP'],
#       dtype='object', length=294)

# %%
pd.get_option('display.max_columns')
# Out:
# 20

# %%
pd.set_option('display.max_columns', None)

# %%
pd.reset_option('display.max_columns')

# %%
columnNames = highschools.columns

# %%
columnNames
# Out:
# Index(['Unnamed: 0', 'unit_code', 'type_cd_txt', 'category_cd',
#        'school_type_txt', 'calendar_only_txt', 'title1_type_flg',
#        'clp_ind_flg', 'focus_clp_flg', 'summer_program_flg',
#        ...
#        'State_Prin_Exp_Pct_10+_Years', 'School Code', 'Subject',
#        'Percent Level 1', 'Percent Level 2', 'Percent Level 3',
#        'Percent Level 4', 'Percent Level 5', 'Percent CCR', 'Percent GLP'],
#       dtype='object', length=294)

# %%
type(columnNames)
# Out:
# pandas.indexes.base.Index

# %%
columnNames.values
# Out:
# array(['Unnamed: 0', 'unit_code', 'type_cd_txt', 'category_cd',
#        'school_type_txt', 'calendar_only_txt', 'title1_type_flg',
#        'clp_ind_flg', 'focus_clp_flg', 'summer_program_flg',
#        'asm_no_spg_flg', 'no_data_spg_flg', 'esea_status', 'student_num',
#        'lea_avg_student_num', 'st_avg_student_num', 'Grad_project_status',
#        'stem_flg', 'Avg_Class_Size_00', 'Avg_Class_Size_01',
#        'Avg_Class_Size_02', 'Avg_Class_Size_03', 'Avg_Class_Size_04',
#        'Avg_Class_Size_05', 'Avg_Class_Size_06', 'Avg_Class_Size_07',
#        'Avg_Class_Size_08', 'Avg_Class_Size_Biology',
#        'Avg_Class_Size_EnglishII', 'Avg_Class_Size_MathI',
#        'Avg_Dist_Size_00', 'Avg_Dist_Size_01', 'Avg_Dist_Size_02',
#        'Avg_Dist_Size_03', 'Avg_Dist_Size_04', 'Avg_Dist_Size_05',
#        'Avg_Dist_Size_06', 'Avg_Dist_Size_07', 'Avg_Dist_Size_08',
#        'Avg_Dist_Size_Biology', 'Avg_Dist_Size_EnglishII',
#        'Avg_Dist_Size_MathI', 'Avg_State_Size_00', 'Avg_State_Size_01',
#        'Avg_State_Size_02', 'Avg_State_Size_03', 'Avg_State_Size_04',
#        'Avg_State_Size_05', 'Avg_State_Size_06', 'Avg_State_Size_07',
#        'Avg_State_Size_08', 'Avg_State_Size_Biology',
#        'Avg_State_Size_EnglishII', 'Avg_State_Size_MathI',
#        'total_expense_num', 'salary_expense_pct', 'benefits_expense_pct',
#        'services_expense_pct', 'supplies_expense_pct',
#        'instruct_equip_exp_pct', 'other_expense_pct',
#        'federal_perpupil_num', 'local_perpupil_num', 'state_perpupil_num',
#        'lea_total_expense_num', 'lea_salary_expense_pct',
#        'lea_benefits_expense_pct', 'lea_services_expense_pct',
#        'lea_supplies_expense_pct', 'lea_instruct_equip_exp_pct',
#        'lea_other_expense_pct', 'lea_federal_perpupil_num',
#        'lea_local_perpupil_num', 'lea_state_perpupil_num',
#        'st_total_expense_num', 'st_salary_expense_pct',
#        'st_benefits_expense_pct', 'st_services_expense_pct',
#        'st_supplies_expense_pct', 'st_instruct_equip_exp_pct',
#        'st_other_expense_pct', 'st_federal_perpupil_num',
#        'st_local_perpupil_num', 'st_state_perpupil_num', 'SPG Grade',
#        'SPG Score', 'Reading SPG Grade', 'Reading  SPG Score',
#        'Math SPG Grade', 'Math SPG Score', 'EVAAS Growth Status',
#        'EVAAS Growth Score', 'Overall Achievement Score', 'Read Score',
#        'Math Score', 'Science Score', 'Math I Score', 'English II Score',
#        'Biology Score', 'The ACT Score', 'ACT WorkKeys Score',
#        'Math Course Rigor Score', 'Cohort Graduation Rate Standard Score',
#        'State Gap Compared', 'GCE_ALL_School_Pct', 'GCE_LEP_School_Pct',
#        'GCE_PRM_School_Pct', 'GCE_RPF_School_Pct', 'GCE_SWD_School_Pct',
#        'PASSED_EOG_School_Pct', 'PASSED_LAA_School_Pct',
#        'PASSED_RTA_School_Pct', 'PROMOTED_School_Pct',
#        'RETAINED_School_Pct', 'GCE_ALL_Dist_Pct', 'GCE_LEP_Dist_Pct',
#        'GCE_PRM_Dist_Pct', 'GCE_RPF_Dist_Pct', 'GCE_SWD_Dist_Pct',
#        'PASSED_EOG_Dist_Pct', 'PASSED_LAA_Dist_Pct', 'PASSED_RTA_Dist_Pct',
#        'PROMOTED_Dist_Pct', 'RETAINED_Dist_Pct', 'GCE_ALL_State_Pct',
#        'GCE_LEP_State_Pct', 'GCE_PRM_State_Pct', 'GCE_RPF_State_Pct',
#        'GCE_SWD_State_Pct', 'PASSED_EOG_State_Pct', 'PASSED_LAA_State_Pct',
#        'PASSED_RTA_State_Pct', 'PROMOTED_State_Pct', 'RETAINED_State_Pct',
#        'sat_avg_score_num', 'lea_sat_avg_score_num',
#        'st_sat_avg_score_num', 'nat_sat_avg_score_num',
#        'sat_participation_pct', 'lea_sat_participation_pct',
#        'st_sat_participation_pct', 'nat_sat_participation_pct',
#        'esea_attendance', 'lea_esea_attendance', 'ap_participation_pct',
#        'lea_ap_participation_pct', 'st_ap_participation_pct',
#        'ap_pct_3_or_above', 'lea_ap_pct_3_or_above',
#        'st_ap_pct_3_or_above', 'ib_participation_pct',
#        'lea_ib_participation_pct', 'st_ib_participation_pct',
#        'ib_pct_4_or_above', 'lea_ib_pct_4_or_above',
#        'st_ib_pct_4_or_above', 'AP_Courses_Offered',
#        'total_specialized_courses', 'ap_ib_courses', 'cte_courses',
#        'univ_college_courses', 'lea_total_specialized_courses',
#        'lea_ap_ib_courses', 'lea_cte_courses', 'lea_univ_college_courses',
#        'st_total_specialized_courses', 'st_ap_ib_courses',
#        'st_cte_courses', 'st_univ_college_courses',
#        'sch_percent_college_enrolled_16_mos_post_grad',
#        'One_Yr_College_Complete_wi_2_yrs_Enrolled_2012',
#        'avg_daily_attend_pct', 'crime_per_c_num', 'short_susp_per_c_num',
#        'long_susp_per_c_num', 'expelled_per_c_num', 'ttl_crimes_num',
#        'stud_internet_comp_num', 'lea_avg_daily_attend_pct',
#        'lea_crime_per_c_num', 'lea_short_susp_per_c_num',
#        'lea_long_susp_per_c_num', 'lea_expelled_per_c_num',
#        'lea_stud_internet_comp_num', 'st_avg_daily_attend_pct',
#        'st_crime_per_c_num', 'st_short_susp_per_c_num',
#        'st_long_susp_per_c_num', 'st_expelled_per_c_num',
#        'st_stud_internet_comp_num', 'digital_media_pct', 'Byod',
#        'avg_age_media_collection', '1_to_1_access', 'books_per_student',
#        'lea_avg_age_media_collection', 'lea_books_per_student',
#        'st_avg_age_media_collection', 'st_books_per_student', 'wap_num',
#        'wap_per_classroom', 'lea_wap_num', 'lea_wap_per_classroom',
#        'st_wap_num', 'st_wap_per_classroom', 'prin_other_pct',
#        'prinyrs_0thru3_pct', 'prinyrs_4thru10_pct', 'prinyrs_11plus_pct',
#        'prin_advance_dgr_pct', '_1yr_prin_trnovr_pct', 'prin_male_pct',
#        'prin_female_pct', 'prin_black_pct', 'prin_white_pct',
#        'flicensed_teach_pct', 'tchyrs_0thru3_pct', 'tchyrs_4thru10_pct',
#        'tchyrs_11plus_pct', 'class_teach_num', 'nbpts_num',
#        'advance_dgr_pct', '_1yr_tchr_trnovr_pct', 'emer_prov_teach_pct',
#        'lateral_teach_pct', 'highqual_class_pct',
#        'lea_flicensed_teach_pct', 'lea_tchyrs_0thru3_pct',
#        'lea_tchyrs_4thru10_pct', 'lea_tchyrs_11plus_pct',
#        'lea_class_teach_num', 'lea_nbpts_num', 'lea_advance_dgr_pct',
#        'lea_1yr_tchr_trnovr_pct', 'lea_emer_prov_teach_pct',
#        'lea_lateral_teach_pct', 'lea_highqual_class_pct',
#        'lea_highqual_class_hp_pct', 'lea_highqual_class_lp_pct',
#        'lea_highqual_class_all_pct', 'lea_not_highqual_class_hp_pct',
#        'lea_not_highqual_class_lp_pct', 'lea_not_highqual_class_all_pct',
#        'st_flicensed_teach_pct', 'st_tchyrs_0thru3_pct',
#        'st_tchyrs_4thru10_pct', 'st_tchyrs_11plus_pct',
#        'st_class_teach_num', 'st_nbpts_num', 'st_advance_dgr_pct',
#        'st_1yr_tchr_trnovr_pct', 'st_emer_prov_teach_pct',
#        'st_lateral_teach_pct', 'st_highqual_class_pct',
#        'st_highqual_class_hp_pct', 'st_highqual_class_lp_pct',
#        'st_highqual_class_all_pct', 'st_not_highqual_class_hp_pct',
#        'st_not_highqual_class_lp_pct', 'st_not_highqual_class_all_pct',
#        'st_prinyrs_0thru3_pct', 'st_prinyrs_4thru10_pct',
#        'st_prinyrs_11plus_pct', 'st_prin_advance_dgr_pct',
#        'st_1yr_prin_trnovr_pct', 'st_prin_male_pct', 'st_prin_female_pct',
#        'st_prin_black_pct', 'st_prin_white_pct', 'st_prin_other_pct',
#        'Tch_Exp_Pct_0_3_Years', 'Tch_Exp_Pct_4_10_Years',
#        'Tch_Exp_Pct_10+_Years', 'Dist_Tch_Exp_Pct_0_3_Years',
#        'Dist_Tch_Exp_Pct_4_10_Years', 'Dist_Tch_Exp_Pct_10+_Years',
#        'State_Tch_Exp_Pct_0_3_Years', 'State_Tch_Exp_Pct_4_10_Years',
#        'State_Tch_Exp_Pct_10+_Years', 'Dist_Prin_Exp_Pct_0_3_Years',
#        'Dist_Prin_Exp_Pct_4_10_Years', 'Dist_Prin_Exp_Pct_10+_Years',
#        'State_Prin_Exp_Pct_0_3_Years', 'State_Prin_Exp_Pct_4_10_Years',
#        'State_Prin_Exp_Pct_10+_Years', 'School Code', 'Subject',
#        'Percent Level 1', 'Percent Level 2', 'Percent Level 3',
#        'Percent Level 4', 'Percent Level 5', 'Percent CCR', 'Percent GLP'], dtype=object)

# %% [markdown]
# - Collect all column names starting with lea_ and st_

# %%
leaColNames = [col for col in columnNames if col.startswith('lea_')]
stColNames = [col for col in columnNames if col.startswith('st_')]
avgStateColNames = [col for col in columnNames if col.startswith('Avg_State_')]
avgClassColNames = [col for col in columnNames if col.startswith('Avg_Class_')]
avgDistColNames = [col for col in columnNames if col.startswith('Avg_Dist_')]

# %%
excludeColNames = leaColNames + stColNames + avgStateColNames + avgClassColNames + avgDistColNames

# %%
useColNames = [col for col in columnNames if col not in excludeColNames]

# %%
useColNames
# Out:
# ['Unnamed: 0',
#  'unit_code',
#  'type_cd_txt',
#  'category_cd',
#  'school_type_txt',
#  'calendar_only_txt',
#  'title1_type_flg',
#  'clp_ind_flg',
#  'focus_clp_flg',
#  'summer_program_flg',
#  'asm_no_spg_flg',
#  'no_data_spg_flg',
#  'esea_status',
#  'student_num',
#  'Grad_project_status',
#  'stem_flg',
#  'total_expense_num',
#  'salary_expense_pct',
#  'benefits_expense_pct',
#  'services_expense_pct',
#  'supplies_expense_pct',
#  'instruct_equip_exp_pct',
#  'other_expense_pct',
#  'federal_perpupil_num',
#  'local_perpupil_num',
#  'state_perpupil_num',
#  'SPG Grade',
#  'SPG Score',
#  'Reading SPG Grade',
#  'Reading  SPG Score',
#  'Math SPG Grade',
#  'Math SPG Score',
#  'EVAAS Growth Status',
#  'EVAAS Growth Score',
#  'Overall Achievement Score',
#  'Read Score',
#  'Math Score',
#  'Science Score',
#  'Math I Score',
#  'English II Score',
#  'Biology Score',
#  'The ACT Score',
#  'ACT WorkKeys Score',
#  'Math Course Rigor Score',
#  'Cohort Graduation Rate Standard Score',
#  'State Gap Compared',
#  'GCE_ALL_School_Pct',
#  'GCE_LEP_School_Pct',
#  'GCE_PRM_School_Pct',
#  'GCE_RPF_School_Pct',
#  'GCE_SWD_School_Pct',
#  'PASSED_EOG_School_Pct',
#  'PASSED_LAA_School_Pct',
#  'PASSED_RTA_School_Pct',
#  'PROMOTED_School_Pct',
#  'RETAINED_School_Pct',
#  'GCE_ALL_Dist_Pct',
#  'GCE_LEP_Dist_Pct',
#  'GCE_PRM_Dist_Pct',
#  'GCE_RPF_Dist_Pct',
#  'GCE_SWD_Dist_Pct',
#  'PASSED_EOG_Dist_Pct',
#  'PASSED_LAA_Dist_Pct',
#  'PASSED_RTA_Dist_Pct',
#  'PROMOTED_Dist_Pct',
#  'RETAINED_Dist_Pct',
#  'GCE_ALL_State_Pct',
#  'GCE_LEP_State_Pct',
#  'GCE_PRM_State_Pct',
#  'GCE_RPF_State_Pct',
#  'GCE_SWD_State_Pct',
#  'PASSED_EOG_State_Pct',
#  'PASSED_LAA_State_Pct',
#  'PASSED_RTA_State_Pct',
#  'PROMOTED_State_Pct',
#  'RETAINED_State_Pct',
#  'sat_avg_score_num',
#  'nat_sat_avg_score_num',
#  'sat_participation_pct',
#  'nat_sat_participation_pct',
#  'esea_attendance',
#  'ap_participation_pct',
#  'ap_pct_3_or_above',
#  'ib_participation_pct',
#  'ib_pct_4_or_above',
#  'AP_Courses_Offered',
#  'total_specialized_courses',
#  'ap_ib_courses',
#  'cte_courses',
#  'univ_college_courses',
#  'sch_percent_college_enrolled_16_mos_post_grad',
#  'One_Yr_College_Complete_wi_2_yrs_Enrolled_2012',
#  'avg_daily_attend_pct',
#  'crime_per_c_num',
#  'short_susp_per_c_num',
#  'long_susp_per_c_num',
#  'expelled_per_c_num',
#  'ttl_crimes_num',
#  'stud_internet_comp_num',
#  'digital_media_pct',
#  'Byod',
#  'avg_age_media_collection',
#  '1_to_1_access',
#  'books_per_student',
#  'wap_num',
#  'wap_per_classroom',
#  'prin_other_pct',
#  'prinyrs_0thru3_pct',
#  'prinyrs_4thru10_pct',
#  'prinyrs_11plus_pct',
#  'prin_advance_dgr_pct',
#  '_1yr_prin_trnovr_pct',
#  'prin_male_pct',
#  'prin_female_pct',
#  'prin_black_pct',
#  'prin_white_pct',
#  'flicensed_teach_pct',
#  'tchyrs_0thru3_pct',
#  'tchyrs_4thru10_pct',
#  'tchyrs_11plus_pct',
#  'class_teach_num',
#  'nbpts_num',
#  'advance_dgr_pct',
#  '_1yr_tchr_trnovr_pct',
#  'emer_prov_teach_pct',
#  'lateral_teach_pct',
#  'highqual_class_pct',
#  'Tch_Exp_Pct_0_3_Years',
#  'Tch_Exp_Pct_4_10_Years',
#  'Tch_Exp_Pct_10+_Years',
#  'Dist_Tch_Exp_Pct_0_3_Years',
#  'Dist_Tch_Exp_Pct_4_10_Years',
#  'Dist_Tch_Exp_Pct_10+_Years',
#  'State_Tch_Exp_Pct_0_3_Years',
#  'State_Tch_Exp_Pct_4_10_Years',
#  'State_Tch_Exp_Pct_10+_Years',
#  'Dist_Prin_Exp_Pct_0_3_Years',
#  'Dist_Prin_Exp_Pct_4_10_Years',
#  'Dist_Prin_Exp_Pct_10+_Years',
#  'State_Prin_Exp_Pct_0_3_Years',
#  'State_Prin_Exp_Pct_4_10_Years',
#  'State_Prin_Exp_Pct_10+_Years',
#  'School Code',
#  'Subject',
#  'Percent Level 1',
#  'Percent Level 2',
#  'Percent Level 3',
#  'Percent Level 4',
#  'Percent Level 5',
#  'Percent CCR',
#  'Percent GLP']

# %%
len(useColNames)
# Out:
# 151

# %% [markdown]
# > Count the number of missing values in

# %% [markdown]
# ## Digress to understand loc, iloc and ix
# loc, iloc and ix are dataframe methods to access rows and columns. They are very flexible and powerful.

# %%
highschools[useColNames].clp_ind_flg.sum()
# Out:
# 56

# %%
highschools[useColNames].stem_flg.sum()
# Out:
# 6

# %%
highschools[useColNames].esea_status.head()
# Out:
# 0    Non_Esea
# 1    Non_Esea
# 2    Non_Esea
# 3    Non_Esea
# 4    Non_Esea
# Name: esea_status, dtype: object

# %%
highschools[useColNames].esea_status.value_counts()
# Out:
# Non_Esea     459
# Esea_Pass    17
# Esea_Fail    2
# Name: esea_status, dtype: int64

# %%
highschoolsFiltered = highschools[useColNames]

# %%
highschoolsFiltered.loc[highschoolsFiltered.esea_status == "Esea_Pass", ['unit_code', 'school_type_txt', 'esea_status']]
# Out:
#     unit_code school_type_txt esea_status
# 10   40306     Regular School  Esea_Pass
# 72   181318    Regular School  Esea_Pass
# 113  260455    Regular School  Esea_Pass
# 139  320314    Regular School  Esea_Pass
# 141  320325    Regular School  Esea_Pass
# 185  400308    Regular School  Esea_Pass
# 210  420358    Regular School  Esea_Pass
# 283  600386    Regular School  Esea_Pass
# 296  600576    Regular School  Esea_Pass
# 297  600579    Regular School  Esea_Pass
# 346  740344    Regular School  Esea_Pass
# 348  740374    Regular School  Esea_Pass
# 349  740388    Regular School  Esea_Pass
# 364  780325    Regular School  Esea_Pass
# 365  780342    Regular School  Esea_Pass
# 450  930352    Regular School  Esea_Pass
# 458  960335    Regular School  Esea_Pass

# %%
pd.get_option('display.max_rows')
# Out:
# 60

# %%
pd.set_option('display.max_rows', None)

# %%
pd.reset_option('display.max_rows')

# %% [markdown]
# ## Find missing values

# %% [markdown]
# Use the entire highschool dataframe and find the columns with highest number of missing values.

# %%
highschools.shape
# Out:
# (478, 294)

# %% [markdown]
# Out of this 294 columns, how many of them have 100% missing data ?

# %%
highschools.isnull().tail()
# Out:
#     Unnamed: 0 unit_code type_cd_txt category_cd school_type_txt  \
# 473  False      False     False       False       False
# 474  False      False     False       False       False
# 475  False      False     False       False       False
# 476  False      False     False       False       False
# 477  False      False     False       False       False
#
#     calendar_only_txt title1_type_flg clp_ind_flg focus_clp_flg  \
# 473  False             False           False       False
# 474  False             False           False       False
# 475  False             False           False       False
# 476  False             False           False       False
# 477  False             False           False       False
#
#     summer_program_flg asm_no_spg_flg no_data_spg_flg esea_status student_num  \
# 473  False              False          False           False       False
# 474  False              False          False           False       False
# 475  False              False          False           False       False
# 476  False              False          False           False       False
# 477  False              False          False           False       False
#
#     lea_avg_student_num st_avg_student_num Grad_project_status stem_flg  \
# 473  False               False              False               False
# 474  False               False              False               False
# 475  False               False              False               False
# 476  False               False              False               False
# 477  False               False              False               False
#
#     Avg_Class_Size_00 Avg_Class_Size_01 Avg_Class_Size_02 Avg_Class_Size_03  \
# 473  False             False             False             False
# 474  True              True              True              True
# 475  True              True              True              True
# 476  True              True              True              True
# 477  True              True              True              True
#
#     Avg_Class_Size_04 Avg_Class_Size_05 Avg_Class_Size_06 Avg_Class_Size_07  \
# 473  False             False             False             True
# 474  True              True              True              True
# 475  True              True              True              True
# 476  True              True              True              True
# 477  True              True              True              True
#
#     Avg_Class_Size_08 Avg_Class_Size_Biology Avg_Class_Size_EnglishII  \
# 473  True              True                   True
# 474  True              False                  False
# 475  True              False                  False
# 476  True              False                  False
# 477  True              False                  False
#
#     Avg_Class_Size_MathI Avg_Dist_Size_00 Avg_Dist_Size_01 Avg_Dist_Size_02  \
# 473  True                 False            False            False
# 474  False                True             True             True
# 475  False                True             True             True
# 476  False                True             True             True
# 477  False                True             True             True
#
#     Avg_Dist_Size_03 Avg_Dist_Size_04 Avg_Dist_Size_05 Avg_Dist_Size_06  \
# 473  False            False            False            False
# 474  True             True             True             True
# 475  True             True             True             True
# 476  True             True             True             True
# 477  True             True             True             True
#
#     Avg_Dist_Size_07 Avg_Dist_Size_08 Avg_Dist_Size_Biology  \
# 473  True             True             True
# 474  True             True             False
# 475  True             True             False
# 476  True             True             False
# 477  True             True             False
#
#     Avg_Dist_Size_EnglishII Avg_Dist_Size_MathI Avg_State_Size_00  \
# 473  True                    True                False
# 474  False                   False               True
# 475  False                   False               True
# 476  False                   False               True
# 477  False                   False               True
#
#     Avg_State_Size_01 Avg_State_Size_02 Avg_State_Size_03 Avg_State_Size_04  \
# 473  False             False             False             False
# 474  True              True              True              True
# 475  True              True              True              True
# 476  True              True              True              True
# 477  True              True              True              True
#
#     Avg_State_Size_05 Avg_State_Size_06 Avg_State_Size_07 Avg_State_Size_08  \
# 473  False             False             True              True
# 474  True              True              True              True
# 475  True              True              True              True
# 476  True              True              True              True
# 477  True              True              True              True
#
#     Avg_State_Size_Biology Avg_State_Size_EnglishII Avg_State_Size_MathI  \
# 473  True                   True                     True
# 474  False                  False                    False
# 475  False                  False                    False
# 476  False                  False                    False
# 477  False                  False                    False
#
#     total_expense_num salary_expense_pct benefits_expense_pct  \
# 473  True              True               True
# 474  True              True               True
# 475  True              True               True
# 476  True              True               True
# 477  True              True               True
#
#     services_expense_pct supplies_expense_pct instruct_equip_exp_pct  \
# 473  True                 True                 True
# 474  True                 True                 True
# 475  True                 True                 True
# 476  True                 True                 True
# 477  True                 True                 True
#
#     other_expense_pct federal_perpupil_num local_perpupil_num  \
# 473  True              True                 True
# 474  True              True                 True
# 475  True              True                 True
# 476  True              True                 True
# 477  True              True                 True
#
#     state_perpupil_num lea_total_expense_num lea_salary_expense_pct  \
# 473  True               False                 False
# 474  True               False                 False
# 475  True               False                 False
# 476  True               False                 False
# 477  True               False                 False
#
#     lea_benefits_expense_pct lea_services_expense_pct  \
# 473  False                    False
# 474  False                    False
# 475  False                    False
# 476  False                    False
# 477  False                    False
#
#     lea_supplies_expense_pct lea_instruct_equip_exp_pct lea_other_expense_pct  \
# 473  False                    False                      False
# 474  False                    False                      False
# 475  False                    False                      False
# 476  False                    False                      False
# 477  False                    False                      False
#
#     lea_federal_perpupil_num lea_local_perpupil_num lea_state_perpupil_num  \
# 473  False                    False                  False
# 474  False                    False                  False
# 475  False                    False                  False
# 476  False                    False                  False
# 477  False                    False                  False
#
#     st_total_expense_num st_salary_expense_pct st_benefits_expense_pct  \
# 473  False                False                 False
# 474  False                False                 False
# 475  False                False                 False
# 476  False                False                 False
# 477  False                False                 False
#
#     st_services_expense_pct st_supplies_expense_pct st_instruct_equip_exp_pct  \
# 473  False                   False                   False
# 474  False                   False                   False
# 475  False                   False                   False
# 476  False                   False                   False
# 477  False                   False                   False
#
#     st_other_expense_pct st_federal_perpupil_num st_local_perpupil_num  \
# 473  False                False                   False
# 474  False                False                   False
# 475  False                False                   False
# 476  False                False                   False
# 477  False                False                   False
#
#     st_state_perpupil_num SPG Grade SPG Score Reading SPG Grade  \
# 473  False                 False     False     False
# 474  False                 False     False     True
# 475  False                 False     False     True
# 476  False                 False     False     True
# 477  False                 False     False     True
#
#     Reading  SPG Score Math SPG Grade Math SPG Score EVAAS Growth Status  \
# 473  False              False          False          False
# 474  True               True           True           False
# 475  True               True           True           False
# 476  True               True           True           False
# 477  True               True           True           False
#
#     EVAAS Growth Score Overall Achievement Score Read Score Math Score  \
# 473  False              False                     False      False
# 474  False              False                     True       True
# 475  False              False                     True       True
# 476  False              False                     True       True
# 477  False              False                     True       True
#
#     Science Score Math I Score English II Score Biology Score The ACT Score  \
# 473  False         True         True             True          True
# 474  True          False        False            False         False
# 475  True          False        False            False         False
# 476  True          False        False            False         False
# 477  True          False        False            False         False
#
#     ACT WorkKeys Score Math Course Rigor Score  \
# 473  True               True
# 474  False              False
# 475  False              False
# 476  True               False
# 477  False              False
#
#     Cohort Graduation Rate Standard Score State Gap Compared  \
# 473  True                                  True
# 474  False                                 True
# 475  False                                 True
# 476  False                                 False
# 477  False                                 True
#
#     GCE_ALL_School_Pct GCE_LEP_School_Pct GCE_PRM_School_Pct  \
# 473  False              True               True
# 474  True               True               True
# 475  True               True               True
# 476  True               True               True
# 477  True               True               True
#
#     GCE_RPF_School_Pct GCE_SWD_School_Pct PASSED_EOG_School_Pct  \
# 473  True               False              False
# 474  True               True               True
# 475  True               True               True
# 476  True               True               True
# 477  True               True               True
#
#     PASSED_LAA_School_Pct PASSED_RTA_School_Pct PROMOTED_School_Pct  \
# 473  True                  True                  False
# 474  True                  True                  True
# 475  True                  True                  True
# 476  True                  True                  True
# 477  True                  True                  True
#
#     RETAINED_School_Pct GCE_ALL_Dist_Pct GCE_LEP_Dist_Pct GCE_PRM_Dist_Pct  \
# 473  True                False            True             True
# 474  True                True             True             True
# 475  True                True             True             True
# 476  True                True             True             True
# 477  True                True             True             True
#
#     GCE_RPF_Dist_Pct GCE_SWD_Dist_Pct PASSED_EOG_Dist_Pct PASSED_LAA_Dist_Pct  \
# 473  False            False            False               False
# 474  True             True             True                True
# 475  True             True             True                True
# 476  True             True             True                True
# 477  True             True             True                True
#
#     PASSED_RTA_Dist_Pct PROMOTED_Dist_Pct RETAINED_Dist_Pct GCE_ALL_State_Pct  \
# 473  True                False             False             False
# 474  True                True              True              True
# 475  True                True              True              True
# 476  True                True              True              True
# 477  True                True              True              True
#
#     GCE_LEP_State_Pct GCE_PRM_State_Pct GCE_RPF_State_Pct GCE_SWD_State_Pct  \
# 473  True              True              True              False
# 474  True              True              True              True
# 475  True              True              True              True
# 476  True              True              True              True
# 477  True              True              True              True
#
#     PASSED_EOG_State_Pct PASSED_LAA_State_Pct PASSED_RTA_State_Pct  \
# 473  False                False                True
# 474  True                 True                 True
# 475  True                 True                 True
# 476  True                 True                 True
# 477  True                 True                 True
#
#     PROMOTED_State_Pct RETAINED_State_Pct sat_avg_score_num  \
# 473  False              False              True
# 474  True               True               False
# 475  True               True               False
# 476  True               True               False
# 477  True               True               False
#
#     lea_sat_avg_score_num st_sat_avg_score_num nat_sat_avg_score_num  \
# 473  False                 False                False
# 474  False                 False                False
# 475  False                 False                False
# 476  False                 False                False
# 477  False                 False                False
#
#     sat_participation_pct lea_sat_participation_pct st_sat_participation_pct  \
# 473  True                  False                     False
# 474  False                 False                     False
# 475  False                 False                     False
# 476  False                 False                     False
# 477  False                 False                     False
#
#     nat_sat_participation_pct esea_attendance lea_esea_attendance  \
# 473  False                     True            True
# 474  False                     True            True
# 475  False                     True            True
# 476  False                     True            True
# 477  False                     True            True
#
#     ap_participation_pct lea_ap_participation_pct st_ap_participation_pct  \
# 473  True                 True                     False
# 474  False                True                     False
# 475  True                 True                     False
# 476  True                 True                     False
# 477  True                 True                     False
#
#     ap_pct_3_or_above lea_ap_pct_3_or_above st_ap_pct_3_or_above  \
# 473  True              False                 False
# 474  False             False                 False
# 475  False             False                 False
# 476  True              False                 False
# 477  False             False                 False
#
#     ib_participation_pct lea_ib_participation_pct st_ib_participation_pct  \
# 473  True                 True                     True
# 474  True                 True                     True
# 475  True                 True                     True
# 476  True                 True                     True
# 477  True                 True                     True
#
#     ib_pct_4_or_above lea_ib_pct_4_or_above st_ib_pct_4_or_above  \
# 473  True              True                  False
# 474  True              True                  False
# 475  True              True                  False
# 476  True              True                  False
# 477  True              True                  False
#
#     AP_Courses_Offered total_specialized_courses ap_ib_courses cte_courses  \
# 473  True               False                     True          True
# 474  True               False                     False         False
# 475  True               False                     False         False
# 476  True               False                     True          False
# 477  False              False                     False         False
#
#     univ_college_courses lea_total_specialized_courses lea_ap_ib_courses  \
# 473  True                 False                         False
# 474  False                False                         False
# 475  False                False                         False
# 476  False                False                         False
# 477  False                False                         False
#
#     lea_cte_courses lea_univ_college_courses st_total_specialized_courses  \
# 473  False           False                    False
# 474  False           False                    False
# 475  False           False                    False
# 476  False           False                    False
# 477  False           False                    False
#
#     st_ap_ib_courses st_cte_courses st_univ_college_courses  \
# 473  False            False          False
# 474  False            False          False
# 475  False            False          False
# 476  False            False          False
# 477  False            False          False
#
#     sch_percent_college_enrolled_16_mos_post_grad  \
# 473  True
# 474  False
# 475  False
# 476  False
# 477  False
#
#     One_Yr_College_Complete_wi_2_yrs_Enrolled_2012 avg_daily_attend_pct  \
# 473  True                                           False
# 474  False                                          False
# 475  False                                          False
# 476  False                                          False
# 477  False                                          False
#
#     crime_per_c_num short_susp_per_c_num long_susp_per_c_num  \
# 473  False           False                False
# 474  False           False                False
# 475  False           False                False
# 476  False           False                False
# 477  False           False                False
#
#     expelled_per_c_num ttl_crimes_num stud_internet_comp_num  \
# 473  False              True           False
# 474  False              True           False
# 475  False              True           False
# 476  False              True           False
# 477  False              True           False
#
#     lea_avg_daily_attend_pct lea_crime_per_c_num lea_short_susp_per_c_num  \
# 473  False                    False               False
# 474  False                    False               False
# 475  False                    False               False
# 476  False                    False               False
# 477  False                    False               False
#
#     lea_long_susp_per_c_num lea_expelled_per_c_num lea_stud_internet_comp_num  \
# 473  False                   False                  False
# 474  False                   False                  False
# 475  False                   False                  False
# 476  False                   False                  False
# 477  False                   False                  False
#
#     st_avg_daily_attend_pct st_crime_per_c_num st_short_susp_per_c_num  \
# 473  False                   False              False
# 474  False                   False              False
# 475  False                   False              False
# 476  False                   False              False
# 477  False                   False              False
#
#     st_long_susp_per_c_num st_expelled_per_c_num st_stud_internet_comp_num  \
# 473  False                  False                 False
# 474  False                  False                 False
# 475  False                  False                 False
# 476  False                  False                 False
# 477  False                  False                 False
#
#     digital_media_pct   Byod avg_age_media_collection 1_to_1_access  \
# 473  False             False  False                    False
# 474  False             False  False                    False
# 475  False             False  False                    False
# 476  True              True   True                     True
# 477  False             False  False                    False
#
#     books_per_student lea_avg_age_media_collection lea_books_per_student  \
# 473  False             False                        False
# 474  False             False                        False
# 475  False             False                        False
# 476  True              True                         True
# 477  False             False                        False
#
#     st_avg_age_media_collection st_books_per_student wap_num  \
# 473  False                       False                False
# 474  False                       False                False
# 475  False                       False                False
# 476  True                        True                 False
# 477  False                       False                False
#
#     wap_per_classroom lea_wap_num lea_wap_per_classroom st_wap_num  \
# 473  False             False       False                 False
# 474  False             False       False                 False
# 475  False             False       False                 False
# 476  False             False       False                 False
# 477  False             False       False                 False
#
#     st_wap_per_classroom prin_other_pct prinyrs_0thru3_pct  \
# 473  False                True           True
# 474  False                True           True
# 475  False                True           True
# 476  False                True           True
# 477  False                True           True
#
#     prinyrs_4thru10_pct prinyrs_11plus_pct prin_advance_dgr_pct  \
# 473  True                True               True
# 474  True                True               True
# 475  True                True               True
# 476  True                True               True
# 477  True                True               True
#
#     _1yr_prin_trnovr_pct prin_male_pct prin_female_pct prin_black_pct  \
# 473  True                 True          True            True
# 474  True                 True          True            True
# 475  True                 True          True            True
# 476  True                 True          True            True
# 477  True                 True          True            True
#
#     prin_white_pct flicensed_teach_pct tchyrs_0thru3_pct tchyrs_4thru10_pct  \
# 473  True           False               False             False
# 474  True           False               False             False
# 475  True           False               False             False
# 476  True           False               False             False
# 477  True           False               False             False
#
#     tchyrs_11plus_pct class_teach_num nbpts_num advance_dgr_pct  \
# 473  False             False           False     False
# 474  False             False           False     False
# 475  False             False           False     False
# 476  False             False           True      False
# 477  False             False           False     False
#
#     _1yr_tchr_trnovr_pct emer_prov_teach_pct lateral_teach_pct  \
# 473  False                True                True
# 474  False                True                False
# 475  False                True                False
# 476  False                True                True
# 477  False                True                False
#
#     highqual_class_pct lea_flicensed_teach_pct lea_tchyrs_0thru3_pct  \
# 473  False              False                   False
# 474  False              False                   False
# 475  False              False                   False
# 476  False              False                   False
# 477  False              False                   False
#
#     lea_tchyrs_4thru10_pct lea_tchyrs_11plus_pct lea_class_teach_num  \
# 473  False                  False                 False
# 474  False                  False                 False
# 475  False                  False                 False
# 476  False                  False                 False
# 477  False                  False                 False
#
#     lea_nbpts_num lea_advance_dgr_pct lea_1yr_tchr_trnovr_pct  \
# 473  False         False               False
# 474  False         False               False
# 475  False         False               False
# 476  False         False               False
# 477  False         False               False
#
#     lea_emer_prov_teach_pct lea_lateral_teach_pct lea_highqual_class_pct  \
# 473  True                    False                 False
# 474  True                    False                 False
# 475  True                    False                 False
# 476  True                    False                 False
# 477  True                    False                 False
#
#     lea_highqual_class_hp_pct lea_highqual_class_lp_pct  \
# 473  False                     False
# 474  False                     False
# 475  False                     False
# 476  False                     False
# 477  False                     True
#
#     lea_highqual_class_all_pct lea_not_highqual_class_hp_pct  \
# 473  False                      False
# 474  False                      False
# 475  False                      False
# 476  False                      False
# 477  False                      False
#
#     lea_not_highqual_class_lp_pct lea_not_highqual_class_all_pct  \
# 473  False                         False
# 474  False                         False
# 475  False                         False
# 476  False                         False
# 477  True                          False
#
#     st_flicensed_teach_pct st_tchyrs_0thru3_pct st_tchyrs_4thru10_pct  \
# 473  False                  False                False
# 474  False                  False                False
# 475  False                  False                False
# 476  False                  False                False
# 477  False                  False                False
#
#     st_tchyrs_11plus_pct st_class_teach_num st_nbpts_num st_advance_dgr_pct  \
# 473  False                False              False        False
# 474  False                False              False        False
# 475  False                False              False        False
# 476  False                False              False        False
# 477  False                False              False        False
#
#     st_1yr_tchr_trnovr_pct st_emer_prov_teach_pct st_lateral_teach_pct  \
# 473  False                  False                  False
# 474  False                  False                  False
# 475  False                  False                  False
# 476  False                  False                  False
# 477  False                  False                  False
#
#     st_highqual_class_pct st_highqual_class_hp_pct st_highqual_class_lp_pct  \
# 473  False                 False                    False
# 474  False                 False                    False
# 475  False                 False                    False
# 476  False                 False                    False
# 477  False                 False                    False
#
#     st_highqual_class_all_pct st_not_highqual_class_hp_pct  \
# 473  False                     False
# 474  False                     False
# 475  False                     False
# 476  False                     False
# 477  False                     False
#
#     st_not_highqual_class_lp_pct st_not_highqual_class_all_pct  \
# 473  False                        False
# 474  False                        False
# 475  False                        False
# 476  False                        False
# 477  False                        False
#
#     st_prinyrs_0thru3_pct st_prinyrs_4thru10_pct st_prinyrs_11plus_pct  \
# 473  False                 False                  False
# 474  False                 False                  False
# 475  False                 False                  False
# 476  False                 False                  False
# 477  False                 False                  False
#
#     st_prin_advance_dgr_pct st_1yr_prin_trnovr_pct st_prin_male_pct  \
# 473  False                   False                  False
# 474  False                   False                  False
# 475  False                   False                  False
# 476  False                   False                  False
# 477  False                   False                  False
#
#     st_prin_female_pct st_prin_black_pct st_prin_white_pct st_prin_other_pct  \
# 473  False              False             False             False
# 474  False              False             False             False
# 475  False              False             False             False
# 476  False              False             False             False
# 477  False              False             False             False
#
#     Tch_Exp_Pct_0_3_Years Tch_Exp_Pct_4_10_Years Tch_Exp_Pct_10+_Years  \
# 473  False                 False                  False
# 474  False                 False                  False
# 475  False                 False                  False
# 476  False                 False                  False
# 477  False                 False                  False
#
#     Dist_Tch_Exp_Pct_0_3_Years Dist_Tch_Exp_Pct_4_10_Years  \
# 473  False                      False
# 474  False                      False
# 475  False                      False
# 476  False                      False
# 477  False                      False
#
#     Dist_Tch_Exp_Pct_10+_Years State_Tch_Exp_Pct_0_3_Years  \
# 473  False                      False
# 474  False                      False
# 475  False                      False
# 476  False                      False
# 477  False                      False
#
#     State_Tch_Exp_Pct_4_10_Years State_Tch_Exp_Pct_10+_Years  \
# 473  False                        False
# 474  False                        False
# 475  False                        False
# 476  False                        False
# 477  False                        False
#
#     Dist_Prin_Exp_Pct_0_3_Years Dist_Prin_Exp_Pct_4_10_Years  \
# 473  False                       False
# 474  False                       False
# 475  False                       False
# 476  False                       False
# 477  False                       False
#
#     Dist_Prin_Exp_Pct_10+_Years State_Prin_Exp_Pct_0_3_Years  \
# 473  False                       False
# 474  False                       False
# 475  False                       False
# 476  False                       False
# 477  False                       False
#
#     State_Prin_Exp_Pct_4_10_Years State_Prin_Exp_Pct_10+_Years School Code  \
# 473  False                         False                        True
# 474  False                         False                        True
# 475  False                         False                        True
# 476  False                         False                        True
# 477  False                         False                        True
#
#     Subject Percent Level 1 Percent Level 2 Percent Level 3 Percent Level 4  \
# 473  True    True            True            True            True
# 474  True    True            True            True            True
# 475  True    True            True            True            True
# 476  True    True            True            True            True
# 477  True    True            True            True            True
#
#     Percent Level 5 Percent CCR Percent GLP
# 473  True            True        True
# 474  True            True        True
# 475  True            True        True
# 476  True            True        True
# 477  True            True        True

# %%
highschools.tail()
# Out:
#      Unnamed: 0 unit_code type_cd_txt category_cd school_type_txt  \
# 473  2398        990304    Public      A           Regular School
# 474  2404        990322    Public      H           Regular School
# 475  2407        990326    Public      H           Regular School
# 476  2409        990332    Public      H           Regular School
# 477  2419        995330    Public      H           Regular School
#
#         calendar_only_txt title1_type_flg clp_ind_flg focus_clp_flg  \
# 473  Traditional Calendar  True            False       False
# 474  Traditional Calendar  False           False       False
# 475  Traditional Calendar  False           False       False
# 476  Traditional Calendar  False           False       False
# 477  Traditional Calendar  False           False       False
#
#     summer_program_flg asm_no_spg_flg no_data_spg_flg esea_status  \
# 473  True               False          False           Non_Esea
# 474  False              False          False           Non_Esea
# 475  False              False          False           Non_Esea
# 476  False              False          False           Non_Esea
# 477  True               False          False           Non_Esea
#
#      student_num  lea_avg_student_num  st_avg_student_num Grad_project_status  \
# 473  332.0        188.0                511                 False
# 474  893.0        571.0                860                 False
# 475  609.0        571.0                860                 False
# 476  212.0        571.0                860                 False
# 477  691.0        691.0                860                 False
#
#     stem_flg  Avg_Class_Size_00  Avg_Class_Size_01  Avg_Class_Size_02  \
# 473  False    18.0               19.0               17.0
# 474  False   NaN                NaN                NaN
# 475  False   NaN                NaN                NaN
# 476  False   NaN                NaN                NaN
# 477  False   NaN                NaN                NaN
#
#      Avg_Class_Size_03  Avg_Class_Size_04  Avg_Class_Size_05  \
# 473  20.0               19.0               25.0
# 474 NaN                NaN                NaN
# 475 NaN                NaN                NaN
# 476 NaN                NaN                NaN
# 477 NaN                NaN                NaN
#
#      Avg_Class_Size_06  Avg_Class_Size_07  Avg_Class_Size_08  \
# 473  17.0              NaN                NaN
# 474 NaN                NaN                NaN
# 475 NaN                NaN                NaN
# 476 NaN                NaN                NaN
# 477 NaN                NaN                NaN
#
#      Avg_Class_Size_Biology  Avg_Class_Size_EnglishII  Avg_Class_Size_MathI  \
# 473 NaN                     NaN                       NaN
# 474  19.0                    22.0                      16.0
# 475  21.0                    19.0                      20.0
# 476  24.0                    23.0                      21.0
# 477  17.0                    16.0                      19.0
#
#      Avg_Dist_Size_00  Avg_Dist_Size_01  Avg_Dist_Size_02  Avg_Dist_Size_03  \
# 473  18.0              17.0              16.0              16.0
# 474 NaN               NaN               NaN               NaN
# 475 NaN               NaN               NaN               NaN
# 476 NaN               NaN               NaN               NaN
# 477 NaN               NaN               NaN               NaN
#
#      Avg_Dist_Size_04  Avg_Dist_Size_05  Avg_Dist_Size_06  Avg_Dist_Size_07  \
# 473  19.0              19.0              21.0             NaN
# 474 NaN               NaN               NaN               NaN
# 475 NaN               NaN               NaN               NaN
# 476 NaN               NaN               NaN               NaN
# 477 NaN               NaN               NaN               NaN
#
#      Avg_Dist_Size_08  Avg_Dist_Size_Biology  Avg_Dist_Size_EnglishII  \
# 473 NaN               NaN                    NaN
# 474 NaN                21.0                   21.0
# 475 NaN                21.0                   21.0
# 476 NaN                21.0                   21.0
# 477 NaN                17.0                   16.0
#
#      Avg_Dist_Size_MathI  Avg_State_Size_00  Avg_State_Size_01  \
# 473 NaN                   19.0               19.0
# 474  17.0                NaN                NaN
# 475  17.0                NaN                NaN
# 476  17.0                NaN                NaN
# 477  20.0                NaN                NaN
#
#      Avg_State_Size_02  Avg_State_Size_03  Avg_State_Size_04  \
# 473  19.0               19.0               20.0
# 474 NaN                NaN                NaN
# 475 NaN                NaN                NaN
# 476 NaN                NaN                NaN
# 477 NaN                NaN                NaN
#
#      Avg_State_Size_05  Avg_State_Size_06  Avg_State_Size_07  \
# 473  21.0               21.0              NaN
# 474 NaN                NaN                NaN
# 475 NaN                NaN                NaN
# 476 NaN                NaN                NaN
# 477 NaN                NaN                NaN
#
#      Avg_State_Size_08  Avg_State_Size_Biology  Avg_State_Size_EnglishII  \
# 473 NaN                NaN                     NaN
# 474 NaN                 18.0                    18.0
# 475 NaN                 18.0                    18.0
# 476 NaN                 18.0                    18.0
# 477 NaN                 18.0                    18.0
#
#      Avg_State_Size_MathI  total_expense_num  salary_expense_pct  \
# 473 NaN                   NaN                NaN
# 474  20.0                 NaN                NaN
# 475  20.0                 NaN                NaN
# 476  20.0                 NaN                NaN
# 477  20.0                 NaN                NaN
#
#      benefits_expense_pct  services_expense_pct  supplies_expense_pct  \
# 473 NaN                   NaN                   NaN
# 474 NaN                   NaN                   NaN
# 475 NaN                   NaN                   NaN
# 476 NaN                   NaN                   NaN
# 477 NaN                   NaN                   NaN
#
#      instruct_equip_exp_pct  other_expense_pct  federal_perpupil_num  \
# 473 NaN                     NaN                NaN
# 474 NaN                     NaN                NaN
# 475 NaN                     NaN                NaN
# 476 NaN                     NaN                NaN
# 477 NaN                     NaN                NaN
#
#      local_perpupil_num  state_perpupil_num  lea_total_expense_num  \
# 473 NaN                 NaN                  9227.72
# 474 NaN                 NaN                  9227.72
# 475 NaN                 NaN                  9227.72
# 476 NaN                 NaN                  9227.72
# 477 NaN                 NaN                  10730.22
#
#      lea_salary_expense_pct  lea_benefits_expense_pct  \
# 473  0.647                   0.22
# 474  0.647                   0.22
# 475  0.647                   0.22
# 476  0.647                   0.22
# 477  0.621                   0.21
#
#      lea_services_expense_pct  lea_supplies_expense_pct  \
# 473  0.060                     0.066
# 474  0.060                     0.066
# 475  0.060                     0.066
# 476  0.060                     0.066
# 477  0.084                     0.061
#
#      lea_instruct_equip_exp_pct  lea_other_expense_pct  \
# 473  0.007                       0.0
# 474  0.007                       0.0
# 475  0.007                       0.0
# 476  0.007                       0.0
# 477  0.024                       0.0
#
#      lea_federal_perpupil_num  lea_local_perpupil_num  lea_state_perpupil_num  \
# 473  1067.33                   1696.76                 6463.63
# 474  1067.33                   1696.76                 6463.63
# 475  1067.33                   1696.76                 6463.63
# 476  1067.33                   1696.76                 6463.63
# 477  1297.05                   2203.00                 7230.17
#
#      st_total_expense_num  st_salary_expense_pct  st_benefits_expense_pct  \
# 473  8859.04               0.62                   0.205
# 474  8859.04               0.62                   0.205
# 475  8859.04               0.62                   0.205
# 476  8859.04               0.62                   0.205
# 477  8859.04               0.62                   0.205
#
#      st_services_expense_pct  st_supplies_expense_pct  \
# 473  0.09                     0.075
# 474  0.09                     0.075
# 475  0.09                     0.075
# 476  0.09                     0.075
# 477  0.09                     0.075
#
#      st_instruct_equip_exp_pct  st_other_expense_pct  st_federal_perpupil_num  \
# 473  0.01                       0                     967.75
# 474  0.01                       0                     967.75
# 475  0.01                       0                     967.75
# 476  0.01                       0                     967.75
# 477  0.01                       0                     967.75
#
#      st_local_perpupil_num  st_state_perpupil_num SPG Grade  SPG Score  \
# 473  2172.86                5718.43                C         64.0
# 474  2172.86                5718.43                B         72.0
# 475  2172.86                5718.43                B         70.0
# 476  2172.86                5718.43                A         91.0
# 477  2172.86                5718.43                B         72.0
#
#     Reading SPG Grade  Reading  SPG Score Math SPG Grade  Math SPG Score  \
# 473  C                 63.0                C              63.0
# 474  NaN              NaN                  NaN           NaN
# 475  NaN              NaN                  NaN           NaN
# 476  NaN              NaN                  NaN           NaN
# 477  NaN              NaN                  NaN           NaN
#
#     EVAAS Growth Status  EVAAS Growth Score  Overall Achievement Score  \
# 473  Exceeded            91.5                58.0
# 474  Met                 83.2                69.0
# 475  Met                 83.9                66.0
# 476  Exceeded            85.4                92.0
# 477  NotMet              62.7                75.0
#
#      Read Score  Math Score  Science Score  Math I Score  English II Score  \
# 473  57.0        56.0        69.0          NaN           NaN
# 474 NaN         NaN         NaN             42.0          61.0
# 475 NaN         NaN         NaN             60.0          50.0
# 476 NaN         NaN         NaN             88.0          94.0
# 477 NaN         NaN         NaN             61.0          62.0
#
#      Biology Score  The ACT Score  ACT WorkKeys Score  \
# 473 NaN            NaN            NaN
# 474  66.0           56.0           71.0
# 475  58.0           46.0           57.0
# 476  83.0           90.0          NaN
# 477  75.0           56.0           82.0
#
#      Math Course Rigor Score  Cohort Graduation Rate Standard Score  \
# 473 NaN                      NaN
# 474  94.0                     93.0
# 475  92.0                     92.0
# 476  100.0                    100.0
# 477  100.0                    92.0
#
#     State Gap Compared  GCE_ALL_School_Pct  GCE_LEP_School_Pct  \
# 473  NaN                0.208              NaN
# 474  NaN               NaN                 NaN
# 475  NaN               NaN                 NaN
# 476  N                 NaN                 NaN
# 477  NaN               NaN                 NaN
#
#      GCE_PRM_School_Pct  GCE_RPF_School_Pct  GCE_SWD_School_Pct  \
# 473 NaN                 NaN                  0.208
# 474 NaN                 NaN                 NaN
# 475 NaN                 NaN                 NaN
# 476 NaN                 NaN                 NaN
# 477 NaN                 NaN                 NaN
#
#      PASSED_EOG_School_Pct  PASSED_LAA_School_Pct  PASSED_RTA_School_Pct  \
# 473  0.521                 NaN                    NaN
# 474 NaN                    NaN                    NaN
# 475 NaN                    NaN                    NaN
# 476 NaN                    NaN                    NaN
# 477 NaN                    NaN                    NaN
#
#      PROMOTED_School_Pct  RETAINED_School_Pct  GCE_ALL_Dist_Pct  \
# 473  0.95                NaN                   0.238
# 474 NaN                  NaN                  NaN
# 475 NaN                  NaN                  NaN
# 476 NaN                  NaN                  NaN
# 477 NaN                  NaN                  NaN
#
#      GCE_LEP_Dist_Pct  GCE_PRM_Dist_Pct  GCE_RPF_Dist_Pct  GCE_SWD_Dist_Pct  \
# 473 NaN               NaN                0.104             0.101
# 474 NaN               NaN               NaN               NaN
# 475 NaN               NaN               NaN               NaN
# 476 NaN               NaN               NaN               NaN
# 477 NaN               NaN               NaN               NaN
#
#      PASSED_EOG_Dist_Pct  PASSED_LAA_Dist_Pct  PASSED_RTA_Dist_Pct  \
# 473  0.542                0.136               NaN
# 474 NaN                  NaN                  NaN
# 475 NaN                  NaN                  NaN
# 476 NaN                  NaN                  NaN
# 477 NaN                  NaN                  NaN
#
#      PROMOTED_Dist_Pct  RETAINED_Dist_Pct  GCE_ALL_State_Pct  \
# 473  0.946              0.054              0.112
# 474 NaN                NaN                NaN
# 475 NaN                NaN                NaN
# 476 NaN                NaN                NaN
# 477 NaN                NaN                NaN
#
#      GCE_LEP_State_Pct  GCE_PRM_State_Pct  GCE_RPF_State_Pct  \
# 473 NaN                NaN                NaN
# 474 NaN                NaN                NaN
# 475 NaN                NaN                NaN
# 476 NaN                NaN                NaN
# 477 NaN                NaN                NaN
#
#      GCE_SWD_State_Pct  PASSED_EOG_State_Pct  PASSED_LAA_State_Pct  \
# 473  0.065              0.579                 0.11
# 474 NaN                NaN                   NaN
# 475 NaN                NaN                   NaN
# 476 NaN                NaN                   NaN
# 477 NaN                NaN                   NaN
#
#      PASSED_RTA_State_Pct  PROMOTED_State_Pct  RETAINED_State_Pct  \
# 473 NaN                    0.856               0.144
# 474 NaN                   NaN                 NaN
# 475 NaN                   NaN                 NaN
# 476 NaN                   NaN                 NaN
# 477 NaN                   NaN                 NaN
#
#      sat_avg_score_num  lea_sat_avg_score_num  st_sat_avg_score_num  \
# 473 NaN                 965.0                  997
# 474  983.0              965.0                  997
# 475  927.0              965.0                  997
# 476  1020.0             965.0                  997
# 477  1029.0             1029.0                 997
#
#      nat_sat_avg_score_num  sat_participation_pct  lea_sat_participation_pct  \
# 473  1006                  NaN                     0.33
# 474  1006                   0.37                   0.33
# 475  1006                   0.39                   0.33
# 476  1006                   0.08                   0.33
# 477  1006                   0.27                   0.27
#
#      st_sat_participation_pct  nat_sat_participation_pct  esea_attendance  \
# 473  0.49                      0.52                      NaN
# 474  0.49                      0.52                      NaN
# 475  0.49                      0.52                      NaN
# 476  0.49                      0.52                      NaN
# 477  0.49                      0.52                      NaN
#
#      lea_esea_attendance  ap_participation_pct  lea_ap_participation_pct  \
# 473 NaN                  NaN                   NaN
# 474 NaN                   0.06                 NaN
# 475 NaN                  NaN                   NaN
# 476 NaN                  NaN                   NaN
# 477 NaN                  NaN                   NaN
#
#      st_ap_participation_pct  ap_pct_3_or_above  lea_ap_pct_3_or_above  \
# 473  0.15                    NaN                 0.59
# 474  0.15                     0.59               0.59
# 475  0.15                     0.57               0.59
# 476  0.15                    NaN                 0.59
# 477  0.15                     0.79               0.79
#
#      st_ap_pct_3_or_above  ib_participation_pct  lea_ib_participation_pct  \
# 473  0.51                 NaN                   NaN
# 474  0.51                 NaN                   NaN
# 475  0.51                 NaN                   NaN
# 476  0.51                 NaN                   NaN
# 477  0.51                 NaN                   NaN
#
#      st_ib_participation_pct  ib_pct_4_or_above  lea_ib_pct_4_or_above  \
# 473 NaN                      NaN                NaN
# 474 NaN                      NaN                NaN
# 475 NaN                      NaN                NaN
# 476 NaN                      NaN                NaN
# 477 NaN                      NaN                NaN
#
#      st_ib_pct_4_or_above  AP_Courses_Offered  total_specialized_courses  \
# 473  0.75                 NaN                  1.0
# 474  0.75                 NaN                  1.0
# 475  0.75                 NaN                  1.0
# 476  0.75                 NaN                  1.0
# 477  0.75                  5.0                 1.0
#
#      ap_ib_courses  cte_courses  univ_college_courses  \
# 473 NaN            NaN          NaN
# 474  0.060470       0.866741     0.064950
# 475  0.022989       0.901478     0.077176
# 476 NaN             0.509434     1.000000
# 477  0.045655       0.777614     0.234168
#
#      lea_total_specialized_courses  lea_ap_ib_courses  lea_cte_courses  \
# 473  1.0                            0.039125           0.830840
# 474  1.0                            0.039125           0.830840
# 475  1.0                            0.039125           0.830840
# 476  1.0                            0.039125           0.830840
# 477  1.0                            0.045655           0.777614
#
#      lea_univ_college_courses  st_total_specialized_courses  st_ap_ib_courses  \
# 473  0.182969                  0.964635                      0.1649
# 474  0.182969                  0.964635                      0.1649
# 475  0.182969                  0.964635                      0.1649
# 476  0.182969                  0.964635                      0.1649
# 477  0.234168                  0.964635                      0.1649
#
#      st_cte_courses  st_univ_college_courses  \
# 473  0.639203        0.07064
# 474  0.639203        0.07064
# 475  0.639203        0.07064
# 476  0.639203        0.07064
# 477  0.639203        0.07064
#
#      sch_percent_college_enrolled_16_mos_post_grad  \
# 473 NaN
# 474  52.709360
# 475  43.046358
# 476  50.000000
# 477  50.285714
#
#      One_Yr_College_Complete_wi_2_yrs_Enrolled_2012  avg_daily_attend_pct  \
# 473 NaN                                              1.000
# 474  52.709360                                       0.960
# 475  43.046358                                       0.947
# 476  50.000000                                       0.991
# 477  50.285714                                       0.941
#
#      crime_per_c_num  short_susp_per_c_num  long_susp_per_c_num  \
# 473  0.30             1.20                  0.30
# 474  1.12             8.17                  0.00
# 475  0.82             6.40                  0.00
# 476  0.00             0.47                  0.00
# 477  1.88             10.13                 0.58
#
#      expelled_per_c_num  ttl_crimes_num  stud_internet_comp_num  \
# 473  0.0                NaN              2.04
# 474  0.0                NaN              0.86
# 475  0.0                NaN              0.72
# 476  0.0                NaN              0.81
# 477  0.0                NaN              0.61
#
#      lea_avg_daily_attend_pct  lea_crime_per_c_num  lea_short_susp_per_c_num  \
# 473  0.962                     0.53                 14.36
# 474  0.960                     0.88                 6.59
# 475  0.960                     0.88                 6.59
# 476  0.960                     0.88                 6.59
# 477  0.946                     1.88                 10.13
#
#      lea_long_susp_per_c_num  lea_expelled_per_c_num  \
# 473  0.27                     0.0
# 474  0.00                     0.0
# 475  0.00                     0.0
# 476  0.00                     0.0
# 477  0.58                     0.0
#
#      lea_stud_internet_comp_num  st_avg_daily_attend_pct  st_crime_per_c_num  \
# 473  0.90                        0.958                    0.58
# 474  0.90                        0.951                    1.27
# 475  0.90                        0.951                    1.27
# 476  0.90                        0.951                    1.27
# 477  0.76                        0.951                    1.27
#
#      st_short_susp_per_c_num  st_long_susp_per_c_num  st_expelled_per_c_num  \
# 473  8.39                     0.06                    0
# 474  14.02                    0.07                    0
# 475  14.02                    0.07                    0
# 476  14.02                    0.07                    0
# 477  14.02                    0.07                    0
#
#      st_stud_internet_comp_num  digital_media_pct Byod  \
# 473  1.2                        0.05               No
# 474  1.2                        0.02               Yes
# 475  1.2                        0.01               Yes
# 476  1.2                       NaN                 NaN
# 477  1.2                        0.18               Yes
#
#      avg_age_media_collection 1_to_1_access  books_per_student  \
# 473  1994.0                    No            46.20
# 474  1995.0                    Yes           14.16
# 475  1996.0                    Yes           13.28
# 476 NaN                        NaN          NaN
# 477  1999.0                    Yes           18.14
#
#      lea_avg_age_media_collection  lea_books_per_student  \
# 473  1999.0                        24.13
# 474  1999.0                        24.13
# 475  1999.0                        24.13
# 476 NaN                           NaN
# 477  1998.0                        32.94
#
#      st_avg_age_media_collection  st_books_per_student  wap_num  \
# 473  2000.0                       19.18                 11.0
# 474  2000.0                       19.18                 46.0
# 475  2000.0                       19.18                 48.0
# 476 NaN                          NaN                    7.0
# 477  2000.0                       19.18                 75.0
#
#      wap_per_classroom  lea_wap_num  lea_wap_per_classroom  st_wap_num  \
# 473  0.42               217.0        0.51                   111757
# 474  0.71               217.0        0.51                   111757
# 475  1.02               217.0        0.51                   111757
# 476  0.58               217.0        0.51                   111757
# 477  1.39               250.0        1.46                   111757
#
#      st_wap_per_classroom  prin_other_pct  prinyrs_0thru3_pct  \
# 473  1.12                 NaN             NaN
# 474  1.12                 NaN             NaN
# 475  1.12                 NaN             NaN
# 476  1.12                 NaN             NaN
# 477  1.12                 NaN             NaN
#
#      prinyrs_4thru10_pct  prinyrs_11plus_pct  prin_advance_dgr_pct  \
# 473 NaN                  NaN                 NaN
# 474 NaN                  NaN                 NaN
# 475 NaN                  NaN                 NaN
# 476 NaN                  NaN                 NaN
# 477 NaN                  NaN                 NaN
#
#      _1yr_prin_trnovr_pct  prin_male_pct  prin_female_pct  prin_black_pct  \
# 473 NaN                   NaN            NaN              NaN
# 474 NaN                   NaN            NaN              NaN
# 475 NaN                   NaN            NaN              NaN
# 476 NaN                   NaN            NaN              NaN
# 477 NaN                   NaN            NaN              NaN
#
#      prin_white_pct  flicensed_teach_pct  tchyrs_0thru3_pct  \
# 473 NaN              1.000                0.077
# 474 NaN              0.949                0.150
# 475 NaN              0.856                0.310
# 476 NaN              1.000                0.000
# 477 NaN              0.982                0.158
#
#      tchyrs_4thru10_pct  tchyrs_11plus_pct  class_teach_num  nbpts_num  \
# 473  0.154               0.769              26.0             1.0
# 474  0.217               0.633              59.0             5.0
# 475  0.167               0.524              42.0             5.0
# 476  0.500               0.500              8.0             NaN
# 477  0.246               0.596              57.0             12.0
#
#      advance_dgr_pct  _1yr_tchr_trnovr_pct  emer_prov_teach_pct  \
# 473  0.444            0.118                NaN
# 474  0.203            0.124                NaN
# 475  0.238            0.177                NaN
# 476  0.125            0.000                NaN
# 477  0.193            0.109                NaN
#
#      lateral_teach_pct  highqual_class_pct  lea_flicensed_teach_pct  \
# 473 NaN                 1.000               0.995
# 474  0.051              0.969               0.917
# 475  0.144              0.939               0.917
# 476 NaN                 1.000               0.917
# 477  0.018              0.990               0.982
#
#      lea_tchyrs_0thru3_pct  lea_tchyrs_4thru10_pct  lea_tchyrs_11plus_pct  \
# 473  0.135                  0.162                   0.703
# 474  0.200                  0.218                   0.582
# 475  0.200                  0.218                   0.582
# 476  0.200                  0.218                   0.582
# 477  0.158                  0.246                   0.596
#
#      lea_class_teach_num  lea_nbpts_num  lea_advance_dgr_pct  \
# 473  19.0                 1.0            0.395
# 474  36.0                 5.0            0.211
# 475  36.0                 5.0            0.211
# 476  36.0                 5.0            0.211
# 477  57.0                 12.0           0.193
#
#      lea_1yr_tchr_trnovr_pct  lea_emer_prov_teach_pct  lea_lateral_teach_pct  \
# 473  0.135                   NaN                       0.005
# 474  0.143                   NaN                       0.083
# 475  0.143                   NaN                       0.083
# 476  0.143                   NaN                       0.083
# 477  0.109                   NaN                       0.018
#
#      lea_highqual_class_pct  lea_highqual_class_hp_pct  \
# 473  0.899                   0.957
# 474  0.960                   0.957
# 475  0.960                   0.957
# 476  0.960                   0.957
# 477  0.989                   1.000
#
#      lea_highqual_class_lp_pct  lea_highqual_class_all_pct  \
# 473  0.979                      0.977
# 474  0.979                      0.977
# 475  0.979                      0.977
# 476  0.979                      0.977
# 477 NaN                         0.995
#
#      lea_not_highqual_class_hp_pct  lea_not_highqual_class_lp_pct  \
# 473  0.043                          0.021
# 474  0.043                          0.021
# 475  0.043                          0.021
# 476  0.043                          0.021
# 477  0.000                         NaN
#
#      lea_not_highqual_class_all_pct  st_flicensed_teach_pct  \
# 473  0.023                           0.808
# 474  0.023                           0.897
# 475  0.023                           0.897
# 476  0.023                           0.897
# 477  0.005                           0.897
#
#      st_tchyrs_0thru3_pct  st_tchyrs_4thru10_pct  st_tchyrs_11plus_pct  \
# 473  0.227                 0.226                  0.547
# 474  0.231                 0.235                  0.534
# 475  0.231                 0.235                  0.534
# 476  0.231                 0.235                  0.534
# 477  0.231                 0.235                  0.534
#
#      st_class_teach_num  st_nbpts_num  st_advance_dgr_pct  \
# 473  36                  2             0.277
# 474  54                  8             0.248
# 475  54                  8             0.248
# 476  54                  8             0.248
# 477  54                  8             0.248
#
#      st_1yr_tchr_trnovr_pct  st_emer_prov_teach_pct  st_lateral_teach_pct  \
# 473  0.157                   0.003                   0.068
# 474  0.148                   0.003                   0.092
# 475  0.148                   0.003                   0.092
# 476  0.148                   0.003                   0.092
# 477  0.148                   0.003                   0.092
#
#      st_highqual_class_pct  st_highqual_class_hp_pct  \
# 473  0.820                  0.964
# 474  0.964                  0.964
# 475  0.964                  0.964
# 476  0.964                  0.964
# 477  0.964                  0.964
#
#      st_highqual_class_lp_pct  st_highqual_class_all_pct  \
# 473  0.976                     0.963
# 474  0.976                     0.963
# 475  0.976                     0.963
# 476  0.976                     0.963
# 477  0.976                     0.963
#
#      st_not_highqual_class_hp_pct  st_not_highqual_class_lp_pct  \
# 473  0.036                         0.024
# 474  0.036                         0.024
# 475  0.036                         0.024
# 476  0.036                         0.024
# 477  0.036                         0.024
#
#      st_not_highqual_class_all_pct  st_prinyrs_0thru3_pct  \
# 473  0.037                          0.43
# 474  0.037                          0.43
# 475  0.037                          0.43
# 476  0.037                          0.43
# 477  0.037                          0.43
#
#      st_prinyrs_4thru10_pct  st_prinyrs_11plus_pct  st_prin_advance_dgr_pct  \
# 473  0.427                   0.143                  0.222
# 474  0.427                   0.143                  0.222
# 475  0.427                   0.143                  0.222
# 476  0.427                   0.143                  0.222
# 477  0.427                   0.143                  0.222
#
#      st_1yr_prin_trnovr_pct  st_prin_male_pct  st_prin_female_pct  \
# 473  0.089                   0.398             0.596
# 474  0.089                   0.398             0.596
# 475  0.089                   0.398             0.596
# 476  0.089                   0.398             0.596
# 477  0.089                   0.398             0.596
#
#      st_prin_black_pct  st_prin_white_pct  st_prin_other_pct  \
# 473  0.237              0.737              0.026
# 474  0.237              0.737              0.026
# 475  0.237              0.737              0.026
# 476  0.237              0.737              0.026
# 477  0.237              0.737              0.026
#
#      Tch_Exp_Pct_0_3_Years  Tch_Exp_Pct_4_10_Years  Tch_Exp_Pct_10+_Years  \
# 473  0.077                  0.154                   0.769
# 474  0.150                  0.217                   0.633
# 475  0.310                  0.167                   0.524
# 476  0.000                  0.500                   0.500
# 477  0.158                  0.246                   0.596
#
#      Dist_Tch_Exp_Pct_0_3_Years  Dist_Tch_Exp_Pct_4_10_Years  \
# 473  0.135                       0.162
# 474  0.200                       0.218
# 475  0.200                       0.218
# 476  0.200                       0.218
# 477  0.158                       0.246
#
#      Dist_Tch_Exp_Pct_10+_Years  State_Tch_Exp_Pct_0_3_Years  \
# 473  0.703                       0.227
# 474  0.582                       0.231
# 475  0.582                       0.231
# 476  0.582                       0.231
# 477  0.596                       0.231
#
#      State_Tch_Exp_Pct_4_10_Years  State_Tch_Exp_Pct_10+_Years  \
# 473  0.226                         0.547
# 474  0.235                         0.534
# 475  0.235                         0.534
# 476  0.235                         0.534
# 477  0.235                         0.534
#
#      Dist_Prin_Exp_Pct_0_3_Years  Dist_Prin_Exp_Pct_4_10_Years  \
# 473  0.357                        0.357
# 474  0.357                        0.357
# 475  0.357                        0.357
# 476  0.357                        0.357
# 477  0.500                        0.250
#
#      Dist_Prin_Exp_Pct_10+_Years  State_Prin_Exp_Pct_0_3_Years  \
# 473  0.286                        0.43
# 474  0.286                        0.43
# 475  0.286                        0.43
# 476  0.286                        0.43
# 477  0.250                        0.43
#
#      State_Prin_Exp_Pct_4_10_Years  State_Prin_Exp_Pct_10+_Years  School Code  \
# 473  0.427                          0.143                        NaN
# 474  0.427                          0.143                        NaN
# 475  0.427                          0.143                        NaN
# 476  0.427                          0.143                        NaN
# 477  0.427                          0.143                        NaN
#
#      Subject  Percent Level 1  Percent Level 2  Percent Level 3  \
# 473 NaN      NaN              NaN              NaN
# 474 NaN      NaN              NaN              NaN
# 475 NaN      NaN              NaN              NaN
# 476 NaN      NaN              NaN              NaN
# 477 NaN      NaN              NaN              NaN
#
#      Percent Level 4  Percent Level 5  Percent CCR  Percent GLP
# 473 NaN              NaN              NaN          NaN
# 474 NaN              NaN              NaN          NaN
# 475 NaN              NaN              NaN          NaN
# 476 NaN              NaN              NaN          NaN
# 477 NaN              NaN              NaN          NaN

# %% [markdown]
# Use `isnull()` to figure out how many missing values are present per column.

# %%
highschools.isnull().sum()
# Out:
# Unnamed: 0                                        0
# unit_code                                         0
# type_cd_txt                                       0
# category_cd                                       0
# school_type_txt                                   0
# calendar_only_txt                                 0
# title1_type_flg                                   0
# clp_ind_flg                                       0
# focus_clp_flg                                     0
# summer_program_flg                                0
# asm_no_spg_flg                                    0
# no_data_spg_flg                                   0
# esea_status                                       0
# student_num                                       0
# lea_avg_student_num                               0
# st_avg_student_num                                0
# Grad_project_status                               0
# stem_flg                                          0
# Avg_Class_Size_00                                 476
# Avg_Class_Size_01                                 475
# Avg_Class_Size_02                                 475
# Avg_Class_Size_03                                 475
# Avg_Class_Size_04                                 475
# Avg_Class_Size_05                                 475
# Avg_Class_Size_06                                 466
# Avg_Class_Size_07                                 465
# Avg_Class_Size_08                                 465
# Avg_Class_Size_Biology                            13
# Avg_Class_Size_EnglishII                          12
# Avg_Class_Size_MathI                              14
# Avg_Dist_Size_00                                  476
# Avg_Dist_Size_01                                  475
# Avg_Dist_Size_02                                  475
# Avg_Dist_Size_03                                  475
# Avg_Dist_Size_04                                  475
# Avg_Dist_Size_05                                  475
# Avg_Dist_Size_06                                  466
# Avg_Dist_Size_07                                  465
# Avg_Dist_Size_08                                  465
# Avg_Dist_Size_Biology                             8
# Avg_Dist_Size_EnglishII                           8
# Avg_Dist_Size_MathI                               8
# Avg_State_Size_00                                 476
# Avg_State_Size_01                                 475
# Avg_State_Size_02                                 475
# Avg_State_Size_03                                 475
# Avg_State_Size_04                                 475
# Avg_State_Size_05                                 475
# Avg_State_Size_06                                 466
# Avg_State_Size_07                                 465
# Avg_State_Size_08                                 465
# Avg_State_Size_Biology                            8
# Avg_State_Size_EnglishII                          8
# Avg_State_Size_MathI                              8
# total_expense_num                                 478
# salary_expense_pct                                478
# benefits_expense_pct                              478
# services_expense_pct                              478
# supplies_expense_pct                              478
# instruct_equip_exp_pct                            478
# other_expense_pct                                 478
# federal_perpupil_num                              478
# local_perpupil_num                                478
# state_perpupil_num                                478
# lea_total_expense_num                             0
# lea_salary_expense_pct                            0
# lea_benefits_expense_pct                          0
# lea_services_expense_pct                          0
# lea_supplies_expense_pct                          0
# lea_instruct_equip_exp_pct                        0
# lea_other_expense_pct                             0
# lea_federal_perpupil_num                          0
# lea_local_perpupil_num                            0
# lea_state_perpupil_num                            0
# st_total_expense_num                              0
# st_salary_expense_pct                             0
# st_benefits_expense_pct                           0
# st_services_expense_pct                           0
# st_supplies_expense_pct                           0
# st_instruct_equip_exp_pct                         0
# st_other_expense_pct                              0
# st_federal_perpupil_num                           0
# st_local_perpupil_num                             0
# st_state_perpupil_num                             0
# SPG Grade                                         28
# SPG Score                                         28
# Reading SPG Grade                                 460
# Reading  SPG Score                                460
# Math SPG Grade                                    460
# Math SPG Score                                    460
# EVAAS Growth Status                               35
# EVAAS Growth Score                                35
# Overall Achievement Score                         28
# Read Score                                        460
# Math Score                                        460
# Science Score                                     460
# Math I Score                                      37
# English II Score                                  40
# Biology Score                                     39
# The ACT Score                                     36
# ACT WorkKeys Score                                119
# Math Course Rigor Score                           41
# Cohort Graduation Rate Standard Score             42
# State Gap Compared                                397
# GCE_ALL_School_Pct                                474
# GCE_LEP_School_Pct                                478
# GCE_PRM_School_Pct                                478
# GCE_RPF_School_Pct                                478
# GCE_SWD_School_Pct                                477
# PASSED_EOG_School_Pct                             475
# PASSED_LAA_School_Pct                             478
# PASSED_RTA_School_Pct                             478
# PROMOTED_School_Pct                               475
# RETAINED_School_Pct                               478
# GCE_ALL_Dist_Pct                                  474
# GCE_LEP_Dist_Pct                                  478
# GCE_PRM_Dist_Pct                                  478
# GCE_RPF_Dist_Pct                                  476
# GCE_SWD_Dist_Pct                                  475
# PASSED_EOG_Dist_Pct                               474
# PASSED_LAA_Dist_Pct                               475
# PASSED_RTA_Dist_Pct                               478
# PROMOTED_Dist_Pct                                 474
# RETAINED_Dist_Pct                                 475
# GCE_ALL_State_Pct                                 474
# GCE_LEP_State_Pct                                 478
# GCE_PRM_State_Pct                                 478
# GCE_RPF_State_Pct                                 478
# GCE_SWD_State_Pct                                 474
# PASSED_EOG_State_Pct                              474
# PASSED_LAA_State_Pct                              474
# PASSED_RTA_State_Pct                              478
# PROMOTED_State_Pct                                474
# RETAINED_State_Pct                                474
# sat_avg_score_num                                 12
# lea_sat_avg_score_num                             0
# st_sat_avg_score_num                              0
# nat_sat_avg_score_num                             0
# sat_participation_pct                             13
# lea_sat_participation_pct                         0
# st_sat_participation_pct                          0
# nat_sat_participation_pct                         0
# esea_attendance                                   478
# lea_esea_attendance                               478
# ap_participation_pct                              154
# lea_ap_participation_pct                          65
# st_ap_participation_pct                           0
# ap_pct_3_or_above                                 113
# lea_ap_pct_3_or_above                             8
# st_ap_pct_3_or_above                              0
# ib_participation_pct                              472
# lea_ib_participation_pct                          478
# st_ib_participation_pct                           478
# ib_pct_4_or_above                                 454
# lea_ib_pct_4_or_above                             293
# st_ib_pct_4_or_above                              0
# AP_Courses_Offered                                140
# total_specialized_courses                         27
# ap_ib_courses                                     110
# cte_courses                                       35
# univ_college_courses                              104
# lea_total_specialized_courses                     27
# lea_ap_ib_courses                                 32
# lea_cte_courses                                   27
# lea_univ_college_courses                          35
# st_total_specialized_courses                      27
# st_ap_ib_courses                                  27
# st_cte_courses                                    27
# st_univ_college_courses                           27
# sch_percent_college_enrolled_16_mos_post_grad     21
# One_Yr_College_Complete_wi_2_yrs_Enrolled_2012    21
# avg_daily_attend_pct                              0
# crime_per_c_num                                   0
# short_susp_per_c_num                              0
# long_susp_per_c_num                               0
# expelled_per_c_num                                0
# ttl_crimes_num                                    478
# stud_internet_comp_num                            9
# lea_avg_daily_attend_pct                          0
# lea_crime_per_c_num                               0
# lea_short_susp_per_c_num                          0
# lea_long_susp_per_c_num                           0
# lea_expelled_per_c_num                            0
# lea_stud_internet_comp_num                        0
# st_avg_daily_attend_pct                           0
# st_crime_per_c_num                                0
# st_short_susp_per_c_num                           0
# st_long_susp_per_c_num                            0
# st_expelled_per_c_num                             0
# st_stud_internet_comp_num                         0
# digital_media_pct                                 91
# Byod                                              91
# avg_age_media_collection                          91
# 1_to_1_access                                     91
# books_per_student                                 91
# lea_avg_age_media_collection                      91
# lea_books_per_student                             100
# st_avg_age_media_collection                       91
# st_books_per_student                              91
# wap_num                                           10
# wap_per_classroom                                 10
# lea_wap_num                                       0
# lea_wap_per_classroom                             0
# st_wap_num                                        0
# st_wap_per_classroom                              0
# prin_other_pct                                    478
# prinyrs_0thru3_pct                                478
# prinyrs_4thru10_pct                               478
# prinyrs_11plus_pct                                478
# prin_advance_dgr_pct                              478
# _1yr_prin_trnovr_pct                              478
# prin_male_pct                                     478
# prin_female_pct                                   478
# prin_black_pct                                    478
# prin_white_pct                                    478
# flicensed_teach_pct                               0
# tchyrs_0thru3_pct                                 0
# tchyrs_4thru10_pct                                0
# tchyrs_11plus_pct                                 0
# class_teach_num                                   0
# nbpts_num                                         30
# advance_dgr_pct                                   0
# _1yr_tchr_trnovr_pct                              3
# emer_prov_teach_pct                               417
# lateral_teach_pct                                 68
# highqual_class_pct                                2
# lea_flicensed_teach_pct                           0
# lea_tchyrs_0thru3_pct                             0
# lea_tchyrs_4thru10_pct                            0
# lea_tchyrs_11plus_pct                             0
# lea_class_teach_num                               0
# lea_nbpts_num                                     2
# lea_advance_dgr_pct                               0
# lea_1yr_tchr_trnovr_pct                           0
# lea_emer_prov_teach_pct                           249
# lea_lateral_teach_pct                             6
# lea_highqual_class_pct                            0
# lea_highqual_class_hp_pct                         22
# lea_highqual_class_lp_pct                         56
# lea_highqual_class_all_pct                        0
# lea_not_highqual_class_hp_pct                     22
# lea_not_highqual_class_lp_pct                     56
# lea_not_highqual_class_all_pct                    0
# st_flicensed_teach_pct                            0
# st_tchyrs_0thru3_pct                              0
# st_tchyrs_4thru10_pct                             0
# st_tchyrs_11plus_pct                              0
# st_class_teach_num                                0
# st_nbpts_num                                      0
# st_advance_dgr_pct                                0
# st_1yr_tchr_trnovr_pct                            0
# st_emer_prov_teach_pct                            0
# st_lateral_teach_pct                              0
# st_highqual_class_pct                             0
# st_highqual_class_hp_pct                          0
# st_highqual_class_lp_pct                          0
# st_highqual_class_all_pct                         0
# st_not_highqual_class_hp_pct                      0
# st_not_highqual_class_lp_pct                      0
# st_not_highqual_class_all_pct                     0
# st_prinyrs_0thru3_pct                             0
# st_prinyrs_4thru10_pct                            0
# st_prinyrs_11plus_pct                             0
# st_prin_advance_dgr_pct                           0
# st_1yr_prin_trnovr_pct                            0
# st_prin_male_pct                                  0
# st_prin_female_pct                                0
# st_prin_black_pct                                 0
# st_prin_white_pct                                 0
# st_prin_other_pct                                 0
# Tch_Exp_Pct_0_3_Years                             0
# Tch_Exp_Pct_4_10_Years                            0
# Tch_Exp_Pct_10+_Years                             0
# Dist_Tch_Exp_Pct_0_3_Years                        0
# Dist_Tch_Exp_Pct_4_10_Years                       0
# Dist_Tch_Exp_Pct_10+_Years                        0
# State_Tch_Exp_Pct_0_3_Years                       0
# State_Tch_Exp_Pct_4_10_Years                      0
# State_Tch_Exp_Pct_10+_Years                       0
# Dist_Prin_Exp_Pct_0_3_Years                       0
# Dist_Prin_Exp_Pct_4_10_Years                      0
# Dist_Prin_Exp_Pct_10+_Years                       0
# State_Prin_Exp_Pct_0_3_Years                      0
# State_Prin_Exp_Pct_4_10_Years                     0
# State_Prin_Exp_Pct_10+_Years                      0
# School Code                                       478
# Subject                                           478
# Percent Level 1                                   478
# Percent Level 2                                   478
# Percent Level 3                                   478
# Percent Level 4                                   478
# Percent Level 5                                   478
# Percent CCR                                       478
# Percent GLP                                       478
# dtype: int64

# %%
type(highschools.isnull().sum())
# Out:
# pandas.core.series.Series

# %% [markdown]
# Get the column names whose value is equal to 478.

# %%
(highschools.isnull().sum() == 478).sum()
# Out:
# 47

# %% [markdown]
# First let's store the result of `highschools.isnull().sum()` which is a Series.

# %%
missingValues = highschools.isnull().sum()

# %%
len(list(missingValues[missingValues == 478].index))
# Out:
# 47

# %%
allMissingValues = list(missingValues[missingValues == 478].index)

# %% [markdown]
# Filter out these columns from the dataframe `highschools`.

# %%
highschools.drop(allMissingValues, axis=1, inplace=True)

# %%
highschools.shape
# Out:
# (478, 247)

# %%
247 + 47
# Out:
# 294

# %% [markdown]
# Next, we will drop columns which have 95% of missing data.

# %%
highschools.isnull().sum()
# Out:
# Unnamed: 0                                        0
# unit_code                                         0
# type_cd_txt                                       0
# category_cd                                       0
# school_type_txt                                   0
# calendar_only_txt                                 0
# title1_type_flg                                   0
# clp_ind_flg                                       0
# focus_clp_flg                                     0
# summer_program_flg                                0
# asm_no_spg_flg                                    0
# no_data_spg_flg                                   0
# esea_status                                       0
# student_num                                       0
# lea_avg_student_num                               0
# st_avg_student_num                                0
# Grad_project_status                               0
# stem_flg                                          0
# Avg_Class_Size_00                                 476
# Avg_Class_Size_01                                 475
# Avg_Class_Size_02                                 475
# Avg_Class_Size_03                                 475
# Avg_Class_Size_04                                 475
# Avg_Class_Size_05                                 475
# Avg_Class_Size_06                                 466
# Avg_Class_Size_07                                 465
# Avg_Class_Size_08                                 465
# Avg_Class_Size_Biology                            13
# Avg_Class_Size_EnglishII                          12
# Avg_Class_Size_MathI                              14
# Avg_Dist_Size_00                                  476
# Avg_Dist_Size_01                                  475
# Avg_Dist_Size_02                                  475
# Avg_Dist_Size_03                                  475
# Avg_Dist_Size_04                                  475
# Avg_Dist_Size_05                                  475
# Avg_Dist_Size_06                                  466
# Avg_Dist_Size_07                                  465
# Avg_Dist_Size_08                                  465
# Avg_Dist_Size_Biology                             8
# Avg_Dist_Size_EnglishII                           8
# Avg_Dist_Size_MathI                               8
# Avg_State_Size_00                                 476
# Avg_State_Size_01                                 475
# Avg_State_Size_02                                 475
# Avg_State_Size_03                                 475
# Avg_State_Size_04                                 475
# Avg_State_Size_05                                 475
# Avg_State_Size_06                                 466
# Avg_State_Size_07                                 465
# Avg_State_Size_08                                 465
# Avg_State_Size_Biology                            8
# Avg_State_Size_EnglishII                          8
# Avg_State_Size_MathI                              8
# lea_total_expense_num                             0
# lea_salary_expense_pct                            0
# lea_benefits_expense_pct                          0
# lea_services_expense_pct                          0
# lea_supplies_expense_pct                          0
# lea_instruct_equip_exp_pct                        0
# lea_other_expense_pct                             0
# lea_federal_perpupil_num                          0
# lea_local_perpupil_num                            0
# lea_state_perpupil_num                            0
# st_total_expense_num                              0
# st_salary_expense_pct                             0
# st_benefits_expense_pct                           0
# st_services_expense_pct                           0
# st_supplies_expense_pct                           0
# st_instruct_equip_exp_pct                         0
# st_other_expense_pct                              0
# st_federal_perpupil_num                           0
# st_local_perpupil_num                             0
# st_state_perpupil_num                             0
# SPG Grade                                         28
# SPG Score                                         28
# Reading SPG Grade                                 460
# Reading  SPG Score                                460
# Math SPG Grade                                    460
# Math SPG Score                                    460
# EVAAS Growth Status                               35
# EVAAS Growth Score                                35
# Overall Achievement Score                         28
# Read Score                                        460
# Math Score                                        460
# Science Score                                     460
# Math I Score                                      37
# English II Score                                  40
# Biology Score                                     39
# The ACT Score                                     36
# ACT WorkKeys Score                                119
# Math Course Rigor Score                           41
# Cohort Graduation Rate Standard Score             42
# State Gap Compared                                397
# GCE_ALL_School_Pct                                474
# GCE_SWD_School_Pct                                477
# PASSED_EOG_School_Pct                             475
# PROMOTED_School_Pct                               475
# GCE_ALL_Dist_Pct                                  474
# GCE_RPF_Dist_Pct                                  476
# GCE_SWD_Dist_Pct                                  475
# PASSED_EOG_Dist_Pct                               474
# PASSED_LAA_Dist_Pct                               475
# PROMOTED_Dist_Pct                                 474
# RETAINED_Dist_Pct                                 475
# GCE_ALL_State_Pct                                 474
# GCE_SWD_State_Pct                                 474
# PASSED_EOG_State_Pct                              474
# PASSED_LAA_State_Pct                              474
# PROMOTED_State_Pct                                474
# RETAINED_State_Pct                                474
# sat_avg_score_num                                 12
# lea_sat_avg_score_num                             0
# st_sat_avg_score_num                              0
# nat_sat_avg_score_num                             0
# sat_participation_pct                             13
# lea_sat_participation_pct                         0
# st_sat_participation_pct                          0
# nat_sat_participation_pct                         0
# ap_participation_pct                              154
# lea_ap_participation_pct                          65
# st_ap_participation_pct                           0
# ap_pct_3_or_above                                 113
# lea_ap_pct_3_or_above                             8
# st_ap_pct_3_or_above                              0
# ib_participation_pct                              472
# ib_pct_4_or_above                                 454
# lea_ib_pct_4_or_above                             293
# st_ib_pct_4_or_above                              0
# AP_Courses_Offered                                140
# total_specialized_courses                         27
# ap_ib_courses                                     110
# cte_courses                                       35
# univ_college_courses                              104
# lea_total_specialized_courses                     27
# lea_ap_ib_courses                                 32
# lea_cte_courses                                   27
# lea_univ_college_courses                          35
# st_total_specialized_courses                      27
# st_ap_ib_courses                                  27
# st_cte_courses                                    27
# st_univ_college_courses                           27
# sch_percent_college_enrolled_16_mos_post_grad     21
# One_Yr_College_Complete_wi_2_yrs_Enrolled_2012    21
# avg_daily_attend_pct                              0
# crime_per_c_num                                   0
# short_susp_per_c_num                              0
# long_susp_per_c_num                               0
# expelled_per_c_num                                0
# stud_internet_comp_num                            9
# lea_avg_daily_attend_pct                          0
# lea_crime_per_c_num                               0
# lea_short_susp_per_c_num                          0
# lea_long_susp_per_c_num                           0
# lea_expelled_per_c_num                            0
# lea_stud_internet_comp_num                        0
# st_avg_daily_attend_pct                           0
# st_crime_per_c_num                                0
# st_short_susp_per_c_num                           0
# st_long_susp_per_c_num                            0
# st_expelled_per_c_num                             0
# st_stud_internet_comp_num                         0
# digital_media_pct                                 91
# Byod                                              91
# avg_age_media_collection                          91
# 1_to_1_access                                     91
# books_per_student                                 91
# lea_avg_age_media_collection                      91
# lea_books_per_student                             100
# st_avg_age_media_collection                       91
# st_books_per_student                              91
# wap_num                                           10
# wap_per_classroom                                 10
# lea_wap_num                                       0
# lea_wap_per_classroom                             0
# st_wap_num                                        0
# st_wap_per_classroom                              0
# flicensed_teach_pct                               0
# tchyrs_0thru3_pct                                 0
# tchyrs_4thru10_pct                                0
# tchyrs_11plus_pct                                 0
# class_teach_num                                   0
# nbpts_num                                         30
# advance_dgr_pct                                   0
# _1yr_tchr_trnovr_pct                              3
# emer_prov_teach_pct                               417
# lateral_teach_pct                                 68
# highqual_class_pct                                2
# lea_flicensed_teach_pct                           0
# lea_tchyrs_0thru3_pct                             0
# lea_tchyrs_4thru10_pct                            0
# lea_tchyrs_11plus_pct                             0
# lea_class_teach_num                               0
# lea_nbpts_num                                     2
# lea_advance_dgr_pct                               0
# lea_1yr_tchr_trnovr_pct                           0
# lea_emer_prov_teach_pct                           249
# lea_lateral_teach_pct                             6
# lea_highqual_class_pct                            0
# lea_highqual_class_hp_pct                         22
# lea_highqual_class_lp_pct                         56
# lea_highqual_class_all_pct                        0
# lea_not_highqual_class_hp_pct                     22
# lea_not_highqual_class_lp_pct                     56
# lea_not_highqual_class_all_pct                    0
# st_flicensed_teach_pct                            0
# st_tchyrs_0thru3_pct                              0
# st_tchyrs_4thru10_pct                             0
# st_tchyrs_11plus_pct                              0
# st_class_teach_num                                0
# st_nbpts_num                                      0
# st_advance_dgr_pct                                0
# st_1yr_tchr_trnovr_pct                            0
# st_emer_prov_teach_pct                            0
# st_lateral_teach_pct                              0
# st_highqual_class_pct                             0
# st_highqual_class_hp_pct                          0
# st_highqual_class_lp_pct                          0
# st_highqual_class_all_pct                         0
# st_not_highqual_class_hp_pct                      0
# st_not_highqual_class_lp_pct                      0
# st_not_highqual_class_all_pct                     0
# st_prinyrs_0thru3_pct                             0
# st_prinyrs_4thru10_pct                            0
# st_prinyrs_11plus_pct                             0
# st_prin_advance_dgr_pct                           0
# st_1yr_prin_trnovr_pct                            0
# st_prin_male_pct                                  0
# st_prin_female_pct                                0
# st_prin_black_pct                                 0
# st_prin_white_pct                                 0
# st_prin_other_pct                                 0
# Tch_Exp_Pct_0_3_Years                             0
# Tch_Exp_Pct_4_10_Years                            0
# Tch_Exp_Pct_10+_Years                             0
# Dist_Tch_Exp_Pct_0_3_Years                        0
# Dist_Tch_Exp_Pct_4_10_Years                       0
# Dist_Tch_Exp_Pct_10+_Years                        0
# State_Tch_Exp_Pct_0_3_Years                       0
# State_Tch_Exp_Pct_4_10_Years                      0
# State_Tch_Exp_Pct_10+_Years                       0
# Dist_Prin_Exp_Pct_0_3_Years                       0
# Dist_Prin_Exp_Pct_4_10_Years                      0
# Dist_Prin_Exp_Pct_10+_Years                       0
# State_Prin_Exp_Pct_0_3_Years                      0
# State_Prin_Exp_Pct_4_10_Years                     0
# State_Prin_Exp_Pct_10+_Years                      0
# dtype: int64

# %%
478 * 0.95
# Out:
# 454.09999999999997

# %% [markdown]
# Drop columns which have more than 454 or more missing values

# %%
missingValues = highschools.isnull().sum()

# %%
missing95Percent = list(missingValues[missingValues >= 478 * 0.95].index)

# %%
missing95Percent
# Out:
# ['Avg_Class_Size_00',
#  'Avg_Class_Size_01',
#  'Avg_Class_Size_02',
#  'Avg_Class_Size_03',
#  'Avg_Class_Size_04',
#  'Avg_Class_Size_05',
#  'Avg_Class_Size_06',
#  'Avg_Class_Size_07',
#  'Avg_Class_Size_08',
#  'Avg_Dist_Size_00',
#  'Avg_Dist_Size_01',
#  'Avg_Dist_Size_02',
#  'Avg_Dist_Size_03',
#  'Avg_Dist_Size_04',
#  'Avg_Dist_Size_05',
#  'Avg_Dist_Size_06',
#  'Avg_Dist_Size_07',
#  'Avg_Dist_Size_08',
#  'Avg_State_Size_00',
#  'Avg_State_Size_01',
#  'Avg_State_Size_02',
#  'Avg_State_Size_03',
#  'Avg_State_Size_04',
#  'Avg_State_Size_05',
#  'Avg_State_Size_06',
#  'Avg_State_Size_07',
#  'Avg_State_Size_08',
#  'Reading SPG Grade',
#  'Reading  SPG Score',
#  'Math SPG Grade',
#  'Math SPG Score',
#  'Read Score',
#  'Math Score',
#  'Science Score',
#  'GCE_ALL_School_Pct',
#  'GCE_SWD_School_Pct',
#  'PASSED_EOG_School_Pct',
#  'PROMOTED_School_Pct',
#  'GCE_ALL_Dist_Pct',
#  'GCE_RPF_Dist_Pct',
#  'GCE_SWD_Dist_Pct',
#  'PASSED_EOG_Dist_Pct',
#  'PASSED_LAA_Dist_Pct',
#  'PROMOTED_Dist_Pct',
#  'RETAINED_Dist_Pct',
#  'GCE_ALL_State_Pct',
#  'GCE_SWD_State_Pct',
#  'PASSED_EOG_State_Pct',
#  'PASSED_LAA_State_Pct',
#  'PROMOTED_State_Pct',
#  'RETAINED_State_Pct',
#  'ib_participation_pct']

# %%
len(missing95Percent)
# Out:
# 52

# %% [markdown]
# Drop these columns from the `highschools` dataframe.

# %%
highschools.drop(missing95Percent, axis=1, inplace=True)

# %%
highschools.shape
# Out:
# (478, 195)

# %%
highschools.isnull().sum()
# Out:
# Unnamed: 0                                        0
# unit_code                                         0
# type_cd_txt                                       0
# category_cd                                       0
# school_type_txt                                   0
# calendar_only_txt                                 0
# title1_type_flg                                   0
# clp_ind_flg                                       0
# focus_clp_flg                                     0
# summer_program_flg                                0
# asm_no_spg_flg                                    0
# no_data_spg_flg                                   0
# esea_status                                       0
# student_num                                       0
# lea_avg_student_num                               0
# st_avg_student_num                                0
# Grad_project_status                               0
# stem_flg                                          0
# Avg_Class_Size_Biology                            13
# Avg_Class_Size_EnglishII                          12
# Avg_Class_Size_MathI                              14
# Avg_Dist_Size_Biology                             8
# Avg_Dist_Size_EnglishII                           8
# Avg_Dist_Size_MathI                               8
# Avg_State_Size_Biology                            8
# Avg_State_Size_EnglishII                          8
# Avg_State_Size_MathI                              8
# lea_total_expense_num                             0
# lea_salary_expense_pct                            0
# lea_benefits_expense_pct                          0
# lea_services_expense_pct                          0
# lea_supplies_expense_pct                          0
# lea_instruct_equip_exp_pct                        0
# lea_other_expense_pct                             0
# lea_federal_perpupil_num                          0
# lea_local_perpupil_num                            0
# lea_state_perpupil_num                            0
# st_total_expense_num                              0
# st_salary_expense_pct                             0
# st_benefits_expense_pct                           0
# st_services_expense_pct                           0
# st_supplies_expense_pct                           0
# st_instruct_equip_exp_pct                         0
# st_other_expense_pct                              0
# st_federal_perpupil_num                           0
# st_local_perpupil_num                             0
# st_state_perpupil_num                             0
# SPG Grade                                         28
# SPG Score                                         28
# EVAAS Growth Status                               35
# EVAAS Growth Score                                35
# Overall Achievement Score                         28
# Math I Score                                      37
# English II Score                                  40
# Biology Score                                     39
# The ACT Score                                     36
# ACT WorkKeys Score                                119
# Math Course Rigor Score                           41
# Cohort Graduation Rate Standard Score             42
# State Gap Compared                                397
# sat_avg_score_num                                 12
# lea_sat_avg_score_num                             0
# st_sat_avg_score_num                              0
# nat_sat_avg_score_num                             0
# sat_participation_pct                             13
# lea_sat_participation_pct                         0
# st_sat_participation_pct                          0
# nat_sat_participation_pct                         0
# ap_participation_pct                              154
# lea_ap_participation_pct                          65
# st_ap_participation_pct                           0
# ap_pct_3_or_above                                 113
# lea_ap_pct_3_or_above                             8
# st_ap_pct_3_or_above                              0
# ib_pct_4_or_above                                 454
# lea_ib_pct_4_or_above                             293
# st_ib_pct_4_or_above                              0
# AP_Courses_Offered                                140
# total_specialized_courses                         27
# ap_ib_courses                                     110
# cte_courses                                       35
# univ_college_courses                              104
# lea_total_specialized_courses                     27
# lea_ap_ib_courses                                 32
# lea_cte_courses                                   27
# lea_univ_college_courses                          35
# st_total_specialized_courses                      27
# st_ap_ib_courses                                  27
# st_cte_courses                                    27
# st_univ_college_courses                           27
# sch_percent_college_enrolled_16_mos_post_grad     21
# One_Yr_College_Complete_wi_2_yrs_Enrolled_2012    21
# avg_daily_attend_pct                              0
# crime_per_c_num                                   0
# short_susp_per_c_num                              0
# long_susp_per_c_num                               0
# expelled_per_c_num                                0
# stud_internet_comp_num                            9
# lea_avg_daily_attend_pct                          0
# lea_crime_per_c_num                               0
# lea_short_susp_per_c_num                          0
# lea_long_susp_per_c_num                           0
# lea_expelled_per_c_num                            0
# lea_stud_internet_comp_num                        0
# st_avg_daily_attend_pct                           0
# st_crime_per_c_num                                0
# st_short_susp_per_c_num                           0
# st_long_susp_per_c_num                            0
# st_expelled_per_c_num                             0
# st_stud_internet_comp_num                         0
# digital_media_pct                                 91
# Byod                                              91
# avg_age_media_collection                          91
# 1_to_1_access                                     91
# books_per_student                                 91
# lea_avg_age_media_collection                      91
# lea_books_per_student                             100
# st_avg_age_media_collection                       91
# st_books_per_student                              91
# wap_num                                           10
# wap_per_classroom                                 10
# lea_wap_num                                       0
# lea_wap_per_classroom                             0
# st_wap_num                                        0
# st_wap_per_classroom                              0
# flicensed_teach_pct                               0
# tchyrs_0thru3_pct                                 0
# tchyrs_4thru10_pct                                0
# tchyrs_11plus_pct                                 0
# class_teach_num                                   0
# nbpts_num                                         30
# advance_dgr_pct                                   0
# _1yr_tchr_trnovr_pct                              3
# emer_prov_teach_pct                               417
# lateral_teach_pct                                 68
# highqual_class_pct                                2
# lea_flicensed_teach_pct                           0
# lea_tchyrs_0thru3_pct                             0
# lea_tchyrs_4thru10_pct                            0
# lea_tchyrs_11plus_pct                             0
# lea_class_teach_num                               0
# lea_nbpts_num                                     2
# lea_advance_dgr_pct                               0
# lea_1yr_tchr_trnovr_pct                           0
# lea_emer_prov_teach_pct                           249
# lea_lateral_teach_pct                             6
# lea_highqual_class_pct                            0
# lea_highqual_class_hp_pct                         22
# lea_highqual_class_lp_pct                         56
# lea_highqual_class_all_pct                        0
# lea_not_highqual_class_hp_pct                     22
# lea_not_highqual_class_lp_pct                     56
# lea_not_highqual_class_all_pct                    0
# st_flicensed_teach_pct                            0
# st_tchyrs_0thru3_pct                              0
# st_tchyrs_4thru10_pct                             0
# st_tchyrs_11plus_pct                              0
# st_class_teach_num                                0
# st_nbpts_num                                      0
# st_advance_dgr_pct                                0
# st_1yr_tchr_trnovr_pct                            0
# st_emer_prov_teach_pct                            0
# st_lateral_teach_pct                              0
# st_highqual_class_pct                             0
# st_highqual_class_hp_pct                          0
# st_highqual_class_lp_pct                          0
# st_highqual_class_all_pct                         0
# st_not_highqual_class_hp_pct                      0
# st_not_highqual_class_lp_pct                      0
# st_not_highqual_class_all_pct                     0
# st_prinyrs_0thru3_pct                             0
# st_prinyrs_4thru10_pct                            0
# st_prinyrs_11plus_pct                             0
# st_prin_advance_dgr_pct                           0
# st_1yr_prin_trnovr_pct                            0
# st_prin_male_pct                                  0
# st_prin_female_pct                                0
# st_prin_black_pct                                 0
# st_prin_white_pct                                 0
# st_prin_other_pct                                 0
# Tch_Exp_Pct_0_3_Years                             0
# Tch_Exp_Pct_4_10_Years                            0
# Tch_Exp_Pct_10+_Years                             0
# Dist_Tch_Exp_Pct_0_3_Years                        0
# Dist_Tch_Exp_Pct_4_10_Years                       0
# Dist_Tch_Exp_Pct_10+_Years                        0
# State_Tch_Exp_Pct_0_3_Years                       0
# State_Tch_Exp_Pct_4_10_Years                      0
# State_Tch_Exp_Pct_10+_Years                       0
# Dist_Prin_Exp_Pct_0_3_Years                       0
# Dist_Prin_Exp_Pct_4_10_Years                      0
# Dist_Prin_Exp_Pct_10+_Years                       0
# State_Prin_Exp_Pct_0_3_Years                      0
# State_Prin_Exp_Pct_4_10_Years                     0
# State_Prin_Exp_Pct_10+_Years                      0
# dtype: int64

# %% [markdown]
# OK, so now we have `highschools` dataset with 195 columns and 478 rows. Our next task is to find out how many of them are categorical variables among these. So get the list of categorical variables from this dataframe.

# %%
highschools.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478 entries, 0 to 477
# Data columns (total 195 columns):
# Unnamed: 0                                        int64
# unit_code                                         object
# type_cd_txt                                       object
# category_cd                                       object
# school_type_txt                                   object
# calendar_only_txt                                 object
# title1_type_flg                                   bool
# clp_ind_flg                                       bool
# focus_clp_flg                                     bool
# summer_program_flg                                bool
# asm_no_spg_flg                                    bool
# no_data_spg_flg                                   bool
# esea_status                                       object
# student_num                                       float64
# lea_avg_student_num                               float64
# st_avg_student_num                                int64
# Grad_project_status                               bool
# stem_flg                                          bool
# Avg_Class_Size_Biology                            float64
# Avg_Class_Size_EnglishII                          float64
# Avg_Class_Size_MathI                              float64
# Avg_Dist_Size_Biology                             float64
# Avg_Dist_Size_EnglishII                           float64
# Avg_Dist_Size_MathI                               float64
# Avg_State_Size_Biology                            float64
# Avg_State_Size_EnglishII                          float64
# Avg_State_Size_MathI                              float64
# lea_total_expense_num                             float64
# lea_salary_expense_pct                            float64
# lea_benefits_expense_pct                          float64
# lea_services_expense_pct                          float64
# lea_supplies_expense_pct                          float64
# lea_instruct_equip_exp_pct                        float64
# lea_other_expense_pct                             float64
# lea_federal_perpupil_num                          float64
# lea_local_perpupil_num                            float64
# lea_state_perpupil_num                            float64
# st_total_expense_num                              float64
# st_salary_expense_pct                             float64
# st_benefits_expense_pct                           float64
# st_services_expense_pct                           float64
# st_supplies_expense_pct                           float64
# st_instruct_equip_exp_pct                         float64
# st_other_expense_pct                              int64
# st_federal_perpupil_num                           float64
# st_local_perpupil_num                             float64
# st_state_perpupil_num                             float64
# SPG Grade                                         object
# SPG Score                                         float64
# EVAAS Growth Status                               object
# EVAAS Growth Score                                float64
# Overall Achievement Score                         float64
# Math I Score                                      float64
# English II Score                                  float64
# Biology Score                                     float64
# The ACT Score                                     float64
# ACT WorkKeys Score                                float64
# Math Course Rigor Score                           float64
# Cohort Graduation Rate Standard Score             float64
# State Gap Compared                                object
# sat_avg_score_num                                 float64
# lea_sat_avg_score_num                             float64
# st_sat_avg_score_num                              int64
# nat_sat_avg_score_num                             int64
# sat_participation_pct                             float64
# lea_sat_participation_pct                         float64
# st_sat_participation_pct                          float64
# nat_sat_participation_pct                         float64
# ap_participation_pct                              float64
# lea_ap_participation_pct                          float64
# st_ap_participation_pct                           float64
# ap_pct_3_or_above                                 float64
# lea_ap_pct_3_or_above                             float64
# st_ap_pct_3_or_above                              float64
# ib_pct_4_or_above                                 float64
# lea_ib_pct_4_or_above                             float64
# st_ib_pct_4_or_above                              float64
# AP_Courses_Offered                                float64
# total_specialized_courses                         float64
# ap_ib_courses                                     float64
# cte_courses                                       float64
# univ_college_courses                              float64
# lea_total_specialized_courses                     float64
# lea_ap_ib_courses                                 float64
# lea_cte_courses                                   float64
# lea_univ_college_courses                          float64
# st_total_specialized_courses                      float64
# st_ap_ib_courses                                  float64
# st_cte_courses                                    float64
# st_univ_college_courses                           float64
# sch_percent_college_enrolled_16_mos_post_grad     float64
# One_Yr_College_Complete_wi_2_yrs_Enrolled_2012    float64
# avg_daily_attend_pct                              float64
# crime_per_c_num                                   float64
# short_susp_per_c_num                              float64
# long_susp_per_c_num                               float64
# expelled_per_c_num                                float64
# stud_internet_comp_num                            float64
# lea_avg_daily_attend_pct                          float64
# lea_crime_per_c_num                               float64
# lea_short_susp_per_c_num                          float64
# lea_long_susp_per_c_num                           float64
# lea_expelled_per_c_num                            float64
# lea_stud_internet_comp_num                        float64
# st_avg_daily_attend_pct                           float64
# st_crime_per_c_num                                float64
# st_short_susp_per_c_num                           float64
# st_long_susp_per_c_num                            float64
# st_expelled_per_c_num                             int64
# st_stud_internet_comp_num                         float64
# digital_media_pct                                 float64
# Byod                                              object
# avg_age_media_collection                          float64
# 1_to_1_access                                     object
# books_per_student                                 float64
# lea_avg_age_media_collection                      float64
# lea_books_per_student                             float64
# st_avg_age_media_collection                       float64
# st_books_per_student                              float64
# wap_num                                           float64
# wap_per_classroom                                 float64
# lea_wap_num                                       float64
# lea_wap_per_classroom                             float64
# st_wap_num                                        int64
# st_wap_per_classroom                              float64
# flicensed_teach_pct                               float64
# tchyrs_0thru3_pct                                 float64
# tchyrs_4thru10_pct                                float64
# tchyrs_11plus_pct                                 float64
# class_teach_num                                   float64
# nbpts_num                                         float64
# advance_dgr_pct                                   float64
# _1yr_tchr_trnovr_pct                              float64
# emer_prov_teach_pct                               float64
# lateral_teach_pct                                 float64
# highqual_class_pct                                float64
# lea_flicensed_teach_pct                           float64
# lea_tchyrs_0thru3_pct                             float64
# lea_tchyrs_4thru10_pct                            float64
# lea_tchyrs_11plus_pct                             float64
# lea_class_teach_num                               float64
# lea_nbpts_num                                     float64
# lea_advance_dgr_pct                               float64
# lea_1yr_tchr_trnovr_pct                           float64
# lea_emer_prov_teach_pct                           float64
# lea_lateral_teach_pct                             float64
# lea_highqual_class_pct                            float64
# lea_highqual_class_hp_pct                         float64
# lea_highqual_class_lp_pct                         float64
# lea_highqual_class_all_pct                        float64
# lea_not_highqual_class_hp_pct                     float64
# lea_not_highqual_class_lp_pct                     float64
# lea_not_highqual_class_all_pct                    float64
# st_flicensed_teach_pct                            float64
# st_tchyrs_0thru3_pct                              float64
# st_tchyrs_4thru10_pct                             float64
# st_tchyrs_11plus_pct                              float64
# st_class_teach_num                                int64
# st_nbpts_num                                      int64
# st_advance_dgr_pct                                float64
# st_1yr_tchr_trnovr_pct                            float64
# st_emer_prov_teach_pct                            float64
# st_lateral_teach_pct                              float64
# st_highqual_class_pct                             float64
# st_highqual_class_hp_pct                          float64
# st_highqual_class_lp_pct                          float64
# st_highqual_class_all_pct                         float64
# st_not_highqual_class_hp_pct                      float64
# st_not_highqual_class_lp_pct                      float64
# st_not_highqual_class_all_pct                     float64
# st_prinyrs_0thru3_pct                             float64
# st_prinyrs_4thru10_pct                            float64
# st_prinyrs_11plus_pct                             float64
# st_prin_advance_dgr_pct                           float64
# st_1yr_prin_trnovr_pct                            float64
# st_prin_male_pct                                  float64
# st_prin_female_pct                                float64
# st_prin_black_pct                                 float64
# st_prin_white_pct                                 float64
# st_prin_other_pct                                 float64
# Tch_Exp_Pct_0_3_Years                             float64
# Tch_Exp_Pct_4_10_Years                            float64
# Tch_Exp_Pct_10+_Years                             float64
# Dist_Tch_Exp_Pct_0_3_Years                        float64
# Dist_Tch_Exp_Pct_4_10_Years                       float64
# Dist_Tch_Exp_Pct_10+_Years                        float64
# State_Tch_Exp_Pct_0_3_Years                       float64
# State_Tch_Exp_Pct_4_10_Years                      float64
# State_Tch_Exp_Pct_10+_Years                       float64
# Dist_Prin_Exp_Pct_0_3_Years                       float64
# Dist_Prin_Exp_Pct_4_10_Years                      float64
# Dist_Prin_Exp_Pct_10+_Years                       float64
# State_Prin_Exp_Pct_0_3_Years                      float64
# State_Prin_Exp_Pct_4_10_Years                     float64
# State_Prin_Exp_Pct_10+_Years                      float64
# dtypes: bool(8), float64(167), int64(9), object(11)
# memory usage: 702.1+ KB

# %%
boolHighSchool = highschools.loc[:, highschools.dtypes == bool]

# %%
type(boolHighSchool)
# Out:
# pandas.core.frame.DataFrame

# %%
boolColumns = list(boolHighSchool.columns)

# %%
highschools[boolColumns].apply(sum)
# Out:
# title1_type_flg        38
# clp_ind_flg            56
# focus_clp_flg          53
# summer_program_flg     179
# asm_no_spg_flg         0
# no_data_spg_flg        0
# Grad_project_status    177
# stem_flg               6
# dtype: int64

# %% [markdown]
# **Next task is to combine the description with these stats**

# %%
# This is a simple function to pull column description
DataDict = pd.read_csv(wd+'/data/dictionary.csv', encoding = "ISO-8859-1")
DataDict.head()
# Out:
#    COLUMN_NAME                       DESCRIPTION
# 0  year         School Year
# 1  unit_code    Code to identifySchool/LEA/State
# 2  school_name  School Name
# 3  lea_name     LEA Name
# 4  state_name   State Name

# %%
DataDict.index
# Out:
# RangeIndex(start=0, stop=389, step=1)

# %%
DataDict.columns
# Out:
# Index(['COLUMN_NAME', 'DESCRIPTION'], dtype='object')

# %%
#DataDict.set_index('COLUMN_NAME', inplace=True)
DataDict.head(20)
# Out:
#           COLUMN_NAME  \
# 0   year
# 1   unit_code
# 2   school_name
# 3   lea_name
# 4   state_name
# 5   category_cd
# 6   street_ad
# 7   scity_ad
# 8   state_ad
# 9   szip_ad
# 10  vphone_ad
# 11  type_cd
# 12  closed_ind
# 13  new_ind
# 14  super_nm
# 15  url_ad
# 16  grade_range_cd
# 17  calendar_type_txt
# 18  school_type_txt
# 19  calendar_only_txt
#
#                                                                                             DESCRIPTION
# 0   School Year
# 1   Code to identifySchool/LEA/State
# 2   School Name
# 3   LEA Name
# 4   State Name
# 5   Category code E, M, H, I, T, or A
# 6   Street address
# 7   City name
# 8   State
# 9   ZIP code
# 10  Phone Number
# 11  Charter or public school
# 12  1=School is closed, 0=School is currently open
# 13  1=School is new this year, 0=School is not new\n*If a school is new this year, no data is available
# 14  Superintendents Name
# 15  URL Address of the school or district
# 16  Range of grades offered
# 17  Description of school calendar and school type
# 18  Description of school type
# 19  Description of Calendar

# %%
type(boolColumns)
boolColumns
# Out:
# ['title1_type_flg',
#  'clp_ind_flg',
#  'focus_clp_flg',
#  'summer_program_flg',
#  'asm_no_spg_flg',
#  'no_data_spg_flg',
#  'Grad_project_status',
#  'stem_flg']

# %%
DataDict[DataDict.COLUMN_NAME == 'lea_name']
# Out:
#     COLUMN_NAME DESCRIPTION
# 3    lea_name    LEA Name
# 37   lea_name    LEA Name
# 46   lea_name    LEA Name
# 84   lea_name    LEA Name
# 99   lea_name    LEA Name
# 130  lea_name    LEA Name
# 137  lea_name    LEA Name
# 187  lea_name    LEA Name
# 211  lea_name    LEA Name
# 266  lea_name    LEA Name
# 277  lea_name    LEA Name

# %%
DataDict
# Out:
#                         COLUMN_NAME  \
# 0    year
# 1    unit_code
# 2    school_name
# 3    lea_name
# 4    state_name
# 5    category_cd
# 6    street_ad
# 7    scity_ad
# 8    state_ad
# 9    szip_ad
# 10   vphone_ad
# 11   type_cd
# 12   closed_ind
# 13   new_ind
# 14   super_nm
# 15   url_ad
# 16   grade_range_cd
# 17   calendar_type_txt
# 18   school_type_txt
# 19   calendar_only_txt
# 20   title1_type_cd
# 21   esea_status
# 22   grad_project_status
# 23   student_num
# 24   lea_avg_student_num
# 25   st_avg_student_num
# 26   welcome_ltr_url
# 27   stem
# 28   county
# 29   clp_ind
# 30   focus_clp_ind
# 31   summer_program_ind
# 32   asm_no_spg_ind
# 33   no_data_spg_ind
# 34   year
# 35   unit_code
# 36   school_name
# 37   lea_name
# 38   state_name
# 39   category_cd
# 40   level
# 41   size
# 42   lea_size
# 43   st_size
# 44   unit_code
# 45   school_name
# 46   lea_name
# 47   state_name
# 48   category_cd
# 49   total_expense_num
# 50   lea_ total_expense_num
# 51   st_ total_expense_num
# 52   salary_expense_pct
# 53   lea_salary_expense_pct
# 54   st_ salary_expense_pct
# 55   benefits_expense_pct
# 56   lea_ benefits_expense_pct
# 57   st_ benefits_expense_pct
# 58   services_expense_pct
# 59   lea_ services_expense_pct
# 60   st_ services_expense_pct
# 61   supplies_expense_pct
# 62   lea_supplies_expense_pct
# 63   st_supplies_expense_pct
# 64   instruct_equip_exp_pct
# 65   lea_ instruct_equip_exp_pct
# 66   st_ instruct_equip_exp_pct
# 67   other_expense_pct
# 68   lea_ other_expense_pct
# 69   st_ other_expense_pct
# 70   lea_ building_expense_pct
# 71   st_ building_expense_pct
# 72   federal_perpupil_num
# 73   lea_ federal_perpupil_num
# 74   st_ federal_perpupil_num
# 75   local_perpupil_num
# 76   lea_ local_perpupil_num
# 77   st_ local_perpupil_num
# 78   state_perpupil_num
# 79   lea_ state_perpupil_num
# 80   st_ state_perpupil_num
# 81   year
# 82   unit_code
# 83   school_name
# 84   lea_name
# 85   state_name
# 86   category_cd
# 87   passed_bog_and_or_eog
# 88   exemption
# 89   outcome
# 90   num_students
# 91   lea_num_students
# 92   st_num_students
# 93   pct_students
# 94   lea_pct_students
# 95   st_pct_students
# 96   year
# 97   unit_code
# 98   school_name
# 99   lea_name
# 100  state_name
# 101  category_cd
# 102  sat_avg_score_num
# 103  lea_ sat_avg_score_num
# 104  st_ sat_avg_score_num
# 105  nat_ sat_avg_score_num
# 106  sat_participation_pct
# 107  lea_ sat_participation_pct
# 108  st_ sat_participation_pct
# 109  nat_ sat_participation_pct
# 110  esea_attendance
# 111  lea_esea_attendance
# 112  ap_participation_pct
# 113  lea_ ap_participation_pct
# 114  st_ ap_participation_pct
# 115  ap_pct_3_or_above
# 116  lea_ ap_pct_3_or_above
# 117  st_ ap_pct_3_or_above
# 118  ib_participation_pct
# 119  lea_ ib_participation_pct
# 120  st_ ib_participation_pct
# 121  ib_pct_4_or_above
# 122  NaN
# 123  lea_ ib_pct_4_or_above
# 124  NaN
# 125  st_ ib_pct_4_or_above
# 126  NaN
# 127  year
# 128  unit_code
# 129  school_name
# 130  lea_name
# 131  state_name
# 132  category_cd
# 133  course_name_standard
# 134  year
# 135  unit_code
# 136  school_name
# 137  lea_name
# 138  state_name
# 139  category_cd
# 140  total_specialized_courses
# 141  lea_ total_specialized_courses
# 142  st_ total_specialized_courses
# 143  ap_ib_courses
# 144  lea_ ap_ib_courses
# 145  st_ ap_ib_courses
# 146  NaN
# 147  cte_courses
# 148  lea_cte_courses
# 149  st_cte_courses
# 150  univ_college_courses
# 151  lea_univ_college_courses
# 152  st_univ_college_courses
# 153  college enrollment
# 154  column name
# 155  graduation_year
# 156  unit_code
# 157  leaname
# 158  schname
# 159  status
# 160  NaN
# 161  NaN
# 162  NaN
# 163  NaN
# 164  NaN
# 165  subgroup
# 166  subgroup_name
# 167  schcount
# 168  leacount
# 169  seacount
# 170  sch_percent_enrolled
# 171  lea_percent_enrolled
# 172  sea_percent_enrolled
# 173  graduationyear
# 174  unitcode
# 175  leaname
# 176  schname
# 177  status
# 178  subgroup
# 179  subgroupname
# 180  schoolcount
# 181  leacount
# 182  seacount
# 183  schoolpercentcomplete
# 184  leapercentcomplete
# 185  seapercentcomplete
# 186  school_name
# 187  lea_name
# 188  state_name
# 189  category_cd
# 190  avg_daily_attend_pct
# 191  lea_ avg_daily_attend_pct
# 192  st_ avg_daily_attend_pct
# 193  crime_per_c_num
# 194  lea_ crime_per_c_num
# 195  st_ crime_per_c_num
# 196  short_susp_per_c_num
# 197  lea_ short_susp_per_c_num
# 198  st_ short_susp_per_c_num
# 199  long_susp_per_c_num
# 200  lea_ long_susp_per_c_num
# 201  st_ long_susp_per_c_num
# 202  expelled_per_c_num
# 203  lea_ expelled_per_c_num
# 204  st_ expelled_per_c_num
# 205  ttl_crimes_num
# 206  stud_internet_comp_num
# 207  lea_stud_internet_comp_num
# 208  st_ stud_internet_comp_num
# 209  unit_code
# 210  school_name
# 211  lea_name
# 212  state_name
# 213  category_cd
# 214  prin_advance_dgr_pct
# 215  st_ prin_advance_dgr_pct
# 216  _1yr_prin_trnovr_pct
# 217  st_1yr_prin_trnovr_pct
# 218  prin_male_pct
# 219  st_ prin_male_pct
# 220  prin_female_pct
# 221  st_prin_female_pct
# 222  prin_black_pct
# 223  st_ prin_black_pct
# 224  prin_white_pct
# 225  st_ prin_white_pct
# 226  prin_other_pct
# 227  st_ prin_other_pct
# 228  flicensed_teach_pct
# 229  lea_ flicensed_teach_pct
# 230  st_ flicensed_teach_pct
# 231  class_teach_num
# 232  lea_class_teach_num
# 233  st_class_teach_num
# 234  nbpts_num
# 235  lea_ nbpts_num
# 236  st_ nbpts_num
# 237  advance_dgr_pct
# 238  lea_ advance_dgr_pct
# 239  st_ advance_dgr_pct
# 240  _1yr_tchr_trnovr_pct
# 241  lea_1yr_tchr_trnovr_pct
# 242  st_1yr_tchr_trnovr_pct
# 243  lateral_teach_pct
# 244  lea_lateral_teach_pct
# 245  st_lateral_teach_pct
# 246  highqual_class_pct
# 247  lea_highqual_class_pct
# 248  st_highqual_class_pct
# 249  lea_highqual_class_hp_pct
# 250  st_ highqual_class_hp_pct
# 251  lea_highqual_class_lp_pct
# 252  st_ highqual_class_lp_pct
# 253  lea_highqual_class_all_pct
# 254  st_ highqual_class_all_pct
# 255  lea_not_highqual_class_hp_pct
# 256  st_ not_highqual_class_hp_pct
# 257  lea_not_highqual_class_lp_pct
# 258  st_not_highqual_class_lp_pct
# 259  lea_not_highqual_class_all_pct
# 260  st_ not_highqual_class_all_pct
# 261  total_class_tch_num
# 262  total_nbpts_num
# 263  year
# 264  unit_code
# 265  school_name
# 266  lea_name
# 267  state_name
# 268  category_cd
# 269  experience
# 270  pct_tch
# 271  lea_pct_teach
# 272  st_pct_teach
# 273  lea_pct_prin
# 274  st_pct_prin
# 275  unit_code
# 276  school_name
# 277  lea_name
# 278  state_name
# 279  category_cd
# 280  standard
# 281  level
# 282  count
# 283  percent
# 284  role
# 285  unit_code
# 286  state_name
# 287  grade
# 288  subject
# 289  proficiency_level
# 290  subgroup
# 291  pct_proficient
# 292  average_score
# 293  participation_rate
# 294  year
# 295  2014
# 296  2013
# 297  2012
# 298  2011
# 299  2010
# 300  2009
# 301  2008
# 302  2007
# 303  2006
# 304  2005
# 305  2004
# 306  2003
# 307  2002
# 308  ccr
# 309  glp
# 310  subject
# 311  rd
# 312  ma
# 313  sc
# 314  m1
# 315  e2
# 316  bi
# 317  eoc
# 318  eog
# 319  all
# 320  actrd
# 321  actma
# 322  actsc
# 323  acten
# 324  actwr
# 325  actall
# 326  actco
# 327  wk
# 328  mcr
# 329  cgr
# 330  grade
# 331  3
# 332  4
# 333  5
# 334  6
# 335  7
# 336  8
# 337  gs
# 338  hs
# 339  all
# 340  eoc
# 341  subgroup
# 342  eds
# 343  not_eds
# 344  lep
# 345  swd
# 346  whte
# 347  blck
# 348  hisp
# 349  amin
# 350  asia
# 351  mult
# 352  male
# 353  fem
# 354  all
# 355  aig
# 356  paci
# 357  masking
# 358  0
# 359  1
# 360  2
# 361  3
# 362  4
# 363  growth_status
# 364  met
# 365  notmet
# 366  exceeds
# 367  category_cd
# 368  e
# 369  m
# 370  h
# 371  i
# 372  t
# 373  a
# 374  lea_type_cd
# 375  c
# 376  o
# 377  p
# 378  read to achieve metrics
# 379  gce_all
# 380  gce_lep
# 381  gce_prm
# 382  gce_rpf
# 383  gce_swd
# 384  passed_eog
# 385  passed_laa
# 386  passed_rta
# 387  promoted\ngrade
# 388  retained
#
#                                                                                                                                                                                                                                                                                                                                                                                              DESCRIPTION
# 0    School Year
# 1    Code to identifySchool/LEA/State
# 2    School Name
# 3    LEA Name
# 4    State Name
# 5    Category code E, M, H, I, T, or A
# 6    Street address
# 7    City name
# 8    State
# 9    ZIP code
# 10   Phone Number
# 11   Charter or public school
# 12   1=School is closed, 0=School is currently open
# 13   1=School is new this year, 0=School is not new\n*If a school is new this year, no data is available
# 14   Superintendents Name
# 15   URL Address of the school or district
# 16   Range of grades offered
# 17   Description of school calendar and school type
# 18   Description of school type
# 19   Description of Calendar
# 20   Title I Status
# 21   ESEA status
# 22   Required Graduation Project, Y=Yes or N=No
# 23   Number of students at school level (school size)
# 24   Average school size within the LEA
# 25   Average school size within the State
# 26   URL for LEA/Charter school welcome letter
# 27   STEM (Science, Technology, Engineering, Math) status
# 28   County the school is physically located in
# 29   Consistently Low Performing indicator (used on SRC\nSnapshot Only)
# 30   Focus school designation due to CLP status (used on SRC\nSnapshot Only)
# 31   Summer school program was included in Read to Achieve\nresults
# 32   Indicator for no SPG due to alternative school status
# 33   Indicator for no SPG due to lack of data
# 34   School Year
# 35   Code to identifySchool/LEA/State
# 36   School Name
# 37   LEA Name
# 38   State Name
# 39   Category code E, M, H, I, T or A
# 40   Grade Level (K-8) or Course (English II, Math I, Biology)
# 41   Average class/course size for school
# 42   Average class/course size for district
# 43   Average class/course size for State
# 44   Code to identifySchool/LEA/State
# 45   School Name
# 46   LEA Name
# 47   State Name
# 48   Category code E, M, H, I, T or A
# 49   Total expense (Dollars Spent) at school level
# 50   Total expense (Dollars Spent) at LEA level
# 51   Total expense (Dollars Spent) at state level
# 52   Percent of expense spent on Salaries at school level
# 53   Percent of expense spent on Salaries at LEA level
# 54   Percent of expense spent on Salaries at state level
# 55   Percent of expense spent on Benefits at school level
# 56   Percent of expense spent on Benefits at LEA level
# 57   Percent of expense spent on Benefits at state level
# 58   Percent of expense spent on Services at school level
# 59   Percent of expense spent on Services at LEA level
# 60   Percent of expense spent on Services at state level
# 61   Percent of expense spent on Supplies at school level
# 62   Percent of expense spent on Supplies at LEA level
# 63   Percent of expense spent on Supplies at state level
# 64   Percent of expense spent on Instructional Equipment at school\nlevel
# 65   Percent of expense spent on Instructional Equipment at LEA\nlevel
# 66   Percent of expense spent on Instructional Equipment at state\nlevel
# 67   Percent of expense spent on Other Expenses at school level
# 68   Percent of expense spent on Other Expenses at LEA level
# 69   Percent of expense spent on Other Expenses at state level
# 70   For future use (not available for 2013-14)
# 71   For future use (not available for 2013-14)
# 72   Federal expense per pupil at school level
# 73   Federal expense per pupil at LEA level
# 74   Federal expense per pupil at state level
# 75   Local expense per pupil at school level
# 76   Local expense per pupil at LEA level
# 77   Local expense per pupil at state level
# 78   State expense per pupil at school level
# 79   State expense per pupil at LEA level
# 80   State expense per pupil at state level
# 81   School Year
# ...
# 348  Hispanic
# 349  American Indian
# 350  Asian
# 351  Two or More Races
# 352  Male
# 353  Female
# 354  All Students
# 355  Academically/Intellectually Gifted
# 356  Pacific Islander
# 357  description
# 358  None
# 359  >95%
# 360  <5%
# 361  <5
# 362  Insufficient Data
# 363  description
# 364  Does Not Meet Expected Growth
# 365  Meets Expected Growth
# 366  Exceeds Expected Growth
# 367  description
# 368  School has elementary schools grades (PK-5)
# 369  School has middle schools grades (6-8)
# 370  School has high schools grades (9-13)
# 371  School has elementary and middle school grades
# 372  School has middle and high school grades
# 373  School has elementary, middle, and high school grades
# 374  description
# 375  Charter
# 376  Other
# 377  Public
# 378  Description
# 379  Number and Percentage of Third Grade Students Passed with Good Cause Exemption
# 380  Number and Percentage of Third Grade Students Passed with Good Cause Exemption Limited English Proficiency
# 381  Number and Percentage of Third Grade Students Passed with Good Cause Exemption Previously Retained
# 382  Number and Percentage of Third Grade Students Passed with Good Cause Exemption Proficient through a Reading Portfolio
# 383  Number and Percentage of Third Grade Students Passed with Good Cause Exemption Students with Disabilities
# 384  Number and Percentage of Third Grade Students Passed BOG3 and/or Grade 3 Reading EOG
# 385  Number and Percentage of Third Grade Students Passed Local Alternative Assessment
# 386  Number and Percentage of Third Grade Students Passed State Read to Achieve Assessment
# 387  Number and Percentage of Third Grade Students Promoted to Fourth
# 388  Number and Percentage of Third Grade Students Retained in Third Grade

# %%
DataDict.shape
# Out:
# (389, 1)

# %%
DataDict.columns
# Out:
# Index(['DESCRIPTION'], dtype='object')

# %% [markdown]
# #### Business Understanding [10]
#
# Describe the purpose of the data set you selected (i.e., why was this data collected in the first place?). Describe how you would define and measure the outcomes from the dataset. That is, why is this data important and how do you know if you have mined useful knowledge from the dataset?
# How would you measure the effectiveness of a good prediction algorithm? Be specific.

# %% [markdown]
# #### Data Meaning Type  [10]
#
# Describe the meaning and type of data (scale, values, etc.) for each attribute in the data file.

# %% [markdown]
# #### Data Quality [15]
#
# Verify data quality: Explain any missing values, duplicate data, and outliers. Are those mistakes? How do you deal with these problems? Give justifications for your methods.

# %%
#Get dimensions of the dataframe that we working with
highschools.shape
# Out:
# (478, 294)

# %%
#Make a copy of the dataset to work with
HighschoolData = highschools.copy()

# %% [markdown]
# ##### *Missing Data Statistics*
#
# In this section we explore missing data in the highschool data that was created from the original north carolina data. After exploring the missing data we will discusss the approach for handling them.

# %%
#Check for missing values
Temp = pd.DataFrame(HighschoolData.isnull().sum())
#print(Temp)
Temp.columns =['DataMissing']
#Columns with atleast 1 missing value
MissingCount = Temp[Temp.DataMissing>0]

#sort 
MissingCount = MissingCount.sort_values('DataMissing',ascending=False)
#basic starts on missing data
print("##################################################")
print("###", '             Stats on missing data        ',  "###")
print("##################################################")
print('No of rows in HighschoolData: ',len(HighschoolData))
print('No of Columns in HighschoolData: ',len(HighschoolData.columns))
print('No. of Columns with Missing data: ',len(MissingCount))
print('No  of Complete data columns: ', len(HighschoolData.columns) - len(MissingCount))
print('No. of Columns with 100% missing Values: ',sum(1 for item in MissingCount.DataMissing if item==len(HighschoolData)))
print('No. of Columns more than 95% missing Values: ',sum(1 for item in MissingCount.DataMissing if item>=0.95*len(HighschoolData)))
print('% of Columns with some Missing data: ',round(float(100*len(MissingCount))/len(HighschoolData.columns),3),'%')
print('% of Columns with 100% Missing data: ',round(float(100*sum(1 for item in MissingCount.DataMissing if item==len(HighschoolData)))/len(HighschoolData.columns),3),'%')
print('% of Columns with more than 95% Missing data: ',round(float(100*sum(1 for item in MissingCount.DataMissing if item>=0.95*len(HighschoolData)))/len(HighschoolData.columns),3),'%')

print(" ")
print("##################################################")
print("###",'       Columns with >95% missing data     ',    "###")
print("##################################################")
#add a columnName for Bar charts plot
MissingCount['ColumnName'] = MissingCount.index
MissingCount['Missing %'] = 100*(MissingCount.DataMissing/len(HighschoolData))
MissingCount = MissingCount.reset_index()
del MissingCount['index']
print((MissingCount.head(100)))
# Out:
# ##################################################
# ###              Stats on missing data         ###
# ##################################################
# No of rows in HighschoolData:  478
# No of Columns in HighschoolData:  294
# No. of Columns with Missing data:  168
# No  of Complete data columns:  126
# No. of Columns with 100% missing Values:  47
# No. of Columns more than 95% missing Values:  99
# % of Columns with some Missing data:  57.143 %
# % of Columns with 100% Missing data:  15.986 %
# % of Columns with more than 95% Missing data:  33.673 %
#
# ##################################################
# ###        Columns with >95% missing data      ###
# ##################################################
#     DataMissing                ColumnName   Missing %
# 0   478          Percent GLP               100.000000
# 1   478          total_expense_num         100.000000
# 2   478          GCE_RPF_State_Pct         100.000000
# 3   478          GCE_PRM_State_Pct         100.000000
# 4   478          GCE_LEP_State_Pct         100.000000
# 5   478          PASSED_RTA_Dist_Pct       100.000000
# 6   478          GCE_PRM_Dist_Pct          100.000000
# 7   478          GCE_LEP_Dist_Pct          100.000000
# 8   478          RETAINED_School_Pct       100.000000
# 9   478          PASSED_RTA_School_Pct     100.000000
# 10  478          PASSED_LAA_School_Pct     100.000000
# 11  478          salary_expense_pct        100.000000
# 12  478          GCE_LEP_School_Pct        100.000000
# 13  478          benefits_expense_pct      100.000000
# 14  478          services_expense_pct      100.000000
# 15  478          supplies_expense_pct      100.000000
# 16  478          instruct_equip_exp_pct    100.000000
# 17  478          other_expense_pct         100.000000
# 18  478          federal_perpupil_num      100.000000
# 19  478          local_perpupil_num        100.000000
# 20  478          state_perpupil_num        100.000000
# 21  478          GCE_RPF_School_Pct        100.000000
# 22  478          PASSED_RTA_State_Pct      100.000000
# 23  478          esea_attendance           100.000000
# 24  478          lea_esea_attendance       100.000000
# 25  478          lea_ib_participation_pct  100.000000
# 26  478          Percent CCR               100.000000
# 27  478          Percent Level 5           100.000000
# 28  478          Percent Level 4           100.000000
# 29  478          Percent Level 3           100.000000
# ..  ...                      ...                  ...
# 70  475          Avg_Class_Size_03         99.372385
# 71  475          Avg_Class_Size_02         99.372385
# 72  474          GCE_ALL_State_Pct         99.163180
# 73  474          GCE_SWD_State_Pct         99.163180
# 74  474          PASSED_EOG_State_Pct      99.163180
# 75  474          PASSED_EOG_Dist_Pct       99.163180
# 76  474          PROMOTED_Dist_Pct         99.163180
# 77  474          GCE_ALL_Dist_Pct          99.163180
# 78  474          PROMOTED_State_Pct        99.163180
# 79  474          RETAINED_State_Pct        99.163180
# 80  474          GCE_ALL_School_Pct        99.163180
# 81  474          PASSED_LAA_State_Pct      99.163180
# 82  472          ib_participation_pct      98.744770
# 83  466          Avg_State_Size_06         97.489540
# 84  466          Avg_Dist_Size_06          97.489540
# 85  466          Avg_Class_Size_06         97.489540
# 86  465          Avg_State_Size_08         97.280335
# 87  465          Avg_State_Size_07         97.280335
# 88  465          Avg_Dist_Size_08          97.280335
# 89  465          Avg_Dist_Size_07          97.280335
# 90  465          Avg_Class_Size_08         97.280335
# 91  465          Avg_Class_Size_07         97.280335
# 92  460          Math SPG Score            96.234310
# 93  460          Math SPG Grade            96.234310
# 94  460          Reading  SPG Score        96.234310
# 95  460          Read Score                96.234310
# 96  460          Math Score                96.234310
# 97  460          Science Score             96.234310
# 98  460          Reading SPG Grade         96.234310
# 99  454          ib_pct_4_or_above         94.979079
#
# [100 rows x 3 columns]

# %% [markdown]
# ##### Approach for handling missing data to be discussed with the rest of the team
# From above we note, of the 293 columns in HighSchoolData, 168 (57.14%) of them have some missing data. 47 (15.99%) of columns have all the data missing where 99 (33.67%) of the columns miss more than 95% of the data. For columns with 100% missing data we are left but to wonder if this were new fields introduced recently and the schools are not fully informed to collect this data or the data for not just collected by mistake. On the other hand, for the partally completed datasets, some schools migh have left this columns blank if they didn't apply to the.
#
# For the sake of this analysis we will drop the columns that have `>95` missing data rather than try complete the missing data with either mean, median or mode. If we complete this large amount of columns, with predetermined data, our model maybe

# %%
#All columns from Original schoolData
AllColumns =HighschoolData.columns 

# All columns with some missing value
ColumnsWithMissingdata = MissingCount.ColumnName 

#columns with more than 95% missing data
Columns2Drop = MissingCount.ColumnName.head(39) 

#columns with missing values that are kept
Columns2Keep = MissingCount.ColumnName.tail(len(MissingCount)-39) 

#All the other columns except those with >95% missing data
SelectedColumns = list(set(AllColumns)-set(Columns2Drop)) 

#new dataset, columns with >95% missing data dropped

schoolDataNew = HighschoolData[SelectedColumns]

## Peek at New Dataframe
print(HighschoolData)
print(schoolDataNew.info())
schoolDataNew.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478 entries, 0 to 477
# Columns: 255 entries, total_specialized_courses to PASSED_EOG_State_Pct
# dtypes: bool(8), float64(225), int64(9), object(13)
# memory usage: 926.2+ KB
# None
#    total_specialized_courses  Math Score Reading SPG Grade  lea_wap_num  \
# 0 NaN                        NaN          NaN               1380.0
# 1 NaN                        NaN          NaN               1380.0
#
#    st_flicensed_teach_pct  st_not_highqual_class_all_pct  \
# 0  0.897                   0.037
# 1  0.897                   0.037
#
#    PASSED_EOG_School_Pct  tchyrs_0thru3_pct type_cd_txt  PASSED_LAA_Dist_Pct  \
# 0 NaN                     0.000              Public     NaN
# 1 NaN                     0.186              Public     NaN
#
#            ...           Avg_Class_Size_05  _1yr_tchr_trnovr_pct  \
# 0          ...          NaN                 0.000
# 1          ...          NaN                 0.128
#
#    st_highqual_class_hp_pct  Grad_project_status  Math Course Rigor Score  \
# 0  0.964                     False               NaN
# 1  0.964                     False               NaN
#
#    lea_long_susp_per_c_num  Avg_Class_Size_04  st_highqual_class_pct  \
# 0  0.23                    NaN                 0.964
# 1  0.23                    NaN                 0.964
#
#    Avg_Class_Size_03  PASSED_EOG_State_Pct
# 0 NaN                NaN
# 1 NaN                NaN
#
# [2 rows x 255 columns]

# %% [markdown]
# #### Simple Statistics [10]
# Visualize appropriate statistics (e.g., range, mode, mean, median, variance, counts) for a subset of attributes. Describe anything meaningful you found from this or if you found something potentially interesting. Note: You can also use data from other sources for comparison. Explain why the statistics run are meaningful.

# %% [markdown]
# #### Visualize Attributes [15]
# Visualize the most interesting attributes (at least 5 attributes, your opinion on what is interesting). Important: Interpret the implications for each visualization. Explain for each attribute why the chosen visualization is appropriate.

# %% [markdown]
# #### Explore Joint Attributes [15]
# Visualize relationships between attributes: Look at the attributes via scatter plots, correlation, cross-tabulation, group-wise averages, etc. as appropriate. Explain any interesting relationships.

# %% [markdown]
# #### New Features [5]
# Are there other features that could be added to the data or created from existing features? Which ones?

# %% [markdown]
# #### Exceptional Work [10]
# You have free reign to provide additional analyses. One idea: implement dimensionality reduction, then visualize and interpret the results.

# %% [markdown]
# #### 1. Data Dictionary
# Since this datasets has numerous columns we needed a fast way to quickly find ColumnName description for easy reference. For exceptional work, we created a function to quickly pull the data from csv datafile. This involved converting the pdf to excel and formating the data for easy import into pandas. The code below is a working code for our data dictionary.

# %%
# This is a simple function to pull column description
DataDict = pd.read_csv(wd+'\\data\\dictionary.csv', encoding = "ISO-8859-1")
DataDict.head()
#DataDict = DataDict.columns['COLUMN_NAME', 'DESCRIPTION']
def get_ColDescription(colname = 'Year'):
    colName = input("Enter column name to check description in Dictionary. You can enter multiple columns separated by comma: ")
    
    print('You entered: ', colName.strip())
    temp = pd.DataFrame()
    colNames = colName.split(',')
    
    try:
        for i in range(0,len(colNames)):
            get = (DataDict[DataDict.COLUMN_NAME==colNames[i].strip().lower()])
            temp = temp.append(get)
        return(temp)
    except Exception as e:
        print(e.args) 

get_ColDescription()
# Out:
# Enter column name to check description in Dictionary. You can enter multiple columns separated by comma: A, T, M, I, E
# You entered:  A, T, M, I, E
#     COLUMN_NAME                                            DESCRIPTION
# 373  a           School has elementary, middle, and high school grades
# 372  t           School has middle and high school grades
# 369  m           School has middle schools grades (6-8)
# 371  i           School has elementary and middle school grades
# 368  e           School has elementary schools grades (PK-5)
